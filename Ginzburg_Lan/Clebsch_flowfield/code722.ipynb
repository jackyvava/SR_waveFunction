# %% [markdown]
# # TG涡

# %% [markdown]
# 函数 \(a(x, y)\)、\(b(x, y)\)、\(c(x, y)\) 和 \(d(x, y)\) 定义如下：
# \begin{align*}
#     H(x) &=
#     \begin{cases}
#       \frac{x}{2} & \text{如果 } 0 \leq x \leq \pi \\
#       \pi - \frac{x}{2} & \text{如果 } \pi < x \leq 2\pi
#     \end{cases} \\
#     a(x, y) &= \cos[H(x)] \cos\left(\frac{\cos(y) (2 - \cos(x))}{\hbar}\right), \\
#     b(x, y) &= \cos[H(x)] \sin\left(\frac{\cos(y) (2 - \cos(x))}{\hbar}\right), \\
#     c(x, y) &= \sin[H(x)] \cos\left(\frac{\cos(y) (2 + \cos(x))}{\hbar}\right), \\
#     d(x, y) &= -\sin[H(x)] \sin\left(\frac{\cos(y) (2 + \cos(x))}{\hbar}\right).
# \end{align*}
# 其中，$\hbar $是一个常数（为了简化，设为1）。

# %% [markdown]
# 速度场计算
# $$
# \mathbf{u} = \hbar(a \mathbf \nabla b-b\mathbf \nabla a + c\mathbf \nabla d - d\mathbf \nabla c)
# $$
#
# 速度场分量 $u_x$ 和 $u_y$ 使用 $a$、$b$、$c$、$d$ 的梯度计算得到：
# $$
# \begin{align*}
#     \nabla a &= \left(\frac{\partial a}{\partial x}, \frac{\partial a}{\partial y}\right), \\
#     \nabla b &= \left(\frac{\partial b}{\partial x}, \frac{\partial b}{\partial y}\right), \\
#     \nabla c &= \left(\frac{\partial c}{\partial x}, \frac{\partial c}{\partial y}\right), \\
#     \nabla d &= \left(\frac{\partial d}{\partial x}, \frac{\partial d}{\partial y}\right).
# \end{align*}
# $$

# %% [markdown]
# 速度场的计算公式为：
# \begin{align*}
#     u_x &= \hbar \left(a \frac{\partial b}{\partial x} - b \frac{\partial a}{\partial x} + c \frac{\partial d}{\partial x} - d \frac{\partial c}{\partial x}\right), \\
#     u_y &= \hbar \left(a \frac{\partial b}{\partial y} - b \frac{\partial a}{\partial y} + c \frac{\partial d}{\partial y} - d \frac{\partial c}{\partial y}\right).
# \end{align*}

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
import torch

# 设置设备为GPU（如果可用）
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
# 定义常数
hbar = 1

# 定义 H(x)
def H(x):
    return np.where((0 <= x) & (x <= np.pi), x / 2, np.pi - x / 2)

# 定义函数 a, b, c, d
def a(x, y):
    return np.cos(H(x)) * np.cos(np.cos(y) * (2 - np.cos(x)) / hbar)

def b(x, y):
    return np.cos(H(x)) * np.sin(np.cos(y) * (2 - np.cos(x)) / hbar)

def c(x, y):
    return np.sin(H(x)) * np.cos(np.cos(y) * (2 + np.cos(x)) / hbar)

def d(x, y):
    return -np.sin(H(x)) * np.sin(np.cos(y) * (2 + np.cos(x)) / hbar)

# 计算梯度
def gradient(f, x, y, eps=1e-5):
    f_x = (f(x + eps, y) - f(x - eps, y)) / (2 * eps)
    f_y = (f(x, y + eps) - f(x, y - eps)) / (2 * eps)
    return f_x, f_y

# %%
# 计算速度场
def compute_velocity_field_np(x, y, dx, dy):
    # 使用内置的np 求解梯度
    a_val = a(x, y)
    b_val = b(x, y)
    c_val = c(x, y)
    d_val = d(x, y)

    a_grad_x, a_grad_y = np.gradient(a_val, dx, dy)
    b_grad_x, b_grad_y = np.gradient(b_val, dx, dy)
    c_grad_x, c_grad_y = np.gradient(c_val, dx, dy)
    d_grad_x, d_grad_y = np.gradient(d_val, dx, dy)

    u_x = hbar * (a_val * b_grad_x - b_val * a_grad_x + c_val * d_grad_x - d_val * c_grad_x)
    u_y = hbar * (a_val * b_grad_y - b_val * a_grad_y + c_val * d_grad_y - d_val * c_grad_y)

    return u_x, u_y

# %% [markdown]
# 此处我们设定low像素:   $32\times 32$
#
# 设定High像素为    $128\times 128$

# %%
size_low = 64
size_High = 256
x_low = np.linspace(0, 2 * np.pi, size_low)
y_low = np.linspace(0, 2 * np.pi, size_low)

x_high = np.linspace(0, 2 * np.pi, size_High)
y_high = np.linspace(0, 2 * np.pi, size_High)


X_low, Y_low = np.meshgrid(x_low, y_low)
X_high, Y_high = np.meshgrid(x_high, y_high)

# %%
# 计算函数值
A_low = a(X_low, Y_low)
B_low = b(X_low, Y_low)
C_low = c(X_low, Y_low)
D_low = d(X_low, Y_low)

A_high = a(X_high, Y_high)
B_high = b(X_high, Y_high)
C_high = c(X_high, Y_high)
D_high = d(X_high, Y_high)

# %%
# 计算步长
dx_low = x_low[1] - x_low[0]
dy_low = y_low[1] - y_low[0]

dx_high = x_high[1] - x_high[0]
dy_high = y_high[1] - y_high[0]

# %% [markdown]
# ## 可视化速度场

# %%
U_x_low, U_y_low = compute_velocity_field_np(X_low, Y_low, dx_low, dy_low)
U_x_high, U_y_high = compute_velocity_field_np(X_high, Y_high, dx_high, dy_high)

# 计算速度场的大小
U_magnitude_low = np.sqrt(U_x_low**2 + U_y_low**2)
U_magnitude_high = np.sqrt(U_x_high**2 + U_y_high**2)

U_magnitude_low.shape, U_magnitude_high.shape
# Out:
# ((64, 64), (256, 256))

# %%
plt.figure(figsize=(16, 6))
plt.subplot(121)
plt.contourf(X_low, Y_low, U_magnitude_low, levels=50, cmap='viridis')
# plt.streamplot(X_low, Y_low, U_x_low, U_y_low, color='white', linewidth=1)
plt.title('TG vortex xy-plane velocity field (low accuracy)')
# plt.streamplot(X, Y, U_x_FD, U_y_FD, color='white', linewidth=1)
plt.xlim(0, 2 * np.pi)
plt.ylim(0, 2 * np.pi)

plt.tick_params(axis='both', direction='in', length=6)
plt.colorbar()



plt.subplot(122)
plt.contourf(X_high, Y_high, U_magnitude_high, levels=50, cmap='viridis')
# plt.streamplot(X_high, Y_high, U_x_high, U_y_high, color='white', linewidth=1)
plt.title('TG vortex xy-plane velocity field (High accuracy)')
# plt.streamplot(X, Y, U_x_FD, U_y_FD, color='white', linewidth=1)
plt.xlim(0, 2 * np.pi)
plt.ylim(0, 2 * np.pi)

plt.tick_params(axis='both', direction='in', length=6)
plt.colorbar()

plt.show()

# %% [markdown]
# ## 可视化涡度场

# %%
def vorticity(U_x, U_y, dx, dy):
    dU_y_dx, _ = np.gradient(U_y, dx, axis=0), np.gradient(U_y, dy, axis=1)
    _, dU_x_dy = np.gradient(U_x, dx, axis=0), np.gradient(U_x, dy, axis=1)
    return dU_y_dx - dU_x_dy

# %%
# 计算旋度
vort_low = vorticity(U_x_low, U_y_low, dx_low, dy_low)
vort_high = vorticity(U_x_high, U_y_high, dx_high, dy_high)


# 归一化旋度
max_vort_low = np.max(np.abs(vort_low))
vort_normalized_low = vort_low / max_vort_low if max_vort_low != 0 else vort_low

max_vort_high = np.max(np.abs(vort_high))
vort_normalized_high = vort_high / max_vort_high if max_vort_high != 0 else vort_high

# %%
plt.figure(figsize=(14, 6))
plt.subplot(121)
plt.contourf(X_low, Y_low, vort_normalized_low, levels=50, cmap='RdBu_r', vmin=-1, vmax=1)
plt.colorbar()
plt.title('TG vortex xy-plane normalized vorticity field (low accuracy)')
plt.tick_params(axis='both', direction='in', length=6)

plt.subplot(122)
plt.contourf(X_high, Y_high, vort_normalized_high, levels=50, cmap='RdBu_r', vmin=-1, vmax=1)
plt.colorbar()
plt.title('TG vortex xy-plane normalized vorticity field (High accuracy)')


plt.tick_params(axis='both', direction='in', length=6)


plt.show()

# %% [markdown]
# ## 特征提取阶段
#
#
# 从速度场得到abcd

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import DataLoader, TensorDataset, random_split

# %%
import os
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation

# %% [markdown]
# ### 数据处理

# %%
# 将数据转换为PyTorch张量
U_x = torch.tensor(U_x_low, dtype=torch.float32).unsqueeze(0).unsqueeze(0).to(device)  # 增加batch和channel维度
U_y = torch.tensor(U_y_low, dtype=torch.float32).unsqueeze(0).unsqueeze(0).to(device)
U_magnitude = torch.tensor(U_magnitude_low, dtype=torch.float32).unsqueeze(0).unsqueeze(0).to(device)

# 合并速度场作为输入
velocity_field = torch.cat((U_x, U_y, U_magnitude), dim=1).to(device)

# 目标abcd (假设为0初始化)
target_abcd = torch.zeros((1, 4, size_low, size_low), dtype=torch.float32).to(device)

# 创建数据集和数据加载器
dataset = TensorDataset(velocity_field, target_abcd)
dataloader = DataLoader(dataset, batch_size=500, shuffle=True)

# %%
U_magnitude.shape,target_abcd.shape
# Out:
# (torch.Size([1, 1, 64, 64]), torch.Size([1, 4, 64, 64]))

# %% [markdown]
# ### 构建模型

# %%
class BasicModelA(nn.Module):
    def __init__(self):
        super(BasicModelA, self).__init__()
        self.conv1 = nn.Conv2d(3, 64, kernel_size=3, padding=1)
        self.bn1 = nn.BatchNorm2d(64)
        self.conv2 = nn.Conv2d(64, 128, kernel_size=3, padding=1)
        self.bn2 = nn.BatchNorm2d(128)
        self.conv3 = nn.Conv2d(128, 256, kernel_size=3, padding=1)
        self.bn3 = nn.BatchNorm2d(256)
        self.pool = nn.MaxPool2d(2, 2)
        self.conv4 = nn.Conv2d(256, 512, kernel_size=3, padding=1)
        self.bn4 = nn.BatchNorm2d(512)
        self.upsample = nn.Upsample(scale_factor=8, mode='bilinear', align_corners=True)
        self.conv5 = nn.Conv2d(512, 4, kernel_size=3, padding=1)

    def forward(self, x):
        x = F.relu(self.bn1(self.conv1(x)))
        x = self.pool(x)
        x = F.relu(self.bn2(self.conv2(x)))
        x = self.pool(x)
        x = F.relu(self.bn3(self.conv3(x)))
        x = self.pool(x)
        x = F.relu(self.bn4(self.conv4(x)))
        x = self.upsample(x)  # 使用上采样恢复到原始尺寸
        x = self.conv5(x)
        return x

# %%
class ConstraintLayer(nn.Module):
    def __init__(self):
        super(ConstraintLayer, self).__init__()

    def forward(self, x):
        # 假设x的形状为 [batch_size, 4, height, width]，其中4代表abcd
        norm = torch.sqrt(x[:, 0, :, :]**2 + x[:, 1, :, :]**2 + x[:, 2, :, :]**2 + x[:, 3, :, :]**2 + 1e-8)
        norm = norm.unsqueeze(1)  # 为了与abcd的四个通道对齐
        x = x / norm  # 归一化
        return x

# %%
 
class ModelAWithConstraints(nn.Module):
    def __init__(self):
        super(ModelAWithConstraints, self).__init__()
        self.model = BasicModelA()
        self.constraint_layer = ConstraintLayer()

    def forward(self, x):
        x = self.model(x)
        x = self.constraint_layer(x)
        return x

# %% [markdown]
# ### 定义Loss function

# %%
def calculate_gradients_with_numpy(tensor):
    # 确保 Tensor 不需要梯度跟踪，且在 CPU 上
    tensor_np = tensor.detach().cpu().numpy()

   
    # 计算梯度
    grad_x = np.gradient(tensor_np, axis=1)  # 假设水平方向是 axis=1
    grad_y = np.gradient(tensor_np, axis=2)  # 假设垂直方向是 axis=2
    
    # 转换回 Tensor
    grad_x_tensor = torch.from_numpy(grad_x).to(tensor.device)
    grad_y_tensor = torch.from_numpy(grad_y).to(tensor.device)
    
    return grad_x_tensor, grad_y_tensor

# %%
def laplacian_2d(array, dx, dy):
    grad_x = np.gradient(array, dx, axis=1, edge_order=2)  # 计算 x 方向的一阶导数
    grad_y = np.gradient(array, dy, axis=0, edge_order=2)  # 计算 y 方向的一阶导数
    
    laplacian_x = np.gradient(grad_x, dx, axis=1, edge_order=2)  # 计算 x 方向的二阶导数
    laplacian_y = np.gradient(grad_y, dy, axis=0, edge_order=2)  # 计算 y 方向的二阶导数
    
    return laplacian_x + laplacian_y


def laplacian_2d_torch(tensor, dx, dy):
    # 确保tensor是浮点类型，因为梯度计算通常需要浮点运算
    tensor = tensor.float()
    tensor_np = tensor.detach().cpu().numpy()

    # 计算x和y方向的一阶导数
    grad_x = np.gradient(tensor_np, axis=1)  # x方向
    grad_y = np.gradient(tensor_np, axis=2)  # y方向

    # 计算x和y方向的二阶导数
    laplacian_x = np.gradient(grad_x, axis=1)
    laplacian_y = np.gradient(grad_y, axis=2)

    laplacian_x_tensor = torch.from_numpy(laplacian_x).to(tensor.device)
    laplacian_y_tensor = torch.from_numpy(laplacian_y).to(tensor.device)

    # 相加得到完整的拉普拉斯算子
    laplacian = laplacian_x_tensor + laplacian_y_tensor

    return laplacian

# %%
A_low_tensor = torch.tensor(A_low, dtype=torch.float32).unsqueeze(0).unsqueeze(0).to(device)
B_low_tensor = torch.tensor(B_low, dtype=torch.float32).unsqueeze(0).unsqueeze(0).to(device)
C_low_tensor = torch.tensor(C_low, dtype=torch.float32).unsqueeze(0).unsqueeze(0).to(device)
D_low_tensor = torch.tensor(D_low, dtype=torch.float32).unsqueeze(0).unsqueeze(0).to(device)

# %%
## 定义动态调整权重的损失函数
def loss_function(predicted_abcd, true_velocity, epsilon, weight_velocity, weight_abcd, weight_norm, weight_curl):
    # 提取 a, b, c, d
    a = predicted_abcd[:, 0, :, :]
    b = predicted_abcd[:, 1, :, :]
    c = predicted_abcd[:, 2, :, :]
    d = predicted_abcd[:, 3, :, :]
    
    # 计算梯度
    a_grad_x, a_grad_y = calculate_gradients_with_numpy(a)
    b_grad_x, b_grad_y = calculate_gradients_with_numpy(b)
    c_grad_x, c_grad_y = calculate_gradients_with_numpy(c)
    d_grad_x, d_grad_y = calculate_gradients_with_numpy(d)

    hbar = 1

    # 计算速度场
    U_x_pred = hbar * (a * b_grad_x - b * a_grad_x + c * d_grad_x - d * c_grad_x)
    U_y_pred = hbar * (a * b_grad_y - b * a_grad_y + c * d_grad_y - d * c_grad_y)
    U_magnitude_pred = torch.sqrt(U_x_pred**2 + U_y_pred**2)
    
    U_x_true = true_velocity[:, 0, :, :]
    U_y_true = true_velocity[:, 1, :, :]
    U_magnitude_true = true_velocity[:, 2, :, :]

    loss_velocity = F.mse_loss(U_magnitude_pred, U_magnitude_true) + F.mse_loss(U_x_pred, U_x_true) + F.mse_loss(U_y_pred, U_y_true)
    
    # 计算归一化约束
    norm = a**2 + b**2 + c**2 + d**2
    norm_constraint = F.mse_loss(norm, torch.ones_like(norm))
    
    # 计算拉普拉斯算子
    lap_b = laplacian_2d_torch(b, dx_low, dy_low)
    lap_a = laplacian_2d_torch(a, dx_low, dy_low)
    lap_d = laplacian_2d_torch(d, dx_low, dy_low)
    lap_c = laplacian_2d_torch(c, dx_low, dy_low)

    a_loss = F.mse_loss(a, A_low_tensor)
    b_loss = F.mse_loss(b, B_low_tensor)
    c_loss = F.mse_loss(c, C_low_tensor)
    d_loss = F.mse_loss(d, D_low_tensor)

    loss_abcd = a_loss + b_loss + c_loss + d_loss

    # 计算螺旋度约束
    curl_constraint = (a * lap_b - b * lap_a + c * lap_d - d * lap_c).sum()
    
    # 计算正则化项
    regularization_term = epsilon * 0.25 * (torch.sum(a**2) + torch.sum(b**2) + torch.sum(c**2) + torch.sum(d**2))
    
    # 总损失
    total_loss = regularization_term
    total_loss += weight_velocity * loss_velocity
    total_loss += weight_abcd * loss_abcd
    total_loss += weight_norm * norm_constraint
    total_loss += weight_curl * curl_constraint
    
    return total_loss

# %% [markdown]
# ### 设置超参数

# %%
# 超参数
learning_rate = 0.001
num_epochs = 10000
initial_epsilon = 0.01
final_epsilon = 0.0001


channels = 3

# 创建模型和优化器
model = ModelAWithConstraints().to(device)

optimizer = optim.Adam(model.parameters(), lr=learning_rate)

# %%
def plot_comparison(predicted, actual, step):
    
    a = predicted_abcd[:, 0, :, :]
    b = predicted_abcd[:, 1, :, :]
    c = predicted_abcd[:, 2, :, :]
    d = predicted_abcd[:, 3, :, :]
    
    a_grad_x, a_grad_y = calculate_gradients_with_numpy(a)
    b_grad_x, b_grad_y = calculate_gradients_with_numpy(b)
    c_grad_x, c_grad_y = calculate_gradients_with_numpy(c)
    d_grad_x, d_grad_y = calculate_gradients_with_numpy(d)

    hbar = 1

    U_x_pred = hbar * (a * b_grad_x - b * a_grad_x + c * d_grad_x - d * c_grad_x)
    U_y_pred = hbar * (a * b_grad_y - b * a_grad_y + c * d_grad_y - d * c_grad_y)
    U_magnitude_pred = torch.sqrt(U_x_pred**2 + U_y_pred**2)

    
    
    plt.subplots(2, 3, figsize=(10, 8))

    plt.subplot(2, 3, 1)
    plt.imshow(U_magnitude_pred[0].detach().cpu().numpy(), cmap='viridis')

    plt.title('Predicted Magnitude')

    plt.subplot(2, 3, 2)
    plt.imshow(U_x_pred[0].detach().cpu().numpy(), cmap='viridis')
    plt.title('Predicted U_x')

    plt.subplot(2, 3, 3)
    plt.imshow(U_y_pred[0].detach().cpu().numpy(), cmap='viridis')
    plt.title('Predicted U_y')

    plt.subplot(2, 3, 4)
    plt.imshow(actual[0,2].detach().cpu().numpy(), cmap='viridis')
    plt.title('Actual Magnitude')

    plt.subplot(2, 3, 5)
    plt.imshow(actual[0,1].detach().cpu().numpy(), cmap='viridis'   )
    plt.title('Actual U_x')

    plt.subplot(2, 3, 6)
    plt.imshow(actual[0,0].detach().cpu().numpy(), cmap='viridis')
    plt.title('Actual U_y')

    plt.suptitle(f'Step {step}')
    plt.show()

# %%
# # 训练模型
# for epoch in range(num_epochs):
#     epsilon = initial_epsilon * ((final_epsilon / initial_epsilon) ** (epoch / num_epochs))
#     for i, (velocity, _) in enumerate(dataloader):
#         optimizer.zero_grad()
#         predicted_abcd = model(velocity)
#         loss = loss_function(predicted_abcd, velocity, epsilon)
#         loss.backward()
#         optimizer.step()
#         if i % 10 == 0:
#             print(f'Epoch [{epoch+1}/{num_epochs}], Step [{i+1}], Loss: {loss.item():.4f}')

# %%
## 动态对应的

# 定义超参数
weight_velocity = 0.2
weight_abcd = 1.0
weight_norm = 0.0001
weight_curl = 0.0001

# 定义超参数
initial_weight_velocity = 1.0
initial_weight_abcd = 1.0
initial_weight_norm = 0.0001
initial_weight_curl = 0.0001

final_weight_velocity = 0.1
final_weight_abcd = 2.0
final_weight_norm = 0.0001
final_weight_curl = 0.0001

# 训练模型
for epoch in range(num_epochs):
    epsilon = initial_epsilon * ((final_epsilon / initial_epsilon) ** (epoch / num_epochs))
    
    # 动态调整权重
    weight_velocity = initial_weight_velocity * ((final_weight_velocity / initial_weight_velocity) ** (epoch / num_epochs))
    weight_abcd = initial_weight_abcd * ((final_weight_abcd / initial_weight_abcd) ** (epoch / num_epochs))
    weight_norm = initial_weight_norm * ((final_weight_norm / initial_weight_norm) ** (epoch / num_epochs))
    weight_curl = initial_weight_curl * ((final_weight_curl / initial_weight_curl) ** (epoch / num_epochs))
    
    for i, (velocity, _) in enumerate(dataloader):
        velocity = velocity.to(device)
        optimizer.zero_grad()
        predicted_abcd = model(velocity)
        loss = loss_function(predicted_abcd, velocity, epsilon, weight_velocity, weight_abcd, weight_norm, weight_curl)
        loss.backward()
        optimizer.step()
        if i % 10 == 0:
            print(f'Epoch [{epoch+1}/{num_epochs}], Step [{i+1}], Loss: {loss.item():.4f}')
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_89200\3168960726.py:38: UserWarning: Using a target size (torch.Size([1, 1, 64, 64])) that is different to the input size (torch.Size([1, 64, 64])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   a_loss = F.mse_loss(a, A_low_tensor)
# C:\Users\user\AppData\Local\Temp\ipykernel_89200\3168960726.py:39: UserWarning: Using a target size (torch.Size([1, 1, 64, 64])) that is different to the input size (torch.Size([1, 64, 64])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   b_loss = F.mse_loss(b, B_low_tensor)
# C:\Users\user\AppData\Local\Temp\ipykernel_89200\3168960726.py:40: UserWarning: Using a target size (torch.Size([1, 1, 64, 64])) that is different to the input size (torch.Size([1, 64, 64])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   c_loss = F.mse_loss(c, C_low_tensor)
# C:\Users\user\AppData\Local\Temp\ipykernel_89200\3168960726.py:41: UserWarning: Using a target size (torch.Size([1, 1, 64, 64])) that is different to the input size (torch.Size([1, 64, 64])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   d_loss = F.mse_loss(d, D_low_tensor)
# Epoch [1/20000], Step [1], Loss: 13.4235
# Epoch [2/20000], Step [1], Loss: 12.1349
# Epoch [3/20000], Step [1], Loss: 11.6060
# Epoch [4/20000], Step [1], Loss: 11.3533
# Epoch [5/20000], Step [1], Loss: 11.2620
# Epoch [6/20000], Step [1], Loss: 11.2207
# Epoch [7/20000], Step [1], Loss: 11.1933
# Epoch [8/20000], Step [1], Loss: 11.1690
# Epoch [9/20000], Step [1], Loss: 11.1449
# Epoch [10/20000], Step [1], Loss: 11.1214
# Epoch [11/20000], Step [1], Loss: 11.0993
# Epoch [12/20000], Step [1], Loss: 11.0790
# Epoch [13/20000], Step [1], Loss: 11.0608
# Epoch [14/20000], Step [1], Loss: 11.0453
# Epoch [15/20000], Step [1], Loss: 11.0327
# Epoch [16/20000], Step [1], Loss: 11.0230
# Epoch [17/20000], Step [1], Loss: 11.0159
# Epoch [18/20000], Step [1], Loss: 11.0106
# Epoch [19/20000], Step [1], Loss: 11.0062
# Epoch [20/20000], Step [1], Loss: 11.0020
# Epoch [21/20000], Step [1], Loss: 10.9975
# Epoch [22/20000], Step [1], Loss: 10.9927
# Epoch [23/20000], Step [1], Loss: 10.9877
# Epoch [24/20000], Step [1], Loss: 10.9829
# Epoch [25/20000], Step [1], Loss: 10.9786
# Epoch [26/20000], Step [1], Loss: 10.9748
# Epoch [27/20000], Step [1], Loss: 10.9716
# Epoch [28/20000], Step [1], Loss: 10.9687
# Epoch [29/20000], Step [1], Loss: 10.9660
# Epoch [30/20000], Step [1], Loss: 10.9635
# Epoch [31/20000], Step [1], Loss: 10.9611
# Epoch [32/20000], Step [1], Loss: 10.9587
# Epoch [33/20000], Step [1], Loss: 10.9565
# Epoch [34/20000], Step [1], Loss: 10.9542
# Epoch [35/20000], Step [1], Loss: 10.9520
# Epoch [36/20000], Step [1], Loss: 10.9497
# Epoch [37/20000], Step [1], Loss: 10.9472
# Epoch [38/20000], Step [1], Loss: 10.9446
# Epoch [39/20000], Step [1], Loss: 10.9418
# Epoch [40/20000], Step [1], Loss: 10.9389
# Epoch [41/20000], Step [1], Loss: 10.9358
# Epoch [42/20000], Step [1], Loss: 10.9327
# Epoch [43/20000], Step [1], Loss: 10.9296
# Epoch [44/20000], Step [1], Loss: 10.9266
# Epoch [45/20000], Step [1], Loss: 10.9236
# Epoch [46/20000], Step [1], Loss: 10.9207
# Epoch [47/20000], Step [1], Loss: 10.9179
# Epoch [48/20000], Step [1], Loss: 10.9152
# Epoch [49/20000], Step [1], Loss: 10.9125
# Epoch [50/20000], Step [1], Loss: 10.9099
# Epoch [51/20000], Step [1], Loss: 10.9073
# Epoch [52/20000], Step [1], Loss: 10.9047
# Epoch [53/20000], Step [1], Loss: 10.9022
# Epoch [54/20000], Step [1], Loss: 10.8998
# Epoch [55/20000], Step [1], Loss: 10.8974
# Epoch [56/20000], Step [1], Loss: 10.8950
# Epoch [57/20000], Step [1], Loss: 10.8927
# Epoch [58/20000], Step [1], Loss: 10.8904
# Epoch [59/20000], Step [1], Loss: 10.8881
# Epoch [60/20000], Step [1], Loss: 10.8858
# Epoch [61/20000], Step [1], Loss: 10.8835
# Epoch [62/20000], Step [1], Loss: 10.8811
# Epoch [63/20000], Step [1], Loss: 10.8788
# Epoch [64/20000], Step [1], Loss: 10.8764
# Epoch [65/20000], Step [1], Loss: 10.8740
# Epoch [66/20000], Step [1], Loss: 10.8715
# Epoch [67/20000], Step [1], Loss: 10.8690
# Epoch [68/20000], Step [1], Loss: 10.8665
# Epoch [69/20000], Step [1], Loss: 10.8640
# Epoch [70/20000], Step [1], Loss: 10.8615
# Epoch [71/20000], Step [1], Loss: 10.8589
# Epoch [72/20000], Step [1], Loss: 10.8564
# Epoch [73/20000], Step [1], Loss: 10.8539
# Epoch [74/20000], Step [1], Loss: 10.8514
# Epoch [75/20000], Step [1], Loss: 10.8489
# Epoch [76/20000], Step [1], Loss: 10.8465
# Epoch [77/20000], Step [1], Loss: 10.8441
# Epoch [78/20000], Step [1], Loss: 10.8417
# Epoch [79/20000], Step [1], Loss: 10.8393
# Epoch [80/20000], Step [1], Loss: 10.8369
# Epoch [81/20000], Step [1], Loss: 10.8346
# Epoch [82/20000], Step [1], Loss: 10.8322
# Epoch [83/20000], Step [1], Loss: 10.8299
# Epoch [84/20000], Step [1], Loss: 10.8275
# Epoch [85/20000], Step [1], Loss: 10.8252
# Epoch [86/20000], Step [1], Loss: 10.8228
# Epoch [87/20000], Step [1], Loss: 10.8205
# Epoch [88/20000], Step [1], Loss: 10.8181
# Epoch [89/20000], Step [1], Loss: 10.8157
# Epoch [90/20000], Step [1], Loss: 10.8133
# Epoch [91/20000], Step [1], Loss: 10.8109
# Epoch [92/20000], Step [1], Loss: 10.8085
# Epoch [93/20000], Step [1], Loss: 10.8060
# Epoch [94/20000], Step [1], Loss: 10.8036
# Epoch [95/20000], Step [1], Loss: 10.8012
# Epoch [96/20000], Step [1], Loss: 10.7987
# Epoch [97/20000], Step [1], Loss: 10.7963
# Epoch [98/20000], Step [1], Loss: 10.7939
# Epoch [99/20000], Step [1], Loss: 10.7915
# Epoch [100/20000], Step [1], Loss: 10.7890
# Epoch [101/20000], Step [1], Loss: 10.7866
# Epoch [102/20000], Step [1], Loss: 10.7842
# Epoch [103/20000], Step [1], Loss: 10.7818
# Epoch [104/20000], Step [1], Loss: 10.7795
# Epoch [105/20000], Step [1], Loss: 10.7771
# Epoch [106/20000], Step [1], Loss: 10.7747
# Epoch [107/20000], Step [1], Loss: 10.7723
# Epoch [108/20000], Step [1], Loss: 10.7699
# Epoch [109/20000], Step [1], Loss: 10.7676
# Epoch [110/20000], Step [1], Loss: 10.7652
# Epoch [111/20000], Step [1], Loss: 10.7628
# Epoch [112/20000], Step [1], Loss: 10.7604
# Epoch [113/20000], Step [1], Loss: 10.7580
# Epoch [114/20000], Step [1], Loss: 10.7556
# Epoch [115/20000], Step [1], Loss: 10.7532
# Epoch [116/20000], Step [1], Loss: 10.7508
# Epoch [117/20000], Step [1], Loss: 10.7484
# Epoch [118/20000], Step [1], Loss: 10.7460
# Epoch [119/20000], Step [1], Loss: 10.7436
# Epoch [120/20000], Step [1], Loss: 10.7413
# Epoch [121/20000], Step [1], Loss: 10.7389
# Epoch [122/20000], Step [1], Loss: 10.7365
# Epoch [123/20000], Step [1], Loss: 10.7341
# Epoch [124/20000], Step [1], Loss: 10.7317
# Epoch [125/20000], Step [1], Loss: 10.7293
# Epoch [126/20000], Step [1], Loss: 10.7269
# Epoch [127/20000], Step [1], Loss: 10.7245
# Epoch [128/20000], Step [1], Loss: 10.7222
# Epoch [129/20000], Step [1], Loss: 10.7198
# Epoch [130/20000], Step [1], Loss: 10.7174
# Epoch [131/20000], Step [1], Loss: 10.7150
# Epoch [132/20000], Step [1], Loss: 10.7126
# Epoch [133/20000], Step [1], Loss: 10.7103
# Epoch [134/20000], Step [1], Loss: 10.7079
# Epoch [135/20000], Step [1], Loss: 10.7055
# Epoch [136/20000], Step [1], Loss: 10.7031
# Epoch [137/20000], Step [1], Loss: 10.7007
# Epoch [138/20000], Step [1], Loss: 10.6983
# Epoch [139/20000], Step [1], Loss: 10.6960
# Epoch [140/20000], Step [1], Loss: 10.6936
# Epoch [141/20000], Step [1], Loss: 10.6912
# Epoch [142/20000], Step [1], Loss: 10.6888
# Epoch [143/20000], Step [1], Loss: 10.6865
# Epoch [144/20000], Step [1], Loss: 10.6841
# Epoch [145/20000], Step [1], Loss: 10.6817
# Epoch [146/20000], Step [1], Loss: 10.6793
# Epoch [147/20000], Step [1], Loss: 10.6770
# Epoch [148/20000], Step [1], Loss: 10.6746
# Epoch [149/20000], Step [1], Loss: 10.6722
# Epoch [150/20000], Step [1], Loss: 10.6698
# Epoch [151/20000], Step [1], Loss: 10.6675
# Epoch [152/20000], Step [1], Loss: 10.6651
# Epoch [153/20000], Step [1], Loss: 10.6627
# Epoch [154/20000], Step [1], Loss: 10.6604
# Epoch [155/20000], Step [1], Loss: 10.6580
# Epoch [156/20000], Step [1], Loss: 10.6556
# Epoch [157/20000], Step [1], Loss: 10.6532
# Epoch [158/20000], Step [1], Loss: 10.6509
# Epoch [159/20000], Step [1], Loss: 10.6485
# Epoch [160/20000], Step [1], Loss: 10.6461
# Epoch [161/20000], Step [1], Loss: 10.6438
# Epoch [162/20000], Step [1], Loss: 10.6414
# Epoch [163/20000], Step [1], Loss: 10.6390
# Epoch [164/20000], Step [1], Loss: 10.6367
# Epoch [165/20000], Step [1], Loss: 10.6343
# Epoch [166/20000], Step [1], Loss: 10.6319
# Epoch [167/20000], Step [1], Loss: 10.6296
# Epoch [168/20000], Step [1], Loss: 10.6272
# Epoch [169/20000], Step [1], Loss: 10.6249
# Epoch [170/20000], Step [1], Loss: 10.6225
# Epoch [171/20000], Step [1], Loss: 10.6201
# Epoch [172/20000], Step [1], Loss: 10.6178
# Epoch [173/20000], Step [1], Loss: 10.6154
# Epoch [174/20000], Step [1], Loss: 10.6131
# Epoch [175/20000], Step [1], Loss: 10.6107
# Epoch [176/20000], Step [1], Loss: 10.6083
# Epoch [177/20000], Step [1], Loss: 10.6060
# Epoch [178/20000], Step [1], Loss: 10.6036
# Epoch [179/20000], Step [1], Loss: 10.6013
# Epoch [180/20000], Step [1], Loss: 10.5989
# Epoch [181/20000], Step [1], Loss: 10.5966
# Epoch [182/20000], Step [1], Loss: 10.5942
# Epoch [183/20000], Step [1], Loss: 10.5919
# Epoch [184/20000], Step [1], Loss: 10.5895
# Epoch [185/20000], Step [1], Loss: 10.5872
# Epoch [186/20000], Step [1], Loss: 10.5848
# Epoch [187/20000], Step [1], Loss: 10.5824
# Epoch [188/20000], Step [1], Loss: 10.5801
# Epoch [189/20000], Step [1], Loss: 10.5777
# Epoch [190/20000], Step [1], Loss: 10.5754
# Epoch [191/20000], Step [1], Loss: 10.5730
# Epoch [192/20000], Step [1], Loss: 10.5707
# Epoch [193/20000], Step [1], Loss: 10.5684
# Epoch [194/20000], Step [1], Loss: 10.5660
# Epoch [195/20000], Step [1], Loss: 10.5637
# Epoch [196/20000], Step [1], Loss: 10.5613
# Epoch [197/20000], Step [1], Loss: 10.5590
# Epoch [198/20000], Step [1], Loss: 10.5566
# Epoch [199/20000], Step [1], Loss: 10.5543
# Epoch [200/20000], Step [1], Loss: 10.5519
# Epoch [201/20000], Step [1], Loss: 10.5496
# Epoch [202/20000], Step [1], Loss: 10.5472
# Epoch [203/20000], Step [1], Loss: 10.5449
# Epoch [204/20000], Step [1], Loss: 10.5426
# Epoch [205/20000], Step [1], Loss: 10.5402
# Epoch [206/20000], Step [1], Loss: 10.5379
# Epoch [207/20000], Step [1], Loss: 10.5355
# Epoch [208/20000], Step [1], Loss: 10.5332
# Epoch [209/20000], Step [1], Loss: 10.5309
# Epoch [210/20000], Step [1], Loss: 10.5285
# Epoch [211/20000], Step [1], Loss: 10.5262
# Epoch [212/20000], Step [1], Loss: 10.5238
# Epoch [213/20000], Step [1], Loss: 10.5215
# Epoch [214/20000], Step [1], Loss: 10.5192
# Epoch [215/20000], Step [1], Loss: 10.5168
# Epoch [216/20000], Step [1], Loss: 10.5145
# Epoch [217/20000], Step [1], Loss: 10.5122
# Epoch [218/20000], Step [1], Loss: 10.5098
# Epoch [219/20000], Step [1], Loss: 10.5075
# Epoch [220/20000], Step [1], Loss: 10.5052
# Epoch [221/20000], Step [1], Loss: 10.5028
# Epoch [222/20000], Step [1], Loss: 10.5005
# Epoch [223/20000], Step [1], Loss: 10.4982
# Epoch [224/20000], Step [1], Loss: 10.4958
# Epoch [225/20000], Step [1], Loss: 10.4935
# Epoch [226/20000], Step [1], Loss: 10.4912
# Epoch [227/20000], Step [1], Loss: 10.4888
# Epoch [228/20000], Step [1], Loss: 10.4865
# Epoch [229/20000], Step [1], Loss: 10.4842
# Epoch [230/20000], Step [1], Loss: 10.4818
# Epoch [231/20000], Step [1], Loss: 10.4795
# Epoch [232/20000], Step [1], Loss: 10.4772
# Epoch [233/20000], Step [1], Loss: 10.4749
# Epoch [234/20000], Step [1], Loss: 10.4725
# Epoch [235/20000], Step [1], Loss: 10.4702
# Epoch [236/20000], Step [1], Loss: 10.4679
# Epoch [237/20000], Step [1], Loss: 10.4656
# Epoch [238/20000], Step [1], Loss: 10.4633
# Epoch [239/20000], Step [1], Loss: 10.4609
# Epoch [240/20000], Step [1], Loss: 10.4586
# Epoch [241/20000], Step [1], Loss: 10.4563
# Epoch [242/20000], Step [1], Loss: 10.4540
# Epoch [243/20000], Step [1], Loss: 10.4516
# Epoch [244/20000], Step [1], Loss: 10.4493
# Epoch [245/20000], Step [1], Loss: 10.4470
# Epoch [246/20000], Step [1], Loss: 10.4447
# Epoch [247/20000], Step [1], Loss: 10.4424
# Epoch [248/20000], Step [1], Loss: 10.4400
# Epoch [249/20000], Step [1], Loss: 10.4377
# Epoch [250/20000], Step [1], Loss: 10.4354
# Epoch [251/20000], Step [1], Loss: 10.4331
# Epoch [252/20000], Step [1], Loss: 10.4308
# Epoch [253/20000], Step [1], Loss: 10.4285
# Epoch [254/20000], Step [1], Loss: 10.4261
# Epoch [255/20000], Step [1], Loss: 10.4238
# Epoch [256/20000], Step [1], Loss: 10.4215
# Epoch [257/20000], Step [1], Loss: 10.4192
# Epoch [258/20000], Step [1], Loss: 10.4169
# Epoch [259/20000], Step [1], Loss: 10.4146
# Epoch [260/20000], Step [1], Loss: 10.4123
# Epoch [261/20000], Step [1], Loss: 10.4100
# Epoch [262/20000], Step [1], Loss: 10.4077
# Epoch [263/20000], Step [1], Loss: 10.4054
# Epoch [264/20000], Step [1], Loss: 10.4030
# Epoch [265/20000], Step [1], Loss: 10.4007
# Epoch [266/20000], Step [1], Loss: 10.3984
# Epoch [267/20000], Step [1], Loss: 10.3961
# Epoch [268/20000], Step [1], Loss: 10.3938
# Epoch [269/20000], Step [1], Loss: 10.3915
# Epoch [270/20000], Step [1], Loss: 10.3892
# Epoch [271/20000], Step [1], Loss: 10.3869
# Epoch [272/20000], Step [1], Loss: 10.3846
# Epoch [273/20000], Step [1], Loss: 10.3823
# Epoch [274/20000], Step [1], Loss: 10.3800
# Epoch [275/20000], Step [1], Loss: 10.3777
# Epoch [276/20000], Step [1], Loss: 10.3754
# Epoch [277/20000], Step [1], Loss: 10.3731
# Epoch [278/20000], Step [1], Loss: 10.3708
# Epoch [279/20000], Step [1], Loss: 10.3685
# Epoch [280/20000], Step [1], Loss: 10.3662
# Epoch [281/20000], Step [1], Loss: 10.3639
# Epoch [282/20000], Step [1], Loss: 10.3616
# Epoch [283/20000], Step [1], Loss: 10.3593
# Epoch [284/20000], Step [1], Loss: 10.3570
# Epoch [285/20000], Step [1], Loss: 10.3547
# Epoch [286/20000], Step [1], Loss: 10.3524
# Epoch [287/20000], Step [1], Loss: 10.3501
# Epoch [288/20000], Step [1], Loss: 10.3478
# Epoch [289/20000], Step [1], Loss: 10.3455
# Epoch [290/20000], Step [1], Loss: 10.3432
# Epoch [291/20000], Step [1], Loss: 10.3409
# Epoch [292/20000], Step [1], Loss: 10.3386
# Epoch [293/20000], Step [1], Loss: 10.3363
# Epoch [294/20000], Step [1], Loss: 10.3340
# Epoch [295/20000], Step [1], Loss: 10.3317
# Epoch [296/20000], Step [1], Loss: 10.3295
# Epoch [297/20000], Step [1], Loss: 10.3272
# Epoch [298/20000], Step [1], Loss: 10.3249
# Epoch [299/20000], Step [1], Loss: 10.3226
# Epoch [300/20000], Step [1], Loss: 10.3203
# Epoch [301/20000], Step [1], Loss: 10.3180
# Epoch [302/20000], Step [1], Loss: 10.3157
# Epoch [303/20000], Step [1], Loss: 10.3134
# Epoch [304/20000], Step [1], Loss: 10.3111
# Epoch [305/20000], Step [1], Loss: 10.3089
# Epoch [306/20000], Step [1], Loss: 10.3066
# Epoch [307/20000], Step [1], Loss: 10.3043
# Epoch [308/20000], Step [1], Loss: 10.3020
# Epoch [309/20000], Step [1], Loss: 10.2997
# Epoch [310/20000], Step [1], Loss: 10.2974
# Epoch [311/20000], Step [1], Loss: 10.2951
# Epoch [312/20000], Step [1], Loss: 10.2929
# Epoch [313/20000], Step [1], Loss: 10.2906
# Epoch [314/20000], Step [1], Loss: 10.2883
# Epoch [315/20000], Step [1], Loss: 10.2860
# Epoch [316/20000], Step [1], Loss: 10.2837
# Epoch [317/20000], Step [1], Loss: 10.2815
# Epoch [318/20000], Step [1], Loss: 10.2792
# Epoch [319/20000], Step [1], Loss: 10.2769
# Epoch [320/20000], Step [1], Loss: 10.2746
# Epoch [321/20000], Step [1], Loss: 10.2724
# Epoch [322/20000], Step [1], Loss: 10.2701
# Epoch [323/20000], Step [1], Loss: 10.2678
# Epoch [324/20000], Step [1], Loss: 10.2655
# Epoch [325/20000], Step [1], Loss: 10.2632
# Epoch [326/20000], Step [1], Loss: 10.2610
# Epoch [327/20000], Step [1], Loss: 10.2587
# Epoch [328/20000], Step [1], Loss: 10.2564
# Epoch [329/20000], Step [1], Loss: 10.2541
# Epoch [330/20000], Step [1], Loss: 10.2519
# Epoch [331/20000], Step [1], Loss: 10.2496
# Epoch [332/20000], Step [1], Loss: 10.2473
# Epoch [333/20000], Step [1], Loss: 10.2451
# Epoch [334/20000], Step [1], Loss: 10.2428
# Epoch [335/20000], Step [1], Loss: 10.2405
# Epoch [336/20000], Step [1], Loss: 10.2382
# Epoch [337/20000], Step [1], Loss: 10.2360
# Epoch [338/20000], Step [1], Loss: 10.2337
# Epoch [339/20000], Step [1], Loss: 10.2314
# Epoch [340/20000], Step [1], Loss: 10.2292
# Epoch [341/20000], Step [1], Loss: 10.2269
# Epoch [342/20000], Step [1], Loss: 10.2246
# Epoch [343/20000], Step [1], Loss: 10.2224
# Epoch [344/20000], Step [1], Loss: 10.2201
# Epoch [345/20000], Step [1], Loss: 10.2178
# Epoch [346/20000], Step [1], Loss: 10.2156
# Epoch [347/20000], Step [1], Loss: 10.2133
# Epoch [348/20000], Step [1], Loss: 10.2111
# Epoch [349/20000], Step [1], Loss: 10.2088
# Epoch [350/20000], Step [1], Loss: 10.2065
# Epoch [351/20000], Step [1], Loss: 10.2043
# Epoch [352/20000], Step [1], Loss: 10.2020
# Epoch [353/20000], Step [1], Loss: 10.1997
# Epoch [354/20000], Step [1], Loss: 10.1975
# Epoch [355/20000], Step [1], Loss: 10.1952
# Epoch [356/20000], Step [1], Loss: 10.1930
# Epoch [357/20000], Step [1], Loss: 10.1907
# Epoch [358/20000], Step [1], Loss: 10.1884
# Epoch [359/20000], Step [1], Loss: 10.1862
# Epoch [360/20000], Step [1], Loss: 10.1839
# Epoch [361/20000], Step [1], Loss: 10.1817
# Epoch [362/20000], Step [1], Loss: 10.1794
# Epoch [363/20000], Step [1], Loss: 10.1772
# Epoch [364/20000], Step [1], Loss: 10.1749
# Epoch [365/20000], Step [1], Loss: 10.1727
# Epoch [366/20000], Step [1], Loss: 10.1704
# Epoch [367/20000], Step [1], Loss: 10.1681
# Epoch [368/20000], Step [1], Loss: 10.1659
# Epoch [369/20000], Step [1], Loss: 10.1636
# Epoch [370/20000], Step [1], Loss: 10.1614
# Epoch [371/20000], Step [1], Loss: 10.1591
# Epoch [372/20000], Step [1], Loss: 10.1569
# Epoch [373/20000], Step [1], Loss: 10.1546
# Epoch [374/20000], Step [1], Loss: 10.1524
# Epoch [375/20000], Step [1], Loss: 10.1501
# Epoch [376/20000], Step [1], Loss: 10.1479
# Epoch [377/20000], Step [1], Loss: 10.1456
# Epoch [378/20000], Step [1], Loss: 10.1434
# Epoch [379/20000], Step [1], Loss: 10.1411
# Epoch [380/20000], Step [1], Loss: 10.1389
# Epoch [381/20000], Step [1], Loss: 10.1366
# Epoch [382/20000], Step [1], Loss: 10.1344
# Epoch [383/20000], Step [1], Loss: 10.1322
# Epoch [384/20000], Step [1], Loss: 10.1299
# Epoch [385/20000], Step [1], Loss: 10.1277
# Epoch [386/20000], Step [1], Loss: 10.1254
# Epoch [387/20000], Step [1], Loss: 10.1232
# Epoch [388/20000], Step [1], Loss: 10.1209
# Epoch [389/20000], Step [1], Loss: 10.1187
# Epoch [390/20000], Step [1], Loss: 10.1164
# Epoch [391/20000], Step [1], Loss: 10.1142
# Epoch [392/20000], Step [1], Loss: 10.1120
# Epoch [393/20000], Step [1], Loss: 10.1097
# Epoch [394/20000], Step [1], Loss: 10.1075
# Epoch [395/20000], Step [1], Loss: 10.1052
# Epoch [396/20000], Step [1], Loss: 10.1030
# Epoch [397/20000], Step [1], Loss: 10.1008
# Epoch [398/20000], Step [1], Loss: 10.0985
# Epoch [399/20000], Step [1], Loss: 10.0963
# Epoch [400/20000], Step [1], Loss: 10.0941
# Epoch [401/20000], Step [1], Loss: 10.0918
# Epoch [402/20000], Step [1], Loss: 10.0896
# Epoch [403/20000], Step [1], Loss: 10.0873
# Epoch [404/20000], Step [1], Loss: 10.0851
# Epoch [405/20000], Step [1], Loss: 10.0829
# Epoch [406/20000], Step [1], Loss: 10.0806
# Epoch [407/20000], Step [1], Loss: 10.0784
# Epoch [408/20000], Step [1], Loss: 10.0762
# Epoch [409/20000], Step [1], Loss: 10.0739
# Epoch [410/20000], Step [1], Loss: 10.0717
# Epoch [411/20000], Step [1], Loss: 10.0695
# Epoch [412/20000], Step [1], Loss: 10.0673
# Epoch [413/20000], Step [1], Loss: 10.0650
# Epoch [414/20000], Step [1], Loss: 10.0628
# Epoch [415/20000], Step [1], Loss: 10.0606
# Epoch [416/20000], Step [1], Loss: 10.0583
# Epoch [417/20000], Step [1], Loss: 10.0561
# Epoch [418/20000], Step [1], Loss: 10.0539
# Epoch [419/20000], Step [1], Loss: 10.0517
# Epoch [420/20000], Step [1], Loss: 10.0494
# Epoch [421/20000], Step [1], Loss: 10.0472
# Epoch [422/20000], Step [1], Loss: 10.0450
# Epoch [423/20000], Step [1], Loss: 10.0428
# Epoch [424/20000], Step [1], Loss: 10.0405
# Epoch [425/20000], Step [1], Loss: 10.0383
# Epoch [426/20000], Step [1], Loss: 10.0361
# Epoch [427/20000], Step [1], Loss: 10.0339
# Epoch [428/20000], Step [1], Loss: 10.0316
# Epoch [429/20000], Step [1], Loss: 10.0294
# Epoch [430/20000], Step [1], Loss: 10.0272
# Epoch [431/20000], Step [1], Loss: 10.0250
# Epoch [432/20000], Step [1], Loss: 10.0227
# Epoch [433/20000], Step [1], Loss: 10.0205
# Epoch [434/20000], Step [1], Loss: 10.0183
# Epoch [435/20000], Step [1], Loss: 10.0161
# Epoch [436/20000], Step [1], Loss: 10.0139
# Epoch [437/20000], Step [1], Loss: 10.0117
# Epoch [438/20000], Step [1], Loss: 10.0094
# Epoch [439/20000], Step [1], Loss: 10.0072
# Epoch [440/20000], Step [1], Loss: 10.0050
# Epoch [441/20000], Step [1], Loss: 10.0028
# Epoch [442/20000], Step [1], Loss: 10.0006
# Epoch [443/20000], Step [1], Loss: 9.9984
# Epoch [444/20000], Step [1], Loss: 9.9961
# Epoch [445/20000], Step [1], Loss: 9.9939
# Epoch [446/20000], Step [1], Loss: 9.9917
# Epoch [447/20000], Step [1], Loss: 9.9895
# Epoch [448/20000], Step [1], Loss: 9.9873
# Epoch [449/20000], Step [1], Loss: 9.9851
# Epoch [450/20000], Step [1], Loss: 9.9829
# Epoch [451/20000], Step [1], Loss: 9.9806
# Epoch [452/20000], Step [1], Loss: 9.9784
# Epoch [453/20000], Step [1], Loss: 9.9762
# Epoch [454/20000], Step [1], Loss: 9.9740
# Epoch [455/20000], Step [1], Loss: 9.9718
# Epoch [456/20000], Step [1], Loss: 9.9696
# Epoch [457/20000], Step [1], Loss: 9.9674
# Epoch [458/20000], Step [1], Loss: 9.9652
# Epoch [459/20000], Step [1], Loss: 9.9630
# Epoch [460/20000], Step [1], Loss: 9.9608
# Epoch [461/20000], Step [1], Loss: 9.9586
# Epoch [462/20000], Step [1], Loss: 9.9564
# Epoch [463/20000], Step [1], Loss: 9.9542
# Epoch [464/20000], Step [1], Loss: 9.9520
# Epoch [465/20000], Step [1], Loss: 9.9497
# Epoch [466/20000], Step [1], Loss: 9.9475
# Epoch [467/20000], Step [1], Loss: 9.9453
# Epoch [468/20000], Step [1], Loss: 9.9431
# Epoch [469/20000], Step [1], Loss: 9.9409
# Epoch [470/20000], Step [1], Loss: 9.9387
# Epoch [471/20000], Step [1], Loss: 9.9365
# Epoch [472/20000], Step [1], Loss: 9.9343
# Epoch [473/20000], Step [1], Loss: 9.9321
# Epoch [474/20000], Step [1], Loss: 9.9299
# Epoch [475/20000], Step [1], Loss: 9.9277
# Epoch [476/20000], Step [1], Loss: 9.9255
# Epoch [477/20000], Step [1], Loss: 9.9233
# Epoch [478/20000], Step [1], Loss: 9.9211
# Epoch [479/20000], Step [1], Loss: 9.9189
# Epoch [480/20000], Step [1], Loss: 9.9167
# Epoch [481/20000], Step [1], Loss: 9.9146
# Epoch [482/20000], Step [1], Loss: 9.9124
# Epoch [483/20000], Step [1], Loss: 9.9102
# Epoch [484/20000], Step [1], Loss: 9.9080
# Epoch [485/20000], Step [1], Loss: 9.9058
# Epoch [486/20000], Step [1], Loss: 9.9036
# Epoch [487/20000], Step [1], Loss: 9.9014
# Epoch [488/20000], Step [1], Loss: 9.8992
# Epoch [489/20000], Step [1], Loss: 9.8970
# Epoch [490/20000], Step [1], Loss: 9.8948
# Epoch [491/20000], Step [1], Loss: 9.8926
# Epoch [492/20000], Step [1], Loss: 9.8904
# Epoch [493/20000], Step [1], Loss: 9.8882
# Epoch [494/20000], Step [1], Loss: 9.8861
# Epoch [495/20000], Step [1], Loss: 9.8839
# Epoch [496/20000], Step [1], Loss: 9.8817
# Epoch [497/20000], Step [1], Loss: 9.8795
# Epoch [498/20000], Step [1], Loss: 9.8773
# Epoch [499/20000], Step [1], Loss: 9.8751
# Epoch [500/20000], Step [1], Loss: 9.8729
# Epoch [501/20000], Step [1], Loss: 9.8707
# Epoch [502/20000], Step [1], Loss: 9.8686
# Epoch [503/20000], Step [1], Loss: 9.8664
# Epoch [504/20000], Step [1], Loss: 9.8642
# Epoch [505/20000], Step [1], Loss: 9.8620
# Epoch [506/20000], Step [1], Loss: 9.8598
# Epoch [507/20000], Step [1], Loss: 9.8576
# Epoch [508/20000], Step [1], Loss: 9.8554
# Epoch [509/20000], Step [1], Loss: 9.8533
# Epoch [510/20000], Step [1], Loss: 9.8511
# Epoch [511/20000], Step [1], Loss: 9.8489
# Epoch [512/20000], Step [1], Loss: 9.8467
# Epoch [513/20000], Step [1], Loss: 9.8445
# Epoch [514/20000], Step [1], Loss: 9.8424
# Epoch [515/20000], Step [1], Loss: 9.8402
# Epoch [516/20000], Step [1], Loss: 9.8380
# Epoch [517/20000], Step [1], Loss: 9.8358
# Epoch [518/20000], Step [1], Loss: 9.8337
# Epoch [519/20000], Step [1], Loss: 9.8315
# Epoch [520/20000], Step [1], Loss: 9.8293
# Epoch [521/20000], Step [1], Loss: 9.8271
# Epoch [522/20000], Step [1], Loss: 9.8249
# Epoch [523/20000], Step [1], Loss: 9.8228
# Epoch [524/20000], Step [1], Loss: 9.8206
# Epoch [525/20000], Step [1], Loss: 9.8184
# Epoch [526/20000], Step [1], Loss: 9.8163
# Epoch [527/20000], Step [1], Loss: 9.8141
# Epoch [528/20000], Step [1], Loss: 9.8119
# Epoch [529/20000], Step [1], Loss: 9.8097
# Epoch [530/20000], Step [1], Loss: 9.8076
# Epoch [531/20000], Step [1], Loss: 9.8054
# Epoch [532/20000], Step [1], Loss: 9.8032
# Epoch [533/20000], Step [1], Loss: 9.8010
# Epoch [534/20000], Step [1], Loss: 9.7989
# Epoch [535/20000], Step [1], Loss: 9.7967
# Epoch [536/20000], Step [1], Loss: 9.7945
# Epoch [537/20000], Step [1], Loss: 9.7924
# Epoch [538/20000], Step [1], Loss: 9.7902
# Epoch [539/20000], Step [1], Loss: 9.7880
# Epoch [540/20000], Step [1], Loss: 9.7859
# Epoch [541/20000], Step [1], Loss: 9.7837
# Epoch [542/20000], Step [1], Loss: 9.7815
# Epoch [543/20000], Step [1], Loss: 9.7794
# Epoch [544/20000], Step [1], Loss: 9.7772
# Epoch [545/20000], Step [1], Loss: 9.7750
# Epoch [546/20000], Step [1], Loss: 9.7729
# Epoch [547/20000], Step [1], Loss: 9.7707
# Epoch [548/20000], Step [1], Loss: 9.7686
# Epoch [549/20000], Step [1], Loss: 9.7664
# Epoch [550/20000], Step [1], Loss: 9.7642
# Epoch [551/20000], Step [1], Loss: 9.7621
# Epoch [552/20000], Step [1], Loss: 9.7599
# Epoch [553/20000], Step [1], Loss: 9.7577
# Epoch [554/20000], Step [1], Loss: 9.7556
# Epoch [555/20000], Step [1], Loss: 9.7534
# Epoch [556/20000], Step [1], Loss: 9.7513
# Epoch [557/20000], Step [1], Loss: 9.7491
# Epoch [558/20000], Step [1], Loss: 9.7470
# Epoch [559/20000], Step [1], Loss: 9.7448
# Epoch [560/20000], Step [1], Loss: 9.7426
# Epoch [561/20000], Step [1], Loss: 9.7405
# Epoch [562/20000], Step [1], Loss: 9.7383
# Epoch [563/20000], Step [1], Loss: 9.7362
# Epoch [564/20000], Step [1], Loss: 9.7340
# Epoch [565/20000], Step [1], Loss: 9.7319
# Epoch [566/20000], Step [1], Loss: 9.7297
# Epoch [567/20000], Step [1], Loss: 9.7276
# Epoch [568/20000], Step [1], Loss: 9.7254
# Epoch [569/20000], Step [1], Loss: 9.7232
# Epoch [570/20000], Step [1], Loss: 9.7211
# Epoch [571/20000], Step [1], Loss: 9.7189
# Epoch [572/20000], Step [1], Loss: 9.7168
# Epoch [573/20000], Step [1], Loss: 9.7146
# Epoch [574/20000], Step [1], Loss: 9.7125
# Epoch [575/20000], Step [1], Loss: 9.7103
# Epoch [576/20000], Step [1], Loss: 9.7082
# Epoch [577/20000], Step [1], Loss: 9.7060
# Epoch [578/20000], Step [1], Loss: 9.7039
# Epoch [579/20000], Step [1], Loss: 9.7017
# Epoch [580/20000], Step [1], Loss: 9.6996
# Epoch [581/20000], Step [1], Loss: 9.6975
# Epoch [582/20000], Step [1], Loss: 9.6953
# Epoch [583/20000], Step [1], Loss: 9.6932
# Epoch [584/20000], Step [1], Loss: 9.6910
# Epoch [585/20000], Step [1], Loss: 9.6889
# Epoch [586/20000], Step [1], Loss: 9.6867
# Epoch [587/20000], Step [1], Loss: 9.6846
# Epoch [588/20000], Step [1], Loss: 9.6824
# Epoch [589/20000], Step [1], Loss: 9.6803
# Epoch [590/20000], Step [1], Loss: 9.6782
# Epoch [591/20000], Step [1], Loss: 9.6760
# Epoch [592/20000], Step [1], Loss: 9.6739
# Epoch [593/20000], Step [1], Loss: 9.6717
# Epoch [594/20000], Step [1], Loss: 9.6696
# Epoch [595/20000], Step [1], Loss: 9.6674
# Epoch [596/20000], Step [1], Loss: 9.6653
# Epoch [597/20000], Step [1], Loss: 9.6632
# Epoch [598/20000], Step [1], Loss: 9.6610
# Epoch [599/20000], Step [1], Loss: 9.6589
# Epoch [600/20000], Step [1], Loss: 9.6568
# Epoch [601/20000], Step [1], Loss: 9.6546
# Epoch [602/20000], Step [1], Loss: 9.6525
# Epoch [603/20000], Step [1], Loss: 9.6503
# Epoch [604/20000], Step [1], Loss: 9.6482
# Epoch [605/20000], Step [1], Loss: 9.6461
# Epoch [606/20000], Step [1], Loss: 9.6439
# Epoch [607/20000], Step [1], Loss: 9.6418
# Epoch [608/20000], Step [1], Loss: 9.6397
# Epoch [609/20000], Step [1], Loss: 9.6375
# Epoch [610/20000], Step [1], Loss: 9.6354
# Epoch [611/20000], Step [1], Loss: 9.6333
# Epoch [612/20000], Step [1], Loss: 9.6311
# Epoch [613/20000], Step [1], Loss: 9.6290
# Epoch [614/20000], Step [1], Loss: 9.6269
# Epoch [615/20000], Step [1], Loss: 9.6248
# Epoch [616/20000], Step [1], Loss: 9.6226
# Epoch [617/20000], Step [1], Loss: 9.6205
# Epoch [618/20000], Step [1], Loss: 9.6184
# Epoch [619/20000], Step [1], Loss: 9.6162
# Epoch [620/20000], Step [1], Loss: 9.6141
# Epoch [621/20000], Step [1], Loss: 9.6120
# Epoch [622/20000], Step [1], Loss: 9.6099
# Epoch [623/20000], Step [1], Loss: 9.6077
# Epoch [624/20000], Step [1], Loss: 9.6056
# Epoch [625/20000], Step [1], Loss: 9.6035
# Epoch [626/20000], Step [1], Loss: 9.6013
# Epoch [627/20000], Step [1], Loss: 9.5992
# Epoch [628/20000], Step [1], Loss: 9.5971
# Epoch [629/20000], Step [1], Loss: 9.5950
# Epoch [630/20000], Step [1], Loss: 9.5929
# Epoch [631/20000], Step [1], Loss: 9.5907
# Epoch [632/20000], Step [1], Loss: 9.5886
# Epoch [633/20000], Step [1], Loss: 9.5865
# Epoch [634/20000], Step [1], Loss: 9.5844
# Epoch [635/20000], Step [1], Loss: 9.5822
# Epoch [636/20000], Step [1], Loss: 9.5801
# Epoch [637/20000], Step [1], Loss: 9.5780
# Epoch [638/20000], Step [1], Loss: 9.5759
# Epoch [639/20000], Step [1], Loss: 9.5738
# Epoch [640/20000], Step [1], Loss: 9.5717
# Epoch [641/20000], Step [1], Loss: 9.5695
# Epoch [642/20000], Step [1], Loss: 9.5674
# Epoch [643/20000], Step [1], Loss: 9.5653
# Epoch [644/20000], Step [1], Loss: 9.5632
# Epoch [645/20000], Step [1], Loss: 9.5611
# Epoch [646/20000], Step [1], Loss: 9.5590
# Epoch [647/20000], Step [1], Loss: 9.5568
# Epoch [648/20000], Step [1], Loss: 9.5547
# Epoch [649/20000], Step [1], Loss: 9.5526
# Epoch [650/20000], Step [1], Loss: 9.5505
# Epoch [651/20000], Step [1], Loss: 9.5484
# Epoch [652/20000], Step [1], Loss: 9.5463
# Epoch [653/20000], Step [1], Loss: 9.5442
# Epoch [654/20000], Step [1], Loss: 9.5420
# Epoch [655/20000], Step [1], Loss: 9.5399
# Epoch [656/20000], Step [1], Loss: 9.5378
# Epoch [657/20000], Step [1], Loss: 9.5357
# Epoch [658/20000], Step [1], Loss: 9.5336
# Epoch [659/20000], Step [1], Loss: 9.5315
# Epoch [660/20000], Step [1], Loss: 9.5294
# Epoch [661/20000], Step [1], Loss: 9.5273
# Epoch [662/20000], Step [1], Loss: 9.5252
# Epoch [663/20000], Step [1], Loss: 9.5231
# Epoch [664/20000], Step [1], Loss: 9.5210
# Epoch [665/20000], Step [1], Loss: 9.5189
# Epoch [666/20000], Step [1], Loss: 9.5168
# Epoch [667/20000], Step [1], Loss: 9.5146
# Epoch [668/20000], Step [1], Loss: 9.5125
# Epoch [669/20000], Step [1], Loss: 9.5104
# Epoch [670/20000], Step [1], Loss: 9.5083
# Epoch [671/20000], Step [1], Loss: 9.5062
# Epoch [672/20000], Step [1], Loss: 9.5041
# Epoch [673/20000], Step [1], Loss: 9.5020
# Epoch [674/20000], Step [1], Loss: 9.4999
# Epoch [675/20000], Step [1], Loss: 9.4978
# Epoch [676/20000], Step [1], Loss: 9.4957
# Epoch [677/20000], Step [1], Loss: 9.4936
# Epoch [678/20000], Step [1], Loss: 9.4915
# Epoch [679/20000], Step [1], Loss: 9.4894
# Epoch [680/20000], Step [1], Loss: 9.4873
# Epoch [681/20000], Step [1], Loss: 9.4852
# Epoch [682/20000], Step [1], Loss: 9.4831
# Epoch [683/20000], Step [1], Loss: 9.4810
# Epoch [684/20000], Step [1], Loss: 9.4789
# Epoch [685/20000], Step [1], Loss: 9.4768
# Epoch [686/20000], Step [1], Loss: 9.4747
# Epoch [687/20000], Step [1], Loss: 9.4726
# Epoch [688/20000], Step [1], Loss: 9.4705
# Epoch [689/20000], Step [1], Loss: 9.4684
# Epoch [690/20000], Step [1], Loss: 9.4664
# Epoch [691/20000], Step [1], Loss: 9.4643
# Epoch [692/20000], Step [1], Loss: 9.4622
# Epoch [693/20000], Step [1], Loss: 9.4601
# Epoch [694/20000], Step [1], Loss: 9.4580
# Epoch [695/20000], Step [1], Loss: 9.4559
# Epoch [696/20000], Step [1], Loss: 9.4538
# Epoch [697/20000], Step [1], Loss: 9.4517
# Epoch [698/20000], Step [1], Loss: 9.4496
# Epoch [699/20000], Step [1], Loss: 9.4475
# Epoch [700/20000], Step [1], Loss: 9.4454
# Epoch [701/20000], Step [1], Loss: 9.4434
# Epoch [702/20000], Step [1], Loss: 9.4413
# Epoch [703/20000], Step [1], Loss: 9.4392
# Epoch [704/20000], Step [1], Loss: 9.4371
# Epoch [705/20000], Step [1], Loss: 9.4350
# Epoch [706/20000], Step [1], Loss: 9.4329
# Epoch [707/20000], Step [1], Loss: 9.4308
# Epoch [708/20000], Step [1], Loss: 9.4287
# Epoch [709/20000], Step [1], Loss: 9.4267
# Epoch [710/20000], Step [1], Loss: 9.4246
# Epoch [711/20000], Step [1], Loss: 9.4225
# Epoch [712/20000], Step [1], Loss: 9.4204
# Epoch [713/20000], Step [1], Loss: 9.4183
# Epoch [714/20000], Step [1], Loss: 9.4162
# Epoch [715/20000], Step [1], Loss: 9.4142
# Epoch [716/20000], Step [1], Loss: 9.4121
# Epoch [717/20000], Step [1], Loss: 9.4100
# Epoch [718/20000], Step [1], Loss: 9.4079
# Epoch [719/20000], Step [1], Loss: 9.4058
# Epoch [720/20000], Step [1], Loss: 9.4037
# Epoch [721/20000], Step [1], Loss: 9.4017
# Epoch [722/20000], Step [1], Loss: 9.3996
# Epoch [723/20000], Step [1], Loss: 9.3975
# Epoch [724/20000], Step [1], Loss: 9.3954
# Epoch [725/20000], Step [1], Loss: 9.3934
# Epoch [726/20000], Step [1], Loss: 9.3913
# Epoch [727/20000], Step [1], Loss: 9.3892
# Epoch [728/20000], Step [1], Loss: 9.3871
# Epoch [729/20000], Step [1], Loss: 9.3850
# Epoch [730/20000], Step [1], Loss: 9.3830
# Epoch [731/20000], Step [1], Loss: 9.3809
# Epoch [732/20000], Step [1], Loss: 9.3788
# Epoch [733/20000], Step [1], Loss: 9.3767
# Epoch [734/20000], Step [1], Loss: 9.3747
# Epoch [735/20000], Step [1], Loss: 9.3726
# Epoch [736/20000], Step [1], Loss: 9.3705
# Epoch [737/20000], Step [1], Loss: 9.3685
# Epoch [738/20000], Step [1], Loss: 9.3664
# Epoch [739/20000], Step [1], Loss: 9.3643
# Epoch [740/20000], Step [1], Loss: 9.3622
# Epoch [741/20000], Step [1], Loss: 9.3602
# Epoch [742/20000], Step [1], Loss: 9.3581
# Epoch [743/20000], Step [1], Loss: 9.3560
# Epoch [744/20000], Step [1], Loss: 9.3540
# Epoch [745/20000], Step [1], Loss: 9.3519
# Epoch [746/20000], Step [1], Loss: 9.3498
# Epoch [747/20000], Step [1], Loss: 9.3478
# Epoch [748/20000], Step [1], Loss: 9.3457
# Epoch [749/20000], Step [1], Loss: 9.3436
# Epoch [750/20000], Step [1], Loss: 9.3416
# Epoch [751/20000], Step [1], Loss: 9.3395
# Epoch [752/20000], Step [1], Loss: 9.3374
# Epoch [753/20000], Step [1], Loss: 9.3354
# Epoch [754/20000], Step [1], Loss: 9.3333
# Epoch [755/20000], Step [1], Loss: 9.3312
# Epoch [756/20000], Step [1], Loss: 9.3292
# Epoch [757/20000], Step [1], Loss: 9.3271
# Epoch [758/20000], Step [1], Loss: 9.3251
# Epoch [759/20000], Step [1], Loss: 9.3230
# Epoch [760/20000], Step [1], Loss: 9.3209
# Epoch [761/20000], Step [1], Loss: 9.3189
# Epoch [762/20000], Step [1], Loss: 9.3168
# Epoch [763/20000], Step [1], Loss: 9.3147
# Epoch [764/20000], Step [1], Loss: 9.3127
# Epoch [765/20000], Step [1], Loss: 9.3106
# Epoch [766/20000], Step [1], Loss: 9.3086
# Epoch [767/20000], Step [1], Loss: 9.3065
# Epoch [768/20000], Step [1], Loss: 9.3045
# Epoch [769/20000], Step [1], Loss: 9.3024
# Epoch [770/20000], Step [1], Loss: 9.3003
# Epoch [771/20000], Step [1], Loss: 9.2983
# Epoch [772/20000], Step [1], Loss: 9.2962
# Epoch [773/20000], Step [1], Loss: 9.2942
# Epoch [774/20000], Step [1], Loss: 9.2921
# Epoch [775/20000], Step [1], Loss: 9.2901
# Epoch [776/20000], Step [1], Loss: 9.2880
# Epoch [777/20000], Step [1], Loss: 9.2860
# Epoch [778/20000], Step [1], Loss: 9.2839
# Epoch [779/20000], Step [1], Loss: 9.2818
# Epoch [780/20000], Step [1], Loss: 9.2798
# Epoch [781/20000], Step [1], Loss: 9.2777
# Epoch [782/20000], Step [1], Loss: 9.2757
# Epoch [783/20000], Step [1], Loss: 9.2736
# Epoch [784/20000], Step [1], Loss: 9.2716
# Epoch [785/20000], Step [1], Loss: 9.2695
# Epoch [786/20000], Step [1], Loss: 9.2675
# Epoch [787/20000], Step [1], Loss: 9.2654
# Epoch [788/20000], Step [1], Loss: 9.2634
# Epoch [789/20000], Step [1], Loss: 9.2614
# Epoch [790/20000], Step [1], Loss: 9.2593
# Epoch [791/20000], Step [1], Loss: 9.2572
# Epoch [792/20000], Step [1], Loss: 9.2552
# Epoch [793/20000], Step [1], Loss: 9.2532
# Epoch [794/20000], Step [1], Loss: 9.2511
# Epoch [795/20000], Step [1], Loss: 9.2491
# Epoch [796/20000], Step [1], Loss: 9.2470
# Epoch [797/20000], Step [1], Loss: 9.2450
# Epoch [798/20000], Step [1], Loss: 9.2429
# Epoch [799/20000], Step [1], Loss: 9.2409
# Epoch [800/20000], Step [1], Loss: 9.2389
# Epoch [801/20000], Step [1], Loss: 9.2368
# Epoch [802/20000], Step [1], Loss: 9.2348
# Epoch [803/20000], Step [1], Loss: 9.2327
# Epoch [804/20000], Step [1], Loss: 9.2307
# Epoch [805/20000], Step [1], Loss: 9.2286
# Epoch [806/20000], Step [1], Loss: 9.2266
# Epoch [807/20000], Step [1], Loss: 9.2246
# Epoch [808/20000], Step [1], Loss: 9.2225
# Epoch [809/20000], Step [1], Loss: 9.2205
# Epoch [810/20000], Step [1], Loss: 9.2185
# Epoch [811/20000], Step [1], Loss: 9.2164
# Epoch [812/20000], Step [1], Loss: 9.2144
# Epoch [813/20000], Step [1], Loss: 9.2123
# Epoch [814/20000], Step [1], Loss: 9.2103
# Epoch [815/20000], Step [1], Loss: 9.2083
# Epoch [816/20000], Step [1], Loss: 9.2062
# Epoch [817/20000], Step [1], Loss: 9.2042
# Epoch [818/20000], Step [1], Loss: 9.2022
# Epoch [819/20000], Step [1], Loss: 9.2001
# Epoch [820/20000], Step [1], Loss: 9.1981
# Epoch [821/20000], Step [1], Loss: 9.1961
# Epoch [822/20000], Step [1], Loss: 9.1940
# Epoch [823/20000], Step [1], Loss: 9.1920
# Epoch [824/20000], Step [1], Loss: 9.1900
# Epoch [825/20000], Step [1], Loss: 9.1879
# Epoch [826/20000], Step [1], Loss: 9.1859
# Epoch [827/20000], Step [1], Loss: 9.1839
# Epoch [828/20000], Step [1], Loss: 9.1818
# Epoch [829/20000], Step [1], Loss: 9.1798
# Epoch [830/20000], Step [1], Loss: 9.1778
# Epoch [831/20000], Step [1], Loss: 9.1758
# Epoch [832/20000], Step [1], Loss: 9.1737
# Epoch [833/20000], Step [1], Loss: 9.1717
# Epoch [834/20000], Step [1], Loss: 9.1697
# Epoch [835/20000], Step [1], Loss: 9.1677
# Epoch [836/20000], Step [1], Loss: 9.1656
# Epoch [837/20000], Step [1], Loss: 9.1636
# Epoch [838/20000], Step [1], Loss: 9.1616
# Epoch [839/20000], Step [1], Loss: 9.1595
# Epoch [840/20000], Step [1], Loss: 9.1575
# Epoch [841/20000], Step [1], Loss: 9.1555
# Epoch [842/20000], Step [1], Loss: 9.1535
# Epoch [843/20000], Step [1], Loss: 9.1515
# Epoch [844/20000], Step [1], Loss: 9.1494
# Epoch [845/20000], Step [1], Loss: 9.1474
# Epoch [846/20000], Step [1], Loss: 9.1454
# Epoch [847/20000], Step [1], Loss: 9.1434
# Epoch [848/20000], Step [1], Loss: 9.1413
# Epoch [849/20000], Step [1], Loss: 9.1393
# Epoch [850/20000], Step [1], Loss: 9.1373
# Epoch [851/20000], Step [1], Loss: 9.1353
# Epoch [852/20000], Step [1], Loss: 9.1333
# Epoch [853/20000], Step [1], Loss: 9.1312
# Epoch [854/20000], Step [1], Loss: 9.1292
# Epoch [855/20000], Step [1], Loss: 9.1272
# Epoch [856/20000], Step [1], Loss: 9.1252
# Epoch [857/20000], Step [1], Loss: 9.1232
# Epoch [858/20000], Step [1], Loss: 9.1212
# Epoch [859/20000], Step [1], Loss: 9.1191
# Epoch [860/20000], Step [1], Loss: 9.1171
# Epoch [861/20000], Step [1], Loss: 9.1151
# Epoch [862/20000], Step [1], Loss: 9.1131
# Epoch [863/20000], Step [1], Loss: 9.1111
# Epoch [864/20000], Step [1], Loss: 9.1091
# Epoch [865/20000], Step [1], Loss: 9.1071
# Epoch [866/20000], Step [1], Loss: 9.1050
# Epoch [867/20000], Step [1], Loss: 9.1030
# Epoch [868/20000], Step [1], Loss: 9.1010
# Epoch [869/20000], Step [1], Loss: 9.0990
# Epoch [870/20000], Step [1], Loss: 9.0970
# Epoch [871/20000], Step [1], Loss: 9.0950
# Epoch [872/20000], Step [1], Loss: 9.0930
# Epoch [873/20000], Step [1], Loss: 9.0910
# Epoch [874/20000], Step [1], Loss: 9.0890
# Epoch [875/20000], Step [1], Loss: 9.0870
# Epoch [876/20000], Step [1], Loss: 9.0849
# Epoch [877/20000], Step [1], Loss: 9.0829
# Epoch [878/20000], Step [1], Loss: 9.0809
# Epoch [879/20000], Step [1], Loss: 9.0789
# Epoch [880/20000], Step [1], Loss: 9.0769
# Epoch [881/20000], Step [1], Loss: 9.0749
# Epoch [882/20000], Step [1], Loss: 9.0729
# Epoch [883/20000], Step [1], Loss: 9.0709
# Epoch [884/20000], Step [1], Loss: 9.0689
# Epoch [885/20000], Step [1], Loss: 9.0669
# Epoch [886/20000], Step [1], Loss: 9.0649
# Epoch [887/20000], Step [1], Loss: 9.0629
# Epoch [888/20000], Step [1], Loss: 9.0609
# Epoch [889/20000], Step [1], Loss: 9.0589
# Epoch [890/20000], Step [1], Loss: 9.0569
# Epoch [891/20000], Step [1], Loss: 9.0549
# Epoch [892/20000], Step [1], Loss: 9.0529
# Epoch [893/20000], Step [1], Loss: 9.0509
# Epoch [894/20000], Step [1], Loss: 9.0489
# Epoch [895/20000], Step [1], Loss: 9.0469
# Epoch [896/20000], Step [1], Loss: 9.0449
# Epoch [897/20000], Step [1], Loss: 9.0429
# Epoch [898/20000], Step [1], Loss: 9.0409
# Epoch [899/20000], Step [1], Loss: 9.0389
# Epoch [900/20000], Step [1], Loss: 9.0369
# Epoch [901/20000], Step [1], Loss: 9.0349
# Epoch [902/20000], Step [1], Loss: 9.0329
# Epoch [903/20000], Step [1], Loss: 9.0309
# Epoch [904/20000], Step [1], Loss: 9.0289
# Epoch [905/20000], Step [1], Loss: 9.0269
# Epoch [906/20000], Step [1], Loss: 9.0249
# Epoch [907/20000], Step [1], Loss: 9.0229
# Epoch [908/20000], Step [1], Loss: 9.0209
# Epoch [909/20000], Step [1], Loss: 9.0189
# Epoch [910/20000], Step [1], Loss: 9.0169
# Epoch [911/20000], Step [1], Loss: 9.0150
# Epoch [912/20000], Step [1], Loss: 9.0130
# Epoch [913/20000], Step [1], Loss: 9.0110
# Epoch [914/20000], Step [1], Loss: 9.0090
# Epoch [915/20000], Step [1], Loss: 9.0070
# Epoch [916/20000], Step [1], Loss: 9.0050
# Epoch [917/20000], Step [1], Loss: 9.0030
# Epoch [918/20000], Step [1], Loss: 9.0010
# Epoch [919/20000], Step [1], Loss: 8.9990
# Epoch [920/20000], Step [1], Loss: 8.9971
# Epoch [921/20000], Step [1], Loss: 8.9951
# Epoch [922/20000], Step [1], Loss: 8.9931
# Epoch [923/20000], Step [1], Loss: 8.9911
# Epoch [924/20000], Step [1], Loss: 8.9891
# Epoch [925/20000], Step [1], Loss: 8.9871
# Epoch [926/20000], Step [1], Loss: 8.9851
# Epoch [927/20000], Step [1], Loss: 8.9831
# Epoch [928/20000], Step [1], Loss: 8.9812
# Epoch [929/20000], Step [1], Loss: 8.9792
# Epoch [930/20000], Step [1], Loss: 8.9772
# Epoch [931/20000], Step [1], Loss: 8.9752
# Epoch [932/20000], Step [1], Loss: 8.9732
# Epoch [933/20000], Step [1], Loss: 8.9712
# Epoch [934/20000], Step [1], Loss: 8.9693
# Epoch [935/20000], Step [1], Loss: 8.9673
# Epoch [936/20000], Step [1], Loss: 8.9653
# Epoch [937/20000], Step [1], Loss: 8.9633
# Epoch [938/20000], Step [1], Loss: 8.9613
# Epoch [939/20000], Step [1], Loss: 8.9594
# Epoch [940/20000], Step [1], Loss: 8.9574
# Epoch [941/20000], Step [1], Loss: 8.9554
# Epoch [942/20000], Step [1], Loss: 8.9534
# Epoch [943/20000], Step [1], Loss: 8.9515
# Epoch [944/20000], Step [1], Loss: 8.9495
# Epoch [945/20000], Step [1], Loss: 8.9475
# Epoch [946/20000], Step [1], Loss: 8.9455
# Epoch [947/20000], Step [1], Loss: 8.9435
# Epoch [948/20000], Step [1], Loss: 8.9416
# Epoch [949/20000], Step [1], Loss: 8.9396
# Epoch [950/20000], Step [1], Loss: 8.9376
# Epoch [951/20000], Step [1], Loss: 8.9356
# Epoch [952/20000], Step [1], Loss: 8.9337
# Epoch [953/20000], Step [1], Loss: 8.9317
# Epoch [954/20000], Step [1], Loss: 8.9297
# Epoch [955/20000], Step [1], Loss: 8.9277
# Epoch [956/20000], Step [1], Loss: 8.9258
# Epoch [957/20000], Step [1], Loss: 8.9238
# Epoch [958/20000], Step [1], Loss: 8.9218
# Epoch [959/20000], Step [1], Loss: 8.9199
# Epoch [960/20000], Step [1], Loss: 8.9179
# Epoch [961/20000], Step [1], Loss: 8.9159
# Epoch [962/20000], Step [1], Loss: 8.9140
# Epoch [963/20000], Step [1], Loss: 8.9120
# Epoch [964/20000], Step [1], Loss: 8.9100
# Epoch [965/20000], Step [1], Loss: 8.9080
# Epoch [966/20000], Step [1], Loss: 8.9061
# Epoch [967/20000], Step [1], Loss: 8.9041
# Epoch [968/20000], Step [1], Loss: 8.9022
# Epoch [969/20000], Step [1], Loss: 8.9002
# Epoch [970/20000], Step [1], Loss: 8.8982
# Epoch [971/20000], Step [1], Loss: 8.8963
# Epoch [972/20000], Step [1], Loss: 8.8943
# Epoch [973/20000], Step [1], Loss: 8.8923
# Epoch [974/20000], Step [1], Loss: 8.8904
# Epoch [975/20000], Step [1], Loss: 8.8884
# Epoch [976/20000], Step [1], Loss: 8.8864
# Epoch [977/20000], Step [1], Loss: 8.8845
# Epoch [978/20000], Step [1], Loss: 8.8825
# Epoch [979/20000], Step [1], Loss: 8.8805
# Epoch [980/20000], Step [1], Loss: 8.8786
# Epoch [981/20000], Step [1], Loss: 8.8766
# Epoch [982/20000], Step [1], Loss: 8.8747
# Epoch [983/20000], Step [1], Loss: 8.8727
# Epoch [984/20000], Step [1], Loss: 8.8707
# Epoch [985/20000], Step [1], Loss: 8.8688
# Epoch [986/20000], Step [1], Loss: 8.8668
# Epoch [987/20000], Step [1], Loss: 8.8649
# Epoch [988/20000], Step [1], Loss: 8.8629
# Epoch [989/20000], Step [1], Loss: 8.8610
# Epoch [990/20000], Step [1], Loss: 8.8590
# Epoch [991/20000], Step [1], Loss: 8.8570
# Epoch [992/20000], Step [1], Loss: 8.8551
# Epoch [993/20000], Step [1], Loss: 8.8531
# Epoch [994/20000], Step [1], Loss: 8.8512
# Epoch [995/20000], Step [1], Loss: 8.8492
# Epoch [996/20000], Step [1], Loss: 8.8473
# Epoch [997/20000], Step [1], Loss: 8.8453
# Epoch [998/20000], Step [1], Loss: 8.8434
# Epoch [999/20000], Step [1], Loss: 8.8414
# Epoch [1000/20000], Step [1], Loss: 8.8394
# Epoch [1001/20000], Step [1], Loss: 8.8375
# Epoch [1002/20000], Step [1], Loss: 8.8355
# Epoch [1003/20000], Step [1], Loss: 8.8336
# Epoch [1004/20000], Step [1], Loss: 8.8317
# Epoch [1005/20000], Step [1], Loss: 8.8297
# Epoch [1006/20000], Step [1], Loss: 8.8277
# Epoch [1007/20000], Step [1], Loss: 8.8258
# Epoch [1008/20000], Step [1], Loss: 8.8238
# Epoch [1009/20000], Step [1], Loss: 8.8219
# Epoch [1010/20000], Step [1], Loss: 8.8200
# Epoch [1011/20000], Step [1], Loss: 8.8180
# Epoch [1012/20000], Step [1], Loss: 8.8161
# Epoch [1013/20000], Step [1], Loss: 8.8141
# Epoch [1014/20000], Step [1], Loss: 8.8122
# Epoch [1015/20000], Step [1], Loss: 8.8102
# Epoch [1016/20000], Step [1], Loss: 8.8083
# Epoch [1017/20000], Step [1], Loss: 8.8063
# Epoch [1018/20000], Step [1], Loss: 8.8044
# Epoch [1019/20000], Step [1], Loss: 8.8024
# Epoch [1020/20000], Step [1], Loss: 8.8005
# Epoch [1021/20000], Step [1], Loss: 8.7985
# Epoch [1022/20000], Step [1], Loss: 8.7966
# Epoch [1023/20000], Step [1], Loss: 8.7947
# Epoch [1024/20000], Step [1], Loss: 8.7927
# Epoch [1025/20000], Step [1], Loss: 8.7908
# Epoch [1026/20000], Step [1], Loss: 8.7888
# Epoch [1027/20000], Step [1], Loss: 8.7869
# Epoch [1028/20000], Step [1], Loss: 8.7850
# Epoch [1029/20000], Step [1], Loss: 8.7830
# Epoch [1030/20000], Step [1], Loss: 8.7811
# Epoch [1031/20000], Step [1], Loss: 8.7791
# Epoch [1032/20000], Step [1], Loss: 8.7772
# Epoch [1033/20000], Step [1], Loss: 8.7753
# Epoch [1034/20000], Step [1], Loss: 8.7733
# Epoch [1035/20000], Step [1], Loss: 8.7714
# Epoch [1036/20000], Step [1], Loss: 8.7695
# Epoch [1037/20000], Step [1], Loss: 8.7675
# Epoch [1038/20000], Step [1], Loss: 8.7656
# Epoch [1039/20000], Step [1], Loss: 8.7636
# Epoch [1040/20000], Step [1], Loss: 8.7617
# Epoch [1041/20000], Step [1], Loss: 8.7598
# Epoch [1042/20000], Step [1], Loss: 8.7578
# Epoch [1043/20000], Step [1], Loss: 8.7559
# Epoch [1044/20000], Step [1], Loss: 8.7540
# Epoch [1045/20000], Step [1], Loss: 8.7520
# Epoch [1046/20000], Step [1], Loss: 8.7501
# Epoch [1047/20000], Step [1], Loss: 8.7482
# Epoch [1048/20000], Step [1], Loss: 8.7462
# Epoch [1049/20000], Step [1], Loss: 8.7443
# Epoch [1050/20000], Step [1], Loss: 8.7424
# Epoch [1051/20000], Step [1], Loss: 8.7405
# Epoch [1052/20000], Step [1], Loss: 8.7385
# Epoch [1053/20000], Step [1], Loss: 8.7366
# Epoch [1054/20000], Step [1], Loss: 8.7347
# Epoch [1055/20000], Step [1], Loss: 8.7327
# Epoch [1056/20000], Step [1], Loss: 8.7308
# Epoch [1057/20000], Step [1], Loss: 8.7289
# Epoch [1058/20000], Step [1], Loss: 8.7270
# Epoch [1059/20000], Step [1], Loss: 8.7250
# Epoch [1060/20000], Step [1], Loss: 8.7231
# Epoch [1061/20000], Step [1], Loss: 8.7212
# Epoch [1062/20000], Step [1], Loss: 8.7193
# Epoch [1063/20000], Step [1], Loss: 8.7173
# Epoch [1064/20000], Step [1], Loss: 8.7154
# Epoch [1065/20000], Step [1], Loss: 8.7135
# Epoch [1066/20000], Step [1], Loss: 8.7116
# Epoch [1067/20000], Step [1], Loss: 8.7096
# Epoch [1068/20000], Step [1], Loss: 8.7077
# Epoch [1069/20000], Step [1], Loss: 8.7058
# Epoch [1070/20000], Step [1], Loss: 8.7039
# Epoch [1071/20000], Step [1], Loss: 8.7019
# Epoch [1072/20000], Step [1], Loss: 8.7000
# Epoch [1073/20000], Step [1], Loss: 8.6981
# Epoch [1074/20000], Step [1], Loss: 8.6962
# Epoch [1075/20000], Step [1], Loss: 8.6943
# Epoch [1076/20000], Step [1], Loss: 8.6923
# Epoch [1077/20000], Step [1], Loss: 8.6904
# Epoch [1078/20000], Step [1], Loss: 8.6885
# Epoch [1079/20000], Step [1], Loss: 8.6866
# Epoch [1080/20000], Step [1], Loss: 8.6847
# Epoch [1081/20000], Step [1], Loss: 8.6828
# Epoch [1082/20000], Step [1], Loss: 8.6808
# Epoch [1083/20000], Step [1], Loss: 8.6789
# Epoch [1084/20000], Step [1], Loss: 8.6770
# Epoch [1085/20000], Step [1], Loss: 8.6751
# Epoch [1086/20000], Step [1], Loss: 8.6732
# Epoch [1087/20000], Step [1], Loss: 8.6713
# Epoch [1088/20000], Step [1], Loss: 8.6693
# Epoch [1089/20000], Step [1], Loss: 8.6674
# Epoch [1090/20000], Step [1], Loss: 8.6655
# Epoch [1091/20000], Step [1], Loss: 8.6636
# Epoch [1092/20000], Step [1], Loss: 8.6617
# Epoch [1093/20000], Step [1], Loss: 8.6598
# Epoch [1094/20000], Step [1], Loss: 8.6579
# Epoch [1095/20000], Step [1], Loss: 8.6560
# Epoch [1096/20000], Step [1], Loss: 8.6540
# Epoch [1097/20000], Step [1], Loss: 8.6521
# Epoch [1098/20000], Step [1], Loss: 8.6502
# Epoch [1099/20000], Step [1], Loss: 8.6483
# Epoch [1100/20000], Step [1], Loss: 8.6464
# ...
# Epoch [19638/20000], Step [1], Loss: 0.1973
# Epoch [19639/20000], Step [1], Loss: 0.1973
# Epoch [19640/20000], Step [1], Loss: 0.1973
# Epoch [19641/20000], Step [1], Loss: 0.1972
# Epoch [19642/20000], Step [1], Loss: 0.1972
# Epoch [19643/20000], Step [1], Loss: 0.1971
# Epoch [19644/20000], Step [1], Loss: 0.1971
# Epoch [19645/20000], Step [1], Loss: 0.1971
# Epoch [19646/20000], Step [1], Loss: 0.1970
# Epoch [19647/20000], Step [1], Loss: 0.1970
# Epoch [19648/20000], Step [1], Loss: 0.1970
# Epoch [19649/20000], Step [1], Loss: 0.1969
# Epoch [19650/20000], Step [1], Loss: 0.1969
# Epoch [19651/20000], Step [1], Loss: 0.1969
# Epoch [19652/20000], Step [1], Loss: 0.1968
# Epoch [19653/20000], Step [1], Loss: 0.1968
# Epoch [19654/20000], Step [1], Loss: 0.1968
# Epoch [19655/20000], Step [1], Loss: 0.1967
# Epoch [19656/20000], Step [1], Loss: 0.1967
# Epoch [19657/20000], Step [1], Loss: 0.1967
# Epoch [19658/20000], Step [1], Loss: 0.1966
# Epoch [19659/20000], Step [1], Loss: 0.1966
# Epoch [19660/20000], Step [1], Loss: 0.1965
# Epoch [19661/20000], Step [1], Loss: 0.1965
# Epoch [19662/20000], Step [1], Loss: 0.1965
# Epoch [19663/20000], Step [1], Loss: 0.1964
# Epoch [19664/20000], Step [1], Loss: 0.1964
# Epoch [19665/20000], Step [1], Loss: 0.1964
# Epoch [19666/20000], Step [1], Loss: 0.1963
# Epoch [19667/20000], Step [1], Loss: 0.1963
# Epoch [19668/20000], Step [1], Loss: 0.1963
# Epoch [19669/20000], Step [1], Loss: 0.1962
# Epoch [19670/20000], Step [1], Loss: 0.1962
# Epoch [19671/20000], Step [1], Loss: 0.1962
# Epoch [19672/20000], Step [1], Loss: 0.1962
# Epoch [19673/20000], Step [1], Loss: 0.1961
# Epoch [19674/20000], Step [1], Loss: 0.1961
# Epoch [19675/20000], Step [1], Loss: 0.1961
# Epoch [19676/20000], Step [1], Loss: 0.1961
# Epoch [19677/20000], Step [1], Loss: 0.1961
# Epoch [19678/20000], Step [1], Loss: 0.1961
# Epoch [19679/20000], Step [1], Loss: 0.1960
# Epoch [19680/20000], Step [1], Loss: 0.1960
# Epoch [19681/20000], Step [1], Loss: 0.1959
# Epoch [19682/20000], Step [1], Loss: 0.1958
# Epoch [19683/20000], Step [1], Loss: 0.1958
# Epoch [19684/20000], Step [1], Loss: 0.1957
# Epoch [19685/20000], Step [1], Loss: 0.1957
# Epoch [19686/20000], Step [1], Loss: 0.1957
# Epoch [19687/20000], Step [1], Loss: 0.1957
# Epoch [19688/20000], Step [1], Loss: 0.1956
# Epoch [19689/20000], Step [1], Loss: 0.1956
# Epoch [19690/20000], Step [1], Loss: 0.1955
# Epoch [19691/20000], Step [1], Loss: 0.1955
# Epoch [19692/20000], Step [1], Loss: 0.1954
# Epoch [19693/20000], Step [1], Loss: 0.1954
# Epoch [19694/20000], Step [1], Loss: 0.1954
# Epoch [19695/20000], Step [1], Loss: 0.1953
# Epoch [19696/20000], Step [1], Loss: 0.1953
# Epoch [19697/20000], Step [1], Loss: 0.1953
# Epoch [19698/20000], Step [1], Loss: 0.1952
# Epoch [19699/20000], Step [1], Loss: 0.1952
# Epoch [19700/20000], Step [1], Loss: 0.1952
# Epoch [19701/20000], Step [1], Loss: 0.1951
# Epoch [19702/20000], Step [1], Loss: 0.1951
# Epoch [19703/20000], Step [1], Loss: 0.1951
# Epoch [19704/20000], Step [1], Loss: 0.1950
# Epoch [19705/20000], Step [1], Loss: 0.1950
# Epoch [19706/20000], Step [1], Loss: 0.1949
# Epoch [19707/20000], Step [1], Loss: 0.1949
# Epoch [19708/20000], Step [1], Loss: 0.1949
# Epoch [19709/20000], Step [1], Loss: 0.1948
# Epoch [19710/20000], Step [1], Loss: 0.1948
# Epoch [19711/20000], Step [1], Loss: 0.1948
# Epoch [19712/20000], Step [1], Loss: 0.1947
# Epoch [19713/20000], Step [1], Loss: 0.1947
# Epoch [19714/20000], Step [1], Loss: 0.1947
# Epoch [19715/20000], Step [1], Loss: 0.1946
# Epoch [19716/20000], Step [1], Loss: 0.1946
# Epoch [19717/20000], Step [1], Loss: 0.1946
# Epoch [19718/20000], Step [1], Loss: 0.1945
# Epoch [19719/20000], Step [1], Loss: 0.1945
# Epoch [19720/20000], Step [1], Loss: 0.1945
# Epoch [19721/20000], Step [1], Loss: 0.1944
# Epoch [19722/20000], Step [1], Loss: 0.1944
# Epoch [19723/20000], Step [1], Loss: 0.1943
# Epoch [19724/20000], Step [1], Loss: 0.1943
# Epoch [19725/20000], Step [1], Loss: 0.1943
# Epoch [19726/20000], Step [1], Loss: 0.1942
# Epoch [19727/20000], Step [1], Loss: 0.1942
# Epoch [19728/20000], Step [1], Loss: 0.1942
# Epoch [19729/20000], Step [1], Loss: 0.1941
# Epoch [19730/20000], Step [1], Loss: 0.1941
# Epoch [19731/20000], Step [1], Loss: 0.1941
# Epoch [19732/20000], Step [1], Loss: 0.1940
# Epoch [19733/20000], Step [1], Loss: 0.1940
# Epoch [19734/20000], Step [1], Loss: 0.1940
# Epoch [19735/20000], Step [1], Loss: 0.1939
# Epoch [19736/20000], Step [1], Loss: 0.1939
# Epoch [19737/20000], Step [1], Loss: 0.1939
# Epoch [19738/20000], Step [1], Loss: 0.1939
# Epoch [19739/20000], Step [1], Loss: 0.1939
# Epoch [19740/20000], Step [1], Loss: 0.1939
# Epoch [19741/20000], Step [1], Loss: 0.1940
# Epoch [19742/20000], Step [1], Loss: 0.1940
# Epoch [19743/20000], Step [1], Loss: 0.1940
# Epoch [19744/20000], Step [1], Loss: 0.1939
# Epoch [19745/20000], Step [1], Loss: 0.1938
# Epoch [19746/20000], Step [1], Loss: 0.1936
# Epoch [19747/20000], Step [1], Loss: 0.1935
# Epoch [19748/20000], Step [1], Loss: 0.1936
# Epoch [19749/20000], Step [1], Loss: 0.1936
# Epoch [19750/20000], Step [1], Loss: 0.1935
# Epoch [19751/20000], Step [1], Loss: 0.1934
# Epoch [19752/20000], Step [1], Loss: 0.1934
# Epoch [19753/20000], Step [1], Loss: 0.1933
# Epoch [19754/20000], Step [1], Loss: 0.1933
# Epoch [19755/20000], Step [1], Loss: 0.1933
# Epoch [19756/20000], Step [1], Loss: 0.1933
# Epoch [19757/20000], Step [1], Loss: 0.1932
# Epoch [19758/20000], Step [1], Loss: 0.1932
# Epoch [19759/20000], Step [1], Loss: 0.1931
# Epoch [19760/20000], Step [1], Loss: 0.1931
# Epoch [19761/20000], Step [1], Loss: 0.1931
# Epoch [19762/20000], Step [1], Loss: 0.1930
# Epoch [19763/20000], Step [1], Loss: 0.1930
# Epoch [19764/20000], Step [1], Loss: 0.1930
# Epoch [19765/20000], Step [1], Loss: 0.1929
# Epoch [19766/20000], Step [1], Loss: 0.1929
# Epoch [19767/20000], Step [1], Loss: 0.1928
# Epoch [19768/20000], Step [1], Loss: 0.1928
# Epoch [19769/20000], Step [1], Loss: 0.1928
# Epoch [19770/20000], Step [1], Loss: 0.1927
# Epoch [19771/20000], Step [1], Loss: 0.1927
# Epoch [19772/20000], Step [1], Loss: 0.1927
# Epoch [19773/20000], Step [1], Loss: 0.1926
# Epoch [19774/20000], Step [1], Loss: 0.1926
# Epoch [19775/20000], Step [1], Loss: 0.1926
# Epoch [19776/20000], Step [1], Loss: 0.1925
# Epoch [19777/20000], Step [1], Loss: 0.1925
# Epoch [19778/20000], Step [1], Loss: 0.1925
# Epoch [19779/20000], Step [1], Loss: 0.1924
# Epoch [19780/20000], Step [1], Loss: 0.1924
# Epoch [19781/20000], Step [1], Loss: 0.1924
# Epoch [19782/20000], Step [1], Loss: 0.1923
# Epoch [19783/20000], Step [1], Loss: 0.1923
# Epoch [19784/20000], Step [1], Loss: 0.1923
# Epoch [19785/20000], Step [1], Loss: 0.1922
# Epoch [19786/20000], Step [1], Loss: 0.1922
# Epoch [19787/20000], Step [1], Loss: 0.1922
# Epoch [19788/20000], Step [1], Loss: 0.1921
# Epoch [19789/20000], Step [1], Loss: 0.1921
# Epoch [19790/20000], Step [1], Loss: 0.1920
# Epoch [19791/20000], Step [1], Loss: 0.1920
# Epoch [19792/20000], Step [1], Loss: 0.1920
# Epoch [19793/20000], Step [1], Loss: 0.1919
# Epoch [19794/20000], Step [1], Loss: 0.1919
# Epoch [19795/20000], Step [1], Loss: 0.1919
# Epoch [19796/20000], Step [1], Loss: 0.1918
# Epoch [19797/20000], Step [1], Loss: 0.1918
# Epoch [19798/20000], Step [1], Loss: 0.1918
# Epoch [19799/20000], Step [1], Loss: 0.1917
# Epoch [19800/20000], Step [1], Loss: 0.1917
# Epoch [19801/20000], Step [1], Loss: 0.1917
# Epoch [19802/20000], Step [1], Loss: 0.1916
# Epoch [19803/20000], Step [1], Loss: 0.1916
# Epoch [19804/20000], Step [1], Loss: 0.1916
# Epoch [19805/20000], Step [1], Loss: 0.1915
# Epoch [19806/20000], Step [1], Loss: 0.1915
# Epoch [19807/20000], Step [1], Loss: 0.1915
# Epoch [19808/20000], Step [1], Loss: 0.1914
# Epoch [19809/20000], Step [1], Loss: 0.1914
# Epoch [19810/20000], Step [1], Loss: 0.1914
# Epoch [19811/20000], Step [1], Loss: 0.1913
# Epoch [19812/20000], Step [1], Loss: 0.1913
# Epoch [19813/20000], Step [1], Loss: 0.1913
# Epoch [19814/20000], Step [1], Loss: 0.1912
# Epoch [19815/20000], Step [1], Loss: 0.1912
# Epoch [19816/20000], Step [1], Loss: 0.1912
# Epoch [19817/20000], Step [1], Loss: 0.1911
# Epoch [19818/20000], Step [1], Loss: 0.1911
# Epoch [19819/20000], Step [1], Loss: 0.1911
# Epoch [19820/20000], Step [1], Loss: 0.1910
# Epoch [19821/20000], Step [1], Loss: 0.1910
# Epoch [19822/20000], Step [1], Loss: 0.1910
# Epoch [19823/20000], Step [1], Loss: 0.1910
# Epoch [19824/20000], Step [1], Loss: 0.1909
# Epoch [19825/20000], Step [1], Loss: 0.1909
# Epoch [19826/20000], Step [1], Loss: 0.1909
# Epoch [19827/20000], Step [1], Loss: 0.1910
# Epoch [19828/20000], Step [1], Loss: 0.1909
# Epoch [19829/20000], Step [1], Loss: 0.1910
# Epoch [19830/20000], Step [1], Loss: 0.1909
# Epoch [19831/20000], Step [1], Loss: 0.1908
# Epoch [19832/20000], Step [1], Loss: 0.1907
# Epoch [19833/20000], Step [1], Loss: 0.1906
# Epoch [19834/20000], Step [1], Loss: 0.1906
# Epoch [19835/20000], Step [1], Loss: 0.1905
# Epoch [19836/20000], Step [1], Loss: 0.1906
# Epoch [19837/20000], Step [1], Loss: 0.1905
# Epoch [19838/20000], Step [1], Loss: 0.1905
# Epoch [19839/20000], Step [1], Loss: 0.1904
# Epoch [19840/20000], Step [1], Loss: 0.1904
# Epoch [19841/20000], Step [1], Loss: 0.1904
# Epoch [19842/20000], Step [1], Loss: 0.1903
# Epoch [19843/20000], Step [1], Loss: 0.1903
# Epoch [19844/20000], Step [1], Loss: 0.1902
# Epoch [19845/20000], Step [1], Loss: 0.1902
# Epoch [19846/20000], Step [1], Loss: 0.1902
# Epoch [19847/20000], Step [1], Loss: 0.1901
# Epoch [19848/20000], Step [1], Loss: 0.1901
# Epoch [19849/20000], Step [1], Loss: 0.1901
# Epoch [19850/20000], Step [1], Loss: 0.1900
# Epoch [19851/20000], Step [1], Loss: 0.1900
# Epoch [19852/20000], Step [1], Loss: 0.1899
# Epoch [19853/20000], Step [1], Loss: 0.1899
# Epoch [19854/20000], Step [1], Loss: 0.1899
# Epoch [19855/20000], Step [1], Loss: 0.1898
# Epoch [19856/20000], Step [1], Loss: 0.1898
# Epoch [19857/20000], Step [1], Loss: 0.1898
# Epoch [19858/20000], Step [1], Loss: 0.1897
# Epoch [19859/20000], Step [1], Loss: 0.1897
# Epoch [19860/20000], Step [1], Loss: 0.1897
# Epoch [19861/20000], Step [1], Loss: 0.1896
# Epoch [19862/20000], Step [1], Loss: 0.1896
# Epoch [19863/20000], Step [1], Loss: 0.1896
# Epoch [19864/20000], Step [1], Loss: 0.1895
# Epoch [19865/20000], Step [1], Loss: 0.1895
# Epoch [19866/20000], Step [1], Loss: 0.1895
# Epoch [19867/20000], Step [1], Loss: 0.1894
# Epoch [19868/20000], Step [1], Loss: 0.1894
# Epoch [19869/20000], Step [1], Loss: 0.1894
# Epoch [19870/20000], Step [1], Loss: 0.1893
# Epoch [19871/20000], Step [1], Loss: 0.1893
# Epoch [19872/20000], Step [1], Loss: 0.1893
# Epoch [19873/20000], Step [1], Loss: 0.1892
# Epoch [19874/20000], Step [1], Loss: 0.1892
# Epoch [19875/20000], Step [1], Loss: 0.1892
# Epoch [19876/20000], Step [1], Loss: 0.1891
# Epoch [19877/20000], Step [1], Loss: 0.1891
# Epoch [19878/20000], Step [1], Loss: 0.1891
# Epoch [19879/20000], Step [1], Loss: 0.1890
# Epoch [19880/20000], Step [1], Loss: 0.1890
# Epoch [19881/20000], Step [1], Loss: 0.1890
# Epoch [19882/20000], Step [1], Loss: 0.1889
# Epoch [19883/20000], Step [1], Loss: 0.1889
# Epoch [19884/20000], Step [1], Loss: 0.1889
# Epoch [19885/20000], Step [1], Loss: 0.1888
# Epoch [19886/20000], Step [1], Loss: 0.1888
# Epoch [19887/20000], Step [1], Loss: 0.1888
# Epoch [19888/20000], Step [1], Loss: 0.1887
# Epoch [19889/20000], Step [1], Loss: 0.1887
# Epoch [19890/20000], Step [1], Loss: 0.1887
# Epoch [19891/20000], Step [1], Loss: 0.1886
# Epoch [19892/20000], Step [1], Loss: 0.1886
# Epoch [19893/20000], Step [1], Loss: 0.1886
# Epoch [19894/20000], Step [1], Loss: 0.1885
# Epoch [19895/20000], Step [1], Loss: 0.1885
# Epoch [19896/20000], Step [1], Loss: 0.1885
# Epoch [19897/20000], Step [1], Loss: 0.1884
# Epoch [19898/20000], Step [1], Loss: 0.1884
# Epoch [19899/20000], Step [1], Loss: 0.1884
# Epoch [19900/20000], Step [1], Loss: 0.1883
# Epoch [19901/20000], Step [1], Loss: 0.1883
# Epoch [19902/20000], Step [1], Loss: 0.1883
# Epoch [19903/20000], Step [1], Loss: 0.1882
# Epoch [19904/20000], Step [1], Loss: 0.1882
# Epoch [19905/20000], Step [1], Loss: 0.1882
# Epoch [19906/20000], Step [1], Loss: 0.1881
# Epoch [19907/20000], Step [1], Loss: 0.1881
# Epoch [19908/20000], Step [1], Loss: 0.1881
# Epoch [19909/20000], Step [1], Loss: 0.1880
# Epoch [19910/20000], Step [1], Loss: 0.1880
# Epoch [19911/20000], Step [1], Loss: 0.1880
# Epoch [19912/20000], Step [1], Loss: 0.1880
# Epoch [19913/20000], Step [1], Loss: 0.1879
# Epoch [19914/20000], Step [1], Loss: 0.1879
# Epoch [19915/20000], Step [1], Loss: 0.1879
# Epoch [19916/20000], Step [1], Loss: 0.1879
# Epoch [19917/20000], Step [1], Loss: 0.1879
# Epoch [19918/20000], Step [1], Loss: 0.1879
# Epoch [19919/20000], Step [1], Loss: 0.1878
# Epoch [19920/20000], Step [1], Loss: 0.1878
# Epoch [19921/20000], Step [1], Loss: 0.1878
# Epoch [19922/20000], Step [1], Loss: 0.1877
# Epoch [19923/20000], Step [1], Loss: 0.1877
# Epoch [19924/20000], Step [1], Loss: 0.1876
# Epoch [19925/20000], Step [1], Loss: 0.1876
# Epoch [19926/20000], Step [1], Loss: 0.1875
# Epoch [19927/20000], Step [1], Loss: 0.1875
# Epoch [19928/20000], Step [1], Loss: 0.1874
# Epoch [19929/20000], Step [1], Loss: 0.1874
# Epoch [19930/20000], Step [1], Loss: 0.1874
# Epoch [19931/20000], Step [1], Loss: 0.1873
# Epoch [19932/20000], Step [1], Loss: 0.1873
# Epoch [19933/20000], Step [1], Loss: 0.1872
# Epoch [19934/20000], Step [1], Loss: 0.1872
# Epoch [19935/20000], Step [1], Loss: 0.1872
# Epoch [19936/20000], Step [1], Loss: 0.1871
# Epoch [19937/20000], Step [1], Loss: 0.1871
# Epoch [19938/20000], Step [1], Loss: 0.1871
# Epoch [19939/20000], Step [1], Loss: 0.1870
# Epoch [19940/20000], Step [1], Loss: 0.1870
# Epoch [19941/20000], Step [1], Loss: 0.1870
# Epoch [19942/20000], Step [1], Loss: 0.1870
# Epoch [19943/20000], Step [1], Loss: 0.1869
# Epoch [19944/20000], Step [1], Loss: 0.1869
# Epoch [19945/20000], Step [1], Loss: 0.1868
# Epoch [19946/20000], Step [1], Loss: 0.1868
# Epoch [19947/20000], Step [1], Loss: 0.1868
# Epoch [19948/20000], Step [1], Loss: 0.1867
# Epoch [19949/20000], Step [1], Loss: 0.1867
# Epoch [19950/20000], Step [1], Loss: 0.1867
# Epoch [19951/20000], Step [1], Loss: 0.1866
# Epoch [19952/20000], Step [1], Loss: 0.1866
# Epoch [19953/20000], Step [1], Loss: 0.1866
# Epoch [19954/20000], Step [1], Loss: 0.1865
# Epoch [19955/20000], Step [1], Loss: 0.1865
# Epoch [19956/20000], Step [1], Loss: 0.1865
# Epoch [19957/20000], Step [1], Loss: 0.1864
# Epoch [19958/20000], Step [1], Loss: 0.1864
# Epoch [19959/20000], Step [1], Loss: 0.1864
# Epoch [19960/20000], Step [1], Loss: 0.1863
# Epoch [19961/20000], Step [1], Loss: 0.1863
# Epoch [19962/20000], Step [1], Loss: 0.1863
# Epoch [19963/20000], Step [1], Loss: 0.1862
# Epoch [19964/20000], Step [1], Loss: 0.1862
# Epoch [19965/20000], Step [1], Loss: 0.1862
# Epoch [19966/20000], Step [1], Loss: 0.1861
# Epoch [19967/20000], Step [1], Loss: 0.1861
# Epoch [19968/20000], Step [1], Loss: 0.1861
# Epoch [19969/20000], Step [1], Loss: 0.1860
# Epoch [19970/20000], Step [1], Loss: 0.1860
# Epoch [19971/20000], Step [1], Loss: 0.1860
# Epoch [19972/20000], Step [1], Loss: 0.1859
# Epoch [19973/20000], Step [1], Loss: 0.1859
# Epoch [19974/20000], Step [1], Loss: 0.1859
# Epoch [19975/20000], Step [1], Loss: 0.1858
# Epoch [19976/20000], Step [1], Loss: 0.1858
# Epoch [19977/20000], Step [1], Loss: 0.1858
# Epoch [19978/20000], Step [1], Loss: 0.1857
# Epoch [19979/20000], Step [1], Loss: 0.1857
# Epoch [19980/20000], Step [1], Loss: 0.1857
# Epoch [19981/20000], Step [1], Loss: 0.1856
# Epoch [19982/20000], Step [1], Loss: 0.1856
# Epoch [19983/20000], Step [1], Loss: 0.1856
# Epoch [19984/20000], Step [1], Loss: 0.1855
# Epoch [19985/20000], Step [1], Loss: 0.1855
# Epoch [19986/20000], Step [1], Loss: 0.1855
# Epoch [19987/20000], Step [1], Loss: 0.1855
# Epoch [19988/20000], Step [1], Loss: 0.1854
# Epoch [19989/20000], Step [1], Loss: 0.1854
# Epoch [19990/20000], Step [1], Loss: 0.1854
# Epoch [19991/20000], Step [1], Loss: 0.1853
# Epoch [19992/20000], Step [1], Loss: 0.1853
# Epoch [19993/20000], Step [1], Loss: 0.1853
# Epoch [19994/20000], Step [1], Loss: 0.1852
# Epoch [19995/20000], Step [1], Loss: 0.1852
# Epoch [19996/20000], Step [1], Loss: 0.1852
# Epoch [19997/20000], Step [1], Loss: 0.1852
# Epoch [19998/20000], Step [1], Loss: 0.1852
# Epoch [19999/20000], Step [1], Loss: 0.1852
# Epoch [20000/20000], Step [1], Loss: 0.1851

# %%
# 测试数据生成
U_x_test, U_y_test = compute_velocity_field_np(X_low, Y_low, dx_low, dy_low)
U_magnitude_test = np.sqrt(U_x_test**2 + U_y_test**2)

# 将测试数据转换为PyTorch张量
U_x_test = torch.tensor(U_x_test, dtype=torch.float32).unsqueeze(0).unsqueeze(0).to(device)
U_y_test = torch.tensor(U_y_test, dtype=torch.float32).unsqueeze(0).unsqueeze(0).to(device)
U_magnitude_test = torch.tensor(U_magnitude_test, dtype=torch.float32).unsqueeze(0).unsqueeze(0).to(device)

# 合并测试速度场作为输入
velocity_field_test = torch.cat((U_x_test, U_y_test, U_magnitude_test), dim=1).to(device)

# 将模型设置为评估模式
model.eval()

# 使用测试数据进行预测
with torch.no_grad():
    predicted_abcd_test = model(velocity_field_test)

# # 打印预测结果
# print("Predicted a, b, c, d:")
# print(predicted_abcd_test)

# 计算预测的速度场
a_test = predicted_abcd_test[:, 0, :, :].squeeze().cpu().numpy()
b_test = predicted_abcd_test[:, 1, :, :].squeeze().cpu().numpy()
c_test = predicted_abcd_test[:, 2, :, :].squeeze().cpu().numpy()
d_test = predicted_abcd_test[:, 3, :, :].squeeze().cpu().numpy()


a_test_grad_x, a_test_grad_y = np.gradient(a_test, dx_low)
b_test_grad_x, b_test_grad_y = np.gradient(b_test, dx_low)
c_test_grad_x, c_test_grad_y = np.gradient(c_test, dx_low)
d_test_grad_x, d_test_grad_y = np.gradient(d_test, dx_low)

U_x_pred_test = a_test * b_test_grad_x - b_test * a_test_grad_x + c_test * d_test_grad_x - d_test * c_test_grad_x
U_y_pred_test = a_test * b_test_grad_y - b_test * a_test_grad_y + c_test * d_test_grad_y - d_test * c_test_grad_y
U_magnitude_pred_test = np.sqrt(U_x_pred_test**2 + U_y_pred_test**2)

# %%
a_pred_result = predicted_abcd_test[:, 0, :, :].squeeze().cpu().numpy()
b_pred_result = predicted_abcd_test[:, 1, :, :].squeeze().cpu().numpy()
c_pred_result = predicted_abcd_test[:, 2, :, :].squeeze().cpu().numpy()
d_pred_result = predicted_abcd_test[:, 3, :, :].squeeze().cpu().numpy()

# %%
plt.figure(figsize=(12, 24))

plt.subplot(731)
plt.imshow(U_x_test.squeeze().cpu().numpy(), cmap='viridis', vmin=-1, vmax=1)
plt.colorbar()
plt.title('True U_x')

plt.subplot(732)
plt.imshow(U_x_pred_test, cmap='viridis', vmin=-1, vmax=1)
plt.colorbar()
plt.title('Predicted U_x')

plt.subplot(733)
plt.imshow((U_x_test.squeeze().cpu().numpy() - U_x_pred_test), cmap='viridis', vmin=-1, vmax=1)
plt.colorbar()
plt.title('Difference U_x')

plt.subplot(734)
plt.imshow(U_y_test.squeeze().cpu().numpy(), cmap='viridis', vmin=-1, vmax=1)
plt.colorbar()
plt.title('True U_y')

plt.subplot(735)
plt.imshow(U_y_pred_test, cmap='viridis', vmin=-1, vmax=1)
plt.colorbar()
plt.title('Predicted U_y')

plt.subplot(736)
plt.imshow((U_y_test.squeeze().cpu().numpy() - U_y_pred_test), cmap='viridis', vmin=-1, vmax=1)
plt.colorbar()
plt.title('Difference U_y')

plt.subplot(737)
plt.imshow(U_magnitude_test.squeeze().cpu().numpy(), cmap='viridis', vmin=0, vmax=1)
plt.colorbar()
plt.title('True U_magnitude')

plt.subplot(738)
plt.imshow(U_magnitude_pred_test, cmap='viridis', vmin=0, vmax=1)
plt.colorbar()
plt.title('Predicted U_magnitude')

plt.subplot(739)
plt.imshow((U_magnitude_test.squeeze().cpu().numpy() - U_magnitude_pred_test), cmap='viridis', vmin=0, vmax=1)
plt.colorbar()
plt.title('Difference U_magnitude')

plt.subplot(7,3,10)
plt.imshow(A_low, cmap='viridis', vmin=-0.5, vmax=1)
plt.colorbar()
plt.title('Real a')

plt.subplot(7,3,11)
plt.imshow(a_pred_result, cmap='viridis', vmin=-0.5, vmax=1)
plt.colorbar()
plt.title('Predicted a')

plt.subplot(7,3,12)
plt.imshow(A_low - a_pred_result, cmap='viridis', vmin=-0.5, vmax=1)
plt.colorbar()
plt.title('Difference a')

plt.subplot(7,3,13)
plt.imshow(B_low, cmap='viridis', vmin=-0.5, vmax=1)
plt.colorbar()
plt.title('Predicted b')

plt.subplot(7,3,14)
plt.imshow(b_pred_result, cmap='viridis', vmin=-0.5, vmax=1)
plt.colorbar()
plt.title('Predicted b')

plt.subplot(7,3,15)
plt.imshow(B_low - b_pred_result, cmap='viridis', vmin=-0.5, vmax=1)
plt.colorbar()
plt.title('Difference b')

plt.subplot(7,3,16)
plt.imshow(C_low, cmap='viridis', vmin=-0.5, vmax=1)
plt.colorbar()
plt.title('Predicted c')

plt.subplot(7,3,17)
plt.imshow(c_pred_result, cmap='viridis', vmin=-0.5, vmax=1)
plt.colorbar()
plt.title('Predicted c')

plt.subplot(7,3,18)
plt.imshow(C_low - c_pred_result, cmap='viridis', vmin=-0.5, vmax=1)
plt.colorbar()
plt.title('Difference c')

plt.subplot(7,3,19)
plt.imshow(D_low, cmap='viridis', vmin=-0.5, vmax=1)
plt.colorbar()
plt.title('Predicted d')

plt.subplot(7,3,20)
plt.imshow(d_pred_result, cmap='viridis', vmin=-0.5, vmax=1)
plt.colorbar()
plt.title('Predicted d')

plt.subplot(7,3,21)
plt.imshow(D_low - d_pred_result, cmap='viridis', vmin=-0.5, vmax=1)
plt.colorbar()
plt.title('Difference d')

plt.tight_layout()
plt.show()

# %%
vort_pre=vorticity(U_x_pred_test, U_y_pred_test, dx_low, dy_low)

# %%
from PIL import Image

def imgConvert(img):
    img = img.convert('RGB')
    return img

# %%
plt.figure(figsize=(2, 2))
plt.imshow(vort_pre, cmap='RdBu_r',  interpolation='nearest',vmin=-1, vmax=1)
# plt.colorbar()
# plt.title('Predicted normalized vorticity field')
plt.tick_params(axis='both', direction='in', length=6)
# plt.colorbar(fraction=0.04)
plt.axis('off')

plt.savefig("D:\\zjPhD\\Programzj\\psiToU\\result\\725\\low\\vort_pre_normalized_Unet_64_64.png",dpi=128,bbox_inches='tight',pad_inches = 0)
plt.show()


img = Image.open('D:\\zjPhD\\Programzj\\psiToU\\result\\725\\low\\vort_pre_normalized_Unet_64_64.png')
img = imgConvert(img)
img.save('D:\\zjPhD\\Programzj\\psiToU\\result\\725\\low\\vort_pre_normalized_Unet_64_64.png')

# %%
plt.figure(figsize=(2, 2))
plt.imshow(U_x_pred_test, cmap='viridis',  interpolation='nearest',vmin=-1, vmax=1)
# plt.colorbar()
# plt.title('Predicted normalized vorticity field')
plt.tick_params(axis='both', direction='in', length=6)
# plt.colorbar(fraction=0.04)
plt.axis('off')

plt.savefig("D:\\zjPhD\\Programzj\\psiToU\\result\\725\\low\\U_x_pred_Unet_64_64.png",dpi=128,bbox_inches='tight',pad_inches = 0)
plt.show()

img = Image.open('D:\\zjPhD\\Programzj\\psiToU\\result\\725\\low\\U_x_pred_Unet_64_64.png')
img = imgConvert(img)
img.save('D:\\zjPhD\\Programzj\\psiToU\\result\\725\\low\\U_x_pred_Unet_64_64.png')

# %%
plt.figure(figsize=(2, 2))
plt.imshow(U_y_pred_test, cmap='viridis',  interpolation='nearest',vmin=-1, vmax=1)
# plt.colorbar()
# plt.title('Predicted normalized vorticity field')
plt.tick_params(axis='both', direction='in', length=6)
# plt.colorbar(fraction=0.04)
plt.axis('off')

plt.savefig("D:\\zjPhD\\Programzj\\psiToU\\result\\725\\low\\U_y_pred_Unet_64_64.png",dpi=128,bbox_inches='tight',pad_inches = 0)
plt.show()

img = Image.open('D:\\zjPhD\\Programzj\\psiToU\\result\\725\\low\\U_y_pred_Unet_64_64.png')
img = imgConvert(img)
img.save('D:\\zjPhD\\Programzj\\psiToU\\result\\725\\low\\U_y_pred_Unet_64_64.png')

# %%
plt.figure(figsize=(2, 2))
plt.imshow(U_magnitude_pred_test, cmap='viridis',  interpolation='nearest',vmin=0, vmax=1)
# plt.colorbar()
# plt.title('Predicted normalized vorticity field')
plt.tick_params(axis='both', direction='in', length=6)
# plt.colorbar(fraction=0.04)
plt.axis('off')

plt.savefig("D:\\zjPhD\\Programzj\\psiToU\\result\\725\\low\\U_magnitude_pred_Unet_64_64.png",dpi=128,bbox_inches='tight',pad_inches = 0)
plt.show()

img = Image.open('D:\\zjPhD\\Programzj\\psiToU\\result\\725\\low\\U_magnitude_pred_Unet_64_64.png')
img = imgConvert(img)
img.save('D:\\zjPhD\\Programzj\\psiToU\\result\\725\\low\\U_magnitude_pred_Unet_64_64.png')
