# %%
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import DataLoader, TensorDataset, random_split
import cv2

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cuda')

# %%
import h5py
import matplotlib.pyplot as plt

# 文件路径
file_path = r'D:\\zjPhD\\turbulenceData\\turbulenceData\\isotropic1024coarse_10.h5'


# 读取HDF5文件
with h5py.File(file_path, 'r') as f:
    # 查看文件中所有的数据集
    datasets = list(f.keys())
    print("数据集列表:", datasets)
    
    # 假设第一个数据集是我们要看的
    dataset_name = datasets[0]
    data = f[dataset_name][()]
    print(f"{dataset_name} 数据形状:", data.shape)
    print(f"{dataset_name} 数据范围:", data.min(), "到", data.max())
# Out:
# 数据集列表: ['Velocity_0001', 'Velocity_0002', 'Velocity_0003', 'Velocity_0004', 'Velocity_0005', 'Velocity_0006', 'Velocity_0007', 'Velocity_0008', 'Velocity_0009', 'Velocity_0010', 'Velocity_0011', 'Velocity_0012', 'Velocity_0013', 'Velocity_0014', 'Velocity_0015', 'Velocity_0016', 'Velocity_0017', 'Velocity_0018', 'Velocity_0019', 'Velocity_0020', 'xcoor', 'ycoor', 'zcoor']
# Velocity_0001 数据形状: (1, 1024, 1024, 3)
# Velocity_0001 数据范围: -2.712391 到 2.6947422

# %%
import h5py
import numpy as np
import matplotlib.pyplot as plt

# 文件路径
file_path = r'D:\\zjPhD\\turbulenceData\\turbulenceData\\isotropic1024coarse_test.h5'

# 读取HDF5文件
with h5py.File(file_path, 'r') as f:
    # 查看文件中所有的数据集
    datasets = list(f.keys())
    print("数据集列表:", datasets)
    
    # 假设第一个数据集是我们要看的
    dataset_name = datasets[0]
    data = f[dataset_name][()]
    print(f"{dataset_name} 数据形状:", data.shape)
    print(f"{dataset_name} 数据范围:", data.min(), "到", data.max())
    
    # 归一化数据到 [0, 1] 范围
    data_normalized = (data[0] - data.min()) / (data.max() - data.min())
    
    # # 可视化数据中的第一个通道
    # plt.imshow(data_normalized[:, :, 0], cmap='viridis')
    # plt.title(f'{dataset_name} 第一个通道')
    # plt.colorbar()
    # plt.show()
    
    # # 可视化数据中的第二个通道
    # plt.imshow(data_normalized[:, :, 1], cmap='viridis')
    # plt.title(f'{dataset_name} 第二个通道')
    # plt.colorbar()
    # plt.show()
    
    # # 可视化数据中的第三个通道
    # plt.imshow(data_normalized[:, :, 2], cmap='viridis')
    # plt.title(f'{dataset_name} 第三个通道')
    # plt.colorbar()
    # plt.show()
# Out:
# 数据集列表: ['Velocity_0001', 'xcoor', 'ycoor', 'zcoor']
# Velocity_0001 数据形状: (1, 1024, 1024, 3)
# Velocity_0001 数据范围: -2.712391 到 2.6947422

# %%
import h5py
import numpy as np

# 文件路径
file_path = r'D:\\zjPhD\\turbulenceData\\turbulenceData\\isotropic1024coarse_10.h5'

# 读取HDF5文件并检查每个 Velocity 数据集的基本信息
with h5py.File(file_path, 'r') as f:
    # 查看文件中所有的数据集
    datasets = list(f.keys())
    print("数据集列表:", datasets)
    
    for dataset_name in datasets:
        if 'Velocity' in dataset_name:
            data = f[dataset_name][()]
            print(f"{dataset_name} 数据形状:", data.shape)
            print(f"{dataset_name} 数据范围:", data.min(), "到", data.max())
            print(f"{dataset_name} 数据均值:", data.mean())
            print(f"{dataset_name} 数据标准差:", data.std())
            print()
# Out:
# 数据集列表: ['Velocity_0001', 'Velocity_0002', 'Velocity_0003', 'Velocity_0004', 'Velocity_0005', 'Velocity_0006', 'Velocity_0007', 'Velocity_0008', 'Velocity_0009', 'Velocity_0010', 'Velocity_0011', 'Velocity_0012', 'Velocity_0013', 'Velocity_0014', 'Velocity_0015', 'Velocity_0016', 'Velocity_0017', 'Velocity_0018', 'Velocity_0019', 'Velocity_0020', 'xcoor', 'ycoor', 'zcoor']
# Velocity_0001 数据形状: (1, 1024, 1024, 3)
# Velocity_0001 数据范围: -2.712391 到 2.6947422
# Velocity_0001 数据均值: 0.07109838
# Velocity_0001 数据标准差: 0.6888756
#
# Velocity_0002 数据形状: (1, 1024, 1024, 3)
# Velocity_0002 数据范围: -2.7356367 到 2.7098155
# Velocity_0002 数据均值: 0.07116876
# Velocity_0002 数据标准差: 0.68889195
#
# Velocity_0003 数据形状: (1, 1024, 1024, 3)
# Velocity_0003 数据范围: -2.722479 到 2.7283216
# Velocity_0003 数据均值: 0.07122495
# Velocity_0003 数据标准差: 0.688922
#
# Velocity_0004 数据形状: (1, 1024, 1024, 3)
# Velocity_0004 数据范围: -2.7307792 到 2.74634
# Velocity_0004 数据均值: 0.07126973
# Velocity_0004 数据标准差: 0.6889681
#
# Velocity_0005 数据形状: (1, 1024, 1024, 3)
# Velocity_0005 数据范围: -2.6752195 到 2.770227
# Velocity_0005 数据均值: 0.071305186
# Velocity_0005 数据标准差: 0.6890285
#
# Velocity_0006 数据形状: (1, 1024, 1024, 3)
# Velocity_0006 数据范围: -2.608722 到 2.7777185
# Velocity_0006 数据均值: 0.07133317
# Velocity_0006 数据标准差: 0.68909943
#
# Velocity_0007 数据形状: (1, 1024, 1024, 3)
# Velocity_0007 数据范围: -2.5889878 到 2.7992706
# Velocity_0007 数据均值: 0.071355015
# Velocity_0007 数据标准差: 0.6891764
#
# Velocity_0008 数据形状: (1, 1024, 1024, 3)
# Velocity_0008 数据范围: -2.584568 到 2.8132267
# Velocity_0008 数据均值: 0.07137236
# Velocity_0008 数据标准差: 0.6892557
#
# Velocity_0009 数据形状: (1, 1024, 1024, 3)
# Velocity_0009 数据范围: -2.5807695 到 2.8110614
# Velocity_0009 数据均值: 0.071388565
# Velocity_0009 数据标准差: 0.68933684
#
# Velocity_0010 数据形状: (1, 1024, 1024, 3)
# Velocity_0010 数据范围: -2.5739505 到 2.8252645
# Velocity_0010 数据均值: 0.0714082
# Velocity_0010 数据标准差: 0.6894169
#
# Velocity_0011 数据形状: (1, 1024, 1024, 3)
# Velocity_0011 数据范围: -2.5682664 到 2.831748
# Velocity_0011 数据均值: 0.07143452
# Velocity_0011 数据标准差: 0.68949455
#
# Velocity_0012 数据形状: (1, 1024, 1024, 3)
# Velocity_0012 数据范围: -2.5639415 到 2.8183084
# Velocity_0012 数据均值: 0.07146752
# Velocity_0012 数据标准差: 0.6895657
#
# Velocity_0013 数据形状: (1, 1024, 1024, 3)
# Velocity_0013 数据范围: -2.5569108 到 2.8257155
# Velocity_0013 数据均值: 0.071504585
# Velocity_0013 数据标准差: 0.6896298
#
# Velocity_0014 数据形状: (1, 1024, 1024, 3)
# Velocity_0014 数据范围: -2.550218 到 2.8258345
# Velocity_0014 数据均值: 0.071542695
# Velocity_0014 数据标准差: 0.68968916
#
# Velocity_0015 数据形状: (1, 1024, 1024, 3)
# Velocity_0015 数据范围: -2.541764 到 2.8032413
# Velocity_0015 数据均值: 0.07158066
# Velocity_0015 数据标准差: 0.6897459
#
# Velocity_0016 数据形状: (1, 1024, 1024, 3)
# Velocity_0016 数据范围: -2.533338 到 2.8086593
# Velocity_0016 数据均值: 0.07161763
# Velocity_0016 数据标准差: 0.6898023
#
# Velocity_0017 数据形状: (1, 1024, 1024, 3)
# Velocity_0017 数据范围: -2.526175 到 2.7972069
# Velocity_0017 数据均值: 0.07165275
# Velocity_0017 数据标准差: 0.68985784
#
# Velocity_0018 数据形状: (1, 1024, 1024, 3)
# Velocity_0018 数据范围: -2.519424 到 2.7872314
# Velocity_0018 数据均值: 0.07168614
# Velocity_0018 数据标准差: 0.6899145
#
# Velocity_0019 数据形状: (1, 1024, 1024, 3)
# Velocity_0019 数据范围: -2.539456 到 2.7889357
# Velocity_0019 数据均值: 0.07171971
# Velocity_0019 数据标准差: 0.68997425
#
# Velocity_0020 数据形状: (1, 1024, 1024, 3)
# Velocity_0020 数据范围: -2.5543127 到 2.7725642
# Velocity_0020 数据均值: 0.07175511
# Velocity_0020 数据标准差: 0.6900401

# %% [markdown]
# # 定义所需要的函数

# %% [markdown]
# ## 计算涡度

# %%
def vorticity(U_x, U_y, dx, dy):
    dU_y_dx, _ = np.gradient(U_y, dx, axis=0), np.gradient(U_y, dy, axis=1)
    _, dU_x_dy = np.gradient(U_x, dx, axis=0), np.gradient(U_x, dy, axis=1)
    return dU_y_dx - dU_x_dy


# 计算归一化的涡度
def vorticity_normalize(vorticity):
    max_vorticity = np.max(np.abs(vorticity))
    vort_normalized = vorticity / max_vorticity if max_vorticity != 0 else vorticity
    return vort_normalized

# %% [markdown]
# # 预训练模型测试新的湍流非对称数据集

# %% [markdown]
# 读取约翰霍普金斯的湍流数据库

# %%
import h5py

import numpy as np
import matplotlib.pyplot as plt

# %%
def downsample(image, size=(64, 64)):
    return cv2.resize(image, size, interpolation=cv2.INTER_AREA)

# %% [markdown]
# ### 原始数据集

# %%
## 读取测试集

file_path = r'D:\\zjPhD\\turbulenceData\\turbulenceData\\isotropic1024coarse_test.h5'

with h5py.File(file_path,'r') as f :
    datasets = list(f.keys())
    print("数据集列表:", datasets)
    
    for dataset_name in datasets:
        if 'Velocity' in dataset_name:
            data = f[dataset_name][()]
            print(f"{dataset_name} 数据形状:", data.shape)
            print(f"{dataset_name} 数据范围:", data.min(), "到", data.max())
            print(f"{dataset_name} 数据均值:", data.mean())
            print(f"{dataset_name} 数据标准差:", data.std())
            print()

    data_normalized = (data[0] - data.min()) / (data.max() - data.min())

    data = f[dataset_name][()]

    u_test = data_normalized[:,:,0]
    v_test = data_normalized[:,:,1]
    w_test = data_normalized[:,:,2]
# Out:
# 数据集列表: ['Velocity_0001', 'xcoor', 'ycoor', 'zcoor']
# Velocity_0001 数据形状: (1, 1024, 1024, 3)
# Velocity_0001 数据范围: -2.712391 到 2.6947422
# Velocity_0001 数据均值: 0.07109838
# Velocity_0001 数据标准差: 0.6888756

# %% [markdown]
# ### 降采样数据集 （64*64）

# %%
# 读取HDF5文件并降采样
with h5py.File(file_path, 'r') as f:
    # 获取所有速度场数据集名称
    velocity_datasets = [name for name in f.keys() if 'Velocity' in name]
    
    # 初始化空列表用于存储所有数据
    all_velocity_fields = []
    
    for dataset_name in velocity_datasets:
        data = f[dataset_name][()]
        # 取出三通道的速度场数据
        U_x = data[0, :, :, 0]
        U_y = data[0, :, :, 1]
        U_magnitude = data[0, :, :, 2]
        
        # 降采样
        U_x_downsampled = downsample(U_x)
        U_y_downsampled = downsample(U_y)
        U_magnitude_downsampled = downsample(U_magnitude)
        
        # 将数据转换为PyTorch张量并增加batch和channel维度
        U_x_tensor = torch.tensor(U_x_downsampled, dtype=torch.float32).unsqueeze(0).unsqueeze(0)
        U_y_tensor = torch.tensor(U_y_downsampled, dtype=torch.float32).unsqueeze(0).unsqueeze(0)
        U_magnitude_tensor = torch.tensor(U_magnitude_downsampled, dtype=torch.float32).unsqueeze(0).unsqueeze(0)
        
        # 合并速度场作为输入
        velocity_field = torch.cat((U_x_tensor, U_y_tensor, U_magnitude_tensor), dim=1)
        
        all_velocity_fields.append(velocity_field)
    
    # 将所有速度场数据合并为一个大的张量
    all_velocity_fields = torch.cat(all_velocity_fields, dim=0)
    
    # 目标abcd (假设为0初始化)
    num_samples = all_velocity_fields.shape[0]
    size_low = all_velocity_fields.shape[2]
    target_abcd = torch.zeros((num_samples, 4, size_low, size_low), dtype=torch.float32)
    
    # 创建数据集和数据加载器
    dataset = TensorDataset(all_velocity_fields, target_abcd)
    dataloader = DataLoader(dataset, batch_size=1, shuffle=True)  # 你可以根据需要调整batch_size

# 检查数据形状
print("all_velocity_fields shape:", all_velocity_fields.shape)
print("target_abcd shape:", target_abcd.shape)
# Out:
# all_velocity_fields shape: torch.Size([1, 3, 64, 64])
# target_abcd shape: torch.Size([1, 4, 64, 64])

# %%
target_abcd.shape
# Out:
# torch.Size([1, 4, 64, 64])

# %%
all_velocity_fields[0,1,0,:].shape
# Out:
# torch.Size([64])

# %%
#可以查看数据范围，xyz都是（0，$2\pi$）
size_low = 64

dx = 2*np.pi/size_low
dy = 2*np.pi/size_low
dz = 2*np.pi/size_low

# %%
u_test =all_velocity_fields[0,0,:,:].numpy()
v_test =all_velocity_fields[0,1,:,:].numpy()
w_test =all_velocity_fields[0,2,:,:].numpy()

# %%
vort_test = vorticity(u_test, v_test, dx, dx)

vorticity_normalized = vorticity_normalize(vort_test)

print(vort_test.shape)
print(vorticity_normalized.shape)
# Out:
# (64, 64)
# (64, 64)

# %%
plt.imshow(vorticity_normalized, cmap='RdBu_r',vmin=-0.3,vmax=0.3,interpolation='bilinear')
plt.colorbar()

# %%
print("u速度场形状",u_test.shape) 
print("v速度场形状",v_test.shape)

# 查看一些速度场   
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)   
plt.imshow(u_test, cmap='viridis')   
plt.subplot(1, 2, 2)
plt.imshow(v_test, cmap='viridis')
# Out:
# u速度场形状 (64, 64)
# v速度场形状 (64, 64)

# %%
plt.imshow(u_test, cmap='viridis')

# %% [markdown]
# # 模型A部分尝试更换数据集

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f'Using device: {device}')
# Out:
# Using device: cuda

# %%
import h5py
import torch
from torch.utils.data import DataLoader, TensorDataset

# 文件路径
file_path = r'D:\\zjPhD\\turbulenceData\\turbulenceData\\isotropic1024coarse_10.h5'

# 读取HDF5文件并降采样
with h5py.File(file_path, 'r') as f:
    # 获取所有速度场数据集名称
    velocity_datasets = [name for name in f.keys() if 'Velocity' in name]
    
    # 初始化空列表用于存储所有数据
    all_velocity_fields = []
    
    for dataset_name in velocity_datasets:
        data = f[dataset_name][()]
        # 取出三通道的速度场数据
        U_x = data[0, :, :, 0]
        U_y = data[0, :, :, 1]
        U_magnitude = data[0, :, :, 2]
        
        # 降采样
        U_x_downsampled = downsample(U_x)
        U_y_downsampled = downsample(U_y)
        U_magnitude_downsampled = downsample(U_magnitude)
        # U_x_downsampled = U_x
        # U_y_downsampled = U_y
        # U_magnitude_downsampled = U_magnitude
        
        # 将数据转换为PyTorch张量并增加batch和channel维度
        U_x_tensor = torch.tensor(U_x_downsampled, dtype=torch.float32).unsqueeze(0).unsqueeze(0)
        U_y_tensor = torch.tensor(U_y_downsampled, dtype=torch.float32).unsqueeze(0).unsqueeze(0)
        U_magnitude_tensor = torch.tensor(U_magnitude_downsampled, dtype=torch.float32).unsqueeze(0).unsqueeze(0)
        
        # 合并速度场作为输入
        velocity_field = torch.cat((U_x_tensor, U_y_tensor, U_magnitude_tensor), dim=1)
        
        all_velocity_fields.append(velocity_field)
    
    # 将所有速度场数据合并为一个大的张量
    all_velocity_fields = torch.cat(all_velocity_fields, dim=0)
    
    # 目标abcd (假设为0初始化)
    num_samples = all_velocity_fields.shape[0]
    size_low = all_velocity_fields.shape[2]
    target_abcd = torch.zeros((num_samples, 4, size_low, size_low), dtype=torch.float32)
    
    # 创建数据集和数据加载器
    dataset = TensorDataset(all_velocity_fields, target_abcd)
    dataloader = DataLoader(dataset, batch_size=2, shuffle=True)  # 调整批量大小

# 检查数据形状
print("all_velocity_fields shape:", all_velocity_fields.shape)
print("target_abcd shape:", target_abcd.shape)
# Out:
# all_velocity_fields shape: torch.Size([20, 3, 64, 64])
# target_abcd shape: torch.Size([20, 4, 64, 64])

# %%
# 简单的模型
class BasicModelA(nn.Module):
    def __init__(self):
        super(BasicModelA, self).__init__()
        self.conv1 = nn.Conv2d(3, 64, kernel_size=3, padding=1)
        self.bn1 = nn.BatchNorm2d(64)
        self.conv2 = nn.Conv2d(64, 128, kernel_size=3, padding=1)
        self.bn2 = nn.BatchNorm2d(128)
        self.conv3 = nn.Conv2d(128, 256, kernel_size=3, padding=1)
        self.bn3 = nn.BatchNorm2d(256)
        self.pool = nn.MaxPool2d(2, 2)
        self.conv4 = nn.Conv2d(256, 512, kernel_size=3, padding=1)
        self.bn4 = nn.BatchNorm2d(512)
        self.upsample = nn.Upsample(scale_factor=8, mode='bilinear', align_corners=True)
        self.conv5 = nn.Conv2d(512, 4, kernel_size=3, padding=1)

    def forward(self, x):
        x = F.relu(self.bn1(self.conv1(x)))
        x = self.pool(x)
        x = F.relu(self.bn2(self.conv2(x)))
        x = self.pool(x)
        x = F.relu(self.bn3(self.conv3(x)))
        x = self.pool(x)
        x = F.relu(self.bn4(self.conv4(x)))
        x = self.upsample(x)  # 使用上采样恢复到原始尺寸
        x = self.conv5(x)
        return x

# %%
# 复杂的模型
class ComplexModelA(nn.Module):
    def __init__(self):
        super(ComplexModelA, self).__init__()
        # Encoder
        self.conv1 = nn.Conv2d(3, 64, kernel_size=3, padding=1)
        self.bn1 = nn.BatchNorm2d(64)
        self.conv2 = nn.Conv2d(64, 128, kernel_size=3, padding=1)
        self.bn2 = nn.BatchNorm2d(128)
        self.conv3 = nn.Conv2d(128, 256, kernel_size=3, padding=1)
        self.bn3 = nn.BatchNorm2d(256)
        self.conv4 = nn.Conv2d(256, 512, kernel_size=3, padding=1)
        self.bn4 = nn.BatchNorm2d(512)
        self.conv5 = nn.Conv2d(512, 1024, kernel_size=3, padding=1)
        self.bn5 = nn.BatchNorm2d(1024)
        
        self.pool = nn.MaxPool2d(2, 2)

        # Decoder
        self.upconv1 = nn.ConvTranspose2d(1024, 512, kernel_size=2, stride=2)
        self.conv6 = nn.Conv2d(1024, 512, kernel_size=3, padding=1)
        self.bn6 = nn.BatchNorm2d(512)
        
        self.upconv2 = nn.ConvTranspose2d(512, 256, kernel_size=2, stride=2)
        self.conv7 = nn.Conv2d(512, 256, kernel_size=3, padding=1)
        self.bn7 = nn.BatchNorm2d(256)
        
        self.upconv3 = nn.ConvTranspose2d(256, 128, kernel_size=2, stride=2)
        self.conv8 = nn.Conv2d(256, 128, kernel_size=3, padding=1)
        self.bn8 = nn.BatchNorm2d(128)
        
        self.upconv4 = nn.ConvTranspose2d(128, 64, kernel_size=2, stride=2)
        self.conv9 = nn.Conv2d(128, 64, kernel_size=3, padding=1)
        self.bn9 = nn.BatchNorm2d(64)
        
        self.conv10 = nn.Conv2d(64, 4, kernel_size=3, padding=1)
        
    def forward(self, x):
        # Encoder
        x1 = F.relu(self.bn1(self.conv1(x)))
        x2 = self.pool(x1)
        x2 = F.relu(self.bn2(self.conv2(x2)))
        x3 = self.pool(x2)
        x3 = F.relu(self.bn3(self.conv3(x3)))
        x4 = self.pool(x3)
        x4 = F.relu(self.bn4(self.conv4(x4)))
        x5 = self.pool(x4)
        x5 = F.relu(self.bn5(self.conv5(x5)))
        
        # Decoder
        x = self.upconv1(x5)
        x = torch.cat((x, x4), dim=1)  # Skip connection
        x = F.relu(self.bn6(self.conv6(x)))
        
        x = self.upconv2(x)
        x = torch.cat((x, x3), dim=1)  # Skip connection
        x = F.relu(self.bn7(self.conv7(x)))
        
        x = self.upconv3(x)
        x = torch.cat((x, x2), dim=1)  # Skip connection
        x = F.relu(self.bn8(self.conv8(x)))
        
        x = self.upconv4(x)
        x = torch.cat((x, x1), dim=1)  # Skip connection
        x = F.relu(self.bn9(self.conv9(x)))
        
        x = self.conv10(x)
        return x

# %%
class ConstraintLayer(nn.Module):
    def __init__(self):
        super(ConstraintLayer, self).__init__()

    def forward(self, x):
        # 假设x的形状为 [batch_size, 4, height, width]，其中4代表abcd
        norm = torch.sqrt(x[:, 0, :, :]**2 + x[:, 1, :, :]**2 + x[:, 2, :, :]**2 + x[:, 3, :, :]**2 + 1e-8)
        norm = norm.unsqueeze(1)  # 为了与abcd的四个通道对齐
        x = x / norm  # 归一化
        return x

# %%
class ModelAWithConstraints(nn.Module):
    def __init__(self):
        super(ModelAWithConstraints, self).__init__()
        self.model = BasicModelA()
        self.constraint_layer = ConstraintLayer()

    def forward(self, x):
        x = self.model(x)
        x = self.constraint_layer(x)
        return x

# %%
def calculate_gradients_with_numpy(tensor):
    # 确保 Tensor 不需要梯度跟踪，且在 CPU 上
    tensor_np = tensor.detach().cpu().numpy()

    # 计算梯度
    grad_x = np.gradient(tensor_np, axis=1)  # 假设水平方向是 axis=1
    grad_y = np.gradient(tensor_np, axis=2)  # 假设垂直方向是 axis=2
    
    # 转换回 Tensor
    grad_x_tensor = torch.from_numpy(grad_x).to(tensor.device)
    grad_y_tensor = torch.from_numpy(grad_y).to(tensor.device)
    
    return grad_x_tensor, grad_y_tensor

# %%
def laplacian_2d(array, dx, dy):
    grad_x = np.gradient(array, dx, axis=1, edge_order=2)  # 计算 x 方向的一阶导数
    grad_y = np.gradient(array, dy, axis=0, edge_order=2)  # 计算 y 方向的一阶导数
    
    laplacian_x = np.gradient(grad_x, dx, axis=1, edge_order=2)  # 计算 x 方向的二阶导数
    laplacian_y = np.gradient(grad_y, dy, axis=0, edge_order=2)  # 计算 y 方向的二阶导数
    
    return laplacian_x + laplacian_y



def laplacian_2d_torch(tensor, dx, dy):
    # 确保tensor是浮点类型，因为梯度计算通常需要浮点运算
    tensor = tensor.float()
    tensor_np = tensor.detach().cpu().numpy()

    # 计算x和y方向的一阶导数
    grad_x = np.gradient(tensor_np, axis=1)  # x方向
    grad_y = np.gradient(tensor_np, axis=2)  # y方向

    # 计算x和y方向的二阶导数
    laplacian_x = np.gradient(grad_x, axis=1)
    laplacian_y = np.gradient(grad_y, axis=2)

    laplacian_x_tensor = torch.from_numpy(laplacian_x).to(tensor.device)
    laplacian_y_tensor = torch.from_numpy(laplacian_y).to(tensor.device)

    # 相加得到完整的拉普拉斯算子
    laplacian = laplacian_x_tensor + laplacian_y_tensor

    return laplacian

# %%
def loss_function(predicted_abcd, true_velocity, model, epsilon, l1_lambda=0.0, l2_lambda=0.0):
    # 提取 a, b, c, d
    a = predicted_abcd[:, 0, :, :]
    b = predicted_abcd[:, 1, :, :]
    c = predicted_abcd[:, 2, :, :]
    d = predicted_abcd[:, 3, :, :]
    
    # 计算梯度
    a_grad_x, a_grad_y = calculate_gradients_with_numpy(a)
    b_grad_x, b_grad_y = calculate_gradients_with_numpy(b)
    c_grad_x, c_grad_y = calculate_gradients_with_numpy(c)
    d_grad_x, d_grad_y = calculate_gradients_with_numpy(d)

    hbar = 1  # 你可以根据具体情况调整这个参数

    # # 根据 a, b, c, d 计算预测的速度场
    # U_x_pred = a + b
    # U_y_pred = c + d
    # U_magnitude_pred = torch.sqrt(U_x_pred**2 + U_y_pred**2)
    
    # # 计算速度场的损失
    # U_x_true = true_velocity[:, 0, :, :]
    # U_y_true = true_velocity[:, 1, :, :]
    # U_magnitude_true = true_velocity[:, 2, :, :]


    # U_x_pred = hbar * (a * b_grad_x - b * a_grad_x + c * d_grad_x - d * c_grad_x)
    # U_y_pred = hbar * (a * b_grad_y - b * a_grad_y + c * d_grad_y - d * c_grad_y)
    # U_magnitude_pred = torch.sqrt(U_x_pred**2 + U_y_pred**2)

    U_x_pred = hbar *(a * b_grad_x )
    U_y_pred = hbar *(c * d_grad_y )
    U_magnitude_pred = torch.sqrt(U_x_pred**2 + U_y_pred**2)
    
    # # 计算速度场的损失
    U_x_true = true_velocity[:, 0, :, :]
    U_y_true = true_velocity[:, 1, :, :]
    U_magnitude_true = true_velocity[:, 2, :, :]

    loss_velocity = F.mse_loss(U_magnitude_pred, U_magnitude_true) + F.mse_loss(U_x_pred, U_x_true) + F.mse_loss(U_y_pred, U_y_true)
    
    # 计算归一化约束
    norm = a**2 + b**2 + c**2 + d**2
    norm_constraint = F.mse_loss(norm, torch.ones_like(norm))
    
    # 计算拉普拉斯算子
    lap_b = laplacian_2d_torch(b, dx, dx)
    lap_a = laplacian_2d_torch(a, dx, dx)
    lap_d = laplacian_2d_torch(d, dx, dx)
    lap_c = laplacian_2d_torch(c, dx, dx)

    # 计算螺旋度约束
    curl_constraint = (a * lap_b - b * lap_a + c * lap_d - d * lap_c).sum()
    
    # 计算L1正则化项
    l1_regularization = torch.tensor(0., requires_grad=True)
    if l1_lambda > 0:
        l1_regularization = sum(torch.sum(torch.abs(param)) for param in model.parameters())

    # 计算L2正则化项
    l2_regularization = torch.tensor(0., requires_grad=True)
    if l2_lambda > 0:
        l2_regularization = sum(torch.sum(param**2) for param in model.parameters())
    
    # 计算正则化项
    regularization_term = epsilon * 0.25 * (torch.sum(a**2) + torch.sum(b**2) + torch.sum(c**2) + torch.sum(d**2))
    
    # 总损失
    total_loss = loss_velocity + l1_lambda * l1_regularization + l2_lambda * l2_regularization #+ norm_constraint + curl_constraint + regularization_term 
    return total_loss

# %%
from torch.cuda.amp import GradScaler, autocast

# %%
learning_rate = 0.0001
num_epochs = 900
epsilon = 0.01
l1_lambda = 0.001  # L1正则化系数
l2_lambda = 0.001  # L2正则化系数


channels = 3

model = ComplexModelA()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

# %%
for epoch in range(num_epochs):
    for i, (velocity, _) in enumerate(dataloader):
        optimizer.zero_grad()
        predicted_abcd = model(velocity)
        # loss = loss_function(predicted_abcd, velocity, epsilon)
        loss = loss_function(predicted_abcd, velocity, model, epsilon, l1_lambda, l2_lambda)

        loss.backward()
        optimizer.step()
        if i % 10 == 0:
            print(f'Epoch [{epoch+1}/{num_epochs}], Step [{i+1}], Loss: {loss.item():.4f}')
# Out:
# Epoch [1/900], Step [1], Loss: 134.7562
# Epoch [2/900], Step [1], Loss: 119.7701
# Epoch [3/900], Step [1], Loss: 105.9447
# Epoch [4/900], Step [1], Loss: 93.1817
# Epoch [5/900], Step [1], Loss: 81.4632
# Epoch [6/900], Step [1], Loss: 70.8000
# Epoch [7/900], Step [1], Loss: 61.2080
# Epoch [8/900], Step [1], Loss: 52.6699
# Epoch [9/900], Step [1], Loss: 45.1917
# Epoch [10/900], Step [1], Loss: 38.7732
# Epoch [11/900], Step [1], Loss: 33.4032
# Epoch [12/900], Step [1], Loss: 28.9756
# Epoch [13/900], Step [1], Loss: 25.1514
# Epoch [14/900], Step [1], Loss: 21.9768
# Epoch [15/900], Step [1], Loss: 19.4068
# Epoch [16/900], Step [1], Loss: 17.4383
# Epoch [17/900], Step [1], Loss: 15.7092
# Epoch [18/900], Step [1], Loss: 14.2725
# Epoch [19/900], Step [1], Loss: 13.0172
# Epoch [20/900], Step [1], Loss: 11.9941
# Epoch [21/900], Step [1], Loss: 11.1865
# Epoch [22/900], Step [1], Loss: 10.5334
# Epoch [23/900], Step [1], Loss: 10.0698
# Epoch [24/900], Step [1], Loss: 9.6848
# Epoch [25/900], Step [1], Loss: 9.3467
# Epoch [26/900], Step [1], Loss: 9.0460
# Epoch [27/900], Step [1], Loss: 8.7958
# Epoch [28/900], Step [1], Loss: 8.5759
# Epoch [29/900], Step [1], Loss: 8.4102
# Epoch [30/900], Step [1], Loss: 8.2956
# Epoch [31/900], Step [1], Loss: 8.2540
# Epoch [32/900], Step [1], Loss: 8.3263
# Epoch [33/900], Step [1], Loss: 8.3061
# Epoch [34/900], Step [1], Loss: 8.2969
# Epoch [35/900], Step [1], Loss: 8.1652
# Epoch [36/900], Step [1], Loss: 8.0248
# Epoch [37/900], Step [1], Loss: 7.8855
# Epoch [38/900], Step [1], Loss: 7.8334
# Epoch [39/900], Step [1], Loss: 7.7841
# Epoch [40/900], Step [1], Loss: 7.7103
# Epoch [41/900], Step [1], Loss: 7.6719
# Epoch [42/900], Step [1], Loss: 7.6650
# Epoch [43/900], Step [1], Loss: 7.5972
# Epoch [44/900], Step [1], Loss: 7.5252
# Epoch [45/900], Step [1], Loss: 7.4749
# Epoch [46/900], Step [1], Loss: 7.4312
# Epoch [47/900], Step [1], Loss: 7.3958
# Epoch [48/900], Step [1], Loss: 7.3614
# Epoch [49/900], Step [1], Loss: 7.3302
# Epoch [50/900], Step [1], Loss: 7.3067
# Epoch [51/900], Step [1], Loss: 7.2795
# Epoch [52/900], Step [1], Loss: 7.2557
# Epoch [53/900], Step [1], Loss: 7.2317
# Epoch [54/900], Step [1], Loss: 7.2101
# Epoch [55/900], Step [1], Loss: 7.1906
# Epoch [56/900], Step [1], Loss: 7.1751
# Epoch [57/900], Step [1], Loss: 7.1553
# Epoch [58/900], Step [1], Loss: 7.1376
# Epoch [59/900], Step [1], Loss: 7.1219
# Epoch [60/900], Step [1], Loss: 7.1052
# Epoch [61/900], Step [1], Loss: 7.0902
# Epoch [62/900], Step [1], Loss: 7.0793
# Epoch [63/900], Step [1], Loss: 7.0623
# Epoch [64/900], Step [1], Loss: 7.0507
# Epoch [65/900], Step [1], Loss: 7.0377
# Epoch [66/900], Step [1], Loss: 7.0262
# Epoch [67/900], Step [1], Loss: 7.0158
# Epoch [68/900], Step [1], Loss: 7.0042
# Epoch [69/900], Step [1], Loss: 6.9968
# Epoch [70/900], Step [1], Loss: 6.9823
# Epoch [71/900], Step [1], Loss: 6.9752
# Epoch [72/900], Step [1], Loss: 6.9632
# Epoch [73/900], Step [1], Loss: 6.9522
# Epoch [74/900], Step [1], Loss: 6.9410
# Epoch [75/900], Step [1], Loss: 6.9308
# Epoch [76/900], Step [1], Loss: 6.9218
# Epoch [77/900], Step [1], Loss: 6.9129
# Epoch [78/900], Step [1], Loss: 6.9015
# Epoch [79/900], Step [1], Loss: 6.8924
# Epoch [80/900], Step [1], Loss: 6.8835
# Epoch [81/900], Step [1], Loss: 6.8724
# Epoch [82/900], Step [1], Loss: 6.8638
# Epoch [83/900], Step [1], Loss: 6.8538
# Epoch [84/900], Step [1], Loss: 6.8434
# Epoch [85/900], Step [1], Loss: 6.8336
# Epoch [86/900], Step [1], Loss: 6.8245
# Epoch [87/900], Step [1], Loss: 6.8151
# Epoch [88/900], Step [1], Loss: 6.8037
# Epoch [89/900], Step [1], Loss: 6.7961
# Epoch [90/900], Step [1], Loss: 6.7860
# Epoch [91/900], Step [1], Loss: 6.7754
# Epoch [92/900], Step [1], Loss: 6.7688
# Epoch [93/900], Step [1], Loss: 6.7569
# Epoch [94/900], Step [1], Loss: 6.7483
# Epoch [95/900], Step [1], Loss: 6.7378
# Epoch [96/900], Step [1], Loss: 6.7284
# Epoch [97/900], Step [1], Loss: 6.7217
# Epoch [98/900], Step [1], Loss: 6.7111
# Epoch [99/900], Step [1], Loss: 6.7031
# Epoch [100/900], Step [1], Loss: 6.6946
# Epoch [101/900], Step [1], Loss: 6.6839
# Epoch [102/900], Step [1], Loss: 6.6725
# Epoch [103/900], Step [1], Loss: 6.6636
# Epoch [104/900], Step [1], Loss: 6.6563
# Epoch [105/900], Step [1], Loss: 6.6459
# Epoch [106/900], Step [1], Loss: 6.6346
# Epoch [107/900], Step [1], Loss: 6.6304
# Epoch [108/900], Step [1], Loss: 6.6193
# Epoch [109/900], Step [1], Loss: 6.6089
# Epoch [110/900], Step [1], Loss: 6.5997
# Epoch [111/900], Step [1], Loss: 6.5932
# Epoch [112/900], Step [1], Loss: 6.5837
# Epoch [113/900], Step [1], Loss: 6.5721
# Epoch [114/900], Step [1], Loss: 6.5643
# Epoch [115/900], Step [1], Loss: 6.5553
# Epoch [116/900], Step [1], Loss: 6.5474
# Epoch [117/900], Step [1], Loss: 6.5375
# Epoch [118/900], Step [1], Loss: 6.5265
# Epoch [119/900], Step [1], Loss: 6.5209
# Epoch [120/900], Step [1], Loss: 6.5094
# Epoch [121/900], Step [1], Loss: 6.5028
# Epoch [122/900], Step [1], Loss: 6.4919
# Epoch [123/900], Step [1], Loss: 6.4829
# Epoch [124/900], Step [1], Loss: 6.4727
# Epoch [125/900], Step [1], Loss: 6.4645
# Epoch [126/900], Step [1], Loss: 6.4570
# Epoch [127/900], Step [1], Loss: 6.4448
# Epoch [128/900], Step [1], Loss: 6.4365
# Epoch [129/900], Step [1], Loss: 6.4273
# Epoch [130/900], Step [1], Loss: 6.4178
# Epoch [131/900], Step [1], Loss: 6.4102
# Epoch [132/900], Step [1], Loss: 6.4018
# Epoch [133/900], Step [1], Loss: 6.3924
# Epoch [134/900], Step [1], Loss: 6.3854
# Epoch [135/900], Step [1], Loss: 6.3767
# Epoch [136/900], Step [1], Loss: 6.3663
# Epoch [137/900], Step [1], Loss: 6.3596
# Epoch [138/900], Step [1], Loss: 6.3498
# Epoch [139/900], Step [1], Loss: 6.3414
# Epoch [140/900], Step [1], Loss: 6.3332
# Epoch [141/900], Step [1], Loss: 6.3250
# Epoch [142/900], Step [1], Loss: 6.3153
# Epoch [143/900], Step [1], Loss: 6.3069
# Epoch [144/900], Step [1], Loss: 6.2993
# Epoch [145/900], Step [1], Loss: 6.2895
# Epoch [146/900], Step [1], Loss: 6.2813
# Epoch [147/900], Step [1], Loss: 6.2720
# Epoch [148/900], Step [1], Loss: 6.2661
# Epoch [149/900], Step [1], Loss: 6.2573
# Epoch [150/900], Step [1], Loss: 6.2470
# Epoch [151/900], Step [1], Loss: 6.2383
# Epoch [152/900], Step [1], Loss: 6.2318
# Epoch [153/900], Step [1], Loss: 6.2213
# Epoch [154/900], Step [1], Loss: 6.2130
# Epoch [155/900], Step [1], Loss: 6.2036
# Epoch [156/900], Step [1], Loss: 6.1957
# Epoch [157/900], Step [1], Loss: 6.1872
# Epoch [158/900], Step [1], Loss: 6.1794
# Epoch [159/900], Step [1], Loss: 6.1720
# Epoch [160/900], Step [1], Loss: 6.1630
# Epoch [161/900], Step [1], Loss: 6.1532
# Epoch [162/900], Step [1], Loss: 6.1465
# Epoch [163/900], Step [1], Loss: 6.1379
# Epoch [164/900], Step [1], Loss: 6.1312
# Epoch [165/900], Step [1], Loss: 6.1234
# Epoch [166/900], Step [1], Loss: 6.1119
# Epoch [167/900], Step [1], Loss: 6.1051
# Epoch [168/900], Step [1], Loss: 6.0973
# Epoch [169/900], Step [1], Loss: 6.0881
# Epoch [170/900], Step [1], Loss: 6.0816
# Epoch [171/900], Step [1], Loss: 6.0727
# Epoch [172/900], Step [1], Loss: 6.0638
# Epoch [173/900], Step [1], Loss: 6.0571
# Epoch [174/900], Step [1], Loss: 6.0485
# Epoch [175/900], Step [1], Loss: 6.0404
# Epoch [176/900], Step [1], Loss: 6.0305
# Epoch [177/900], Step [1], Loss: 6.0215
# Epoch [178/900], Step [1], Loss: 6.0152
# Epoch [179/900], Step [1], Loss: 6.0074
# Epoch [180/900], Step [1], Loss: 5.9997
# Epoch [181/900], Step [1], Loss: 5.9921
# Epoch [182/900], Step [1], Loss: 5.9835
# Epoch [183/900], Step [1], Loss: 5.9775
# Epoch [184/900], Step [1], Loss: 5.9679
# Epoch [185/900], Step [1], Loss: 5.9607
# Epoch [186/900], Step [1], Loss: 5.9493
# Epoch [187/900], Step [1], Loss: 5.9446
# Epoch [188/900], Step [1], Loss: 5.9349
# Epoch [189/900], Step [1], Loss: 5.9280
# Epoch [190/900], Step [1], Loss: 5.9187
# Epoch [191/900], Step [1], Loss: 5.9106
# Epoch [192/900], Step [1], Loss: 5.9053
# Epoch [193/900], Step [1], Loss: 5.8959
# Epoch [194/900], Step [1], Loss: 5.8863
# Epoch [195/900], Step [1], Loss: 5.8814
# Epoch [196/900], Step [1], Loss: 5.8723
# Epoch [197/900], Step [1], Loss: 5.8657
# Epoch [198/900], Step [1], Loss: 5.8563
# Epoch [199/900], Step [1], Loss: 5.8486
# Epoch [200/900], Step [1], Loss: 5.8433
# Epoch [201/900], Step [1], Loss: 5.8352
# Epoch [202/900], Step [1], Loss: 5.8276
# Epoch [203/900], Step [1], Loss: 5.8179
# Epoch [204/900], Step [1], Loss: 5.8097
# Epoch [205/900], Step [1], Loss: 5.8038
# Epoch [206/900], Step [1], Loss: 5.7942
# Epoch [207/900], Step [1], Loss: 5.7879
# Epoch [208/900], Step [1], Loss: 5.7824
# Epoch [209/900], Step [1], Loss: 5.7732
# Epoch [210/900], Step [1], Loss: 5.7646
# Epoch [211/900], Step [1], Loss: 5.7587
# Epoch [212/900], Step [1], Loss: 5.7504
# Epoch [213/900], Step [1], Loss: 5.7447
# Epoch [214/900], Step [1], Loss: 5.7363
# Epoch [215/900], Step [1], Loss: 5.7279
# Epoch [216/900], Step [1], Loss: 5.7200
# Epoch [217/900], Step [1], Loss: 5.7156
# Epoch [218/900], Step [1], Loss: 5.7053
# Epoch [219/900], Step [1], Loss: 5.6997
# Epoch [220/900], Step [1], Loss: 5.6911
# Epoch [221/900], Step [1], Loss: 5.6836
# Epoch [222/900], Step [1], Loss: 5.6765
# Epoch [223/900], Step [1], Loss: 5.6689
# Epoch [224/900], Step [1], Loss: 5.6627
# Epoch [225/900], Step [1], Loss: 5.6556
# Epoch [226/900], Step [1], Loss: 5.6486
# Epoch [227/900], Step [1], Loss: 5.6401
# Epoch [228/900], Step [1], Loss: 5.6344
# Epoch [229/900], Step [1], Loss: 5.6258
# Epoch [230/900], Step [1], Loss: 5.6184
# Epoch [231/900], Step [1], Loss: 5.6106
# Epoch [232/900], Step [1], Loss: 5.6028
# Epoch [233/900], Step [1], Loss: 5.5947
# Epoch [234/900], Step [1], Loss: 5.5879
# Epoch [235/900], Step [1], Loss: 5.5803
# Epoch [236/900], Step [1], Loss: 5.5722
# Epoch [237/900], Step [1], Loss: 5.5656
# Epoch [238/900], Step [1], Loss: 5.5607
# Epoch [239/900], Step [1], Loss: 5.5515
# Epoch [240/900], Step [1], Loss: 5.5441
# Epoch [241/900], Step [1], Loss: 5.5380
# Epoch [242/900], Step [1], Loss: 5.5299
# Epoch [243/900], Step [1], Loss: 5.5223
# Epoch [244/900], Step [1], Loss: 5.5190
# Epoch [245/900], Step [1], Loss: 5.5113
# Epoch [246/900], Step [1], Loss: 5.5024
# Epoch [247/900], Step [1], Loss: 5.4947
# Epoch [248/900], Step [1], Loss: 5.4898
# Epoch [249/900], Step [1], Loss: 5.4804
# Epoch [250/900], Step [1], Loss: 5.4732
# Epoch [251/900], Step [1], Loss: 5.4659
# Epoch [252/900], Step [1], Loss: 5.4580
# Epoch [253/900], Step [1], Loss: 5.4532
# Epoch [254/900], Step [1], Loss: 5.4454
# Epoch [255/900], Step [1], Loss: 5.4398
# Epoch [256/900], Step [1], Loss: 5.4308
# Epoch [257/900], Step [1], Loss: 5.4260
# Epoch [258/900], Step [1], Loss: 5.4174
# Epoch [259/900], Step [1], Loss: 5.4103
# Epoch [260/900], Step [1], Loss: 5.4038
# Epoch [261/900], Step [1], Loss: 5.3953
# Epoch [262/900], Step [1], Loss: 5.3892
# Epoch [263/900], Step [1], Loss: 5.3848
# Epoch [264/900], Step [1], Loss: 5.3758
# Epoch [265/900], Step [1], Loss: 5.3709
# Epoch [266/900], Step [1], Loss: 5.3617
# Epoch [267/900], Step [1], Loss: 5.3544
# Epoch [268/900], Step [1], Loss: 5.3478
# Epoch [269/900], Step [1], Loss: 5.3412
# Epoch [270/900], Step [1], Loss: 5.3347
# Epoch [271/900], Step [1], Loss: 5.3299
# Epoch [272/900], Step [1], Loss: 5.3207
# Epoch [273/900], Step [1], Loss: 5.3142
# Epoch [274/900], Step [1], Loss: 5.3057
# Epoch [275/900], Step [1], Loss: 5.2980
# Epoch [276/900], Step [1], Loss: 5.2919
# Epoch [277/900], Step [1], Loss: 5.2859
# Epoch [278/900], Step [1], Loss: 5.2799
# Epoch [279/900], Step [1], Loss: 5.2712
# Epoch [280/900], Step [1], Loss: 5.2643
# Epoch [281/900], Step [1], Loss: 5.2588
# Epoch [282/900], Step [1], Loss: 5.2521
# Epoch [283/900], Step [1], Loss: 5.2448
# Epoch [284/900], Step [1], Loss: 5.2391
# Epoch [285/900], Step [1], Loss: 5.2321
# Epoch [286/900], Step [1], Loss: 5.2231
# Epoch [287/900], Step [1], Loss: 5.2187
# Epoch [288/900], Step [1], Loss: 5.2109
# Epoch [289/900], Step [1], Loss: 5.2056
# Epoch [290/900], Step [1], Loss: 5.1965
# Epoch [291/900], Step [1], Loss: 5.1918
# Epoch [292/900], Step [1], Loss: 5.1839
# Epoch [293/900], Step [1], Loss: 5.1760
# Epoch [294/900], Step [1], Loss: 5.1707
# Epoch [295/900], Step [1], Loss: 5.1659
# Epoch [296/900], Step [1], Loss: 5.1574
# Epoch [297/900], Step [1], Loss: 5.1520
# Epoch [298/900], Step [1], Loss: 5.1439
# Epoch [299/900], Step [1], Loss: 5.1354
# Epoch [300/900], Step [1], Loss: 5.1289
# Epoch [301/900], Step [1], Loss: 5.1212
# Epoch [302/900], Step [1], Loss: 5.1168
# Epoch [303/900], Step [1], Loss: 5.1097
# Epoch [304/900], Step [1], Loss: 5.1038
# Epoch [305/900], Step [1], Loss: 5.0960
# Epoch [306/900], Step [1], Loss: 5.0888
# Epoch [307/900], Step [1], Loss: 5.0837
# Epoch [308/900], Step [1], Loss: 5.0760
# Epoch [309/900], Step [1], Loss: 5.0684
# Epoch [310/900], Step [1], Loss: 5.0642
# Epoch [311/900], Step [1], Loss: 5.0551
# Epoch [312/900], Step [1], Loss: 5.0502
# Epoch [313/900], Step [1], Loss: 5.0440
# Epoch [314/900], Step [1], Loss: 5.0370
# Epoch [315/900], Step [1], Loss: 5.0319
# Epoch [316/900], Step [1], Loss: 5.0255
# Epoch [317/900], Step [1], Loss: 5.0168
# Epoch [318/900], Step [1], Loss: 5.0112
# Epoch [319/900], Step [1], Loss: 5.0026
# Epoch [320/900], Step [1], Loss: 4.9977
# Epoch [321/900], Step [1], Loss: 4.9907
# Epoch [322/900], Step [1], Loss: 4.9839
# Epoch [323/900], Step [1], Loss: 4.9753
# Epoch [324/900], Step [1], Loss: 4.9705
# Epoch [325/900], Step [1], Loss: 4.9633
# Epoch [326/900], Step [1], Loss: 4.9582
# Epoch [327/900], Step [1], Loss: 4.9519
# Epoch [328/900], Step [1], Loss: 4.9452
# Epoch [329/900], Step [1], Loss: 4.9377
# Epoch [330/900], Step [1], Loss: 4.9311
# Epoch [331/900], Step [1], Loss: 4.9264
# Epoch [332/900], Step [1], Loss: 4.9171
# Epoch [333/900], Step [1], Loss: 4.9131
# Epoch [334/900], Step [1], Loss: 4.9062
# Epoch [335/900], Step [1], Loss: 4.9008
# Epoch [336/900], Step [1], Loss: 4.8932
# Epoch [337/900], Step [1], Loss: 4.8859
# Epoch [338/900], Step [1], Loss: 4.8822
# Epoch [339/900], Step [1], Loss: 4.8742
# Epoch [340/900], Step [1], Loss: 4.8669
# Epoch [341/900], Step [1], Loss: 4.8594
# Epoch [342/900], Step [1], Loss: 4.8542
# Epoch [343/900], Step [1], Loss: 4.8482
# Epoch [344/900], Step [1], Loss: 4.8411
# Epoch [345/900], Step [1], Loss: 4.8370
# Epoch [346/900], Step [1], Loss: 4.8300
# Epoch [347/900], Step [1], Loss: 4.8223
# Epoch [348/900], Step [1], Loss: 4.8139
# Epoch [349/900], Step [1], Loss: 4.8101
# Epoch [350/900], Step [1], Loss: 4.8022
# Epoch [351/900], Step [1], Loss: 4.7971
# Epoch [352/900], Step [1], Loss: 4.7888
# Epoch [353/900], Step [1], Loss: 4.7821
# Epoch [354/900], Step [1], Loss: 4.7766
# Epoch [355/900], Step [1], Loss: 4.7731
# Epoch [356/900], Step [1], Loss: 4.7662
# Epoch [357/900], Step [1], Loss: 4.7579
# Epoch [358/900], Step [1], Loss: 4.7503
# Epoch [359/900], Step [1], Loss: 4.7439
# Epoch [360/900], Step [1], Loss: 4.7380
# Epoch [361/900], Step [1], Loss: 4.7329
# Epoch [362/900], Step [1], Loss: 4.7249
# Epoch [363/900], Step [1], Loss: 4.7187
# Epoch [364/900], Step [1], Loss: 4.7143
# Epoch [365/900], Step [1], Loss: 4.7066
# Epoch [366/900], Step [1], Loss: 4.7018
# Epoch [367/900], Step [1], Loss: 4.6937
# Epoch [368/900], Step [1], Loss: 4.6871
# Epoch [369/900], Step [1], Loss: 4.6833
# Epoch [370/900], Step [1], Loss: 4.6768
# Epoch [371/900], Step [1], Loss: 4.6701
# Epoch [372/900], Step [1], Loss: 4.6615
# Epoch [373/900], Step [1], Loss: 4.6573
# Epoch [374/900], Step [1], Loss: 4.6512
# Epoch [375/900], Step [1], Loss: 4.6437
# Epoch [376/900], Step [1], Loss: 4.6405
# Epoch [377/900], Step [1], Loss: 4.6310
# Epoch [378/900], Step [1], Loss: 4.6260
# Epoch [379/900], Step [1], Loss: 4.6179
# Epoch [380/900], Step [1], Loss: 4.6119
# Epoch [381/900], Step [1], Loss: 4.6059
# Epoch [382/900], Step [1], Loss: 4.6009
# Epoch [383/900], Step [1], Loss: 4.5939
# Epoch [384/900], Step [1], Loss: 4.5901
# Epoch [385/900], Step [1], Loss: 4.5832
# Epoch [386/900], Step [1], Loss: 4.5776
# Epoch [387/900], Step [1], Loss: 4.5715
# Epoch [388/900], Step [1], Loss: 4.5631
# Epoch [389/900], Step [1], Loss: 4.5571
# Epoch [390/900], Step [1], Loss: 4.5514
# Epoch [391/900], Step [1], Loss: 4.5470
# Epoch [392/900], Step [1], Loss: 4.5388
# Epoch [393/900], Step [1], Loss: 4.5337
# Epoch [394/900], Step [1], Loss: 4.5290
# Epoch [395/900], Step [1], Loss: 4.5219
# Epoch [396/900], Step [1], Loss: 4.5136
# Epoch [397/900], Step [1], Loss: 4.5103
# Epoch [398/900], Step [1], Loss: 4.5039
# Epoch [399/900], Step [1], Loss: 4.4934
# Epoch [400/900], Step [1], Loss: 4.4908
# Epoch [401/900], Step [1], Loss: 4.4842
# Epoch [402/900], Step [1], Loss: 4.4786
# Epoch [403/900], Step [1], Loss: 4.4695
# Epoch [404/900], Step [1], Loss: 4.4669
# Epoch [405/900], Step [1], Loss: 4.4593
# Epoch [406/900], Step [1], Loss: 4.4542
# Epoch [407/900], Step [1], Loss: 4.4455
# Epoch [408/900], Step [1], Loss: 4.4423
# Epoch [409/900], Step [1], Loss: 4.4352
# Epoch [410/900], Step [1], Loss: 4.4275
# Epoch [411/900], Step [1], Loss: 4.4237
# Epoch [412/900], Step [1], Loss: 4.4185
# Epoch [413/900], Step [1], Loss: 4.4096
# Epoch [414/900], Step [1], Loss: 4.4044
# Epoch [415/900], Step [1], Loss: 4.3989
# Epoch [416/900], Step [1], Loss: 4.3923
# Epoch [417/900], Step [1], Loss: 4.3842
# Epoch [418/900], Step [1], Loss: 4.3799
# Epoch [419/900], Step [1], Loss: 4.3749
# Epoch [420/900], Step [1], Loss: 4.3681
# Epoch [421/900], Step [1], Loss: 4.3616
# Epoch [422/900], Step [1], Loss: 4.3558
# Epoch [423/900], Step [1], Loss: 4.3493
# Epoch [424/900], Step [1], Loss: 4.3440
# Epoch [425/900], Step [1], Loss: 4.3404
# Epoch [426/900], Step [1], Loss: 4.3314
# Epoch [427/900], Step [1], Loss: 4.3284
# Epoch [428/900], Step [1], Loss: 4.3198
# Epoch [429/900], Step [1], Loss: 4.3159
# Epoch [430/900], Step [1], Loss: 4.3102
# Epoch [431/900], Step [1], Loss: 4.3021
# Epoch [432/900], Step [1], Loss: 4.2956
# Epoch [433/900], Step [1], Loss: 4.2923
# Epoch [434/900], Step [1], Loss: 4.2846
# Epoch [435/900], Step [1], Loss: 4.2795
# Epoch [436/900], Step [1], Loss: 4.2721
# Epoch [437/900], Step [1], Loss: 4.2673
# Epoch [438/900], Step [1], Loss: 4.2593
# Epoch [439/900], Step [1], Loss: 4.2551
# Epoch [440/900], Step [1], Loss: 4.2489
# Epoch [441/900], Step [1], Loss: 4.2422
# Epoch [442/900], Step [1], Loss: 4.2379
# Epoch [443/900], Step [1], Loss: 4.2328
# Epoch [444/900], Step [1], Loss: 4.2250
# Epoch [445/900], Step [1], Loss: 4.2196
# Epoch [446/900], Step [1], Loss: 4.2141
# Epoch [447/900], Step [1], Loss: 4.2081
# Epoch [448/900], Step [1], Loss: 4.2027
# Epoch [449/900], Step [1], Loss: 4.1978
# Epoch [450/900], Step [1], Loss: 4.1903
# Epoch [451/900], Step [1], Loss: 4.1870
# Epoch [452/900], Step [1], Loss: 4.1793
# Epoch [453/900], Step [1], Loss: 4.1740
# Epoch [454/900], Step [1], Loss: 4.1675
# Epoch [455/900], Step [1], Loss: 4.1622
# Epoch [456/900], Step [1], Loss: 4.1545
# Epoch [457/900], Step [1], Loss: 4.1501
# Epoch [458/900], Step [1], Loss: 4.1445
# Epoch [459/900], Step [1], Loss: 4.1373
# Epoch [460/900], Step [1], Loss: 4.1321
# Epoch [461/900], Step [1], Loss: 4.1268
# Epoch [462/900], Step [1], Loss: 4.1221
# Epoch [463/900], Step [1], Loss: 4.1154
# Epoch [464/900], Step [1], Loss: 4.1099
# Epoch [465/900], Step [1], Loss: 4.1052
# Epoch [466/900], Step [1], Loss: 4.0997
# Epoch [467/900], Step [1], Loss: 4.0948
# Epoch [468/900], Step [1], Loss: 4.0872
# Epoch [469/900], Step [1], Loss: 4.0787
# Epoch [470/900], Step [1], Loss: 4.0761
# Epoch [471/900], Step [1], Loss: 4.0710
# Epoch [472/900], Step [1], Loss: 4.0627
# Epoch [473/900], Step [1], Loss: 4.0581
# Epoch [474/900], Step [1], Loss: 4.0542
# Epoch [475/900], Step [1], Loss: 4.0454
# Epoch [476/900], Step [1], Loss: 4.0390
# Epoch [477/900], Step [1], Loss: 4.0369
# Epoch [478/900], Step [1], Loss: 4.0324
# Epoch [479/900], Step [1], Loss: 4.0226
# Epoch [480/900], Step [1], Loss: 4.0200
# Epoch [481/900], Step [1], Loss: 4.0143
# Epoch [482/900], Step [1], Loss: 4.0056
# Epoch [483/900], Step [1], Loss: 4.0025
# Epoch [484/900], Step [1], Loss: 3.9935
# Epoch [485/900], Step [1], Loss: 3.9891
# Epoch [486/900], Step [1], Loss: 3.9853
# Epoch [487/900], Step [1], Loss: 3.9778
# Epoch [488/900], Step [1], Loss: 3.9732
# Epoch [489/900], Step [1], Loss: 3.9682
# Epoch [490/900], Step [1], Loss: 3.9617
# Epoch [491/900], Step [1], Loss: 3.9554
# Epoch [492/900], Step [1], Loss: 3.9487
# Epoch [493/900], Step [1], Loss: 3.9449
# Epoch [494/900], Step [1], Loss: 3.9391
# Epoch [495/900], Step [1], Loss: 3.9348
# Epoch [496/900], Step [1], Loss: 3.9305
# Epoch [497/900], Step [1], Loss: 3.9216
# Epoch [498/900], Step [1], Loss: 3.9170
# Epoch [499/900], Step [1], Loss: 3.9118
# Epoch [500/900], Step [1], Loss: 3.9060
# Epoch [501/900], Step [1], Loss: 3.8998
# Epoch [502/900], Step [1], Loss: 3.8958
# Epoch [503/900], Step [1], Loss: 3.8908
# Epoch [504/900], Step [1], Loss: 3.8844
# Epoch [505/900], Step [1], Loss: 3.8776
# Epoch [506/900], Step [1], Loss: 3.8706
# Epoch [507/900], Step [1], Loss: 3.8680
# Epoch [508/900], Step [1], Loss: 3.8622
# Epoch [509/900], Step [1], Loss: 3.8569
# Epoch [510/900], Step [1], Loss: 3.8498
# Epoch [511/900], Step [1], Loss: 3.8435
# Epoch [512/900], Step [1], Loss: 3.8395
# Epoch [513/900], Step [1], Loss: 3.8333
# Epoch [514/900], Step [1], Loss: 3.8276
# Epoch [515/900], Step [1], Loss: 3.8245
# Epoch [516/900], Step [1], Loss: 3.8187
# Epoch [517/900], Step [1], Loss: 3.8147
# Epoch [518/900], Step [1], Loss: 3.8075
# Epoch [519/900], Step [1], Loss: 3.8030
# Epoch [520/900], Step [1], Loss: 3.7986
# Epoch [521/900], Step [1], Loss: 3.7909
# Epoch [522/900], Step [1], Loss: 3.7856
# Epoch [523/900], Step [1], Loss: 3.7825
# Epoch [524/900], Step [1], Loss: 3.7748
# Epoch [525/900], Step [1], Loss: 3.7686
# Epoch [526/900], Step [1], Loss: 3.7626
# Epoch [527/900], Step [1], Loss: 3.7596
# Epoch [528/900], Step [1], Loss: 3.7531
# Epoch [529/900], Step [1], Loss: 3.7466
# Epoch [530/900], Step [1], Loss: 3.7432
# Epoch [531/900], Step [1], Loss: 3.7365
# Epoch [532/900], Step [1], Loss: 3.7311
# Epoch [533/900], Step [1], Loss: 3.7249
# Epoch [534/900], Step [1], Loss: 3.7216
# Epoch [535/900], Step [1], Loss: 3.7154
# Epoch [536/900], Step [1], Loss: 3.7075
# Epoch [537/900], Step [1], Loss: 3.7060
# Epoch [538/900], Step [1], Loss: 3.6971
# Epoch [539/900], Step [1], Loss: 3.6955
# Epoch [540/900], Step [1], Loss: 3.6880
# Epoch [541/900], Step [1], Loss: 3.6819
# Epoch [542/900], Step [1], Loss: 3.6780
# Epoch [543/900], Step [1], Loss: 3.6747
# Epoch [544/900], Step [1], Loss: 3.6688
# Epoch [545/900], Step [1], Loss: 3.6640
# Epoch [546/900], Step [1], Loss: 3.6567
# Epoch [547/900], Step [1], Loss: 3.6525
# Epoch [548/900], Step [1], Loss: 3.6474
# Epoch [549/900], Step [1], Loss: 3.6408
# Epoch [550/900], Step [1], Loss: 3.6369
# Epoch [551/900], Step [1], Loss: 3.6280
# Epoch [552/900], Step [1], Loss: 3.6264
# Epoch [553/900], Step [1], Loss: 3.6203
# Epoch [554/900], Step [1], Loss: 3.6161
# Epoch [555/900], Step [1], Loss: 3.6073
# Epoch [556/900], Step [1], Loss: 3.6043
# Epoch [557/900], Step [1], Loss: 3.6014
# Epoch [558/900], Step [1], Loss: 3.5944
# Epoch [559/900], Step [1], Loss: 3.5881
# Epoch [560/900], Step [1], Loss: 3.5827
# Epoch [561/900], Step [1], Loss: 3.5762
# Epoch [562/900], Step [1], Loss: 3.5737
# Epoch [563/900], Step [1], Loss: 3.5676
# Epoch [564/900], Step [1], Loss: 3.5627
# Epoch [565/900], Step [1], Loss: 3.5550
# Epoch [566/900], Step [1], Loss: 3.5526
# Epoch [567/900], Step [1], Loss: 3.5469
# Epoch [568/900], Step [1], Loss: 3.5416
# Epoch [569/900], Step [1], Loss: 3.5364
# Epoch [570/900], Step [1], Loss: 3.5300
# Epoch [571/900], Step [1], Loss: 3.5250
# Epoch [572/900], Step [1], Loss: 3.5194
# Epoch [573/900], Step [1], Loss: 3.5139
# Epoch [574/900], Step [1], Loss: 3.5080
# Epoch [575/900], Step [1], Loss: 3.5063
# Epoch [576/900], Step [1], Loss: 3.4989
# Epoch [577/900], Step [1], Loss: 3.4976
# Epoch [578/900], Step [1], Loss: 3.4890
# Epoch [579/900], Step [1], Loss: 3.4844
# Epoch [580/900], Step [1], Loss: 3.4791
# Epoch [581/900], Step [1], Loss: 3.4737
# Epoch [582/900], Step [1], Loss: 3.4715
# Epoch [583/900], Step [1], Loss: 3.4661
# Epoch [584/900], Step [1], Loss: 3.4607
# Epoch [585/900], Step [1], Loss: 3.4519
# Epoch [586/900], Step [1], Loss: 3.4471
# Epoch [587/900], Step [1], Loss: 3.4433
# Epoch [588/900], Step [1], Loss: 3.4387
# Epoch [589/900], Step [1], Loss: 3.4329
# Epoch [590/900], Step [1], Loss: 3.4272
# Epoch [591/900], Step [1], Loss: 3.4247
# Epoch [592/900], Step [1], Loss: 3.4182
# Epoch [593/900], Step [1], Loss: 3.4145
# Epoch [594/900], Step [1], Loss: 3.4080
# Epoch [595/900], Step [1], Loss: 3.4036
# Epoch [596/900], Step [1], Loss: 3.3973
# Epoch [597/900], Step [1], Loss: 3.3935
# Epoch [598/900], Step [1], Loss: 3.3899
# Epoch [599/900], Step [1], Loss: 3.3828
# Epoch [600/900], Step [1], Loss: 3.3795
# Epoch [601/900], Step [1], Loss: 3.3743
# Epoch [602/900], Step [1], Loss: 3.3684
# Epoch [603/900], Step [1], Loss: 3.3634
# Epoch [604/900], Step [1], Loss: 3.3587
# Epoch [605/900], Step [1], Loss: 3.3549
# Epoch [606/900], Step [1], Loss: 3.3477
# Epoch [607/900], Step [1], Loss: 3.3436
# Epoch [608/900], Step [1], Loss: 3.3375
# Epoch [609/900], Step [1], Loss: 3.3347
# Epoch [610/900], Step [1], Loss: 3.3266
# Epoch [611/900], Step [1], Loss: 3.3248
# Epoch [612/900], Step [1], Loss: 3.3183
# Epoch [613/900], Step [1], Loss: 3.3132
# Epoch [614/900], Step [1], Loss: 3.3077
# Epoch [615/900], Step [1], Loss: 3.3014
# Epoch [616/900], Step [1], Loss: 3.2989
# Epoch [617/900], Step [1], Loss: 3.2959
# Epoch [618/900], Step [1], Loss: 3.2866
# Epoch [619/900], Step [1], Loss: 3.2829
# Epoch [620/900], Step [1], Loss: 3.2798
# Epoch [621/900], Step [1], Loss: 3.2737
# Epoch [622/900], Step [1], Loss: 3.2701
# Epoch [623/900], Step [1], Loss: 3.2660
# Epoch [624/900], Step [1], Loss: 3.2575
# Epoch [625/900], Step [1], Loss: 3.2536
# Epoch [626/900], Step [1], Loss: 3.2483
# Epoch [627/900], Step [1], Loss: 3.2448
# Epoch [628/900], Step [1], Loss: 3.2388
# Epoch [629/900], Step [1], Loss: 3.2350
# Epoch [630/900], Step [1], Loss: 3.2294
# Epoch [631/900], Step [1], Loss: 3.2270
# Epoch [632/900], Step [1], Loss: 3.2206
# Epoch [633/900], Step [1], Loss: 3.2164
# Epoch [634/900], Step [1], Loss: 3.2123
# Epoch [635/900], Step [1], Loss: 3.2050
# Epoch [636/900], Step [1], Loss: 3.2011
# Epoch [637/900], Step [1], Loss: 3.1945
# Epoch [638/900], Step [1], Loss: 3.1926
# Epoch [639/900], Step [1], Loss: 3.1879
# Epoch [640/900], Step [1], Loss: 3.1822
# Epoch [641/900], Step [1], Loss: 3.1783
# Epoch [642/900], Step [1], Loss: 3.1732
# Epoch [643/900], Step [1], Loss: 3.1691
# Epoch [644/900], Step [1], Loss: 3.1610
# Epoch [645/900], Step [1], Loss: 3.1601
# Epoch [646/900], Step [1], Loss: 3.1544
# Epoch [647/900], Step [1], Loss: 3.1499
# Epoch [648/900], Step [1], Loss: 3.1448
# Epoch [649/900], Step [1], Loss: 3.1380
# Epoch [650/900], Step [1], Loss: 3.1340
# Epoch [651/900], Step [1], Loss: 3.1297
# Epoch [652/900], Step [1], Loss: 3.1251
# Epoch [653/900], Step [1], Loss: 3.1198
# Epoch [654/900], Step [1], Loss: 3.1138
# Epoch [655/900], Step [1], Loss: 3.1110
# Epoch [656/900], Step [1], Loss: 3.1048
# Epoch [657/900], Step [1], Loss: 3.1022
# Epoch [658/900], Step [1], Loss: 3.0987
# Epoch [659/900], Step [1], Loss: 3.0918
# Epoch [660/900], Step [1], Loss: 3.0883
# Epoch [661/900], Step [1], Loss: 3.0815
# Epoch [662/900], Step [1], Loss: 3.0780
# Epoch [663/900], Step [1], Loss: 3.0718
# Epoch [664/900], Step [1], Loss: 3.0700
# Epoch [665/900], Step [1], Loss: 3.0642
# Epoch [666/900], Step [1], Loss: 3.0573
# Epoch [667/900], Step [1], Loss: 3.0551
# Epoch [668/900], Step [1], Loss: 3.0492
# Epoch [669/900], Step [1], Loss: 3.0472
# Epoch [670/900], Step [1], Loss: 3.0407
# Epoch [671/900], Step [1], Loss: 3.0371
# Epoch [672/900], Step [1], Loss: 3.0327
# Epoch [673/900], Step [1], Loss: 3.0273
# Epoch [674/900], Step [1], Loss: 3.0219
# Epoch [675/900], Step [1], Loss: 3.0180
# Epoch [676/900], Step [1], Loss: 3.0149
# Epoch [677/900], Step [1], Loss: 3.0097
# Epoch [678/900], Step [1], Loss: 3.0022
# Epoch [679/900], Step [1], Loss: 2.9990
# Epoch [680/900], Step [1], Loss: 2.9948
# Epoch [681/900], Step [1], Loss: 2.9904
# Epoch [682/900], Step [1], Loss: 2.9848
# Epoch [683/900], Step [1], Loss: 2.9815
# Epoch [684/900], Step [1], Loss: 2.9735
# Epoch [685/900], Step [1], Loss: 2.9722
# Epoch [686/900], Step [1], Loss: 2.9669
# Epoch [687/900], Step [1], Loss: 2.9612
# Epoch [688/900], Step [1], Loss: 2.9582
# Epoch [689/900], Step [1], Loss: 2.9537
# Epoch [690/900], Step [1], Loss: 2.9477
# Epoch [691/900], Step [1], Loss: 2.9463
# Epoch [692/900], Step [1], Loss: 2.9392
# Epoch [693/900], Step [1], Loss: 2.9334
# Epoch [694/900], Step [1], Loss: 2.9305
# Epoch [695/900], Step [1], Loss: 2.9257
# Epoch [696/900], Step [1], Loss: 2.9225
# Epoch [697/900], Step [1], Loss: 2.9169
# Epoch [698/900], Step [1], Loss: 2.9111
# Epoch [699/900], Step [1], Loss: 2.9091
# Epoch [700/900], Step [1], Loss: 2.9026
# Epoch [701/900], Step [1], Loss: 2.8984
# Epoch [702/900], Step [1], Loss: 2.8918
# Epoch [703/900], Step [1], Loss: 2.8917
# Epoch [704/900], Step [1], Loss: 2.8841
# Epoch [705/900], Step [1], Loss: 2.8799
# Epoch [706/900], Step [1], Loss: 2.8752
# Epoch [707/900], Step [1], Loss: 2.8720
# Epoch [708/900], Step [1], Loss: 2.8689
# Epoch [709/900], Step [1], Loss: 2.8625
# Epoch [710/900], Step [1], Loss: 2.8595
# Epoch [711/900], Step [1], Loss: 2.8549
# Epoch [712/900], Step [1], Loss: 2.8483
# Epoch [713/900], Step [1], Loss: 2.8454
# Epoch [714/900], Step [1], Loss: 2.8409
# Epoch [715/900], Step [1], Loss: 2.8365
# Epoch [716/900], Step [1], Loss: 2.8317
# Epoch [717/900], Step [1], Loss: 2.8279
# Epoch [718/900], Step [1], Loss: 2.8249
# Epoch [719/900], Step [1], Loss: 2.8204
# Epoch [720/900], Step [1], Loss: 2.8127
# Epoch [721/900], Step [1], Loss: 2.8123
# Epoch [722/900], Step [1], Loss: 2.8058
# Epoch [723/900], Step [1], Loss: 2.8025
# Epoch [724/900], Step [1], Loss: 2.7993
# Epoch [725/900], Step [1], Loss: 2.7931
# Epoch [726/900], Step [1], Loss: 2.7879
# Epoch [727/900], Step [1], Loss: 2.7841
# Epoch [728/900], Step [1], Loss: 2.7801
# Epoch [729/900], Step [1], Loss: 2.7770
# Epoch [730/900], Step [1], Loss: 2.7703
# Epoch [731/900], Step [1], Loss: 2.7677
# Epoch [732/900], Step [1], Loss: 2.7637
# Epoch [733/900], Step [1], Loss: 2.7561
# Epoch [734/900], Step [1], Loss: 2.7554
# Epoch [735/900], Step [1], Loss: 2.7508
# Epoch [736/900], Step [1], Loss: 2.7450
# Epoch [737/900], Step [1], Loss: 2.7390
# Epoch [738/900], Step [1], Loss: 2.7387
# Epoch [739/900], Step [1], Loss: 2.7306
# Epoch [740/900], Step [1], Loss: 2.7300
# Epoch [741/900], Step [1], Loss: 2.7222
# Epoch [742/900], Step [1], Loss: 2.7183
# Epoch [743/900], Step [1], Loss: 2.7160
# Epoch [744/900], Step [1], Loss: 2.7120
# Epoch [745/900], Step [1], Loss: 2.7043
# Epoch [746/900], Step [1], Loss: 2.7027
# Epoch [747/900], Step [1], Loss: 2.6999
# Epoch [748/900], Step [1], Loss: 2.6917
# Epoch [749/900], Step [1], Loss: 2.6896
# Epoch [750/900], Step [1], Loss: 2.6845
# Epoch [751/900], Step [1], Loss: 2.6815
# Epoch [752/900], Step [1], Loss: 2.6763
# Epoch [753/900], Step [1], Loss: 2.6722
# Epoch [754/900], Step [1], Loss: 2.6701
# Epoch [755/900], Step [1], Loss: 2.6649
# Epoch [756/900], Step [1], Loss: 2.6598
# Epoch [757/900], Step [1], Loss: 2.6574
# Epoch [758/900], Step [1], Loss: 2.6520
# Epoch [759/900], Step [1], Loss: 2.6480
# Epoch [760/900], Step [1], Loss: 2.6443
# Epoch [761/900], Step [1], Loss: 2.6400
# Epoch [762/900], Step [1], Loss: 2.6353
# Epoch [763/900], Step [1], Loss: 2.6326
# Epoch [764/900], Step [1], Loss: 2.6261
# Epoch [765/900], Step [1], Loss: 2.6210
# Epoch [766/900], Step [1], Loss: 2.6188
# Epoch [767/900], Step [1], Loss: 2.6149
# Epoch [768/900], Step [1], Loss: 2.6107
# Epoch [769/900], Step [1], Loss: 2.6082
# Epoch [770/900], Step [1], Loss: 2.6020
# Epoch [771/900], Step [1], Loss: 2.5978
# Epoch [772/900], Step [1], Loss: 2.5917
# Epoch [773/900], Step [1], Loss: 2.5886
# Epoch [774/900], Step [1], Loss: 2.5860
# Epoch [775/900], Step [1], Loss: 2.5817
# Epoch [776/900], Step [1], Loss: 2.5764
# Epoch [777/900], Step [1], Loss: 2.5739
# Epoch [778/900], Step [1], Loss: 2.5672
# Epoch [779/900], Step [1], Loss: 2.5633
# Epoch [780/900], Step [1], Loss: 2.5615
# Epoch [781/900], Step [1], Loss: 2.5591
# Epoch [782/900], Step [1], Loss: 2.5532
# Epoch [783/900], Step [1], Loss: 2.5491
# Epoch [784/900], Step [1], Loss: 2.5442
# Epoch [785/900], Step [1], Loss: 2.5413
# Epoch [786/900], Step [1], Loss: 2.5382
# Epoch [787/900], Step [1], Loss: 2.5320
# Epoch [788/900], Step [1], Loss: 2.5284
# Epoch [789/900], Step [1], Loss: 2.5238
# Epoch [790/900], Step [1], Loss: 2.5210
# Epoch [791/900], Step [1], Loss: 2.5172
# Epoch [792/900], Step [1], Loss: 2.5119
# Epoch [793/900], Step [1], Loss: 2.5075
# Epoch [794/900], Step [1], Loss: 2.5056
# Epoch [795/900], Step [1], Loss: 2.5023
# Epoch [796/900], Step [1], Loss: 2.4968
# Epoch [797/900], Step [1], Loss: 2.4925
# Epoch [798/900], Step [1], Loss: 2.4884
# Epoch [799/900], Step [1], Loss: 2.4846
# Epoch [800/900], Step [1], Loss: 2.4806
# Epoch [801/900], Step [1], Loss: 2.4766
# Epoch [802/900], Step [1], Loss: 2.4726
# Epoch [803/900], Step [1], Loss: 2.4689
# Epoch [804/900], Step [1], Loss: 2.4650
# Epoch [805/900], Step [1], Loss: 2.4622
# Epoch [806/900], Step [1], Loss: 2.4571
# Epoch [807/900], Step [1], Loss: 2.4534
# Epoch [808/900], Step [1], Loss: 2.4482
# Epoch [809/900], Step [1], Loss: 2.4467
# Epoch [810/900], Step [1], Loss: 2.4402
# Epoch [811/900], Step [1], Loss: 2.4373
# Epoch [812/900], Step [1], Loss: 2.4363
# Epoch [813/900], Step [1], Loss: 2.4284
# Epoch [814/900], Step [1], Loss: 2.4243
# Epoch [815/900], Step [1], Loss: 2.4221
# Epoch [816/900], Step [1], Loss: 2.4161
# Epoch [817/900], Step [1], Loss: 2.4134
# Epoch [818/900], Step [1], Loss: 2.4125
# Epoch [819/900], Step [1], Loss: 2.4045
# Epoch [820/900], Step [1], Loss: 2.4039
# Epoch [821/900], Step [1], Loss: 2.3985
# Epoch [822/900], Step [1], Loss: 2.3940
# Epoch [823/900], Step [1], Loss: 2.3904
# Epoch [824/900], Step [1], Loss: 2.3851
# Epoch [825/900], Step [1], Loss: 2.3852
# Epoch [826/900], Step [1], Loss: 2.3789
# Epoch [827/900], Step [1], Loss: 2.3735
# Epoch [828/900], Step [1], Loss: 2.3718
# Epoch [829/900], Step [1], Loss: 2.3681
# Epoch [830/900], Step [1], Loss: 2.3668
# Epoch [831/900], Step [1], Loss: 2.3609
# Epoch [832/900], Step [1], Loss: 2.3567
# Epoch [833/900], Step [1], Loss: 2.3528
# Epoch [834/900], Step [1], Loss: 2.3474
# Epoch [835/900], Step [1], Loss: 2.3441
# Epoch [836/900], Step [1], Loss: 2.3405
# Epoch [837/900], Step [1], Loss: 2.3379
# Epoch [838/900], Step [1], Loss: 2.3353
# Epoch [839/900], Step [1], Loss: 2.3293
# Epoch [840/900], Step [1], Loss: 2.3264
# Epoch [841/900], Step [1], Loss: 2.3229
# Epoch [842/900], Step [1], Loss: 2.3189
# Epoch [843/900], Step [1], Loss: 2.3165
# Epoch [844/900], Step [1], Loss: 2.3111
# Epoch [845/900], Step [1], Loss: 2.3098
# Epoch [846/900], Step [1], Loss: 2.3040
# Epoch [847/900], Step [1], Loss: 2.2987
# Epoch [848/900], Step [1], Loss: 2.2966
# Epoch [849/900], Step [1], Loss: 2.2935
# Epoch [850/900], Step [1], Loss: 2.2909
# Epoch [851/900], Step [1], Loss: 2.2860
# Epoch [852/900], Step [1], Loss: 2.2831
# Epoch [853/900], Step [1], Loss: 2.2786
# Epoch [854/900], Step [1], Loss: 2.2767
# Epoch [855/900], Step [1], Loss: 2.2708
# Epoch [856/900], Step [1], Loss: 2.2669
# Epoch [857/900], Step [1], Loss: 2.2648
# Epoch [858/900], Step [1], Loss: 2.2606
# Epoch [859/900], Step [1], Loss: 2.2558
# Epoch [860/900], Step [1], Loss: 2.2528
# Epoch [861/900], Step [1], Loss: 2.2481
# Epoch [862/900], Step [1], Loss: 2.2457
# Epoch [863/900], Step [1], Loss: 2.2423
# Epoch [864/900], Step [1], Loss: 2.2404
# Epoch [865/900], Step [1], Loss: 2.2345
# Epoch [866/900], Step [1], Loss: 2.2288
# Epoch [867/900], Step [1], Loss: 2.2286
# Epoch [868/900], Step [1], Loss: 2.2250
# Epoch [869/900], Step [1], Loss: 2.2187
# Epoch [870/900], Step [1], Loss: 2.2156
# Epoch [871/900], Step [1], Loss: 2.2114
# Epoch [872/900], Step [1], Loss: 2.2101
# Epoch [873/900], Step [1], Loss: 2.2050
# Epoch [874/900], Step [1], Loss: 2.2039
# Epoch [875/900], Step [1], Loss: 2.1983
# Epoch [876/900], Step [1], Loss: 2.1956
# Epoch [877/900], Step [1], Loss: 2.1919
# Epoch [878/900], Step [1], Loss: 2.1868
# Epoch [879/900], Step [1], Loss: 2.1836
# Epoch [880/900], Step [1], Loss: 2.1804
# Epoch [881/900], Step [1], Loss: 2.1775
# Epoch [882/900], Step [1], Loss: 2.1729
# Epoch [883/900], Step [1], Loss: 2.1703
# Epoch [884/900], Step [1], Loss: 2.1663
# Epoch [885/900], Step [1], Loss: 2.1640
# Epoch [886/900], Step [1], Loss: 2.1612
# Epoch [887/900], Step [1], Loss: 2.1558
# Epoch [888/900], Step [1], Loss: 2.1523
# Epoch [889/900], Step [1], Loss: 2.1488
# Epoch [890/900], Step [1], Loss: 2.1462
# Epoch [891/900], Step [1], Loss: 2.1416
# Epoch [892/900], Step [1], Loss: 2.1387
# Epoch [893/900], Step [1], Loss: 2.1362
# Epoch [894/900], Step [1], Loss: 2.1324
# Epoch [895/900], Step [1], Loss: 2.1263
# Epoch [896/900], Step [1], Loss: 2.1255
# Epoch [897/900], Step [1], Loss: 2.1208
# Epoch [898/900], Step [1], Loss: 2.1170
# Epoch [899/900], Step [1], Loss: 2.1165
# Epoch [900/900], Step [1], Loss: 2.1120

# %%
predicted_abcd[1,1,:,:].shape
# Out:
# torch.Size([64, 64])

# %%
a_pre = predicted_abcd[1,0,:,:].detach().cpu().numpy()
b_pre = predicted_abcd[1,1,:,:].detach().cpu().numpy()
c_pre = predicted_abcd[1,2,:,:].detach().cpu().numpy()
d_pre = predicted_abcd[1,3,:,:].detach().cpu().numpy()

# %%
a_test_grad_x, a_test_grad_y = np.gradient(a_pre, dx)
b_test_grad_x, b_test_grad_y = np.gradient(b_pre, dx)
c_test_grad_x, c_test_grad_y = np.gradient(c_pre, dx)
d_test_grad_x, d_test_grad_y = np.gradient(d_pre, dx)

# %%
# U_x_pred_test = a_pre * b_test_grad_x - b_pre * a_test_grad_x + c_pre * d_test_grad_x - d_pre * c_test_grad_x
# U_y_pred_test = a_pre * b_test_grad_y - b_pre * a_test_grad_y + c_pre * d_test_grad_y - d_pre * c_test_grad_y
# U_magnitude_pred_test = np.sqrt(U_x_pred_test**2 + U_y_pred_test**2)

# %%
U_x_pred_test = a_pre + b_pre
U_y_pred_test = c_pre + d_pre
U_magnitude_pred_test = np.sqrt(U_x_pred_test**2 + U_y_pred_test**2)

# %%
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.imshow(U_x_pred_test, cmap='viridis')
# plt.colorbar()
plt.subplot(1, 2, 2)
plt.imshow(U_y_pred_test, cmap='viridis')

# %%
vort_pre = vorticity(U_x_pred_test, U_y_pred_test, dx, dx)

vorticity_normalized_pre = vorticity_normalize(vort_pre)

plt.imshow(vorticity_normalized_pre, cmap='RdBu_r',vmin=-0.3,vmax=0.3,interpolation='bilinear')
plt.colorbar()
