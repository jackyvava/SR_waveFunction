# %%
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import DataLoader, TensorDataset, random_split
import cv2

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cuda')

# %%
import h5py
import matplotlib.pyplot as plt

# 文件路径
file_path = r'D:\\zjPhD\\turbulenceData\\turbulenceData\\isotropic1024coarse_10.h5'


# 读取HDF5文件
with h5py.File(file_path, 'r') as f:
    # 查看文件中所有的数据集
    datasets = list(f.keys())
    print("数据集列表:", datasets)
    
    # 假设第一个数据集是我们要看的
    dataset_name = datasets[0]
    data = f[dataset_name][()]
    print(f"{dataset_name} 数据形状:", data.shape)
    print(f"{dataset_name} 数据范围:", data.min(), "到", data.max())
# Out:
# 数据集列表: ['Velocity_0001', 'Velocity_0002', 'Velocity_0003', 'Velocity_0004', 'Velocity_0005', 'Velocity_0006', 'Velocity_0007', 'Velocity_0008', 'Velocity_0009', 'Velocity_0010', 'Velocity_0011', 'Velocity_0012', 'Velocity_0013', 'Velocity_0014', 'Velocity_0015', 'Velocity_0016', 'Velocity_0017', 'Velocity_0018', 'Velocity_0019', 'Velocity_0020', 'xcoor', 'ycoor', 'zcoor']
# Velocity_0001 数据形状: (1, 1024, 1024, 3)
# Velocity_0001 数据范围: -2.712391 到 2.6947422

# %%
import h5py
import numpy as np
import matplotlib.pyplot as plt

# 文件路径
file_path = r'D:\\zjPhD\\turbulenceData\\turbulenceData\\isotropic1024coarse_test.h5'

# 读取HDF5文件
with h5py.File(file_path, 'r') as f:
    # 查看文件中所有的数据集
    datasets = list(f.keys())
    print("数据集列表:", datasets)
    
    # 假设第一个数据集是我们要看的
    dataset_name = datasets[0]
    data = f[dataset_name][()]
    print(f"{dataset_name} 数据形状:", data.shape)
    print(f"{dataset_name} 数据范围:", data.min(), "到", data.max())
    
    # 归一化数据到 [0, 1] 范围
    data_normalized = (data[0] - data.min()) / (data.max() - data.min())
    
    # # 可视化数据中的第一个通道
    # plt.imshow(data_normalized[:, :, 0], cmap='viridis')
    # plt.title(f'{dataset_name} 第一个通道')
    # plt.colorbar()
    # plt.show()
    
    # # 可视化数据中的第二个通道
    # plt.imshow(data_normalized[:, :, 1], cmap='viridis')
    # plt.title(f'{dataset_name} 第二个通道')
    # plt.colorbar()
    # plt.show()
    
    # # 可视化数据中的第三个通道
    # plt.imshow(data_normalized[:, :, 2], cmap='viridis')
    # plt.title(f'{dataset_name} 第三个通道')
    # plt.colorbar()
    # plt.show()
# Out:
# 数据集列表: ['Velocity_0001', 'xcoor', 'ycoor', 'zcoor']
# Velocity_0001 数据形状: (1, 1024, 1024, 3)
# Velocity_0001 数据范围: -2.712391 到 2.6947422

# %%
import h5py
import numpy as np

# 文件路径
file_path = r'D:\\zjPhD\\turbulenceData\\turbulenceData\\isotropic1024coarse_10.h5'

# 读取HDF5文件并检查每个 Velocity 数据集的基本信息
with h5py.File(file_path, 'r') as f:
    # 查看文件中所有的数据集
    datasets = list(f.keys())
    print("数据集列表:", datasets)
    
    for dataset_name in datasets:
        if 'Velocity' in dataset_name:
            data = f[dataset_name][()]
            print(f"{dataset_name} 数据形状:", data.shape)
            print(f"{dataset_name} 数据范围:", data.min(), "到", data.max())
            print(f"{dataset_name} 数据均值:", data.mean())
            print(f"{dataset_name} 数据标准差:", data.std())
            print()
# Out:
# 数据集列表: ['Velocity_0001', 'Velocity_0002', 'Velocity_0003', 'Velocity_0004', 'Velocity_0005', 'Velocity_0006', 'Velocity_0007', 'Velocity_0008', 'Velocity_0009', 'Velocity_0010', 'Velocity_0011', 'Velocity_0012', 'Velocity_0013', 'Velocity_0014', 'Velocity_0015', 'Velocity_0016', 'Velocity_0017', 'Velocity_0018', 'Velocity_0019', 'Velocity_0020', 'xcoor', 'ycoor', 'zcoor']
# Velocity_0001 数据形状: (1, 1024, 1024, 3)
# Velocity_0001 数据范围: -2.712391 到 2.6947422
# Velocity_0001 数据均值: 0.07109838
# Velocity_0001 数据标准差: 0.6888756
#
# Velocity_0002 数据形状: (1, 1024, 1024, 3)
# Velocity_0002 数据范围: -2.7356367 到 2.7098155
# Velocity_0002 数据均值: 0.07116876
# Velocity_0002 数据标准差: 0.68889195
#
# Velocity_0003 数据形状: (1, 1024, 1024, 3)
# Velocity_0003 数据范围: -2.722479 到 2.7283216
# Velocity_0003 数据均值: 0.07122495
# Velocity_0003 数据标准差: 0.688922
#
# Velocity_0004 数据形状: (1, 1024, 1024, 3)
# Velocity_0004 数据范围: -2.7307792 到 2.74634
# Velocity_0004 数据均值: 0.07126973
# Velocity_0004 数据标准差: 0.6889681
#
# Velocity_0005 数据形状: (1, 1024, 1024, 3)
# Velocity_0005 数据范围: -2.6752195 到 2.770227
# Velocity_0005 数据均值: 0.071305186
# Velocity_0005 数据标准差: 0.6890285
#
# Velocity_0006 数据形状: (1, 1024, 1024, 3)
# Velocity_0006 数据范围: -2.608722 到 2.7777185
# Velocity_0006 数据均值: 0.07133317
# Velocity_0006 数据标准差: 0.68909943
#
# Velocity_0007 数据形状: (1, 1024, 1024, 3)
# Velocity_0007 数据范围: -2.5889878 到 2.7992706
# Velocity_0007 数据均值: 0.071355015
# Velocity_0007 数据标准差: 0.6891764
#
# Velocity_0008 数据形状: (1, 1024, 1024, 3)
# Velocity_0008 数据范围: -2.584568 到 2.8132267
# Velocity_0008 数据均值: 0.07137236
# Velocity_0008 数据标准差: 0.6892557
#
# Velocity_0009 数据形状: (1, 1024, 1024, 3)
# Velocity_0009 数据范围: -2.5807695 到 2.8110614
# Velocity_0009 数据均值: 0.071388565
# Velocity_0009 数据标准差: 0.68933684
#
# Velocity_0010 数据形状: (1, 1024, 1024, 3)
# Velocity_0010 数据范围: -2.5739505 到 2.8252645
# Velocity_0010 数据均值: 0.0714082
# Velocity_0010 数据标准差: 0.6894169
#
# Velocity_0011 数据形状: (1, 1024, 1024, 3)
# Velocity_0011 数据范围: -2.5682664 到 2.831748
# Velocity_0011 数据均值: 0.07143452
# Velocity_0011 数据标准差: 0.68949455
#
# Velocity_0012 数据形状: (1, 1024, 1024, 3)
# Velocity_0012 数据范围: -2.5639415 到 2.8183084
# Velocity_0012 数据均值: 0.07146752
# Velocity_0012 数据标准差: 0.6895657
#
# Velocity_0013 数据形状: (1, 1024, 1024, 3)
# Velocity_0013 数据范围: -2.5569108 到 2.8257155
# Velocity_0013 数据均值: 0.071504585
# Velocity_0013 数据标准差: 0.6896298
#
# Velocity_0014 数据形状: (1, 1024, 1024, 3)
# Velocity_0014 数据范围: -2.550218 到 2.8258345
# Velocity_0014 数据均值: 0.071542695
# Velocity_0014 数据标准差: 0.68968916
#
# Velocity_0015 数据形状: (1, 1024, 1024, 3)
# Velocity_0015 数据范围: -2.541764 到 2.8032413
# Velocity_0015 数据均值: 0.07158066
# Velocity_0015 数据标准差: 0.6897459
#
# Velocity_0016 数据形状: (1, 1024, 1024, 3)
# Velocity_0016 数据范围: -2.533338 到 2.8086593
# Velocity_0016 数据均值: 0.07161763
# Velocity_0016 数据标准差: 0.6898023
#
# Velocity_0017 数据形状: (1, 1024, 1024, 3)
# Velocity_0017 数据范围: -2.526175 到 2.7972069
# Velocity_0017 数据均值: 0.07165275
# Velocity_0017 数据标准差: 0.68985784
#
# Velocity_0018 数据形状: (1, 1024, 1024, 3)
# Velocity_0018 数据范围: -2.519424 到 2.7872314
# Velocity_0018 数据均值: 0.07168614
# Velocity_0018 数据标准差: 0.6899145
#
# Velocity_0019 数据形状: (1, 1024, 1024, 3)
# Velocity_0019 数据范围: -2.539456 到 2.7889357
# Velocity_0019 数据均值: 0.07171971
# Velocity_0019 数据标准差: 0.68997425
#
# Velocity_0020 数据形状: (1, 1024, 1024, 3)
# Velocity_0020 数据范围: -2.5543127 到 2.7725642
# Velocity_0020 数据均值: 0.07175511
# Velocity_0020 数据标准差: 0.6900401

# %% [markdown]
# # 定义所需要的函数

# %% [markdown]
# ## 计算涡度

# %%
def vorticity(U_x, U_y, dx, dy):
    dU_y_dx, _ = np.gradient(U_y, dx, axis=0), np.gradient(U_y, dy, axis=1)
    _, dU_x_dy = np.gradient(U_x, dx, axis=0), np.gradient(U_x, dy, axis=1)
    return dU_y_dx - dU_x_dy


# 计算归一化的涡度
def vorticity_normalize(vorticity):
    max_vorticity = np.max(np.abs(vorticity))
    vort_normalized = vorticity / max_vorticity if max_vorticity != 0 else vorticity
    return vort_normalized

# %% [markdown]
# # 预训练模型测试新的湍流非对称数据集

# %% [markdown]
# 读取约翰霍普金斯的湍流数据库

# %%
import h5py

import numpy as np
import matplotlib.pyplot as plt

# %%
def downsample(image, size=(64, 64)):
    return cv2.resize(image, size, interpolation=cv2.INTER_AREA)

# %% [markdown]
# ### 原始数据集

# %%
## 读取测试集

file_path = r'D:\\zjPhD\\turbulenceData\\turbulenceData\\isotropic1024coarse_test.h5'

with h5py.File(file_path,'r') as f :
    datasets = list(f.keys())
    print("数据集列表:", datasets)
    
    for dataset_name in datasets:
        if 'Velocity' in dataset_name:
            data = f[dataset_name][()]
            print(f"{dataset_name} 数据形状:", data.shape)
            print(f"{dataset_name} 数据范围:", data.min(), "到", data.max())
            print(f"{dataset_name} 数据均值:", data.mean())
            print(f"{dataset_name} 数据标准差:", data.std())
            print()

    data_normalized = (data[0] - data.min()) / (data.max() - data.min())

    data = f[dataset_name][()]

    u_test = data_normalized[:,:,0]
    v_test = data_normalized[:,:,1]
    w_test = data_normalized[:,:,2]
# Out:
# 数据集列表: ['Velocity_0001', 'xcoor', 'ycoor', 'zcoor']
# Velocity_0001 数据形状: (1, 1024, 1024, 3)
# Velocity_0001 数据范围: -2.712391 到 2.6947422
# Velocity_0001 数据均值: 0.07109838
# Velocity_0001 数据标准差: 0.6888756

# %% [markdown]
# ### 降采样数据集 （64*64）

# %%
# 读取HDF5文件并降采样
with h5py.File(file_path, 'r') as f:
    # 获取所有速度场数据集名称
    velocity_datasets = [name for name in f.keys() if 'Velocity' in name]
    
    # 初始化空列表用于存储所有数据
    all_velocity_fields = []
    
    for dataset_name in velocity_datasets:
        data = f[dataset_name][()]
        # 取出三通道的速度场数据
        U_x = data[0, :, :, 0]
        U_y = data[0, :, :, 1]
        U_magnitude = data[0, :, :, 2]
        
        # 降采样
        U_x_downsampled = downsample(U_x)
        U_y_downsampled = downsample(U_y)
        U_magnitude_downsampled = downsample(U_magnitude)
        
        # 将数据转换为PyTorch张量并增加batch和channel维度
        U_x_tensor = torch.tensor(U_x_downsampled, dtype=torch.float32).unsqueeze(0).unsqueeze(0)
        U_y_tensor = torch.tensor(U_y_downsampled, dtype=torch.float32).unsqueeze(0).unsqueeze(0)
        U_magnitude_tensor = torch.tensor(U_magnitude_downsampled, dtype=torch.float32).unsqueeze(0).unsqueeze(0)
        
        # 合并速度场作为输入
        velocity_field = torch.cat((U_x_tensor, U_y_tensor, U_magnitude_tensor), dim=1)
        
        all_velocity_fields.append(velocity_field)
    
    # 将所有速度场数据合并为一个大的张量
    all_velocity_fields = torch.cat(all_velocity_fields, dim=0)
    
    # 目标abcd (假设为0初始化)
    num_samples = all_velocity_fields.shape[0]
    size_low = all_velocity_fields.shape[2]
    target_abcd = torch.zeros((num_samples, 4, size_low, size_low), dtype=torch.float32)
    
    # 创建数据集和数据加载器
    dataset = TensorDataset(all_velocity_fields, target_abcd)
    dataloader = DataLoader(dataset, batch_size=1, shuffle=True)  # 你可以根据需要调整batch_size

# 检查数据形状
print("all_velocity_fields shape:", all_velocity_fields.shape)
print("target_abcd shape:", target_abcd.shape)
# Out:
# all_velocity_fields shape: torch.Size([1, 3, 64, 64])
# target_abcd shape: torch.Size([1, 4, 64, 64])

# %%
target_abcd.shape
# Out:
# torch.Size([1, 4, 64, 64])

# %%
all_velocity_fields[0,1,0,:].shape
# Out:
# torch.Size([64])

# %%
#可以查看数据范围，xyz都是（0，$2\pi$）
size_low = 64

dx = 2*np.pi/size_low
dy = 2*np.pi/size_low
dz = 2*np.pi/size_low

# %%
u_test =all_velocity_fields[0,0,:,:].numpy()
v_test =all_velocity_fields[0,1,:,:].numpy()
w_test =all_velocity_fields[0,2,:,:].numpy()

# %%
vort_test = vorticity(u_test, v_test, dx, dx)

vorticity_normalized = vorticity_normalize(vort_test)

print(vort_test.shape)
print(vorticity_normalized.shape)
# Out:
# (64, 64)
# (64, 64)

# %%
plt.imshow(vorticity_normalized, cmap='RdBu_r',vmin=-0.3,vmax=0.3,interpolation='bilinear')
plt.colorbar()

# %%
print("u速度场形状",u_test.shape) 
print("v速度场形状",v_test.shape)

# 查看一些速度场   
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)   
plt.imshow(u_test, cmap='viridis')   
plt.subplot(1, 2, 2)
plt.imshow(v_test, cmap='viridis')
# Out:
# u速度场形状 (64, 64)
# v速度场形状 (64, 64)

# %%
plt.imshow(u_test, cmap='viridis')

# %% [markdown]
# # 模型A部分尝试更换数据集

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f'Using device: {device}')
# Out:
# Using device: cuda

# %%
import h5py
import torch
from torch.utils.data import DataLoader, TensorDataset

# 文件路径
file_path = r'D:\\zjPhD\\turbulenceData\\turbulenceData\\isotropic1024coarse_10.h5'

# 读取HDF5文件并降采样
with h5py.File(file_path, 'r') as f:
    # 获取所有速度场数据集名称
    velocity_datasets = [name for name in f.keys() if 'Velocity' in name]
    
    # 初始化空列表用于存储所有数据
    all_velocity_fields = []
    
    for dataset_name in velocity_datasets:
        data = f[dataset_name][()]
        # 取出三通道的速度场数据
        U_x = data[0, :, :, 0]
        U_y = data[0, :, :, 1]
        U_magnitude = data[0, :, :, 2]
        
        # 降采样
        U_x_downsampled = downsample(U_x)
        U_y_downsampled = downsample(U_y)
        U_magnitude_downsampled = downsample(U_magnitude)
        # U_x_downsampled = U_x
        # U_y_downsampled = U_y
        # U_magnitude_downsampled = U_magnitude
        
        # 将数据转换为PyTorch张量并增加batch和channel维度
        U_x_tensor = torch.tensor(U_x_downsampled, dtype=torch.float32).unsqueeze(0).unsqueeze(0)
        U_y_tensor = torch.tensor(U_y_downsampled, dtype=torch.float32).unsqueeze(0).unsqueeze(0)
        U_magnitude_tensor = torch.tensor(U_magnitude_downsampled, dtype=torch.float32).unsqueeze(0).unsqueeze(0)
        
        # 合并速度场作为输入
        velocity_field = torch.cat((U_x_tensor, U_y_tensor, U_magnitude_tensor), dim=1)
        
        all_velocity_fields.append(velocity_field)
    
    # 将所有速度场数据合并为一个大的张量
    all_velocity_fields = torch.cat(all_velocity_fields, dim=0)
    
    # 目标abcd (假设为0初始化)
    num_samples = all_velocity_fields.shape[0]
    size_low = all_velocity_fields.shape[2]
    target_abcd = torch.zeros((num_samples, 4, size_low, size_low), dtype=torch.float32)
    
    # 创建数据集和数据加载器
    dataset = TensorDataset(all_velocity_fields, target_abcd)
    dataloader = DataLoader(dataset, batch_size=2, shuffle=True)  # 调整批量大小

# 检查数据形状
print("all_velocity_fields shape:", all_velocity_fields.shape)
print("target_abcd shape:", target_abcd.shape)
# Out:
# all_velocity_fields shape: torch.Size([20, 3, 64, 64])
# target_abcd shape: torch.Size([20, 4, 64, 64])

# %%
# 简单的模型
class BasicModelA(nn.Module):
    def __init__(self):
        super(BasicModelA, self).__init__()
        self.conv1 = nn.Conv2d(3, 64, kernel_size=3, padding=1)
        self.bn1 = nn.BatchNorm2d(64)
        self.conv2 = nn.Conv2d(64, 128, kernel_size=3, padding=1)
        self.bn2 = nn.BatchNorm2d(128)
        self.conv3 = nn.Conv2d(128, 256, kernel_size=3, padding=1)
        self.bn3 = nn.BatchNorm2d(256)
        self.pool = nn.MaxPool2d(2, 2)
        self.conv4 = nn.Conv2d(256, 512, kernel_size=3, padding=1)
        self.bn4 = nn.BatchNorm2d(512)
        self.upsample = nn.Upsample(scale_factor=8, mode='bilinear', align_corners=True)
        self.conv5 = nn.Conv2d(512, 4, kernel_size=3, padding=1)

    def forward(self, x):
        x = F.relu(self.bn1(self.conv1(x)))
        x = self.pool(x)
        x = F.relu(self.bn2(self.conv2(x)))
        x = self.pool(x)
        x = F.relu(self.bn3(self.conv3(x)))
        x = self.pool(x)
        x = F.relu(self.bn4(self.conv4(x)))
        x = self.upsample(x)  # 使用上采样恢复到原始尺寸
        x = self.conv5(x)
        return x

# %%
# 复杂的模型
class ComplexModelA(nn.Module):
    def __init__(self):
        super(ComplexModelA, self).__init__()
        # Encoder
        self.conv1 = nn.Conv2d(3, 64, kernel_size=3, padding=1)
        self.bn1 = nn.BatchNorm2d(64)
        self.conv2 = nn.Conv2d(64, 128, kernel_size=3, padding=1)
        self.bn2 = nn.BatchNorm2d(128)
        self.conv3 = nn.Conv2d(128, 256, kernel_size=3, padding=1)
        self.bn3 = nn.BatchNorm2d(256)
        self.conv4 = nn.Conv2d(256, 512, kernel_size=3, padding=1)
        self.bn4 = nn.BatchNorm2d(512)
        self.conv5 = nn.Conv2d(512, 1024, kernel_size=3, padding=1)
        self.bn5 = nn.BatchNorm2d(1024)
        
        self.pool = nn.MaxPool2d(2, 2)

        # Decoder
        self.upconv1 = nn.ConvTranspose2d(1024, 512, kernel_size=2, stride=2)
        self.conv6 = nn.Conv2d(1024, 512, kernel_size=3, padding=1)
        self.bn6 = nn.BatchNorm2d(512)
        
        self.upconv2 = nn.ConvTranspose2d(512, 256, kernel_size=2, stride=2)
        self.conv7 = nn.Conv2d(512, 256, kernel_size=3, padding=1)
        self.bn7 = nn.BatchNorm2d(256)
        
        self.upconv3 = nn.ConvTranspose2d(256, 128, kernel_size=2, stride=2)
        self.conv8 = nn.Conv2d(256, 128, kernel_size=3, padding=1)
        self.bn8 = nn.BatchNorm2d(128)
        
        self.upconv4 = nn.ConvTranspose2d(128, 64, kernel_size=2, stride=2)
        self.conv9 = nn.Conv2d(128, 64, kernel_size=3, padding=1)
        self.bn9 = nn.BatchNorm2d(64)
        
        self.conv10 = nn.Conv2d(64, 4, kernel_size=3, padding=1)
        
    def forward(self, x):
        # Encoder
        x1 = F.relu(self.bn1(self.conv1(x)))
        x2 = self.pool(x1)
        x2 = F.relu(self.bn2(self.conv2(x2)))
        x3 = self.pool(x2)
        x3 = F.relu(self.bn3(self.conv3(x3)))
        x4 = self.pool(x3)
        x4 = F.relu(self.bn4(self.conv4(x4)))
        x5 = self.pool(x4)
        x5 = F.relu(self.bn5(self.conv5(x5)))
        
        # Decoder
        x = self.upconv1(x5)
        x = torch.cat((x, x4), dim=1)  # Skip connection
        x = F.relu(self.bn6(self.conv6(x)))
        
        x = self.upconv2(x)
        x = torch.cat((x, x3), dim=1)  # Skip connection
        x = F.relu(self.bn7(self.conv7(x)))
        
        x = self.upconv3(x)
        x = torch.cat((x, x2), dim=1)  # Skip connection
        x = F.relu(self.bn8(self.conv8(x)))
        
        x = self.upconv4(x)
        x = torch.cat((x, x1), dim=1)  # Skip connection
        x = F.relu(self.bn9(self.conv9(x)))
        
        x = self.conv10(x)
        return x

# %%
class ConstraintLayer(nn.Module):
    def __init__(self):
        super(ConstraintLayer, self).__init__()

    def forward(self, x):
        # 假设x的形状为 [batch_size, 4, height, width]，其中4代表abcd
        norm = torch.sqrt(x[:, 0, :, :]**2 + x[:, 1, :, :]**2 + x[:, 2, :, :]**2 + x[:, 3, :, :]**2 + 1e-8)
        norm = norm.unsqueeze(1)  # 为了与abcd的四个通道对齐
        x = x / norm  # 归一化
        return x

# %%
class ModelAWithConstraints(nn.Module):
    def __init__(self):
        super(ModelAWithConstraints, self).__init__()
        self.model = BasicModelA()
        self.constraint_layer = ConstraintLayer()

    def forward(self, x):
        x = self.model(x)
        x = self.constraint_layer(x)
        return x

# %%
def calculate_gradients_with_numpy(tensor):
    # 确保 Tensor 不需要梯度跟踪，且在 CPU 上
    tensor_np = tensor.detach().cpu().numpy()

    # 计算梯度
    grad_x = np.gradient(tensor_np, axis=1)  # 假设水平方向是 axis=1
    grad_y = np.gradient(tensor_np, axis=2)  # 假设垂直方向是 axis=2
    
    # 转换回 Tensor
    grad_x_tensor = torch.from_numpy(grad_x).to(tensor.device)
    grad_y_tensor = torch.from_numpy(grad_y).to(tensor.device)
    
    return grad_x_tensor, grad_y_tensor

# %%
def laplacian_2d(array, dx, dy):
    grad_x = np.gradient(array, dx, axis=1, edge_order=2)  # 计算 x 方向的一阶导数
    grad_y = np.gradient(array, dy, axis=0, edge_order=2)  # 计算 y 方向的一阶导数
    
    laplacian_x = np.gradient(grad_x, dx, axis=1, edge_order=2)  # 计算 x 方向的二阶导数
    laplacian_y = np.gradient(grad_y, dy, axis=0, edge_order=2)  # 计算 y 方向的二阶导数
    
    return laplacian_x + laplacian_y



def laplacian_2d_torch(tensor, dx, dy):
    # 确保tensor是浮点类型，因为梯度计算通常需要浮点运算
    tensor = tensor.float()
    tensor_np = tensor.detach().cpu().numpy()

    # 计算x和y方向的一阶导数
    grad_x = np.gradient(tensor_np, axis=1)  # x方向
    grad_y = np.gradient(tensor_np, axis=2)  # y方向

    # 计算x和y方向的二阶导数
    laplacian_x = np.gradient(grad_x, axis=1)
    laplacian_y = np.gradient(grad_y, axis=2)

    laplacian_x_tensor = torch.from_numpy(laplacian_x).to(tensor.device)
    laplacian_y_tensor = torch.from_numpy(laplacian_y).to(tensor.device)

    # 相加得到完整的拉普拉斯算子
    laplacian = laplacian_x_tensor + laplacian_y_tensor

    return laplacian

# %%
def loss_function(predicted_abcd, true_velocity, model, epsilon, l1_lambda=0.0, l2_lambda=0.0):
    # 提取 a, b, c, d
    a = predicted_abcd[:, 0, :, :]
    b = predicted_abcd[:, 1, :, :]
    c = predicted_abcd[:, 2, :, :]
    d = predicted_abcd[:, 3, :, :]
    
    # 计算梯度
    a_grad_x, a_grad_y = calculate_gradients_with_numpy(a)
    b_grad_x, b_grad_y = calculate_gradients_with_numpy(b)
    c_grad_x, c_grad_y = calculate_gradients_with_numpy(c)
    d_grad_x, d_grad_y = calculate_gradients_with_numpy(d)

    hbar = 1  # 你可以根据具体情况调整这个参数

    # # 根据 a, b, c, d 计算预测的速度场
    # U_x_pred = a + b
    # U_y_pred = c + d
    # U_magnitude_pred = torch.sqrt(U_x_pred**2 + U_y_pred**2)
    
    # # 计算速度场的损失
    # U_x_true = true_velocity[:, 0, :, :]
    # U_y_true = true_velocity[:, 1, :, :]
    # U_magnitude_true = true_velocity[:, 2, :, :]


    U_x_pred = hbar * (a * b_grad_x - b * a_grad_x + c * d_grad_x - d * c_grad_x)
    U_y_pred = hbar * (a * b_grad_y - b * a_grad_y + c * d_grad_y - d * c_grad_y)
    U_magnitude_pred = torch.sqrt(U_x_pred**2 + U_y_pred**2)
    
    # # 计算速度场的损失
    U_x_true = true_velocity[:, 0, :, :]
    U_y_true = true_velocity[:, 1, :, :]
    U_magnitude_true = true_velocity[:, 2, :, :]

    loss_velocity = F.mse_loss(U_magnitude_pred, U_magnitude_true) + F.mse_loss(U_x_pred, U_x_true) + F.mse_loss(U_y_pred, U_y_true)
    
    # 计算归一化约束
    norm = a**2 + b**2 + c**2 + d**2
    norm_constraint = F.mse_loss(norm, torch.ones_like(norm))
    
    # 计算拉普拉斯算子
    lap_b = laplacian_2d_torch(b, dx, dx)
    lap_a = laplacian_2d_torch(a, dx, dx)
    lap_d = laplacian_2d_torch(d, dx, dx)
    lap_c = laplacian_2d_torch(c, dx, dx)

    # 计算螺旋度约束
    curl_constraint = (a * lap_b - b * lap_a + c * lap_d - d * lap_c).sum()
    
    # 计算L1正则化项
    l1_regularization = torch.tensor(0., requires_grad=True)
    if l1_lambda > 0:
        l1_regularization = sum(torch.sum(torch.abs(param)) for param in model.parameters())

    # 计算L2正则化项
    l2_regularization = torch.tensor(0., requires_grad=True)
    if l2_lambda > 0:
        l2_regularization = sum(torch.sum(param**2) for param in model.parameters())
    
    # 计算正则化项
    regularization_term = epsilon * 0.25 * (torch.sum(a**2) + torch.sum(b**2) + torch.sum(c**2) + torch.sum(d**2))
    
    # 总损失
    total_loss = loss_velocity + l1_lambda * l1_regularization + l2_lambda * l2_regularization #+ norm_constraint + curl_constraint + regularization_term 
    return total_loss

# %%
from torch.cuda.amp import GradScaler, autocast

# %%
learning_rate = 0.0001
num_epochs = 10000
epsilon = 0.01
l1_lambda = 0.001  # L1正则化系数
l2_lambda = 0.001  # L2正则化系数


channels = 3

model = ComplexModelA()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

# %%
for epoch in range(num_epochs):
    for i, (velocity, _) in enumerate(dataloader):
        optimizer.zero_grad()
        predicted_abcd = model(velocity)
        # loss = loss_function(predicted_abcd, velocity, epsilon)
        loss = loss_function(predicted_abcd, velocity, model, epsilon, l1_lambda, l2_lambda)

        loss.backward()
        optimizer.step()
        if i % 10 == 0:
            print(f'Epoch [{epoch+1}/{num_epochs}], Step [{i+1}], Loss: {loss.item():.4f}')
# Out:
# Epoch [1/10000], Step [1], Loss: 134.8659
# Epoch [2/10000], Step [1], Loss: 119.7714
# Epoch [3/10000], Step [1], Loss: 105.9229
# Epoch [4/10000], Step [1], Loss: 93.1491
# Epoch [5/10000], Step [1], Loss: 81.4194
# Epoch [6/10000], Step [1], Loss: 70.7496
# Epoch [7/10000], Step [1], Loss: 61.1356
# Epoch [8/10000], Step [1], Loss: 52.5836
# Epoch [9/10000], Step [1], Loss: 45.0998
# Epoch [10/10000], Step [1], Loss: 38.6739
# Epoch [11/10000], Step [1], Loss: 33.3100
# Epoch [12/10000], Step [1], Loss: 28.8902
# Epoch [13/10000], Step [1], Loss: 25.0726
# Epoch [14/10000], Step [1], Loss: 21.9241
# Epoch [15/10000], Step [1], Loss: 19.3909
# Epoch [16/10000], Step [1], Loss: 17.4316
# Epoch [17/10000], Step [1], Loss: 15.7239
# Epoch [18/10000], Step [1], Loss: 14.2895
# Epoch [19/10000], Step [1], Loss: 13.0602
# Epoch [20/10000], Step [1], Loss: 12.0316
# Epoch [21/10000], Step [1], Loss: 11.1904
# Epoch [22/10000], Step [1], Loss: 10.5540
# Epoch [23/10000], Step [1], Loss: 10.0585
# Epoch [24/10000], Step [1], Loss: 9.6643
# Epoch [25/10000], Step [1], Loss: 9.3067
# Epoch [26/10000], Step [1], Loss: 8.9991
# Epoch [27/10000], Step [1], Loss: 8.7286
# Epoch [28/10000], Step [1], Loss: 8.4864
# Epoch [29/10000], Step [1], Loss: 8.2815
# Epoch [30/10000], Step [1], Loss: 8.1145
# Epoch [31/10000], Step [1], Loss: 7.9600
# Epoch [32/10000], Step [1], Loss: 7.8455
# Epoch [33/10000], Step [1], Loss: 7.7451
# Epoch [34/10000], Step [1], Loss: 7.6594
# Epoch [35/10000], Step [1], Loss: 7.5801
# Epoch [36/10000], Step [1], Loss: 7.5042
# Epoch [37/10000], Step [1], Loss: 7.4267
# Epoch [38/10000], Step [1], Loss: 7.3658
# Epoch [39/10000], Step [1], Loss: 7.3224
# Epoch [40/10000], Step [1], Loss: 7.2557
# Epoch [41/10000], Step [1], Loss: 7.2067
# Epoch [42/10000], Step [1], Loss: 7.1666
# Epoch [43/10000], Step [1], Loss: 7.1274
# Epoch [44/10000], Step [1], Loss: 7.0910
# Epoch [45/10000], Step [1], Loss: 7.0482
# Epoch [46/10000], Step [1], Loss: 7.0118
# Epoch [47/10000], Step [1], Loss: 6.9930
# Epoch [48/10000], Step [1], Loss: 6.9702
# Epoch [49/10000], Step [1], Loss: 6.9598
# Epoch [50/10000], Step [1], Loss: 6.9318
# Epoch [51/10000], Step [1], Loss: 6.8984
# Epoch [52/10000], Step [1], Loss: 6.8844
# Epoch [53/10000], Step [1], Loss: 6.8572
# Epoch [54/10000], Step [1], Loss: 6.8380
# Epoch [55/10000], Step [1], Loss: 6.8068
# Epoch [56/10000], Step [1], Loss: 6.7811
# Epoch [57/10000], Step [1], Loss: 6.7837
# Epoch [58/10000], Step [1], Loss: 6.8317
# Epoch [59/10000], Step [1], Loss: 6.7944
# Epoch [60/10000], Step [1], Loss: 6.7575
# Epoch [61/10000], Step [1], Loss: 6.7215
# Epoch [62/10000], Step [1], Loss: 6.6899
# Epoch [63/10000], Step [1], Loss: 6.6751
# Epoch [64/10000], Step [1], Loss: 6.6541
# Epoch [65/10000], Step [1], Loss: 6.6386
# Epoch [66/10000], Step [1], Loss: 6.6319
# Epoch [67/10000], Step [1], Loss: 6.6033
# Epoch [68/10000], Step [1], Loss: 6.6088
# Epoch [69/10000], Step [1], Loss: 6.6130
# Epoch [70/10000], Step [1], Loss: 6.5911
# Epoch [71/10000], Step [1], Loss: 6.5688
# Epoch [72/10000], Step [1], Loss: 6.5428
# Epoch [73/10000], Step [1], Loss: 6.5325
# Epoch [74/10000], Step [1], Loss: 6.5423
# Epoch [75/10000], Step [1], Loss: 6.5473
# Epoch [76/10000], Step [1], Loss: 6.5893
# Epoch [77/10000], Step [1], Loss: 6.5242
# Epoch [78/10000], Step [1], Loss: 6.4954
# Epoch [79/10000], Step [1], Loss: 6.4684
# Epoch [80/10000], Step [1], Loss: 6.4452
# Epoch [81/10000], Step [1], Loss: 6.4403
# Epoch [82/10000], Step [1], Loss: 6.4298
# Epoch [83/10000], Step [1], Loss: 6.4260
# Epoch [84/10000], Step [1], Loss: 6.4718
# Epoch [85/10000], Step [1], Loss: 6.4277
# Epoch [86/10000], Step [1], Loss: 6.4056
# Epoch [87/10000], Step [1], Loss: 6.3833
# Epoch [88/10000], Step [1], Loss: 6.3627
# Epoch [89/10000], Step [1], Loss: 6.3534
# Epoch [90/10000], Step [1], Loss: 6.3492
# Epoch [91/10000], Step [1], Loss: 6.3734
# Epoch [92/10000], Step [1], Loss: 6.3653
# Epoch [93/10000], Step [1], Loss: 6.3339
# Epoch [94/10000], Step [1], Loss: 6.3146
# Epoch [95/10000], Step [1], Loss: 6.2871
# Epoch [96/10000], Step [1], Loss: 6.2705
# Epoch [97/10000], Step [1], Loss: 6.2730
# Epoch [98/10000], Step [1], Loss: 6.2582
# Epoch [99/10000], Step [1], Loss: 6.2584
# Epoch [100/10000], Step [1], Loss: 6.2452
# Epoch [101/10000], Step [1], Loss: 6.2294
# Epoch [102/10000], Step [1], Loss: 6.2272
# Epoch [103/10000], Step [1], Loss: 6.2216
# Epoch [104/10000], Step [1], Loss: 6.2260
# Epoch [105/10000], Step [1], Loss: 6.1974
# Epoch [106/10000], Step [1], Loss: 6.1891
# Epoch [107/10000], Step [1], Loss: 6.1649
# Epoch [108/10000], Step [1], Loss: 6.1585
# Epoch [109/10000], Step [1], Loss: 6.1520
# Epoch [110/10000], Step [1], Loss: 6.1370
# Epoch [111/10000], Step [1], Loss: 6.1527
# Epoch [112/10000], Step [1], Loss: 6.2483
# Epoch [113/10000], Step [1], Loss: 6.1932
# Epoch [114/10000], Step [1], Loss: 6.1526
# Epoch [115/10000], Step [1], Loss: 6.1215
# Epoch [116/10000], Step [1], Loss: 6.1022
# Epoch [117/10000], Step [1], Loss: 6.0800
# Epoch [118/10000], Step [1], Loss: 6.0605
# Epoch [119/10000], Step [1], Loss: 6.0559
# Epoch [120/10000], Step [1], Loss: 6.0399
# Epoch [121/10000], Step [1], Loss: 6.0302
# Epoch [122/10000], Step [1], Loss: 6.0418
# Epoch [123/10000], Step [1], Loss: 6.0893
# Epoch [124/10000], Step [1], Loss: 6.0694
# Epoch [125/10000], Step [1], Loss: 6.0374
# Epoch [126/10000], Step [1], Loss: 6.0074
# Epoch [127/10000], Step [1], Loss: 5.9858
# Epoch [128/10000], Step [1], Loss: 5.9678
# Epoch [129/10000], Step [1], Loss: 5.9580
# Epoch [130/10000], Step [1], Loss: 5.9391
# Epoch [131/10000], Step [1], Loss: 5.9417
# Epoch [132/10000], Step [1], Loss: 5.9326
# Epoch [133/10000], Step [1], Loss: 5.9171
# Epoch [134/10000], Step [1], Loss: 5.9176
# Epoch [135/10000], Step [1], Loss: 5.9184
# Epoch [136/10000], Step [1], Loss: 5.9008
# Epoch [137/10000], Step [1], Loss: 5.8819
# Epoch [138/10000], Step [1], Loss: 5.8706
# Epoch [139/10000], Step [1], Loss: 5.9057
# Epoch [140/10000], Step [1], Loss: 6.0242
# Epoch [141/10000], Step [1], Loss: 5.9289
# Epoch [142/10000], Step [1], Loss: 5.8968
# Epoch [143/10000], Step [1], Loss: 5.8668
# Epoch [144/10000], Step [1], Loss: 5.8388
# Epoch [145/10000], Step [1], Loss: 5.8198
# Epoch [146/10000], Step [1], Loss: 5.8064
# Epoch [147/10000], Step [1], Loss: 5.7930
# Epoch [148/10000], Step [1], Loss: 5.7850
# Epoch [149/10000], Step [1], Loss: 5.7699
# Epoch [150/10000], Step [1], Loss: 5.7640
# Epoch [151/10000], Step [1], Loss: 5.8237
# Epoch [152/10000], Step [1], Loss: 5.8176
# Epoch [153/10000], Step [1], Loss: 5.7866
# Epoch [154/10000], Step [1], Loss: 5.7678
# Epoch [155/10000], Step [1], Loss: 5.7298
# Epoch [156/10000], Step [1], Loss: 5.7161
# Epoch [157/10000], Step [1], Loss: 5.7053
# Epoch [158/10000], Step [1], Loss: 5.6914
# Epoch [159/10000], Step [1], Loss: 5.6905
# Epoch [160/10000], Step [1], Loss: 5.6821
# Epoch [161/10000], Step [1], Loss: 5.6677
# Epoch [162/10000], Step [1], Loss: 5.6575
# Epoch [163/10000], Step [1], Loss: 5.6520
# Epoch [164/10000], Step [1], Loss: 5.6489
# Epoch [165/10000], Step [1], Loss: 5.7084
# Epoch [166/10000], Step [1], Loss: 5.8084
# Epoch [167/10000], Step [1], Loss: 5.7118
# Epoch [168/10000], Step [1], Loss: 5.6736
# Epoch [169/10000], Step [1], Loss: 5.6459
# Epoch [170/10000], Step [1], Loss: 5.6124
# Epoch [171/10000], Step [1], Loss: 5.5962
# Epoch [172/10000], Step [1], Loss: 5.5784
# Epoch [173/10000], Step [1], Loss: 5.5711
# Epoch [174/10000], Step [1], Loss: 5.5581
# Epoch [175/10000], Step [1], Loss: 5.5528
# Epoch [176/10000], Step [1], Loss: 5.5420
# Epoch [177/10000], Step [1], Loss: 5.5357
# Epoch [178/10000], Step [1], Loss: 5.5352
# Epoch [179/10000], Step [1], Loss: 5.5295
# Epoch [180/10000], Step [1], Loss: 5.5092
# Epoch [181/10000], Step [1], Loss: 5.5092
# Epoch [182/10000], Step [1], Loss: 5.5007
# Epoch [183/10000], Step [1], Loss: 5.4938
# Epoch [184/10000], Step [1], Loss: 5.4787
# Epoch [185/10000], Step [1], Loss: 5.4680
# Epoch [186/10000], Step [1], Loss: 5.4520
# Epoch [187/10000], Step [1], Loss: 5.4922
# Epoch [188/10000], Step [1], Loss: 5.5904
# Epoch [189/10000], Step [1], Loss: 5.5250
# Epoch [190/10000], Step [1], Loss: 5.4800
# Epoch [191/10000], Step [1], Loss: 5.4550
# Epoch [192/10000], Step [1], Loss: 5.4321
# Epoch [193/10000], Step [1], Loss: 5.4201
# Epoch [194/10000], Step [1], Loss: 5.4009
# Epoch [195/10000], Step [1], Loss: 5.3929
# Epoch [196/10000], Step [1], Loss: 5.3752
# Epoch [197/10000], Step [1], Loss: 5.3662
# Epoch [198/10000], Step [1], Loss: 5.3766
# Epoch [199/10000], Step [1], Loss: 5.3847
# Epoch [200/10000], Step [1], Loss: 5.3586
# Epoch [201/10000], Step [1], Loss: 5.3458
# Epoch [202/10000], Step [1], Loss: 5.3415
# Epoch [203/10000], Step [1], Loss: 5.3273
# Epoch [204/10000], Step [1], Loss: 5.3260
# Epoch [205/10000], Step [1], Loss: 5.3118
# Epoch [206/10000], Step [1], Loss: 5.3005
# Epoch [207/10000], Step [1], Loss: 5.2912
# Epoch [208/10000], Step [1], Loss: 5.2774
# Epoch [209/10000], Step [1], Loss: 5.2736
# Epoch [210/10000], Step [1], Loss: 5.3190
# Epoch [211/10000], Step [1], Loss: 5.4547
# Epoch [212/10000], Step [1], Loss: 5.3555
# Epoch [213/10000], Step [1], Loss: 5.3165
# Epoch [214/10000], Step [1], Loss: 5.2916
# Epoch [215/10000], Step [1], Loss: 5.2577
# Epoch [216/10000], Step [1], Loss: 5.2443
# Epoch [217/10000], Step [1], Loss: 5.2206
# Epoch [218/10000], Step [1], Loss: 5.2083
# Epoch [219/10000], Step [1], Loss: 5.1960
# Epoch [220/10000], Step [1], Loss: 5.1964
# Epoch [221/10000], Step [1], Loss: 5.1816
# Epoch [222/10000], Step [1], Loss: 5.1728
# Epoch [223/10000], Step [1], Loss: 5.1698
# Epoch [224/10000], Step [1], Loss: 5.1573
# Epoch [225/10000], Step [1], Loss: 5.1542
# Epoch [226/10000], Step [1], Loss: 5.1831
# Epoch [227/10000], Step [1], Loss: 5.1771
# Epoch [228/10000], Step [1], Loss: 5.1468
# Epoch [229/10000], Step [1], Loss: 5.1244
# Epoch [230/10000], Step [1], Loss: 5.1099
# Epoch [231/10000], Step [1], Loss: 5.1129
# Epoch [232/10000], Step [1], Loss: 5.1120
# Epoch [233/10000], Step [1], Loss: 5.0975
# Epoch [234/10000], Step [1], Loss: 5.1001
# Epoch [235/10000], Step [1], Loss: 5.0950
# Epoch [236/10000], Step [1], Loss: 5.0773
# Epoch [237/10000], Step [1], Loss: 5.0623
# Epoch [238/10000], Step [1], Loss: 5.0509
# Epoch [239/10000], Step [1], Loss: 5.0454
# Epoch [240/10000], Step [1], Loss: 5.0389
# Epoch [241/10000], Step [1], Loss: 5.0388
# Epoch [242/10000], Step [1], Loss: 5.0447
# Epoch [243/10000], Step [1], Loss: 5.0793
# Epoch [244/10000], Step [1], Loss: 5.1055
# Epoch [245/10000], Step [1], Loss: 5.0610
# Epoch [246/10000], Step [1], Loss: 5.0395
# Epoch [247/10000], Step [1], Loss: 5.0065
# Epoch [248/10000], Step [1], Loss: 4.9909
# Epoch [249/10000], Step [1], Loss: 4.9745
# Epoch [250/10000], Step [1], Loss: 4.9670
# Epoch [251/10000], Step [1], Loss: 4.9597
# Epoch [252/10000], Step [1], Loss: 4.9549
# Epoch [253/10000], Step [1], Loss: 4.9425
# Epoch [254/10000], Step [1], Loss: 4.9365
# Epoch [255/10000], Step [1], Loss: 4.9368
# Epoch [256/10000], Step [1], Loss: 4.9227
# Epoch [257/10000], Step [1], Loss: 4.9291
# Epoch [258/10000], Step [1], Loss: 4.9170
# Epoch [259/10000], Step [1], Loss: 4.9038
# Epoch [260/10000], Step [1], Loss: 4.8883
# Epoch [261/10000], Step [1], Loss: 4.9086
# Epoch [262/10000], Step [1], Loss: 4.9201
# Epoch [263/10000], Step [1], Loss: 4.8948
# Epoch [264/10000], Step [1], Loss: 4.8774
# Epoch [265/10000], Step [1], Loss: 4.8555
# Epoch [266/10000], Step [1], Loss: 4.8483
# Epoch [267/10000], Step [1], Loss: 4.8381
# Epoch [268/10000], Step [1], Loss: 4.8292
# Epoch [269/10000], Step [1], Loss: 4.8713
# Epoch [270/10000], Step [1], Loss: 5.0607
# Epoch [271/10000], Step [1], Loss: 4.8911
# Epoch [272/10000], Step [1], Loss: 4.8612
# Epoch [273/10000], Step [1], Loss: 4.8341
# Epoch [274/10000], Step [1], Loss: 4.8134
# Epoch [275/10000], Step [1], Loss: 4.7956
# Epoch [276/10000], Step [1], Loss: 4.7858
# Epoch [277/10000], Step [1], Loss: 4.7790
# Epoch [278/10000], Step [1], Loss: 4.7660
# Epoch [279/10000], Step [1], Loss: 4.7537
# Epoch [280/10000], Step [1], Loss: 4.7747
# Epoch [281/10000], Step [1], Loss: 4.7647
# Epoch [282/10000], Step [1], Loss: 4.7471
# Epoch [283/10000], Step [1], Loss: 4.7313
# Epoch [284/10000], Step [1], Loss: 4.7177
# Epoch [285/10000], Step [1], Loss: 4.7112
# Epoch [286/10000], Step [1], Loss: 4.7244
# Epoch [287/10000], Step [1], Loss: 4.7055
# Epoch [288/10000], Step [1], Loss: 4.7287
# Epoch [289/10000], Step [1], Loss: 4.7413
# Epoch [290/10000], Step [1], Loss: 4.7211
# Epoch [291/10000], Step [1], Loss: 4.6984
# Epoch [292/10000], Step [1], Loss: 4.6787
# Epoch [293/10000], Step [1], Loss: 4.6605
# Epoch [294/10000], Step [1], Loss: 4.6454
# Epoch [295/10000], Step [1], Loss: 4.6447
# Epoch [296/10000], Step [1], Loss: 4.6512
# Epoch [297/10000], Step [1], Loss: 4.6666
# Epoch [298/10000], Step [1], Loss: 4.6535
# Epoch [299/10000], Step [1], Loss: 4.6289
# Epoch [300/10000], Step [1], Loss: 4.6117
# Epoch [301/10000], Step [1], Loss: 4.6010
# Epoch [302/10000], Step [1], Loss: 4.5919
# Epoch [303/10000], Step [1], Loss: 4.5789
# Epoch [304/10000], Step [1], Loss: 4.5848
# Epoch [305/10000], Step [1], Loss: 4.5785
# Epoch [306/10000], Step [1], Loss: 4.5780
# Epoch [307/10000], Step [1], Loss: 4.6131
# Epoch [308/10000], Step [1], Loss: 4.5841
# Epoch [309/10000], Step [1], Loss: 4.5588
# Epoch [310/10000], Step [1], Loss: 4.5418
# Epoch [311/10000], Step [1], Loss: 4.5305
# Epoch [312/10000], Step [1], Loss: 4.5277
# Epoch [313/10000], Step [1], Loss: 4.5172
# Epoch [314/10000], Step [1], Loss: 4.5185
# Epoch [315/10000], Step [1], Loss: 4.5096
# Epoch [316/10000], Step [1], Loss: 4.4987
# Epoch [317/10000], Step [1], Loss: 4.4874
# Epoch [318/10000], Step [1], Loss: 4.4807
# Epoch [319/10000], Step [1], Loss: 4.4884
# Epoch [320/10000], Step [1], Loss: 4.4755
# Epoch [321/10000], Step [1], Loss: 4.4723
# Epoch [322/10000], Step [1], Loss: 4.4640
# Epoch [323/10000], Step [1], Loss: 4.4636
# Epoch [324/10000], Step [1], Loss: 4.4556
# Epoch [325/10000], Step [1], Loss: 4.4397
# Epoch [326/10000], Step [1], Loss: 4.4284
# Epoch [327/10000], Step [1], Loss: 4.4207
# Epoch [328/10000], Step [1], Loss: 4.4296
# Epoch [329/10000], Step [1], Loss: 4.4140
# Epoch [330/10000], Step [1], Loss: 4.4102
# Epoch [331/10000], Step [1], Loss: 4.4003
# Epoch [332/10000], Step [1], Loss: 4.3919
# Epoch [333/10000], Step [1], Loss: 4.3933
# Epoch [334/10000], Step [1], Loss: 4.3801
# Epoch [335/10000], Step [1], Loss: 4.3758
# Epoch [336/10000], Step [1], Loss: 4.3625
# Epoch [337/10000], Step [1], Loss: 4.3604
# Epoch [338/10000], Step [1], Loss: 4.3543
# Epoch [339/10000], Step [1], Loss: 4.3586
# Epoch [340/10000], Step [1], Loss: 4.3485
# Epoch [341/10000], Step [1], Loss: 4.3357
# Epoch [342/10000], Step [1], Loss: 4.3236
# Epoch [343/10000], Step [1], Loss: 4.3184
# Epoch [344/10000], Step [1], Loss: 4.3296
# Epoch [345/10000], Step [1], Loss: 4.3188
# Epoch [346/10000], Step [1], Loss: 4.3044
# Epoch [347/10000], Step [1], Loss: 4.2913
# Epoch [348/10000], Step [1], Loss: 4.2779
# Epoch [349/10000], Step [1], Loss: 4.2798
# Epoch [350/10000], Step [1], Loss: 4.2815
# Epoch [351/10000], Step [1], Loss: 4.2699
# Epoch [352/10000], Step [1], Loss: 4.2600
# Epoch [353/10000], Step [1], Loss: 4.2501
# Epoch [354/10000], Step [1], Loss: 4.2455
# Epoch [355/10000], Step [1], Loss: 4.2418
# Epoch [356/10000], Step [1], Loss: 4.2311
# Epoch [357/10000], Step [1], Loss: 4.2477
# Epoch [358/10000], Step [1], Loss: 4.2337
# Epoch [359/10000], Step [1], Loss: 4.2157
# Epoch [360/10000], Step [1], Loss: 4.2053
# Epoch [361/10000], Step [1], Loss: 4.2006
# Epoch [362/10000], Step [1], Loss: 4.1972
# Epoch [363/10000], Step [1], Loss: 4.1941
# Epoch [364/10000], Step [1], Loss: 4.1906
# Epoch [365/10000], Step [1], Loss: 4.1793
# Epoch [366/10000], Step [1], Loss: 4.1675
# Epoch [367/10000], Step [1], Loss: 4.1617
# Epoch [368/10000], Step [1], Loss: 4.1646
# Epoch [369/10000], Step [1], Loss: 4.1610
# Epoch [370/10000], Step [1], Loss: 4.1476
# Epoch [371/10000], Step [1], Loss: 4.1399
# Epoch [372/10000], Step [1], Loss: 4.1327
# Epoch [373/10000], Step [1], Loss: 4.1339
# Epoch [374/10000], Step [1], Loss: 4.1355
# Epoch [375/10000], Step [1], Loss: 4.1264
# Epoch [376/10000], Step [1], Loss: 4.1169
# Epoch [377/10000], Step [1], Loss: 4.0990
# Epoch [378/10000], Step [1], Loss: 4.0900
# Epoch [379/10000], Step [1], Loss: 4.0965
# Epoch [380/10000], Step [1], Loss: 4.0850
# Epoch [381/10000], Step [1], Loss: 4.0745
# Epoch [382/10000], Step [1], Loss: 4.0720
# Epoch [383/10000], Step [1], Loss: 4.0681
# Epoch [384/10000], Step [1], Loss: 4.0631
# Epoch [385/10000], Step [1], Loss: 4.0525
# Epoch [386/10000], Step [1], Loss: 4.0493
# Epoch [387/10000], Step [1], Loss: 4.0450
# Epoch [388/10000], Step [1], Loss: 4.0351
# Epoch [389/10000], Step [1], Loss: 4.0262
# Epoch [390/10000], Step [1], Loss: 4.0170
# Epoch [391/10000], Step [1], Loss: 4.0130
# Epoch [392/10000], Step [1], Loss: 4.0091
# Epoch [393/10000], Step [1], Loss: 4.0082
# Epoch [394/10000], Step [1], Loss: 3.9970
# Epoch [395/10000], Step [1], Loss: 3.9979
# Epoch [396/10000], Step [1], Loss: 3.9773
# Epoch [397/10000], Step [1], Loss: 3.9884
# Epoch [398/10000], Step [1], Loss: 3.9799
# Epoch [399/10000], Step [1], Loss: 3.9628
# Epoch [400/10000], Step [1], Loss: 3.9562
# Epoch [401/10000], Step [1], Loss: 3.9577
# Epoch [402/10000], Step [1], Loss: 3.9578
# Epoch [403/10000], Step [1], Loss: 3.9647
# Epoch [404/10000], Step [1], Loss: 3.9353
# Epoch [405/10000], Step [1], Loss: 3.9237
# Epoch [406/10000], Step [1], Loss: 3.9151
# Epoch [407/10000], Step [1], Loss: 3.9129
# Epoch [408/10000], Step [1], Loss: 3.9066
# Epoch [409/10000], Step [1], Loss: 3.9026
# Epoch [410/10000], Step [1], Loss: 3.9010
# Epoch [411/10000], Step [1], Loss: 3.8998
# Epoch [412/10000], Step [1], Loss: 3.8902
# Epoch [413/10000], Step [1], Loss: 3.8758
# Epoch [414/10000], Step [1], Loss: 3.8646
# Epoch [415/10000], Step [1], Loss: 3.8605
# Epoch [416/10000], Step [1], Loss: 3.8739
# Epoch [417/10000], Step [1], Loss: 3.8640
# Epoch [418/10000], Step [1], Loss: 3.8464
# Epoch [419/10000], Step [1], Loss: 3.8346
# Epoch [420/10000], Step [1], Loss: 3.8281
# Epoch [421/10000], Step [1], Loss: 3.8188
# Epoch [422/10000], Step [1], Loss: 3.8301
# Epoch [423/10000], Step [1], Loss: 3.8453
# Epoch [424/10000], Step [1], Loss: 3.8697
# Epoch [425/10000], Step [1], Loss: 3.8420
# Epoch [426/10000], Step [1], Loss: 3.8227
# Epoch [427/10000], Step [1], Loss: 3.8032
# Epoch [428/10000], Step [1], Loss: 3.7880
# Epoch [429/10000], Step [1], Loss: 3.7813
# Epoch [430/10000], Step [1], Loss: 3.7753
# Epoch [431/10000], Step [1], Loss: 3.7673
# Epoch [432/10000], Step [1], Loss: 3.7676
# Epoch [433/10000], Step [1], Loss: 3.7658
# Epoch [434/10000], Step [1], Loss: 3.7506
# Epoch [435/10000], Step [1], Loss: 3.7433
# Epoch [436/10000], Step [1], Loss: 3.7354
# Epoch [437/10000], Step [1], Loss: 3.7268
# Epoch [438/10000], Step [1], Loss: 3.7295
# Epoch [439/10000], Step [1], Loss: 3.7199
# Epoch [440/10000], Step [1], Loss: 3.7163
# Epoch [441/10000], Step [1], Loss: 3.7173
# Epoch [442/10000], Step [1], Loss: 3.7170
# Epoch [443/10000], Step [1], Loss: 3.7060
# Epoch [444/10000], Step [1], Loss: 3.6936
# Epoch [445/10000], Step [1], Loss: 3.6866
# Epoch [446/10000], Step [1], Loss: 3.6855
# Epoch [447/10000], Step [1], Loss: 3.6730
# Epoch [448/10000], Step [1], Loss: 3.6718
# Epoch [449/10000], Step [1], Loss: 3.6655
# Epoch [450/10000], Step [1], Loss: 3.6631
# Epoch [451/10000], Step [1], Loss: 3.6639
# Epoch [452/10000], Step [1], Loss: 3.6587
# Epoch [453/10000], Step [1], Loss: 3.6443
# Epoch [454/10000], Step [1], Loss: 3.6311
# Epoch [455/10000], Step [1], Loss: 3.6239
# Epoch [456/10000], Step [1], Loss: 3.6244
# Epoch [457/10000], Step [1], Loss: 3.6087
# Epoch [458/10000], Step [1], Loss: 3.6295
# Epoch [459/10000], Step [1], Loss: 3.6035
# Epoch [460/10000], Step [1], Loss: 3.5938
# Epoch [461/10000], Step [1], Loss: 3.5946
# Epoch [462/10000], Step [1], Loss: 3.5834
# Epoch [463/10000], Step [1], Loss: 3.5803
# Epoch [464/10000], Step [1], Loss: 3.5686
# Epoch [465/10000], Step [1], Loss: 3.6168
# Epoch [466/10000], Step [1], Loss: 3.5712
# Epoch [467/10000], Step [1], Loss: 3.5587
# Epoch [468/10000], Step [1], Loss: 3.5553
# Epoch [469/10000], Step [1], Loss: 3.5453
# Epoch [470/10000], Step [1], Loss: 3.5498
# Epoch [471/10000], Step [1], Loss: 3.5331
# Epoch [472/10000], Step [1], Loss: 3.5220
# Epoch [473/10000], Step [1], Loss: 3.5171
# Epoch [474/10000], Step [1], Loss: 3.5123
# Epoch [475/10000], Step [1], Loss: 3.5129
# Epoch [476/10000], Step [1], Loss: 3.5040
# Epoch [477/10000], Step [1], Loss: 3.4942
# Epoch [478/10000], Step [1], Loss: 3.4911
# Epoch [479/10000], Step [1], Loss: 3.4901
# Epoch [480/10000], Step [1], Loss: 3.4802
# Epoch [481/10000], Step [1], Loss: 3.4711
# Epoch [482/10000], Step [1], Loss: 3.4658
# Epoch [483/10000], Step [1], Loss: 3.4591
# Epoch [484/10000], Step [1], Loss: 3.4585
# Epoch [485/10000], Step [1], Loss: 3.4461
# Epoch [486/10000], Step [1], Loss: 3.4548
# Epoch [487/10000], Step [1], Loss: 3.4417
# Epoch [488/10000], Step [1], Loss: 3.4434
# Epoch [489/10000], Step [1], Loss: 3.4350
# Epoch [490/10000], Step [1], Loss: 3.4291
# Epoch [491/10000], Step [1], Loss: 3.4216
# Epoch [492/10000], Step [1], Loss: 3.4105
# Epoch [493/10000], Step [1], Loss: 3.4099
# Epoch [494/10000], Step [1], Loss: 3.3995
# Epoch [495/10000], Step [1], Loss: 3.3971
# Epoch [496/10000], Step [1], Loss: 3.3964
# Epoch [497/10000], Step [1], Loss: 3.4030
# Epoch [498/10000], Step [1], Loss: 3.3868
# Epoch [499/10000], Step [1], Loss: 3.3892
# Epoch [500/10000], Step [1], Loss: 3.3724
# Epoch [501/10000], Step [1], Loss: 3.3652
# Epoch [502/10000], Step [1], Loss: 3.3635
# Epoch [503/10000], Step [1], Loss: 3.3553
# Epoch [504/10000], Step [1], Loss: 3.3425
# Epoch [505/10000], Step [1], Loss: 3.3495
# Epoch [506/10000], Step [1], Loss: 3.3333
# Epoch [507/10000], Step [1], Loss: 3.3316
# Epoch [508/10000], Step [1], Loss: 3.3238
# Epoch [509/10000], Step [1], Loss: 3.3165
# Epoch [510/10000], Step [1], Loss: 3.3274
# Epoch [511/10000], Step [1], Loss: 3.3084
# Epoch [512/10000], Step [1], Loss: 3.3056
# Epoch [513/10000], Step [1], Loss: 3.2914
# Epoch [514/10000], Step [1], Loss: 3.2838
# Epoch [515/10000], Step [1], Loss: 3.2860
# Epoch [516/10000], Step [1], Loss: 3.2749
# Epoch [517/10000], Step [1], Loss: 3.2713
# Epoch [518/10000], Step [1], Loss: 3.2697
# Epoch [519/10000], Step [1], Loss: 3.2748
# Epoch [520/10000], Step [1], Loss: 3.2548
# Epoch [521/10000], Step [1], Loss: 3.2473
# Epoch [522/10000], Step [1], Loss: 3.2419
# Epoch [523/10000], Step [1], Loss: 3.2729
# Epoch [524/10000], Step [1], Loss: 3.2478
# Epoch [525/10000], Step [1], Loss: 3.2414
# Epoch [526/10000], Step [1], Loss: 3.2233
# Epoch [527/10000], Step [1], Loss: 3.2190
# Epoch [528/10000], Step [1], Loss: 3.2131
# Epoch [529/10000], Step [1], Loss: 3.2241
# Epoch [530/10000], Step [1], Loss: 3.2180
# Epoch [531/10000], Step [1], Loss: 3.2007
# Epoch [532/10000], Step [1], Loss: 3.1881
# Epoch [533/10000], Step [1], Loss: 3.1829
# Epoch [534/10000], Step [1], Loss: 3.1743
# Epoch [535/10000], Step [1], Loss: 3.1761
# Epoch [536/10000], Step [1], Loss: 3.1634
# Epoch [537/10000], Step [1], Loss: 3.1676
# Epoch [538/10000], Step [1], Loss: 3.1668
# Epoch [539/10000], Step [1], Loss: 3.1603
# Epoch [540/10000], Step [1], Loss: 3.1485
# Epoch [541/10000], Step [1], Loss: 3.1394
# Epoch [542/10000], Step [1], Loss: 3.1326
# Epoch [543/10000], Step [1], Loss: 3.1324
# Epoch [544/10000], Step [1], Loss: 3.1288
# Epoch [545/10000], Step [1], Loss: 3.1196
# Epoch [546/10000], Step [1], Loss: 3.1200
# Epoch [547/10000], Step [1], Loss: 3.1156
# Epoch [548/10000], Step [1], Loss: 3.1024
# Epoch [549/10000], Step [1], Loss: 3.0980
# Epoch [550/10000], Step [1], Loss: 3.0970
# Epoch [551/10000], Step [1], Loss: 3.1185
# Epoch [552/10000], Step [1], Loss: 3.0878
# Epoch [553/10000], Step [1], Loss: 3.0829
# Epoch [554/10000], Step [1], Loss: 3.0779
# Epoch [555/10000], Step [1], Loss: 3.0745
# Epoch [556/10000], Step [1], Loss: 3.0804
# Epoch [557/10000], Step [1], Loss: 3.0584
# Epoch [558/10000], Step [1], Loss: 3.0463
# Epoch [559/10000], Step [1], Loss: 3.0517
# Epoch [560/10000], Step [1], Loss: 3.0360
# Epoch [561/10000], Step [1], Loss: 3.0320
# Epoch [562/10000], Step [1], Loss: 3.0481
# Epoch [563/10000], Step [1], Loss: 3.0293
# Epoch [564/10000], Step [1], Loss: 3.0230
# Epoch [565/10000], Step [1], Loss: 3.0179
# Epoch [566/10000], Step [1], Loss: 3.0131
# Epoch [567/10000], Step [1], Loss: 3.0193
# Epoch [568/10000], Step [1], Loss: 3.0004
# Epoch [569/10000], Step [1], Loss: 2.9976
# Epoch [570/10000], Step [1], Loss: 2.9871
# Epoch [571/10000], Step [1], Loss: 2.9863
# Epoch [572/10000], Step [1], Loss: 2.9822
# Epoch [573/10000], Step [1], Loss: 2.9729
# Epoch [574/10000], Step [1], Loss: 2.9713
# Epoch [575/10000], Step [1], Loss: 2.9746
# Epoch [576/10000], Step [1], Loss: 2.9646
# Epoch [577/10000], Step [1], Loss: 2.9575
# Epoch [578/10000], Step [1], Loss: 2.9421
# Epoch [579/10000], Step [1], Loss: 2.9425
# Epoch [580/10000], Step [1], Loss: 2.9355
# Epoch [581/10000], Step [1], Loss: 2.9320
# Epoch [582/10000], Step [1], Loss: 2.9311
# Epoch [583/10000], Step [1], Loss: 2.9354
# Epoch [584/10000], Step [1], Loss: 2.9154
# Epoch [585/10000], Step [1], Loss: 2.9205
# Epoch [586/10000], Step [1], Loss: 2.9041
# Epoch [587/10000], Step [1], Loss: 2.9013
# Epoch [588/10000], Step [1], Loss: 2.8954
# Epoch [589/10000], Step [1], Loss: 2.8897
# Epoch [590/10000], Step [1], Loss: 2.8858
# Epoch [591/10000], Step [1], Loss: 2.8787
# Epoch [592/10000], Step [1], Loss: 2.8809
# Epoch [593/10000], Step [1], Loss: 2.8705
# Epoch [594/10000], Step [1], Loss: 2.8663

# %%
predicted_abcd[1,1,:,:].shape
# Out:
# torch.Size([64, 64])

# %%
a_pre = predicted_abcd[1,0,:,:].detach().cpu().numpy()
b_pre = predicted_abcd[1,1,:,:].detach().cpu().numpy()
c_pre = predicted_abcd[1,2,:,:].detach().cpu().numpy()
d_pre = predicted_abcd[1,3,:,:].detach().cpu().numpy()

# %%
a_test_grad_x, a_test_grad_y = np.gradient(a_pre, dx)
b_test_grad_x, b_test_grad_y = np.gradient(b_pre, dx)
c_test_grad_x, c_test_grad_y = np.gradient(c_pre, dx)
d_test_grad_x, d_test_grad_y = np.gradient(d_pre, dx)

# %%
# U_x_pred_test = a_pre * b_test_grad_x - b_pre * a_test_grad_x + c_pre * d_test_grad_x - d_pre * c_test_grad_x
# U_y_pred_test = a_pre * b_test_grad_y - b_pre * a_test_grad_y + c_pre * d_test_grad_y - d_pre * c_test_grad_y
# U_magnitude_pred_test = np.sqrt(U_x_pred_test**2 + U_y_pred_test**2)

# %%
U_x_pred_test = a_pre + b_pre
U_y_pred_test = c_pre + d_pre
U_magnitude_pred_test = np.sqrt(U_x_pred_test**2 + U_y_pred_test**2)

# %%
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.imshow(U_x_pred_test, cmap='viridis')
# plt.colorbar()
plt.subplot(1, 2, 2)
plt.imshow(U_y_pred_test, cmap='viridis')

# %%
vort_pre = vorticity(U_x_pred_test, U_y_pred_test, dx, dx)

vorticity_normalized_pre = vorticity_normalize(vort_pre)

plt.imshow(vorticity_normalized_pre, cmap='RdBu_r',vmin=-0.2,vmax=0.2,interpolation='bilinear')
plt.colorbar()
