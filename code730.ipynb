# %%
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import DataLoader, TensorDataset, random_split
import cv2

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cuda')

# %%
import h5py
import matplotlib.pyplot as plt

# 文件路径
file_path = r'D:\\zjPhD\\turbulenceData\\turbulenceData\\isotropic1024coarse_10.h5'


# 读取HDF5文件
with h5py.File(file_path, 'r') as f:
    # 查看文件中所有的数据集
    datasets = list(f.keys())
    print("数据集列表:", datasets)
    
    # 假设第一个数据集是我们要看的
    dataset_name = datasets[0]
    data = f[dataset_name][()]
    print(f"{dataset_name} 数据形状:", data.shape)
    print(f"{dataset_name} 数据范围:", data.min(), "到", data.max())
# Out:
# 数据集列表: ['Velocity_0001', 'Velocity_0002', 'Velocity_0003', 'Velocity_0004', 'Velocity_0005', 'Velocity_0006', 'Velocity_0007', 'Velocity_0008', 'Velocity_0009', 'Velocity_0010', 'Velocity_0011', 'Velocity_0012', 'Velocity_0013', 'Velocity_0014', 'Velocity_0015', 'Velocity_0016', 'Velocity_0017', 'Velocity_0018', 'Velocity_0019', 'Velocity_0020', 'xcoor', 'ycoor', 'zcoor']
# Velocity_0001 数据形状: (1, 1024, 1024, 3)
# Velocity_0001 数据范围: -2.712391 到 2.6947422

# %%
import h5py
import numpy as np
import matplotlib.pyplot as plt

# 文件路径
file_path = r'D:\\zjPhD\\turbulenceData\\turbulenceData\\isotropic1024coarse_test.h5'

# 读取HDF5文件
with h5py.File(file_path, 'r') as f:
    # 查看文件中所有的数据集
    datasets = list(f.keys())
    print("数据集列表:", datasets)
    
    # 假设第一个数据集是我们要看的
    dataset_name = datasets[0]
    data = f[dataset_name][()]
    print(f"{dataset_name} 数据形状:", data.shape)
    print(f"{dataset_name} 数据范围:", data.min(), "到", data.max())
    
    # 归一化数据到 [0, 1] 范围
    data_normalized = (data[0] - data.min()) / (data.max() - data.min())
    
    # # 可视化数据中的第一个通道
    # plt.imshow(data_normalized[:, :, 0], cmap='viridis')
    # plt.title(f'{dataset_name} 第一个通道')
    # plt.colorbar()
    # plt.show()
    
    # # 可视化数据中的第二个通道
    # plt.imshow(data_normalized[:, :, 1], cmap='viridis')
    # plt.title(f'{dataset_name} 第二个通道')
    # plt.colorbar()
    # plt.show()
    
    # # 可视化数据中的第三个通道
    # plt.imshow(data_normalized[:, :, 2], cmap='viridis')
    # plt.title(f'{dataset_name} 第三个通道')
    # plt.colorbar()
    # plt.show()
# Out:
# 数据集列表: ['Velocity_0001', 'xcoor', 'ycoor', 'zcoor']
# Velocity_0001 数据形状: (1, 1024, 1024, 3)
# Velocity_0001 数据范围: -2.712391 到 2.6947422

# %%
import h5py
import numpy as np

# 文件路径
file_path = r'D:\\zjPhD\\turbulenceData\\turbulenceData\\isotropic1024coarse_10.h5'

# 读取HDF5文件并检查每个 Velocity 数据集的基本信息
with h5py.File(file_path, 'r') as f:
    # 查看文件中所有的数据集
    datasets = list(f.keys())
    print("数据集列表:", datasets)
    
    for dataset_name in datasets:
        if 'Velocity' in dataset_name:
            data = f[dataset_name][()]
            print(f"{dataset_name} 数据形状:", data.shape)
            print(f"{dataset_name} 数据范围:", data.min(), "到", data.max())
            print(f"{dataset_name} 数据均值:", data.mean())
            print(f"{dataset_name} 数据标准差:", data.std())
            print()
# Out:
# 数据集列表: ['Velocity_0001', 'Velocity_0002', 'Velocity_0003', 'Velocity_0004', 'Velocity_0005', 'Velocity_0006', 'Velocity_0007', 'Velocity_0008', 'Velocity_0009', 'Velocity_0010', 'Velocity_0011', 'Velocity_0012', 'Velocity_0013', 'Velocity_0014', 'Velocity_0015', 'Velocity_0016', 'Velocity_0017', 'Velocity_0018', 'Velocity_0019', 'Velocity_0020', 'xcoor', 'ycoor', 'zcoor']
# Velocity_0001 数据形状: (1, 1024, 1024, 3)
# Velocity_0001 数据范围: -2.712391 到 2.6947422
# Velocity_0001 数据均值: 0.07109838
# Velocity_0001 数据标准差: 0.6888756
#
# Velocity_0002 数据形状: (1, 1024, 1024, 3)
# Velocity_0002 数据范围: -2.7356367 到 2.7098155
# Velocity_0002 数据均值: 0.07116876
# Velocity_0002 数据标准差: 0.68889195
#
# Velocity_0003 数据形状: (1, 1024, 1024, 3)
# Velocity_0003 数据范围: -2.722479 到 2.7283216
# Velocity_0003 数据均值: 0.07122495
# Velocity_0003 数据标准差: 0.688922
#
# Velocity_0004 数据形状: (1, 1024, 1024, 3)
# Velocity_0004 数据范围: -2.7307792 到 2.74634
# Velocity_0004 数据均值: 0.07126973
# Velocity_0004 数据标准差: 0.6889681
#
# Velocity_0005 数据形状: (1, 1024, 1024, 3)
# Velocity_0005 数据范围: -2.6752195 到 2.770227
# Velocity_0005 数据均值: 0.071305186
# Velocity_0005 数据标准差: 0.6890285
#
# Velocity_0006 数据形状: (1, 1024, 1024, 3)
# Velocity_0006 数据范围: -2.608722 到 2.7777185
# Velocity_0006 数据均值: 0.07133317
# Velocity_0006 数据标准差: 0.68909943
#
# Velocity_0007 数据形状: (1, 1024, 1024, 3)
# Velocity_0007 数据范围: -2.5889878 到 2.7992706
# Velocity_0007 数据均值: 0.071355015
# Velocity_0007 数据标准差: 0.6891764
#
# Velocity_0008 数据形状: (1, 1024, 1024, 3)
# Velocity_0008 数据范围: -2.584568 到 2.8132267
# Velocity_0008 数据均值: 0.07137236
# Velocity_0008 数据标准差: 0.6892557
#
# Velocity_0009 数据形状: (1, 1024, 1024, 3)
# Velocity_0009 数据范围: -2.5807695 到 2.8110614
# Velocity_0009 数据均值: 0.071388565
# Velocity_0009 数据标准差: 0.68933684
#
# Velocity_0010 数据形状: (1, 1024, 1024, 3)
# Velocity_0010 数据范围: -2.5739505 到 2.8252645
# Velocity_0010 数据均值: 0.0714082
# Velocity_0010 数据标准差: 0.6894169
#
# Velocity_0011 数据形状: (1, 1024, 1024, 3)
# Velocity_0011 数据范围: -2.5682664 到 2.831748
# Velocity_0011 数据均值: 0.07143452
# Velocity_0011 数据标准差: 0.68949455
#
# Velocity_0012 数据形状: (1, 1024, 1024, 3)
# Velocity_0012 数据范围: -2.5639415 到 2.8183084
# Velocity_0012 数据均值: 0.07146752
# Velocity_0012 数据标准差: 0.6895657
#
# Velocity_0013 数据形状: (1, 1024, 1024, 3)
# Velocity_0013 数据范围: -2.5569108 到 2.8257155
# Velocity_0013 数据均值: 0.071504585
# Velocity_0013 数据标准差: 0.6896298
#
# Velocity_0014 数据形状: (1, 1024, 1024, 3)
# Velocity_0014 数据范围: -2.550218 到 2.8258345
# Velocity_0014 数据均值: 0.071542695
# Velocity_0014 数据标准差: 0.68968916
#
# Velocity_0015 数据形状: (1, 1024, 1024, 3)
# Velocity_0015 数据范围: -2.541764 到 2.8032413
# Velocity_0015 数据均值: 0.07158066
# Velocity_0015 数据标准差: 0.6897459
#
# Velocity_0016 数据形状: (1, 1024, 1024, 3)
# Velocity_0016 数据范围: -2.533338 到 2.8086593
# Velocity_0016 数据均值: 0.07161763
# Velocity_0016 数据标准差: 0.6898023
#
# Velocity_0017 数据形状: (1, 1024, 1024, 3)
# Velocity_0017 数据范围: -2.526175 到 2.7972069
# Velocity_0017 数据均值: 0.07165275
# Velocity_0017 数据标准差: 0.68985784
#
# Velocity_0018 数据形状: (1, 1024, 1024, 3)
# Velocity_0018 数据范围: -2.519424 到 2.7872314
# Velocity_0018 数据均值: 0.07168614
# Velocity_0018 数据标准差: 0.6899145
#
# Velocity_0019 数据形状: (1, 1024, 1024, 3)
# Velocity_0019 数据范围: -2.539456 到 2.7889357
# Velocity_0019 数据均值: 0.07171971
# Velocity_0019 数据标准差: 0.68997425
#
# Velocity_0020 数据形状: (1, 1024, 1024, 3)
# Velocity_0020 数据范围: -2.5543127 到 2.7725642
# Velocity_0020 数据均值: 0.07175511
# Velocity_0020 数据标准差: 0.6900401

# %% [markdown]
# # 定义所需要的函数

# %% [markdown]
# ## 计算涡度

# %%
def vorticity(U_x, U_y, dx, dy):
    dU_y_dx, _ = np.gradient(U_y, dx, axis=0), np.gradient(U_y, dy, axis=1)
    _, dU_x_dy = np.gradient(U_x, dx, axis=0), np.gradient(U_x, dy, axis=1)
    return dU_y_dx - dU_x_dy


# 计算归一化的涡度
def vorticity_normalize(vorticity):
    max_vorticity = np.max(np.abs(vorticity))
    vort_normalized = vorticity / max_vorticity if max_vorticity != 0 else vorticity
    return vort_normalized

# %% [markdown]
# # 预训练模型测试新的湍流非对称数据集

# %% [markdown]
# 读取约翰霍普金斯的湍流数据库

# %%
import h5py

import numpy as np
import matplotlib.pyplot as plt

# %%
def downsample(image, size=(64, 64)):
    return cv2.resize(image, size, interpolation=cv2.INTER_AREA)

# %% [markdown]
# ### 原始数据集

# %%
## 读取测试集

file_path = r'D:\\zjPhD\\turbulenceData\\turbulenceData\\isotropic1024coarse_test.h5'

with h5py.File(file_path,'r') as f :
    datasets = list(f.keys())
    print("数据集列表:", datasets)
    
    for dataset_name in datasets:
        if 'Velocity' in dataset_name:
            data = f[dataset_name][()]
            print(f"{dataset_name} 数据形状:", data.shape)
            print(f"{dataset_name} 数据范围:", data.min(), "到", data.max())
            print(f"{dataset_name} 数据均值:", data.mean())
            print(f"{dataset_name} 数据标准差:", data.std())
            print()

    data_normalized = (data[0] - data.min()) / (data.max() - data.min())

    data = f[dataset_name][()]

    u_test = data_normalized[:,:,0]
    v_test = data_normalized[:,:,1]
    w_test = data_normalized[:,:,2]
# Out:
# 数据集列表: ['Velocity_0001', 'xcoor', 'ycoor', 'zcoor']
# Velocity_0001 数据形状: (1, 1024, 1024, 3)
# Velocity_0001 数据范围: -2.712391 到 2.6947422
# Velocity_0001 数据均值: 0.07109838
# Velocity_0001 数据标准差: 0.6888756

# %% [markdown]
# ### 降采样数据集 （64*64）

# %%
# 读取HDF5文件并降采样
with h5py.File(file_path, 'r') as f:
    # 获取所有速度场数据集名称
    velocity_datasets = [name for name in f.keys() if 'Velocity' in name]
    
    # 初始化空列表用于存储所有数据
    all_velocity_fields = []
    
    for dataset_name in velocity_datasets:
        data = f[dataset_name][()]
        # 取出三通道的速度场数据
        U_x = data[0, :, :, 0]
        U_y = data[0, :, :, 1]
        U_magnitude = data[0, :, :, 2]
        
        # 降采样
        U_x_downsampled = downsample(U_x)
        U_y_downsampled = downsample(U_y)
        U_magnitude_downsampled = downsample(U_magnitude)
        
        # 将数据转换为PyTorch张量并增加batch和channel维度
        U_x_tensor = torch.tensor(U_x_downsampled, dtype=torch.float32).unsqueeze(0).unsqueeze(0)
        U_y_tensor = torch.tensor(U_y_downsampled, dtype=torch.float32).unsqueeze(0).unsqueeze(0)
        U_magnitude_tensor = torch.tensor(U_magnitude_downsampled, dtype=torch.float32).unsqueeze(0).unsqueeze(0)
        
        # 合并速度场作为输入
        velocity_field = torch.cat((U_x_tensor, U_y_tensor, U_magnitude_tensor), dim=1)
        
        all_velocity_fields.append(velocity_field)
    
    # 将所有速度场数据合并为一个大的张量
    all_velocity_fields = torch.cat(all_velocity_fields, dim=0)
    
    # 目标abcd (假设为0初始化)
    num_samples = all_velocity_fields.shape[0]
    size_low = all_velocity_fields.shape[2]
    target_abcd = torch.zeros((num_samples, 4, size_low, size_low), dtype=torch.float32)
    
    # 创建数据集和数据加载器
    dataset = TensorDataset(all_velocity_fields, target_abcd)
    dataloader = DataLoader(dataset, batch_size=1, shuffle=True)  # 你可以根据需要调整batch_size

# 检查数据形状
print("all_velocity_fields shape:", all_velocity_fields.shape)
print("target_abcd shape:", target_abcd.shape)
# Out:
# all_velocity_fields shape: torch.Size([1, 3, 64, 64])
# target_abcd shape: torch.Size([1, 4, 64, 64])

# %%
target_abcd.shape
# Out:
# torch.Size([1, 4, 64, 64])

# %%
all_velocity_fields[0,1,0,:].shape
# Out:
# torch.Size([64])

# %%
#可以查看数据范围，xyz都是（0，$2\pi$）
size_low = 64

dx = 2*np.pi/size_low
dy = 2*np.pi/size_low
dz = 2*np.pi/size_low

# %%
u_test =all_velocity_fields[0,0,:,:].numpy()
v_test =all_velocity_fields[0,1,:,:].numpy()
w_test =all_velocity_fields[0,2,:,:].numpy()

# %%
vort_test = vorticity(u_test, v_test, dx, dx)

vorticity_normalized = vorticity_normalize(vort_test)

print(vort_test.shape)
print(vorticity_normalized.shape)
# Out:
# (64, 64)
# (64, 64)

# %%
plt.imshow(vorticity_normalized, cmap='RdBu_r',vmin=-0.3,vmax=0.3,interpolation='bilinear')
plt.colorbar()

# %%
print("u速度场形状",u_test.shape) 
print("v速度场形状",v_test.shape)

# 查看一些速度场   
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)   
plt.imshow(u_test, cmap='viridis')   
plt.subplot(1, 2, 2)
plt.imshow(v_test, cmap='viridis')
# Out:
# u速度场形状 (64, 64)
# v速度场形状 (64, 64)

# %%
plt.imshow(u_test, cmap='viridis')

# %% [markdown]
# # 模型A部分尝试更换数据集

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f'Using device: {device}')
# Out:
# Using device: cuda

# %%
import h5py
import torch
from torch.utils.data import DataLoader, TensorDataset

# 文件路径
file_path = r'D:\\zjPhD\\turbulenceData\\turbulenceData\\isotropic1024coarse_10.h5'

# 读取HDF5文件并降采样
with h5py.File(file_path, 'r') as f:
    # 获取所有速度场数据集名称
    velocity_datasets = [name for name in f.keys() if 'Velocity' in name]
    
    # 初始化空列表用于存储所有数据
    all_velocity_fields = []
    
    for dataset_name in velocity_datasets:
        data = f[dataset_name][()]
        # 取出三通道的速度场数据
        U_x = data[0, :, :, 0]
        U_y = data[0, :, :, 1]
        U_magnitude = data[0, :, :, 2]
        
        # 降采样
        U_x_downsampled = downsample(U_x)
        U_y_downsampled = downsample(U_y)
        U_magnitude_downsampled = downsample(U_magnitude)
        # U_x_downsampled = U_x
        # U_y_downsampled = U_y
        # U_magnitude_downsampled = U_magnitude
        
        # 将数据转换为PyTorch张量并增加batch和channel维度
        U_x_tensor = torch.tensor(U_x_downsampled, dtype=torch.float32).unsqueeze(0).unsqueeze(0)
        U_y_tensor = torch.tensor(U_y_downsampled, dtype=torch.float32).unsqueeze(0).unsqueeze(0)
        U_magnitude_tensor = torch.tensor(U_magnitude_downsampled, dtype=torch.float32).unsqueeze(0).unsqueeze(0)
        
        # 合并速度场作为输入
        velocity_field = torch.cat((U_x_tensor, U_y_tensor, U_magnitude_tensor), dim=1)
        
        all_velocity_fields.append(velocity_field)
    
    # 将所有速度场数据合并为一个大的张量
    all_velocity_fields = torch.cat(all_velocity_fields, dim=0)
    
    # 目标abcd (假设为0初始化)
    num_samples = all_velocity_fields.shape[0]
    size_low = all_velocity_fields.shape[2]
    target_abcd = torch.zeros((num_samples, 4, size_low, size_low), dtype=torch.float32)
    
    # 创建数据集和数据加载器
    dataset = TensorDataset(all_velocity_fields, target_abcd)
    dataloader = DataLoader(dataset, batch_size=2, shuffle=True)  # 调整批量大小

# 检查数据形状
print("all_velocity_fields shape:", all_velocity_fields.shape)
print("target_abcd shape:", target_abcd.shape)
# Out:
# all_velocity_fields shape: torch.Size([20, 3, 64, 64])
# target_abcd shape: torch.Size([20, 4, 64, 64])

# %%
# 简单的模型
class BasicModelA(nn.Module):
    def __init__(self):
        super(BasicModelA, self).__init__()
        self.conv1 = nn.Conv2d(3, 64, kernel_size=3, padding=1)
        self.bn1 = nn.BatchNorm2d(64)
        self.conv2 = nn.Conv2d(64, 128, kernel_size=3, padding=1)
        self.bn2 = nn.BatchNorm2d(128)
        self.conv3 = nn.Conv2d(128, 256, kernel_size=3, padding=1)
        self.bn3 = nn.BatchNorm2d(256)
        self.pool = nn.MaxPool2d(2, 2)
        self.conv4 = nn.Conv2d(256, 512, kernel_size=3, padding=1)
        self.bn4 = nn.BatchNorm2d(512)
        self.upsample = nn.Upsample(scale_factor=8, mode='bilinear', align_corners=True)
        self.conv5 = nn.Conv2d(512, 4, kernel_size=3, padding=1)

    def forward(self, x):
        x = F.relu(self.bn1(self.conv1(x)))
        x = self.pool(x)
        x = F.relu(self.bn2(self.conv2(x)))
        x = self.pool(x)
        x = F.relu(self.bn3(self.conv3(x)))
        x = self.pool(x)
        x = F.relu(self.bn4(self.conv4(x)))
        x = self.upsample(x)  # 使用上采样恢复到原始尺寸
        x = self.conv5(x)
        return x

# %%
# 复杂的模型
class ComplexModelA(nn.Module):
    def __init__(self):
        super(ComplexModelA, self).__init__()
        # Encoder
        self.conv1 = nn.Conv2d(3, 64, kernel_size=3, padding=1)
        self.bn1 = nn.BatchNorm2d(64)
        self.conv2 = nn.Conv2d(64, 128, kernel_size=3, padding=1)
        self.bn2 = nn.BatchNorm2d(128)
        self.conv3 = nn.Conv2d(128, 256, kernel_size=3, padding=1)
        self.bn3 = nn.BatchNorm2d(256)
        self.conv4 = nn.Conv2d(256, 512, kernel_size=3, padding=1)
        self.bn4 = nn.BatchNorm2d(512)
        self.conv5 = nn.Conv2d(512, 1024, kernel_size=3, padding=1)
        self.bn5 = nn.BatchNorm2d(1024)
        
        self.pool = nn.MaxPool2d(2, 2)

        # Decoder
        self.upconv1 = nn.ConvTranspose2d(1024, 512, kernel_size=2, stride=2)
        self.conv6 = nn.Conv2d(1024, 512, kernel_size=3, padding=1)
        self.bn6 = nn.BatchNorm2d(512)
        
        self.upconv2 = nn.ConvTranspose2d(512, 256, kernel_size=2, stride=2)
        self.conv7 = nn.Conv2d(512, 256, kernel_size=3, padding=1)
        self.bn7 = nn.BatchNorm2d(256)
        
        self.upconv3 = nn.ConvTranspose2d(256, 128, kernel_size=2, stride=2)
        self.conv8 = nn.Conv2d(256, 128, kernel_size=3, padding=1)
        self.bn8 = nn.BatchNorm2d(128)
        
        self.upconv4 = nn.ConvTranspose2d(128, 64, kernel_size=2, stride=2)
        self.conv9 = nn.Conv2d(128, 64, kernel_size=3, padding=1)
        self.bn9 = nn.BatchNorm2d(64)
        
        self.conv10 = nn.Conv2d(64, 4, kernel_size=3, padding=1)
        
    def forward(self, x):
        # Encoder
        x1 = F.relu(self.bn1(self.conv1(x)))
        x2 = self.pool(x1)
        x2 = F.relu(self.bn2(self.conv2(x2)))
        x3 = self.pool(x2)
        x3 = F.relu(self.bn3(self.conv3(x3)))
        x4 = self.pool(x3)
        x4 = F.relu(self.bn4(self.conv4(x4)))
        x5 = self.pool(x4)
        x5 = F.relu(self.bn5(self.conv5(x5)))
        
        # Decoder
        x = self.upconv1(x5)
        x = torch.cat((x, x4), dim=1)  # Skip connection
        x = F.relu(self.bn6(self.conv6(x)))
        
        x = self.upconv2(x)
        x = torch.cat((x, x3), dim=1)  # Skip connection
        x = F.relu(self.bn7(self.conv7(x)))
        
        x = self.upconv3(x)
        x = torch.cat((x, x2), dim=1)  # Skip connection
        x = F.relu(self.bn8(self.conv8(x)))
        
        x = self.upconv4(x)
        x = torch.cat((x, x1), dim=1)  # Skip connection
        x = F.relu(self.bn9(self.conv9(x)))
        
        x = self.conv10(x)
        return x

# %%
class ConstraintLayer(nn.Module):
    def __init__(self):
        super(ConstraintLayer, self).__init__()

    def forward(self, x):
        # 假设x的形状为 [batch_size, 4, height, width]，其中4代表abcd
        norm = torch.sqrt(x[:, 0, :, :]**2 + x[:, 1, :, :]**2 + x[:, 2, :, :]**2 + x[:, 3, :, :]**2 + 1e-8)
        norm = norm.unsqueeze(1)  # 为了与abcd的四个通道对齐
        x = x / norm  # 归一化
        return x

# %%
class ModelAWithConstraints(nn.Module):
    def __init__(self):
        super(ModelAWithConstraints, self).__init__()
        self.model = BasicModelA()
        self.constraint_layer = ConstraintLayer()

    def forward(self, x):
        x = self.model(x)
        x = self.constraint_layer(x)
        return x

# %%
def calculate_gradients_with_numpy(tensor):
    # 确保 Tensor 不需要梯度跟踪，且在 CPU 上
    tensor_np = tensor.detach().cpu().numpy()

    # 计算梯度
    grad_x = np.gradient(tensor_np, axis=1)  # 假设水平方向是 axis=1
    grad_y = np.gradient(tensor_np, axis=2)  # 假设垂直方向是 axis=2
    
    # 转换回 Tensor
    grad_x_tensor = torch.from_numpy(grad_x).to(tensor.device)
    grad_y_tensor = torch.from_numpy(grad_y).to(tensor.device)
    
    return grad_x_tensor, grad_y_tensor

# %%
def laplacian_2d(array, dx, dy):
    grad_x = np.gradient(array, dx, axis=1, edge_order=2)  # 计算 x 方向的一阶导数
    grad_y = np.gradient(array, dy, axis=0, edge_order=2)  # 计算 y 方向的一阶导数
    
    laplacian_x = np.gradient(grad_x, dx, axis=1, edge_order=2)  # 计算 x 方向的二阶导数
    laplacian_y = np.gradient(grad_y, dy, axis=0, edge_order=2)  # 计算 y 方向的二阶导数
    
    return laplacian_x + laplacian_y



def laplacian_2d_torch(tensor, dx, dy):
    # 确保tensor是浮点类型，因为梯度计算通常需要浮点运算
    tensor = tensor.float()
    tensor_np = tensor.detach().cpu().numpy()

    # 计算x和y方向的一阶导数
    grad_x = np.gradient(tensor_np, axis=1)  # x方向
    grad_y = np.gradient(tensor_np, axis=2)  # y方向

    # 计算x和y方向的二阶导数
    laplacian_x = np.gradient(grad_x, axis=1)
    laplacian_y = np.gradient(grad_y, axis=2)

    laplacian_x_tensor = torch.from_numpy(laplacian_x).to(tensor.device)
    laplacian_y_tensor = torch.from_numpy(laplacian_y).to(tensor.device)

    # 相加得到完整的拉普拉斯算子
    laplacian = laplacian_x_tensor + laplacian_y_tensor

    return laplacian

# %%
def loss_function(predicted_abcd, true_velocity, model, epsilon, l1_lambda=0.0, l2_lambda=0.0):
    # 提取 a, b, c, d
    a = predicted_abcd[:, 0, :, :]
    b = predicted_abcd[:, 1, :, :]
    c = predicted_abcd[:, 2, :, :]
    d = predicted_abcd[:, 3, :, :]
    
    # 计算梯度
    a_grad_x, a_grad_y = calculate_gradients_with_numpy(a)
    b_grad_x, b_grad_y = calculate_gradients_with_numpy(b)
    c_grad_x, c_grad_y = calculate_gradients_with_numpy(c)
    d_grad_x, d_grad_y = calculate_gradients_with_numpy(d)

    hbar = 1  # 你可以根据具体情况调整这个参数

    # # 根据 a, b, c, d 计算预测的速度场
    # U_x_pred = a + b
    # U_y_pred = c + d
    # U_magnitude_pred = torch.sqrt(U_x_pred**2 + U_y_pred**2)
    
    # # 计算速度场的损失
    # U_x_true = true_velocity[:, 0, :, :]
    # U_y_true = true_velocity[:, 1, :, :]
    # U_magnitude_true = true_velocity[:, 2, :, :]


    # U_x_pred = hbar * (a * b_grad_x - b * a_grad_x + c * d_grad_x - d * c_grad_x)
    # U_y_pred = hbar * (a * b_grad_y - b * a_grad_y + c * d_grad_y - d * c_grad_y)
    # U_magnitude_pred = torch.sqrt(U_x_pred**2 + U_y_pred**2)

    U_x_pred = hbar *(a * b_grad_x - b * a_grad_x )
    U_y_pred = hbar *(c * d_grad_y - d * c_grad_y)
    U_magnitude_pred = torch.sqrt(U_x_pred**2 + U_y_pred**2)
    
    # # 计算速度场的损失
    U_x_true = true_velocity[:, 0, :, :]
    U_y_true = true_velocity[:, 1, :, :]
    U_magnitude_true = true_velocity[:, 2, :, :]

    loss_velocity = F.mse_loss(U_magnitude_pred, U_magnitude_true) + F.mse_loss(U_x_pred, U_x_true) + F.mse_loss(U_y_pred, U_y_true)
    
    # 计算归一化约束
    norm = a**2 + b**2 + c**2 + d**2
    norm_constraint = F.mse_loss(norm, torch.ones_like(norm))
    
    # 计算拉普拉斯算子
    lap_b = laplacian_2d_torch(b, dx, dx)
    lap_a = laplacian_2d_torch(a, dx, dx)
    lap_d = laplacian_2d_torch(d, dx, dx)
    lap_c = laplacian_2d_torch(c, dx, dx)

    # 计算螺旋度约束
    curl_constraint = (a * lap_b - b * lap_a + c * lap_d - d * lap_c).sum()
    
    # 计算L1正则化项
    l1_regularization = torch.tensor(0., requires_grad=True)
    if l1_lambda > 0:
        l1_regularization = sum(torch.sum(torch.abs(param)) for param in model.parameters())

    # 计算L2正则化项
    l2_regularization = torch.tensor(0., requires_grad=True)
    if l2_lambda > 0:
        l2_regularization = sum(torch.sum(param**2) for param in model.parameters())
    
    # 计算正则化项
    regularization_term = epsilon * 0.25 * (torch.sum(a**2) + torch.sum(b**2) + torch.sum(c**2) + torch.sum(d**2))
    
    # 总损失
    total_loss = loss_velocity + l1_lambda * l1_regularization + l2_lambda * l2_regularization #+ norm_constraint + curl_constraint + regularization_term 
    return total_loss

# %%
from torch.cuda.amp import GradScaler, autocast

# %%
learning_rate = 0.0001
num_epochs = 3000
epsilon = 0.01
l1_lambda = 0.001  # L1正则化系数
l2_lambda = 0.001  # L2正则化系数


channels = 3

model = ComplexModelA()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

# %%
for epoch in range(num_epochs):
    for i, (velocity, _) in enumerate(dataloader):
        optimizer.zero_grad()
        predicted_abcd = model(velocity)
        # loss = loss_function(predicted_abcd, velocity, epsilon)
        loss = loss_function(predicted_abcd, velocity, model, epsilon, l1_lambda, l2_lambda)

        loss.backward()
        optimizer.step()
        if i % 10 == 0:
            print(f'Epoch [{epoch+1}/{num_epochs}], Step [{i+1}], Loss: {loss.item():.4f}')
# Out:
# Epoch [1/3000], Step [1], Loss: 134.8254
# Epoch [2/3000], Step [1], Loss: 119.7783
# Epoch [3/3000], Step [1], Loss: 105.8611
# Epoch [4/3000], Step [1], Loss: 93.0520
# Epoch [5/3000], Step [1], Loss: 81.3247
# Epoch [6/3000], Step [1], Loss: 70.6611
# Epoch [7/3000], Step [1], Loss: 61.0638
# Epoch [8/3000], Step [1], Loss: 52.5239
# Epoch [9/3000], Step [1], Loss: 45.0499
# Epoch [10/3000], Step [1], Loss: 38.6420
# Epoch [11/3000], Step [1], Loss: 33.2676
# Epoch [12/3000], Step [1], Loss: 28.8532
# Epoch [13/3000], Step [1], Loss: 25.0314
# Epoch [14/3000], Step [1], Loss: 21.8870
# Epoch [15/3000], Step [1], Loss: 19.3632
# Epoch [16/3000], Step [1], Loss: 17.4104
# Epoch [17/3000], Step [1], Loss: 15.7086
# Epoch [18/3000], Step [1], Loss: 14.2678
# Epoch [19/3000], Step [1], Loss: 13.0354
# Epoch [20/3000], Step [1], Loss: 12.0086
# Epoch [21/3000], Step [1], Loss: 11.1967
# Epoch [22/3000], Step [1], Loss: 10.5480
# Epoch [23/3000], Step [1], Loss: 10.0588
# Epoch [24/3000], Step [1], Loss: 9.6635
# Epoch [25/3000], Step [1], Loss: 9.3137
# Epoch [26/3000], Step [1], Loss: 9.0035
# Epoch [27/3000], Step [1], Loss: 8.7345
# Epoch [28/3000], Step [1], Loss: 8.4849
# Epoch [29/3000], Step [1], Loss: 8.2917
# Epoch [30/3000], Step [1], Loss: 8.1136
# Epoch [31/3000], Step [1], Loss: 7.9814
# Epoch [32/3000], Step [1], Loss: 7.8589
# Epoch [33/3000], Step [1], Loss: 7.7667
# Epoch [34/3000], Step [1], Loss: 7.6759
# Epoch [35/3000], Step [1], Loss: 7.5969
# Epoch [36/3000], Step [1], Loss: 7.5194
# Epoch [37/3000], Step [1], Loss: 7.4494
# Epoch [38/3000], Step [1], Loss: 7.3866
# Epoch [39/3000], Step [1], Loss: 7.3282
# Epoch [40/3000], Step [1], Loss: 7.2825
# Epoch [41/3000], Step [1], Loss: 7.2294
# Epoch [42/3000], Step [1], Loss: 7.1767
# Epoch [43/3000], Step [1], Loss: 7.1386
# Epoch [44/3000], Step [1], Loss: 7.0958
# Epoch [45/3000], Step [1], Loss: 7.0692
# Epoch [46/3000], Step [1], Loss: 7.0433
# Epoch [47/3000], Step [1], Loss: 7.0115
# Epoch [48/3000], Step [1], Loss: 6.9805
# Epoch [49/3000], Step [1], Loss: 6.9659
# Epoch [50/3000], Step [1], Loss: 6.9376
# Epoch [51/3000], Step [1], Loss: 6.9094
# Epoch [52/3000], Step [1], Loss: 6.8974
# Epoch [53/3000], Step [1], Loss: 6.8673
# Epoch [54/3000], Step [1], Loss: 6.8494
# Epoch [55/3000], Step [1], Loss: 6.8309
# Epoch [56/3000], Step [1], Loss: 6.8056
# Epoch [57/3000], Step [1], Loss: 6.7900
# Epoch [58/3000], Step [1], Loss: 6.7662
# Epoch [59/3000], Step [1], Loss: 6.7483
# Epoch [60/3000], Step [1], Loss: 6.7299
# Epoch [61/3000], Step [1], Loss: 6.7239
# Epoch [62/3000], Step [1], Loss: 6.7034
# Epoch [63/3000], Step [1], Loss: 6.6909
# Epoch [64/3000], Step [1], Loss: 6.6727
# Epoch [65/3000], Step [1], Loss: 6.6539
# Epoch [66/3000], Step [1], Loss: 6.6424
# Epoch [67/3000], Step [1], Loss: 6.6441
# Epoch [68/3000], Step [1], Loss: 6.6290
# Epoch [69/3000], Step [1], Loss: 6.6067
# Epoch [70/3000], Step [1], Loss: 6.5878
# Epoch [71/3000], Step [1], Loss: 6.5912
# Epoch [72/3000], Step [1], Loss: 6.6162
# Epoch [73/3000], Step [1], Loss: 6.5790
# Epoch [74/3000], Step [1], Loss: 6.5444
# Epoch [75/3000], Step [1], Loss: 6.5265
# Epoch [76/3000], Step [1], Loss: 6.5182
# Epoch [77/3000], Step [1], Loss: 6.5110
# Epoch [78/3000], Step [1], Loss: 6.5045
# Epoch [79/3000], Step [1], Loss: 6.4892
# Epoch [80/3000], Step [1], Loss: 6.4788
# Epoch [81/3000], Step [1], Loss: 6.4694
# Epoch [82/3000], Step [1], Loss: 6.4639
# Epoch [83/3000], Step [1], Loss: 6.4470
# Epoch [84/3000], Step [1], Loss: 6.4408
# Epoch [85/3000], Step [1], Loss: 6.4201
# Epoch [86/3000], Step [1], Loss: 6.4201
# Epoch [87/3000], Step [1], Loss: 6.4056
# Epoch [88/3000], Step [1], Loss: 6.3878
# Epoch [89/3000], Step [1], Loss: 6.3868
# Epoch [90/3000], Step [1], Loss: 6.3737
# Epoch [91/3000], Step [1], Loss: 6.3746
# Epoch [92/3000], Step [1], Loss: 6.3752
# Epoch [93/3000], Step [1], Loss: 6.3484
# Epoch [94/3000], Step [1], Loss: 6.3437
# Epoch [95/3000], Step [1], Loss: 6.3165
# Epoch [96/3000], Step [1], Loss: 6.3041
# Epoch [97/3000], Step [1], Loss: 6.3054
# Epoch [98/3000], Step [1], Loss: 6.2992
# Epoch [99/3000], Step [1], Loss: 6.2891
# Epoch [100/3000], Step [1], Loss: 6.2770
# Epoch [101/3000], Step [1], Loss: 6.2653
# Epoch [102/3000], Step [1], Loss: 6.2576
# Epoch [103/3000], Step [1], Loss: 6.2367
# Epoch [104/3000], Step [1], Loss: 6.2263
# Epoch [105/3000], Step [1], Loss: 6.2410
# Epoch [106/3000], Step [1], Loss: 6.2211
# Epoch [107/3000], Step [1], Loss: 6.2030
# Epoch [108/3000], Step [1], Loss: 6.1913
# Epoch [109/3000], Step [1], Loss: 6.1791
# Epoch [110/3000], Step [1], Loss: 6.1691
# Epoch [111/3000], Step [1], Loss: 6.1641
# Epoch [112/3000], Step [1], Loss: 6.1619
# Epoch [113/3000], Step [1], Loss: 6.1462
# Epoch [114/3000], Step [1], Loss: 6.1499
# Epoch [115/3000], Step [1], Loss: 6.1331
# Epoch [116/3000], Step [1], Loss: 6.1175
# Epoch [117/3000], Step [1], Loss: 6.1082
# Epoch [118/3000], Step [1], Loss: 6.0955
# Epoch [119/3000], Step [1], Loss: 6.1100
# Epoch [120/3000], Step [1], Loss: 6.1047
# Epoch [121/3000], Step [1], Loss: 6.0853
# Epoch [122/3000], Step [1], Loss: 6.0731
# Epoch [123/3000], Step [1], Loss: 6.0697
# Epoch [124/3000], Step [1], Loss: 6.0463
# Epoch [125/3000], Step [1], Loss: 6.0360
# Epoch [126/3000], Step [1], Loss: 6.0390
# Epoch [127/3000], Step [1], Loss: 6.0195
# Epoch [128/3000], Step [1], Loss: 6.0123
# Epoch [129/3000], Step [1], Loss: 5.9911
# Epoch [130/3000], Step [1], Loss: 5.9865
# Epoch [131/3000], Step [1], Loss: 5.9747
# Epoch [132/3000], Step [1], Loss: 5.9757
# Epoch [133/3000], Step [1], Loss: 5.9858
# Epoch [134/3000], Step [1], Loss: 5.9709
# Epoch [135/3000], Step [1], Loss: 5.9492
# Epoch [136/3000], Step [1], Loss: 5.9364
# Epoch [137/3000], Step [1], Loss: 5.9206
# Epoch [138/3000], Step [1], Loss: 5.9147
# Epoch [139/3000], Step [1], Loss: 5.9066
# Epoch [140/3000], Step [1], Loss: 5.9027
# Epoch [141/3000], Step [1], Loss: 5.9035
# Epoch [142/3000], Step [1], Loss: 5.8802
# Epoch [143/3000], Step [1], Loss: 5.8672
# Epoch [144/3000], Step [1], Loss: 5.8653
# Epoch [145/3000], Step [1], Loss: 5.8651
# Epoch [146/3000], Step [1], Loss: 5.8606
# Epoch [147/3000], Step [1], Loss: 5.8445
# Epoch [148/3000], Step [1], Loss: 5.8248
# Epoch [149/3000], Step [1], Loss: 5.8159
# Epoch [150/3000], Step [1], Loss: 5.8051
# Epoch [151/3000], Step [1], Loss: 5.8001
# Epoch [152/3000], Step [1], Loss: 5.7924
# Epoch [153/3000], Step [1], Loss: 5.7943
# Epoch [154/3000], Step [1], Loss: 5.7835
# Epoch [155/3000], Step [1], Loss: 5.7657
# Epoch [156/3000], Step [1], Loss: 5.7560
# Epoch [157/3000], Step [1], Loss: 5.7416
# Epoch [158/3000], Step [1], Loss: 5.7435
# Epoch [159/3000], Step [1], Loss: 5.7266
# Epoch [160/3000], Step [1], Loss: 5.7159
# Epoch [161/3000], Step [1], Loss: 5.7145
# Epoch [162/3000], Step [1], Loss: 5.7041
# Epoch [163/3000], Step [1], Loss: 5.7180
# Epoch [164/3000], Step [1], Loss: 5.6982
# Epoch [165/3000], Step [1], Loss: 5.6808
# Epoch [166/3000], Step [1], Loss: 5.6690
# Epoch [167/3000], Step [1], Loss: 5.6697
# Epoch [168/3000], Step [1], Loss: 5.6542
# Epoch [169/3000], Step [1], Loss: 5.6557
# Epoch [170/3000], Step [1], Loss: 5.6379
# Epoch [171/3000], Step [1], Loss: 5.6273
# Epoch [172/3000], Step [1], Loss: 5.6212
# Epoch [173/3000], Step [1], Loss: 5.6138
# Epoch [174/3000], Step [1], Loss: 5.6147
# Epoch [175/3000], Step [1], Loss: 5.5985
# Epoch [176/3000], Step [1], Loss: 5.5872
# Epoch [177/3000], Step [1], Loss: 5.5765
# Epoch [178/3000], Step [1], Loss: 5.5722
# Epoch [179/3000], Step [1], Loss: 5.5579
# Epoch [180/3000], Step [1], Loss: 5.5806
# Epoch [181/3000], Step [1], Loss: 5.5539
# Epoch [182/3000], Step [1], Loss: 5.5459
# Epoch [183/3000], Step [1], Loss: 5.5339
# Epoch [184/3000], Step [1], Loss: 5.5234
# Epoch [185/3000], Step [1], Loss: 5.5072
# Epoch [186/3000], Step [1], Loss: 5.5176
# Epoch [187/3000], Step [1], Loss: 5.5151
# Epoch [188/3000], Step [1], Loss: 5.4965
# Epoch [189/3000], Step [1], Loss: 5.4846
# Epoch [190/3000], Step [1], Loss: 5.4738
# Epoch [191/3000], Step [1], Loss: 5.4724
# Epoch [192/3000], Step [1], Loss: 5.4652
# Epoch [193/3000], Step [1], Loss: 5.4554
# Epoch [194/3000], Step [1], Loss: 5.4402
# Epoch [195/3000], Step [1], Loss: 5.4327
# Epoch [196/3000], Step [1], Loss: 5.4228
# Epoch [197/3000], Step [1], Loss: 5.4187
# Epoch [198/3000], Step [1], Loss: 5.4088
# Epoch [199/3000], Step [1], Loss: 5.4156
# Epoch [200/3000], Step [1], Loss: 5.4060
# Epoch [201/3000], Step [1], Loss: 5.3808
# Epoch [202/3000], Step [1], Loss: 5.3717
# Epoch [203/3000], Step [1], Loss: 5.3722
# Epoch [204/3000], Step [1], Loss: 5.3613
# Epoch [205/3000], Step [1], Loss: 5.3660
# Epoch [206/3000], Step [1], Loss: 5.3536
# Epoch [207/3000], Step [1], Loss: 5.3406
# Epoch [208/3000], Step [1], Loss: 5.3302
# Epoch [209/3000], Step [1], Loss: 5.3285
# Epoch [210/3000], Step [1], Loss: 5.3196
# Epoch [211/3000], Step [1], Loss: 5.3081
# Epoch [212/3000], Step [1], Loss: 5.3052
# Epoch [213/3000], Step [1], Loss: 5.3052
# Epoch [214/3000], Step [1], Loss: 5.2909
# Epoch [215/3000], Step [1], Loss: 5.2738
# Epoch [216/3000], Step [1], Loss: 5.2652
# Epoch [217/3000], Step [1], Loss: 5.2567
# Epoch [218/3000], Step [1], Loss: 5.2562
# Epoch [219/3000], Step [1], Loss: 5.2501
# Epoch [220/3000], Step [1], Loss: 5.2472
# Epoch [221/3000], Step [1], Loss: 5.2380
# Epoch [222/3000], Step [1], Loss: 5.2256
# Epoch [223/3000], Step [1], Loss: 5.2169
# Epoch [224/3000], Step [1], Loss: 5.2236
# Epoch [225/3000], Step [1], Loss: 5.2111
# Epoch [226/3000], Step [1], Loss: 5.1886
# Epoch [227/3000], Step [1], Loss: 5.1878
# Epoch [228/3000], Step [1], Loss: 5.1845
# Epoch [229/3000], Step [1], Loss: 5.1695
# Epoch [230/3000], Step [1], Loss: 5.1636
# Epoch [231/3000], Step [1], Loss: 5.1573
# Epoch [232/3000], Step [1], Loss: 5.1548
# Epoch [233/3000], Step [1], Loss: 5.1556
# Epoch [234/3000], Step [1], Loss: 5.1359
# Epoch [235/3000], Step [1], Loss: 5.1403
# Epoch [236/3000], Step [1], Loss: 5.1363
# Epoch [237/3000], Step [1], Loss: 5.1202
# Epoch [238/3000], Step [1], Loss: 5.1027
# Epoch [239/3000], Step [1], Loss: 5.1070
# Epoch [240/3000], Step [1], Loss: 5.1060
# Epoch [241/3000], Step [1], Loss: 5.0891
# Epoch [242/3000], Step [1], Loss: 5.0767
# Epoch [243/3000], Step [1], Loss: 5.0627
# Epoch [244/3000], Step [1], Loss: 5.0645
# Epoch [245/3000], Step [1], Loss: 5.0500
# Epoch [246/3000], Step [1], Loss: 5.0436
# Epoch [247/3000], Step [1], Loss: 5.0344
# Epoch [248/3000], Step [1], Loss: 5.0331
# Epoch [249/3000], Step [1], Loss: 5.0225
# Epoch [250/3000], Step [1], Loss: 5.0070
# Epoch [251/3000], Step [1], Loss: 5.0129
# Epoch [252/3000], Step [1], Loss: 5.0070
# Epoch [253/3000], Step [1], Loss: 4.9865
# Epoch [254/3000], Step [1], Loss: 4.9805
# Epoch [255/3000], Step [1], Loss: 4.9834
# Epoch [256/3000], Step [1], Loss: 4.9804
# Epoch [257/3000], Step [1], Loss: 4.9685
# Epoch [258/3000], Step [1], Loss: 4.9529
# Epoch [259/3000], Step [1], Loss: 4.9619
# Epoch [260/3000], Step [1], Loss: 4.9393
# Epoch [261/3000], Step [1], Loss: 4.9277
# Epoch [262/3000], Step [1], Loss: 4.9243
# Epoch [263/3000], Step [1], Loss: 4.9165
# Epoch [264/3000], Step [1], Loss: 4.9118
# Epoch [265/3000], Step [1], Loss: 4.9198
# Epoch [266/3000], Step [1], Loss: 4.9018
# Epoch [267/3000], Step [1], Loss: 4.9056
# Epoch [268/3000], Step [1], Loss: 4.8802
# Epoch [269/3000], Step [1], Loss: 4.8677
# Epoch [270/3000], Step [1], Loss: 4.8595
# Epoch [271/3000], Step [1], Loss: 4.8612
# Epoch [272/3000], Step [1], Loss: 4.8500
# Epoch [273/3000], Step [1], Loss: 4.8325
# Epoch [274/3000], Step [1], Loss: 4.8386
# Epoch [275/3000], Step [1], Loss: 4.8307
# Epoch [276/3000], Step [1], Loss: 4.8162
# Epoch [277/3000], Step [1], Loss: 4.8037
# Epoch [278/3000], Step [1], Loss: 4.8106
# Epoch [279/3000], Step [1], Loss: 4.8022
# Epoch [280/3000], Step [1], Loss: 4.7933
# Epoch [281/3000], Step [1], Loss: 4.7741
# Epoch [282/3000], Step [1], Loss: 4.7776
# Epoch [283/3000], Step [1], Loss: 4.7789
# Epoch [284/3000], Step [1], Loss: 4.7751
# Epoch [285/3000], Step [1], Loss: 4.7555
# Epoch [286/3000], Step [1], Loss: 4.7554
# Epoch [287/3000], Step [1], Loss: 4.7549
# Epoch [288/3000], Step [1], Loss: 4.7330
# Epoch [289/3000], Step [1], Loss: 4.7398
# Epoch [290/3000], Step [1], Loss: 4.7229
# Epoch [291/3000], Step [1], Loss: 4.7186
# Epoch [292/3000], Step [1], Loss: 4.7021
# Epoch [293/3000], Step [1], Loss: 4.7084
# Epoch [294/3000], Step [1], Loss: 4.7058
# Epoch [295/3000], Step [1], Loss: 4.6895
# Epoch [296/3000], Step [1], Loss: 4.6740
# Epoch [297/3000], Step [1], Loss: 4.6640
# Epoch [298/3000], Step [1], Loss: 4.6582
# Epoch [299/3000], Step [1], Loss: 4.6525
# Epoch [300/3000], Step [1], Loss: 4.6465
# Epoch [301/3000], Step [1], Loss: 4.6393
# Epoch [302/3000], Step [1], Loss: 4.6317
# Epoch [303/3000], Step [1], Loss: 4.6243
# Epoch [304/3000], Step [1], Loss: 4.6228
# Epoch [305/3000], Step [1], Loss: 4.6240
# Epoch [306/3000], Step [1], Loss: 4.6131
# Epoch [307/3000], Step [1], Loss: 4.6035
# Epoch [308/3000], Step [1], Loss: 4.5955
# Epoch [309/3000], Step [1], Loss: 4.5809
# Epoch [310/3000], Step [1], Loss: 4.5803
# Epoch [311/3000], Step [1], Loss: 4.5809
# Epoch [312/3000], Step [1], Loss: 4.5635
# Epoch [313/3000], Step [1], Loss: 4.5695
# Epoch [314/3000], Step [1], Loss: 4.5535
# Epoch [315/3000], Step [1], Loss: 4.5461
# Epoch [316/3000], Step [1], Loss: 4.5326
# Epoch [317/3000], Step [1], Loss: 4.5278
# Epoch [318/3000], Step [1], Loss: 4.5210
# Epoch [319/3000], Step [1], Loss: 4.5140
# Epoch [320/3000], Step [1], Loss: 4.5129
# Epoch [321/3000], Step [1], Loss: 4.5054
# Epoch [322/3000], Step [1], Loss: 4.5097
# Epoch [323/3000], Step [1], Loss: 4.4969
# Epoch [324/3000], Step [1], Loss: 4.4875
# Epoch [325/3000], Step [1], Loss: 4.4689
# Epoch [326/3000], Step [1], Loss: 4.4676
# Epoch [327/3000], Step [1], Loss: 4.4691
# Epoch [328/3000], Step [1], Loss: 4.4652
# Epoch [329/3000], Step [1], Loss: 4.4548
# Epoch [330/3000], Step [1], Loss: 4.4445
# Epoch [331/3000], Step [1], Loss: 4.4347
# Epoch [332/3000], Step [1], Loss: 4.4307
# Epoch [333/3000], Step [1], Loss: 4.4237
# Epoch [334/3000], Step [1], Loss: 4.4231
# Epoch [335/3000], Step [1], Loss: 4.4065
# Epoch [336/3000], Step [1], Loss: 4.4022
# Epoch [337/3000], Step [1], Loss: 4.4006
# Epoch [338/3000], Step [1], Loss: 4.3991
# Epoch [339/3000], Step [1], Loss: 4.3829
# Epoch [340/3000], Step [1], Loss: 4.3821
# Epoch [341/3000], Step [1], Loss: 4.3756
# Epoch [342/3000], Step [1], Loss: 4.3608
# Epoch [343/3000], Step [1], Loss: 4.3563
# Epoch [344/3000], Step [1], Loss: 4.3565
# Epoch [345/3000], Step [1], Loss: 4.3559
# Epoch [346/3000], Step [1], Loss: 4.3338
# Epoch [347/3000], Step [1], Loss: 4.3170
# Epoch [348/3000], Step [1], Loss: 4.3239
# Epoch [349/3000], Step [1], Loss: 4.3147
# Epoch [350/3000], Step [1], Loss: 4.3079
# Epoch [351/3000], Step [1], Loss: 4.3103
# Epoch [352/3000], Step [1], Loss: 4.2995
# Epoch [353/3000], Step [1], Loss: 4.2936
# Epoch [354/3000], Step [1], Loss: 4.2794
# Epoch [355/3000], Step [1], Loss: 4.2901
# Epoch [356/3000], Step [1], Loss: 4.2689
# Epoch [357/3000], Step [1], Loss: 4.2620
# Epoch [358/3000], Step [1], Loss: 4.2584
# Epoch [359/3000], Step [1], Loss: 4.2659
# Epoch [360/3000], Step [1], Loss: 4.2518
# Epoch [361/3000], Step [1], Loss: 4.2500
# Epoch [362/3000], Step [1], Loss: 4.2317
# Epoch [363/3000], Step [1], Loss: 4.2199
# Epoch [364/3000], Step [1], Loss: 4.2091
# Epoch [365/3000], Step [1], Loss: 4.2033
# Epoch [366/3000], Step [1], Loss: 4.2001
# Epoch [367/3000], Step [1], Loss: 4.2077
# Epoch [368/3000], Step [1], Loss: 4.2054
# Epoch [369/3000], Step [1], Loss: 4.1921
# Epoch [370/3000], Step [1], Loss: 4.1739
# Epoch [371/3000], Step [1], Loss: 4.1705
# Epoch [372/3000], Step [1], Loss: 4.1724
# Epoch [373/3000], Step [1], Loss: 4.1601
# Epoch [374/3000], Step [1], Loss: 4.1573
# Epoch [375/3000], Step [1], Loss: 4.1813
# Epoch [376/3000], Step [1], Loss: 4.1602
# Epoch [377/3000], Step [1], Loss: 4.1462
# Epoch [378/3000], Step [1], Loss: 4.1292
# Epoch [379/3000], Step [1], Loss: 4.1242
# Epoch [380/3000], Step [1], Loss: 4.1267
# Epoch [381/3000], Step [1], Loss: 4.1103
# Epoch [382/3000], Step [1], Loss: 4.0950
# Epoch [383/3000], Step [1], Loss: 4.0983
# Epoch [384/3000], Step [1], Loss: 4.1095
# Epoch [385/3000], Step [1], Loss: 4.0953
# Epoch [386/3000], Step [1], Loss: 4.0843
# Epoch [387/3000], Step [1], Loss: 4.0722
# Epoch [388/3000], Step [1], Loss: 4.0648
# Epoch [389/3000], Step [1], Loss: 4.0576
# Epoch [390/3000], Step [1], Loss: 4.0567
# Epoch [391/3000], Step [1], Loss: 4.0547
# Epoch [392/3000], Step [1], Loss: 4.0417
# Epoch [393/3000], Step [1], Loss: 4.0440
# Epoch [394/3000], Step [1], Loss: 4.0251
# Epoch [395/3000], Step [1], Loss: 4.0185
# Epoch [396/3000], Step [1], Loss: 4.0156
# Epoch [397/3000], Step [1], Loss: 4.0032
# Epoch [398/3000], Step [1], Loss: 4.0050
# Epoch [399/3000], Step [1], Loss: 3.9983
# Epoch [400/3000], Step [1], Loss: 3.9988
# Epoch [401/3000], Step [1], Loss: 3.9936
# Epoch [402/3000], Step [1], Loss: 3.9782
# Epoch [403/3000], Step [1], Loss: 3.9664
# Epoch [404/3000], Step [1], Loss: 3.9746
# Epoch [405/3000], Step [1], Loss: 3.9635
# Epoch [406/3000], Step [1], Loss: 3.9461
# Epoch [407/3000], Step [1], Loss: 3.9435
# Epoch [408/3000], Step [1], Loss: 3.9356
# Epoch [409/3000], Step [1], Loss: 3.9312
# Epoch [410/3000], Step [1], Loss: 3.9605
# Epoch [411/3000], Step [1], Loss: 3.9432
# Epoch [412/3000], Step [1], Loss: 3.9296
# Epoch [413/3000], Step [1], Loss: 3.9187
# Epoch [414/3000], Step [1], Loss: 3.8995
# Epoch [415/3000], Step [1], Loss: 3.8927
# Epoch [416/3000], Step [1], Loss: 3.8849
# Epoch [417/3000], Step [1], Loss: 3.8763
# Epoch [418/3000], Step [1], Loss: 3.8713
# Epoch [419/3000], Step [1], Loss: 3.8655
# Epoch [420/3000], Step [1], Loss: 3.8688
# Epoch [421/3000], Step [1], Loss: 3.8584
# Epoch [422/3000], Step [1], Loss: 3.8554
# Epoch [423/3000], Step [1], Loss: 3.8418
# Epoch [424/3000], Step [1], Loss: 3.8472
# Epoch [425/3000], Step [1], Loss: 3.8384
# Epoch [426/3000], Step [1], Loss: 3.8185
# Epoch [427/3000], Step [1], Loss: 3.8153
# Epoch [428/3000], Step [1], Loss: 3.8175
# Epoch [429/3000], Step [1], Loss: 3.8211
# Epoch [430/3000], Step [1], Loss: 3.8025
# Epoch [431/3000], Step [1], Loss: 3.7933
# Epoch [432/3000], Step [1], Loss: 3.7924
# Epoch [433/3000], Step [1], Loss: 3.7783
# Epoch [434/3000], Step [1], Loss: 3.7783
# Epoch [435/3000], Step [1], Loss: 3.7740
# Epoch [436/3000], Step [1], Loss: 3.7633
# Epoch [437/3000], Step [1], Loss: 3.7457
# Epoch [438/3000], Step [1], Loss: 3.7423
# Epoch [439/3000], Step [1], Loss: 3.7465
# Epoch [440/3000], Step [1], Loss: 3.7441
# Epoch [441/3000], Step [1], Loss: 3.7230
# Epoch [442/3000], Step [1], Loss: 3.7145
# Epoch [443/3000], Step [1], Loss: 3.7263
# Epoch [444/3000], Step [1], Loss: 3.7132
# Epoch [445/3000], Step [1], Loss: 3.7006
# Epoch [446/3000], Step [1], Loss: 3.6950
# Epoch [447/3000], Step [1], Loss: 3.6875
# Epoch [448/3000], Step [1], Loss: 3.6905
# Epoch [449/3000], Step [1], Loss: 3.6827
# Epoch [450/3000], Step [1], Loss: 3.6804
# Epoch [451/3000], Step [1], Loss: 3.6713
# Epoch [452/3000], Step [1], Loss: 3.6698
# Epoch [453/3000], Step [1], Loss: 3.6663
# Epoch [454/3000], Step [1], Loss: 3.6473
# Epoch [455/3000], Step [1], Loss: 3.6549
# Epoch [456/3000], Step [1], Loss: 3.6598
# Epoch [457/3000], Step [1], Loss: 3.6436
# Epoch [458/3000], Step [1], Loss: 3.6383
# Epoch [459/3000], Step [1], Loss: 3.6258
# Epoch [460/3000], Step [1], Loss: 3.6396
# Epoch [461/3000], Step [1], Loss: 3.6243
# Epoch [462/3000], Step [1], Loss: 3.6106
# Epoch [463/3000], Step [1], Loss: 3.6072
# Epoch [464/3000], Step [1], Loss: 3.5969
# Epoch [465/3000], Step [1], Loss: 3.5962
# Epoch [466/3000], Step [1], Loss: 3.5812
# Epoch [467/3000], Step [1], Loss: 3.5736
# Epoch [468/3000], Step [1], Loss: 3.5668
# Epoch [469/3000], Step [1], Loss: 3.5599
# Epoch [470/3000], Step [1], Loss: 3.5713
# Epoch [471/3000], Step [1], Loss: 3.5525
# Epoch [472/3000], Step [1], Loss: 3.5411
# Epoch [473/3000], Step [1], Loss: 3.5402
# Epoch [474/3000], Step [1], Loss: 3.5379
# Epoch [475/3000], Step [1], Loss: 3.5390
# Epoch [476/3000], Step [1], Loss: 3.5219
# Epoch [477/3000], Step [1], Loss: 3.5220
# Epoch [478/3000], Step [1], Loss: 3.5374
# Epoch [479/3000], Step [1], Loss: 3.5143
# Epoch [480/3000], Step [1], Loss: 3.4987
# Epoch [481/3000], Step [1], Loss: 3.4973
# Epoch [482/3000], Step [1], Loss: 3.4988
# Epoch [483/3000], Step [1], Loss: 3.4879
# Epoch [484/3000], Step [1], Loss: 3.4797
# Epoch [485/3000], Step [1], Loss: 3.4681
# Epoch [486/3000], Step [1], Loss: 3.4657
# Epoch [487/3000], Step [1], Loss: 3.4928
# Epoch [488/3000], Step [1], Loss: 3.4628
# Epoch [489/3000], Step [1], Loss: 3.4551
# Epoch [490/3000], Step [1], Loss: 3.4548
# Epoch [491/3000], Step [1], Loss: 3.4433
# Epoch [492/3000], Step [1], Loss: 3.4442
# Epoch [493/3000], Step [1], Loss: 3.4293
# Epoch [494/3000], Step [1], Loss: 3.4208
# Epoch [495/3000], Step [1], Loss: 3.4143
# Epoch [496/3000], Step [1], Loss: 3.4245
# Epoch [497/3000], Step [1], Loss: 3.4063
# Epoch [498/3000], Step [1], Loss: 3.4066
# Epoch [499/3000], Step [1], Loss: 3.4154
# Epoch [500/3000], Step [1], Loss: 3.3995
# Epoch [501/3000], Step [1], Loss: 3.3906
# Epoch [502/3000], Step [1], Loss: 3.3742
# Epoch [503/3000], Step [1], Loss: 3.3736
# Epoch [504/3000], Step [1], Loss: 3.3649
# Epoch [505/3000], Step [1], Loss: 3.3656
# Epoch [506/3000], Step [1], Loss: 3.3575
# Epoch [507/3000], Step [1], Loss: 3.3619
# Epoch [508/3000], Step [1], Loss: 3.3480
# Epoch [509/3000], Step [1], Loss: 3.3443
# Epoch [510/3000], Step [1], Loss: 3.3423
# Epoch [511/3000], Step [1], Loss: 3.3404
# Epoch [512/3000], Step [1], Loss: 3.3302
# Epoch [513/3000], Step [1], Loss: 3.3230
# Epoch [514/3000], Step [1], Loss: 3.3109
# Epoch [515/3000], Step [1], Loss: 3.3062
# Epoch [516/3000], Step [1], Loss: 3.2976
# Epoch [517/3000], Step [1], Loss: 3.2934
# Epoch [518/3000], Step [1], Loss: 3.2906
# Epoch [519/3000], Step [1], Loss: 3.2802
# Epoch [520/3000], Step [1], Loss: 3.2767
# Epoch [521/3000], Step [1], Loss: 3.2589
# Epoch [522/3000], Step [1], Loss: 3.2619
# Epoch [523/3000], Step [1], Loss: 3.2671
# Epoch [524/3000], Step [1], Loss: 3.2599
# Epoch [525/3000], Step [1], Loss: 3.2529
# Epoch [526/3000], Step [1], Loss: 3.2471
# Epoch [527/3000], Step [1], Loss: 3.2420
# Epoch [528/3000], Step [1], Loss: 3.2466
# Epoch [529/3000], Step [1], Loss: 3.2362
# Epoch [530/3000], Step [1], Loss: 3.2438
# Epoch [531/3000], Step [1], Loss: 3.2326
# Epoch [532/3000], Step [1], Loss: 3.2169
# Epoch [533/3000], Step [1], Loss: 3.2141
# Epoch [534/3000], Step [1], Loss: 3.2099
# Epoch [535/3000], Step [1], Loss: 3.1983
# Epoch [536/3000], Step [1], Loss: 3.1918
# Epoch [537/3000], Step [1], Loss: 3.1851
# Epoch [538/3000], Step [1], Loss: 3.1790
# Epoch [539/3000], Step [1], Loss: 3.1787
# Epoch [540/3000], Step [1], Loss: 3.1721
# Epoch [541/3000], Step [1], Loss: 3.1608
# Epoch [542/3000], Step [1], Loss: 3.1462
# Epoch [543/3000], Step [1], Loss: 3.1430
# Epoch [544/3000], Step [1], Loss: 3.1408
# Epoch [545/3000], Step [1], Loss: 3.1605
# Epoch [546/3000], Step [1], Loss: 3.1424
# Epoch [547/3000], Step [1], Loss: 3.1338
# Epoch [548/3000], Step [1], Loss: 3.1220
# Epoch [549/3000], Step [1], Loss: 3.1189
# Epoch [550/3000], Step [1], Loss: 3.1124
# Epoch [551/3000], Step [1], Loss: 3.1069
# Epoch [552/3000], Step [1], Loss: 3.1035
# Epoch [553/3000], Step [1], Loss: 3.0989
# Epoch [554/3000], Step [1], Loss: 3.0875
# Epoch [555/3000], Step [1], Loss: 3.0751
# Epoch [556/3000], Step [1], Loss: 3.0762
# Epoch [557/3000], Step [1], Loss: 3.0758
# Epoch [558/3000], Step [1], Loss: 3.0667
# Epoch [559/3000], Step [1], Loss: 3.0626
# Epoch [560/3000], Step [1], Loss: 3.0546
# Epoch [561/3000], Step [1], Loss: 3.0466
# Epoch [562/3000], Step [1], Loss: 3.0472
# Epoch [563/3000], Step [1], Loss: 3.0389
# Epoch [564/3000], Step [1], Loss: 3.0368
# Epoch [565/3000], Step [1], Loss: 3.0246
# Epoch [566/3000], Step [1], Loss: 3.0233
# Epoch [567/3000], Step [1], Loss: 3.0253
# Epoch [568/3000], Step [1], Loss: 3.0291
# Epoch [569/3000], Step [1], Loss: 3.0216
# Epoch [570/3000], Step [1], Loss: 3.0139
# Epoch [571/3000], Step [1], Loss: 3.0102
# Epoch [572/3000], Step [1], Loss: 3.0093
# Epoch [573/3000], Step [1], Loss: 3.0001
# Epoch [574/3000], Step [1], Loss: 2.9882
# Epoch [575/3000], Step [1], Loss: 2.9783
# Epoch [576/3000], Step [1], Loss: 2.9711
# Epoch [577/3000], Step [1], Loss: 2.9697
# Epoch [578/3000], Step [1], Loss: 2.9732
# Epoch [579/3000], Step [1], Loss: 2.9618
# Epoch [580/3000], Step [1], Loss: 2.9557
# Epoch [581/3000], Step [1], Loss: 2.9486
# Epoch [582/3000], Step [1], Loss: 2.9467
# Epoch [583/3000], Step [1], Loss: 2.9355
# Epoch [584/3000], Step [1], Loss: 2.9336
# Epoch [585/3000], Step [1], Loss: 2.9247
# Epoch [586/3000], Step [1], Loss: 2.9396
# Epoch [587/3000], Step [1], Loss: 2.9236
# Epoch [588/3000], Step [1], Loss: 2.9194
# Epoch [589/3000], Step [1], Loss: 2.9173
# Epoch [590/3000], Step [1], Loss: 2.9080
# Epoch [591/3000], Step [1], Loss: 2.9219
# Epoch [592/3000], Step [1], Loss: 2.9055
# Epoch [593/3000], Step [1], Loss: 2.8865
# Epoch [594/3000], Step [1], Loss: 2.8802
# Epoch [595/3000], Step [1], Loss: 2.8763
# Epoch [596/3000], Step [1], Loss: 2.8795
# Epoch [597/3000], Step [1], Loss: 2.8737
# Epoch [598/3000], Step [1], Loss: 2.8658
# Epoch [599/3000], Step [1], Loss: 2.8650
# Epoch [600/3000], Step [1], Loss: 2.8582
# Epoch [601/3000], Step [1], Loss: 2.8574
# Epoch [602/3000], Step [1], Loss: 2.8533
# Epoch [603/3000], Step [1], Loss: 2.8561
# Epoch [604/3000], Step [1], Loss: 2.8494
# Epoch [605/3000], Step [1], Loss: 2.8363
# Epoch [606/3000], Step [1], Loss: 2.8261
# Epoch [607/3000], Step [1], Loss: 2.8192
# Epoch [608/3000], Step [1], Loss: 2.8140
# Epoch [609/3000], Step [1], Loss: 2.8085
# Epoch [610/3000], Step [1], Loss: 2.8010
# Epoch [611/3000], Step [1], Loss: 2.7951
# Epoch [612/3000], Step [1], Loss: 2.7979
# Epoch [613/3000], Step [1], Loss: 2.7905
# Epoch [614/3000], Step [1], Loss: 2.7855
# Epoch [615/3000], Step [1], Loss: 2.7813
# Epoch [616/3000], Step [1], Loss: 2.7766
# Epoch [617/3000], Step [1], Loss: 2.7630
# Epoch [618/3000], Step [1], Loss: 2.7579
# Epoch [619/3000], Step [1], Loss: 2.7544
# Epoch [620/3000], Step [1], Loss: 2.7622
# Epoch [621/3000], Step [1], Loss: 2.7651
# Epoch [622/3000], Step [1], Loss: 2.7508
# Epoch [623/3000], Step [1], Loss: 2.7420
# Epoch [624/3000], Step [1], Loss: 2.7343
# Epoch [625/3000], Step [1], Loss: 2.7278
# Epoch [626/3000], Step [1], Loss: 2.7223
# Epoch [627/3000], Step [1], Loss: 2.7285
# Epoch [628/3000], Step [1], Loss: 2.7135
# Epoch [629/3000], Step [1], Loss: 2.7164
# Epoch [630/3000], Step [1], Loss: 2.7109
# Epoch [631/3000], Step [1], Loss: 2.7043
# Epoch [632/3000], Step [1], Loss: 2.6963
# Epoch [633/3000], Step [1], Loss: 2.6917
# Epoch [634/3000], Step [1], Loss: 2.6900
# Epoch [635/3000], Step [1], Loss: 2.6891
# Epoch [636/3000], Step [1], Loss: 2.6789
# Epoch [637/3000], Step [1], Loss: 2.6747
# Epoch [638/3000], Step [1], Loss: 2.6686
# Epoch [639/3000], Step [1], Loss: 2.6719
# Epoch [640/3000], Step [1], Loss: 2.6728
# Epoch [641/3000], Step [1], Loss: 2.6709
# Epoch [642/3000], Step [1], Loss: 2.6580
# Epoch [643/3000], Step [1], Loss: 2.6542
# Epoch [644/3000], Step [1], Loss: 2.6404
# Epoch [645/3000], Step [1], Loss: 2.6286
# Epoch [646/3000], Step [1], Loss: 2.6297
# Epoch [647/3000], Step [1], Loss: 2.6344
# Epoch [648/3000], Step [1], Loss: 2.6357
# Epoch [649/3000], Step [1], Loss: 2.6286
# Epoch [650/3000], Step [1], Loss: 2.6206
# Epoch [651/3000], Step [1], Loss: 2.6089
# Epoch [652/3000], Step [1], Loss: 2.6067
# Epoch [653/3000], Step [1], Loss: 2.6092
# Epoch [654/3000], Step [1], Loss: 2.5951
# Epoch [655/3000], Step [1], Loss: 2.5859
# Epoch [656/3000], Step [1], Loss: 2.5736
# Epoch [657/3000], Step [1], Loss: 2.5685
# Epoch [658/3000], Step [1], Loss: 2.5687
# Epoch [659/3000], Step [1], Loss: 2.5582
# Epoch [660/3000], Step [1], Loss: 2.5502
# Epoch [661/3000], Step [1], Loss: 2.5518
# Epoch [662/3000], Step [1], Loss: 2.5581
# Epoch [663/3000], Step [1], Loss: 2.5482
# Epoch [664/3000], Step [1], Loss: 2.5486
# Epoch [665/3000], Step [1], Loss: 2.5410
# Epoch [666/3000], Step [1], Loss: 2.5312
# Epoch [667/3000], Step [1], Loss: 2.5342
# Epoch [668/3000], Step [1], Loss: 2.5330
# Epoch [669/3000], Step [1], Loss: 2.5252
# Epoch [670/3000], Step [1], Loss: 2.5289
# Epoch [671/3000], Step [1], Loss: 2.5151
# Epoch [672/3000], Step [1], Loss: 2.5030
# Epoch [673/3000], Step [1], Loss: 2.5102
# Epoch [674/3000], Step [1], Loss: 2.4990
# Epoch [675/3000], Step [1], Loss: 2.4871
# Epoch [676/3000], Step [1], Loss: 2.4887
# Epoch [677/3000], Step [1], Loss: 2.4833
# Epoch [678/3000], Step [1], Loss: 2.4775
# Epoch [679/3000], Step [1], Loss: 2.4792
# Epoch [680/3000], Step [1], Loss: 2.4710
# Epoch [681/3000], Step [1], Loss: 2.4605
# Epoch [682/3000], Step [1], Loss: 2.4548
# Epoch [683/3000], Step [1], Loss: 2.4550
# Epoch [684/3000], Step [1], Loss: 2.4560
# Epoch [685/3000], Step [1], Loss: 2.4490
# Epoch [686/3000], Step [1], Loss: 2.4411
# Epoch [687/3000], Step [1], Loss: 2.4327
# Epoch [688/3000], Step [1], Loss: 2.4440
# Epoch [689/3000], Step [1], Loss: 2.4360
# Epoch [690/3000], Step [1], Loss: 2.4442
# Epoch [691/3000], Step [1], Loss: 2.4241
# Epoch [692/3000], Step [1], Loss: 2.4251
# Epoch [693/3000], Step [1], Loss: 2.4212
# Epoch [694/3000], Step [1], Loss: 2.4170
# Epoch [695/3000], Step [1], Loss: 2.4088
# Epoch [696/3000], Step [1], Loss: 2.3978
# Epoch [697/3000], Step [1], Loss: 2.3966
# Epoch [698/3000], Step [1], Loss: 2.3871
# Epoch [699/3000], Step [1], Loss: 2.3814
# Epoch [700/3000], Step [1], Loss: 2.3740
# Epoch [701/3000], Step [1], Loss: 2.3685
# Epoch [702/3000], Step [1], Loss: 2.3659
# Epoch [703/3000], Step [1], Loss: 2.3679
# Epoch [704/3000], Step [1], Loss: 2.3592
# Epoch [705/3000], Step [1], Loss: 2.3553
# Epoch [706/3000], Step [1], Loss: 2.3488
# Epoch [707/3000], Step [1], Loss: 2.3376
# Epoch [708/3000], Step [1], Loss: 2.3511
# Epoch [709/3000], Step [1], Loss: 2.3518
# Epoch [710/3000], Step [1], Loss: 2.3447
# Epoch [711/3000], Step [1], Loss: 2.3322
# Epoch [712/3000], Step [1], Loss: 2.3251
# Epoch [713/3000], Step [1], Loss: 2.3186
# Epoch [714/3000], Step [1], Loss: 2.3252
# Epoch [715/3000], Step [1], Loss: 2.3278
# Epoch [716/3000], Step [1], Loss: 2.3249
# Epoch [717/3000], Step [1], Loss: 2.3056
# Epoch [718/3000], Step [1], Loss: 2.2937
# Epoch [719/3000], Step [1], Loss: 2.2880
# Epoch [720/3000], Step [1], Loss: 2.2891
# Epoch [721/3000], Step [1], Loss: 2.2984
# Epoch [722/3000], Step [1], Loss: 2.2855
# Epoch [723/3000], Step [1], Loss: 2.2805
# Epoch [724/3000], Step [1], Loss: 2.2722
# Epoch [725/3000], Step [1], Loss: 2.2679
# Epoch [726/3000], Step [1], Loss: 2.2638
# Epoch [727/3000], Step [1], Loss: 2.2642
# Epoch [728/3000], Step [1], Loss: 2.2574
# Epoch [729/3000], Step [1], Loss: 2.2515
# Epoch [730/3000], Step [1], Loss: 2.2527
# Epoch [731/3000], Step [1], Loss: 2.2382
# Epoch [732/3000], Step [1], Loss: 2.2353
# Epoch [733/3000], Step [1], Loss: 2.2221
# Epoch [734/3000], Step [1], Loss: 2.2214
# Epoch [735/3000], Step [1], Loss: 2.2195
# Epoch [736/3000], Step [1], Loss: 2.2219
# Epoch [737/3000], Step [1], Loss: 2.2083
# Epoch [738/3000], Step [1], Loss: 2.2051
# Epoch [739/3000], Step [1], Loss: 2.2017
# Epoch [740/3000], Step [1], Loss: 2.1926
# Epoch [741/3000], Step [1], Loss: 2.1940
# Epoch [742/3000], Step [1], Loss: 2.1884
# Epoch [743/3000], Step [1], Loss: 2.2074
# Epoch [744/3000], Step [1], Loss: 2.1853
# Epoch [745/3000], Step [1], Loss: 2.1797
# Epoch [746/3000], Step [1], Loss: 2.1730
# Epoch [747/3000], Step [1], Loss: 2.1740
# Epoch [748/3000], Step [1], Loss: 2.1724
# Epoch [749/3000], Step [1], Loss: 2.1556
# Epoch [750/3000], Step [1], Loss: 2.1516
# Epoch [751/3000], Step [1], Loss: 2.1428
# Epoch [752/3000], Step [1], Loss: 2.1464
# Epoch [753/3000], Step [1], Loss: 2.1409
# Epoch [754/3000], Step [1], Loss: 2.1330
# Epoch [755/3000], Step [1], Loss: 2.1283
# Epoch [756/3000], Step [1], Loss: 2.1258
# Epoch [757/3000], Step [1], Loss: 2.1205
# Epoch [758/3000], Step [1], Loss: 2.1161
# Epoch [759/3000], Step [1], Loss: 2.1206
# Epoch [760/3000], Step [1], Loss: 2.1140
# Epoch [761/3000], Step [1], Loss: 2.1084
# Epoch [762/3000], Step [1], Loss: 2.1028
# Epoch [763/3000], Step [1], Loss: 2.0981
# Epoch [764/3000], Step [1], Loss: 2.0985
# Epoch [765/3000], Step [1], Loss: 2.0967
# Epoch [766/3000], Step [1], Loss: 2.1040
# Epoch [767/3000], Step [1], Loss: 2.0848
# Epoch [768/3000], Step [1], Loss: 2.0767
# Epoch [769/3000], Step [1], Loss: 2.0758
# Epoch [770/3000], Step [1], Loss: 2.0770
# Epoch [771/3000], Step [1], Loss: 2.0682
# Epoch [772/3000], Step [1], Loss: 2.0638
# Epoch [773/3000], Step [1], Loss: 2.0694
# Epoch [774/3000], Step [1], Loss: 2.0643
# Epoch [775/3000], Step [1], Loss: 2.0560
# Epoch [776/3000], Step [1], Loss: 2.0527
# Epoch [777/3000], Step [1], Loss: 2.0523
# Epoch [778/3000], Step [1], Loss: 2.0481
# Epoch [779/3000], Step [1], Loss: 2.0347
# Epoch [780/3000], Step [1], Loss: 2.0292
# Epoch [781/3000], Step [1], Loss: 2.0256
# Epoch [782/3000], Step [1], Loss: 2.0176
# Epoch [783/3000], Step [1], Loss: 2.0125
# Epoch [784/3000], Step [1], Loss: 2.0113
# Epoch [785/3000], Step [1], Loss: 2.0179
# Epoch [786/3000], Step [1], Loss: 2.0083
# Epoch [787/3000], Step [1], Loss: 2.0021
# Epoch [788/3000], Step [1], Loss: 1.9959
# Epoch [789/3000], Step [1], Loss: 1.9897
# Epoch [790/3000], Step [1], Loss: 1.9966
# Epoch [791/3000], Step [1], Loss: 1.9897
# Epoch [792/3000], Step [1], Loss: 1.9874
# Epoch [793/3000], Step [1], Loss: 1.9915
# Epoch [794/3000], Step [1], Loss: 1.9927
# Epoch [795/3000], Step [1], Loss: 1.9842
# Epoch [796/3000], Step [1], Loss: 1.9805
# Epoch [797/3000], Step [1], Loss: 1.9835
# Epoch [798/3000], Step [1], Loss: 1.9707
# Epoch [799/3000], Step [1], Loss: 1.9646
# Epoch [800/3000], Step [1], Loss: 1.9593
# Epoch [801/3000], Step [1], Loss: 1.9511
# Epoch [802/3000], Step [1], Loss: 1.9470
# Epoch [803/3000], Step [1], Loss: 1.9386
# Epoch [804/3000], Step [1], Loss: 1.9333
# Epoch [805/3000], Step [1], Loss: 1.9281
# Epoch [806/3000], Step [1], Loss: 1.9291
# Epoch [807/3000], Step [1], Loss: 1.9312
# Epoch [808/3000], Step [1], Loss: 1.9239
# Epoch [809/3000], Step [1], Loss: 1.9263
# Epoch [810/3000], Step [1], Loss: 1.9246
# Epoch [811/3000], Step [1], Loss: 1.9140
# Epoch [812/3000], Step [1], Loss: 1.9057
# Epoch [813/3000], Step [1], Loss: 1.8934
# Epoch [814/3000], Step [1], Loss: 1.8902
# Epoch [815/3000], Step [1], Loss: 1.8948
# Epoch [816/3000], Step [1], Loss: 1.8842
# Epoch [817/3000], Step [1], Loss: 1.8781
# Epoch [818/3000], Step [1], Loss: 1.8763
# Epoch [819/3000], Step [1], Loss: 1.8762
# Epoch [820/3000], Step [1], Loss: 1.8774
# Epoch [821/3000], Step [1], Loss: 1.8697
# Epoch [822/3000], Step [1], Loss: 1.8611
# Epoch [823/3000], Step [1], Loss: 1.8633
# Epoch [824/3000], Step [1], Loss: 1.8565
# Epoch [825/3000], Step [1], Loss: 1.8563
# Epoch [826/3000], Step [1], Loss: 1.8482
# Epoch [827/3000], Step [1], Loss: 1.8430
# Epoch [828/3000], Step [1], Loss: 1.8414
# Epoch [829/3000], Step [1], Loss: 1.8369
# Epoch [830/3000], Step [1], Loss: 1.8395
# Epoch [831/3000], Step [1], Loss: 1.8358
# Epoch [832/3000], Step [1], Loss: 1.8329
# Epoch [833/3000], Step [1], Loss: 1.8295
# Epoch [834/3000], Step [1], Loss: 1.8194
# Epoch [835/3000], Step [1], Loss: 1.8088
# Epoch [836/3000], Step [1], Loss: 1.8107
# Epoch [837/3000], Step [1], Loss: 1.8084
# Epoch [838/3000], Step [1], Loss: 1.8066
# Epoch [839/3000], Step [1], Loss: 1.7976
# Epoch [840/3000], Step [1], Loss: 1.7927
# Epoch [841/3000], Step [1], Loss: 1.7905
# Epoch [842/3000], Step [1], Loss: 1.7884
# Epoch [843/3000], Step [1], Loss: 1.7910
# Epoch [844/3000], Step [1], Loss: 1.7800
# Epoch [845/3000], Step [1], Loss: 1.7820
# Epoch [846/3000], Step [1], Loss: 1.7738
# Epoch [847/3000], Step [1], Loss: 1.7660
# Epoch [848/3000], Step [1], Loss: 1.7747
# Epoch [849/3000], Step [1], Loss: 1.7720
# Epoch [850/3000], Step [1], Loss: 1.7591
# Epoch [851/3000], Step [1], Loss: 1.7528
# Epoch [852/3000], Step [1], Loss: 1.7480
# Epoch [853/3000], Step [1], Loss: 1.7465
# Epoch [854/3000], Step [1], Loss: 1.7439
# Epoch [855/3000], Step [1], Loss: 1.7395
# Epoch [856/3000], Step [1], Loss: 1.7353
# Epoch [857/3000], Step [1], Loss: 1.7382
# Epoch [858/3000], Step [1], Loss: 1.7395
# Epoch [859/3000], Step [1], Loss: 1.7302
# Epoch [860/3000], Step [1], Loss: 1.7209
# Epoch [861/3000], Step [1], Loss: 1.7200
# Epoch [862/3000], Step [1], Loss: 1.7113
# Epoch [863/3000], Step [1], Loss: 1.7116
# Epoch [864/3000], Step [1], Loss: 1.7233
# Epoch [865/3000], Step [1], Loss: 1.7060
# Epoch [866/3000], Step [1], Loss: 1.6969
# Epoch [867/3000], Step [1], Loss: 1.6925
# Epoch [868/3000], Step [1], Loss: 1.6982
# Epoch [869/3000], Step [1], Loss: 1.6873
# Epoch [870/3000], Step [1], Loss: 1.6817
# Epoch [871/3000], Step [1], Loss: 1.6823
# Epoch [872/3000], Step [1], Loss: 1.6779
# Epoch [873/3000], Step [1], Loss: 1.6758
# Epoch [874/3000], Step [1], Loss: 1.6791
# Epoch [875/3000], Step [1], Loss: 1.6689
# Epoch [876/3000], Step [1], Loss: 1.6624
# Epoch [877/3000], Step [1], Loss: 1.6615
# Epoch [878/3000], Step [1], Loss: 1.6508
# Epoch [879/3000], Step [1], Loss: 1.6485
# Epoch [880/3000], Step [1], Loss: 1.6461
# Epoch [881/3000], Step [1], Loss: 1.6536
# Epoch [882/3000], Step [1], Loss: 1.6449
# Epoch [883/3000], Step [1], Loss: 1.6421
# Epoch [884/3000], Step [1], Loss: 1.6404
# Epoch [885/3000], Step [1], Loss: 1.6461
# Epoch [886/3000], Step [1], Loss: 1.6374
# Epoch [887/3000], Step [1], Loss: 1.6344
# Epoch [888/3000], Step [1], Loss: 1.6305
# Epoch [889/3000], Step [1], Loss: 1.6323
# Epoch [890/3000], Step [1], Loss: 1.6253
# Epoch [891/3000], Step [1], Loss: 1.6209
# Epoch [892/3000], Step [1], Loss: 1.6136
# Epoch [893/3000], Step [1], Loss: 1.6070
# Epoch [894/3000], Step [1], Loss: 1.6017
# Epoch [895/3000], Step [1], Loss: 1.5962
# Epoch [896/3000], Step [1], Loss: 1.5939
# Epoch [897/3000], Step [1], Loss: 1.5906
# Epoch [898/3000], Step [1], Loss: 1.5884
# Epoch [899/3000], Step [1], Loss: 1.5854
# Epoch [900/3000], Step [1], Loss: 1.5828
# Epoch [901/3000], Step [1], Loss: 1.5979
# Epoch [902/3000], Step [1], Loss: 1.5778
# Epoch [903/3000], Step [1], Loss: 1.5715
# Epoch [904/3000], Step [1], Loss: 1.5656
# Epoch [905/3000], Step [1], Loss: 1.5613
# Epoch [906/3000], Step [1], Loss: 1.5542
# Epoch [907/3000], Step [1], Loss: 1.5508
# Epoch [908/3000], Step [1], Loss: 1.5537
# Epoch [909/3000], Step [1], Loss: 1.5542
# Epoch [910/3000], Step [1], Loss: 1.5521
# Epoch [911/3000], Step [1], Loss: 1.5416
# Epoch [912/3000], Step [1], Loss: 1.5443
# Epoch [913/3000], Step [1], Loss: 1.5417
# Epoch [914/3000], Step [1], Loss: 1.5525
# Epoch [915/3000], Step [1], Loss: 1.5410
# Epoch [916/3000], Step [1], Loss: 1.5303
# Epoch [917/3000], Step [1], Loss: 1.5285
# Epoch [918/3000], Step [1], Loss: 1.5195
# Epoch [919/3000], Step [1], Loss: 1.5176
# Epoch [920/3000], Step [1], Loss: 1.5148
# Epoch [921/3000], Step [1], Loss: 1.5139
# Epoch [922/3000], Step [1], Loss: 1.5158
# Epoch [923/3000], Step [1], Loss: 1.5076
# Epoch [924/3000], Step [1], Loss: 1.5034
# Epoch [925/3000], Step [1], Loss: 1.4924
# Epoch [926/3000], Step [1], Loss: 1.4905
# Epoch [927/3000], Step [1], Loss: 1.4855
# Epoch [928/3000], Step [1], Loss: 1.4860
# Epoch [929/3000], Step [1], Loss: 1.4813
# Epoch [930/3000], Step [1], Loss: 1.4749
# Epoch [931/3000], Step [1], Loss: 1.4758
# Epoch [932/3000], Step [1], Loss: 1.4728
# Epoch [933/3000], Step [1], Loss: 1.4658
# Epoch [934/3000], Step [1], Loss: 1.4644
# Epoch [935/3000], Step [1], Loss: 1.4624
# Epoch [936/3000], Step [1], Loss: 1.4566
# Epoch [937/3000], Step [1], Loss: 1.4647
# Epoch [938/3000], Step [1], Loss: 1.4544
# Epoch [939/3000], Step [1], Loss: 1.4525
# Epoch [940/3000], Step [1], Loss: 1.4433
# Epoch [941/3000], Step [1], Loss: 1.4419
# Epoch [942/3000], Step [1], Loss: 1.4375
# Epoch [943/3000], Step [1], Loss: 1.4421
# Epoch [944/3000], Step [1], Loss: 1.4323
# Epoch [945/3000], Step [1], Loss: 1.4287
# Epoch [946/3000], Step [1], Loss: 1.4256
# Epoch [947/3000], Step [1], Loss: 1.4284
# Epoch [948/3000], Step [1], Loss: 1.4169
# Epoch [949/3000], Step [1], Loss: 1.4151
# Epoch [950/3000], Step [1], Loss: 1.4159
# Epoch [951/3000], Step [1], Loss: 1.4137
# Epoch [952/3000], Step [1], Loss: 1.4183
# Epoch [953/3000], Step [1], Loss: 1.4134
# Epoch [954/3000], Step [1], Loss: 1.4071
# Epoch [955/3000], Step [1], Loss: 1.4013
# Epoch [956/3000], Step [1], Loss: 1.4029
# Epoch [957/3000], Step [1], Loss: 1.3962
# Epoch [958/3000], Step [1], Loss: 1.3992
# Epoch [959/3000], Step [1], Loss: 1.3896
# Epoch [960/3000], Step [1], Loss: 1.3903
# Epoch [961/3000], Step [1], Loss: 1.3860
# Epoch [962/3000], Step [1], Loss: 1.3809
# Epoch [963/3000], Step [1], Loss: 1.3737
# Epoch [964/3000], Step [1], Loss: 1.3761
# Epoch [965/3000], Step [1], Loss: 1.3688
# Epoch [966/3000], Step [1], Loss: 1.3625
# Epoch [967/3000], Step [1], Loss: 1.3588
# Epoch [968/3000], Step [1], Loss: 1.3554
# Epoch [969/3000], Step [1], Loss: 1.3642
# Epoch [970/3000], Step [1], Loss: 1.3609
# Epoch [971/3000], Step [1], Loss: 1.3543
# Epoch [972/3000], Step [1], Loss: 1.3502
# Epoch [973/3000], Step [1], Loss: 1.3489
# Epoch [974/3000], Step [1], Loss: 1.3400
# Epoch [975/3000], Step [1], Loss: 1.3387
# Epoch [976/3000], Step [1], Loss: 1.3398
# Epoch [977/3000], Step [1], Loss: 1.3355
# Epoch [978/3000], Step [1], Loss: 1.3304
# Epoch [979/3000], Step [1], Loss: 1.3256
# Epoch [980/3000], Step [1], Loss: 1.3244
# Epoch [981/3000], Step [1], Loss: 1.3250
# Epoch [982/3000], Step [1], Loss: 1.3163
# Epoch [983/3000], Step [1], Loss: 1.3174
# Epoch [984/3000], Step [1], Loss: 1.3131
# Epoch [985/3000], Step [1], Loss: 1.3094
# Epoch [986/3000], Step [1], Loss: 1.3097
# Epoch [987/3000], Step [1], Loss: 1.3098
# Epoch [988/3000], Step [1], Loss: 1.3000
# Epoch [989/3000], Step [1], Loss: 1.2960
# Epoch [990/3000], Step [1], Loss: 1.2926
# Epoch [991/3000], Step [1], Loss: 1.2930
# Epoch [992/3000], Step [1], Loss: 1.2889
# Epoch [993/3000], Step [1], Loss: 1.2810
# Epoch [994/3000], Step [1], Loss: 1.2830
# Epoch [995/3000], Step [1], Loss: 1.2946
# Epoch [996/3000], Step [1], Loss: 1.2789
# Epoch [997/3000], Step [1], Loss: 1.2830
# Epoch [998/3000], Step [1], Loss: 1.2799
# Epoch [999/3000], Step [1], Loss: 1.2762
# Epoch [1000/3000], Step [1], Loss: 1.2798
# Epoch [1001/3000], Step [1], Loss: 1.2744
# Epoch [1002/3000], Step [1], Loss: 1.2713
# Epoch [1003/3000], Step [1], Loss: 1.2682
# Epoch [1004/3000], Step [1], Loss: 1.2648
# Epoch [1005/3000], Step [1], Loss: 1.2706
# Epoch [1006/3000], Step [1], Loss: 1.2602
# Epoch [1007/3000], Step [1], Loss: 1.2539
# Epoch [1008/3000], Step [1], Loss: 1.2513
# Epoch [1009/3000], Step [1], Loss: 1.2534
# Epoch [1010/3000], Step [1], Loss: 1.2381
# Epoch [1011/3000], Step [1], Loss: 1.2332
# Epoch [1012/3000], Step [1], Loss: 1.2338
# Epoch [1013/3000], Step [1], Loss: 1.2292
# Epoch [1014/3000], Step [1], Loss: 1.2277
# Epoch [1015/3000], Step [1], Loss: 1.2277
# Epoch [1016/3000], Step [1], Loss: 1.2211
# Epoch [1017/3000], Step [1], Loss: 1.2209
# Epoch [1018/3000], Step [1], Loss: 1.2161
# Epoch [1019/3000], Step [1], Loss: 1.2180
# Epoch [1020/3000], Step [1], Loss: 1.2074
# Epoch [1021/3000], Step [1], Loss: 1.2074
# Epoch [1022/3000], Step [1], Loss: 1.1975
# Epoch [1023/3000], Step [1], Loss: 1.2028
# Epoch [1024/3000], Step [1], Loss: 1.1964
# Epoch [1025/3000], Step [1], Loss: 1.1946
# Epoch [1026/3000], Step [1], Loss: 1.1960
# Epoch [1027/3000], Step [1], Loss: 1.1923
# Epoch [1028/3000], Step [1], Loss: 1.1929
# Epoch [1029/3000], Step [1], Loss: 1.1827
# Epoch [1030/3000], Step [1], Loss: 1.1839
# Epoch [1031/3000], Step [1], Loss: 1.1849
# Epoch [1032/3000], Step [1], Loss: 1.1754
# Epoch [1033/3000], Step [1], Loss: 1.1718
# Epoch [1034/3000], Step [1], Loss: 1.1736
# Epoch [1035/3000], Step [1], Loss: 1.1660
# Epoch [1036/3000], Step [1], Loss: 1.1644
# Epoch [1037/3000], Step [1], Loss: 1.1581
# Epoch [1038/3000], Step [1], Loss: 1.1587
# Epoch [1039/3000], Step [1], Loss: 1.1575
# Epoch [1040/3000], Step [1], Loss: 1.1578
# Epoch [1041/3000], Step [1], Loss: 1.1499
# Epoch [1042/3000], Step [1], Loss: 1.1488
# Epoch [1043/3000], Step [1], Loss: 1.1486
# Epoch [1044/3000], Step [1], Loss: 1.1435
# Epoch [1045/3000], Step [1], Loss: 1.1479
# Epoch [1046/3000], Step [1], Loss: 1.1409
# Epoch [1047/3000], Step [1], Loss: 1.1344
# Epoch [1048/3000], Step [1], Loss: 1.1308
# Epoch [1049/3000], Step [1], Loss: 1.1295
# Epoch [1050/3000], Step [1], Loss: 1.1305
# Epoch [1051/3000], Step [1], Loss: 1.1468
# Epoch [1052/3000], Step [1], Loss: 1.1336
# Epoch [1053/3000], Step [1], Loss: 1.1209
# Epoch [1054/3000], Step [1], Loss: 1.1150
# Epoch [1055/3000], Step [1], Loss: 1.1204
# Epoch [1056/3000], Step [1], Loss: 1.1120
# Epoch [1057/3000], Step [1], Loss: 1.1071
# Epoch [1058/3000], Step [1], Loss: 1.1075
# Epoch [1059/3000], Step [1], Loss: 1.1002
# Epoch [1060/3000], Step [1], Loss: 1.0993
# Epoch [1061/3000], Step [1], Loss: 1.1004
# Epoch [1062/3000], Step [1], Loss: 1.0942
# Epoch [1063/3000], Step [1], Loss: 1.0939
# Epoch [1064/3000], Step [1], Loss: 1.0961
# Epoch [1065/3000], Step [1], Loss: 1.0929
# Epoch [1066/3000], Step [1], Loss: 1.0868
# Epoch [1067/3000], Step [1], Loss: 1.0830
# Epoch [1068/3000], Step [1], Loss: 1.0885
# Epoch [1069/3000], Step [1], Loss: 1.0821
# Epoch [1070/3000], Step [1], Loss: 1.0758
# Epoch [1071/3000], Step [1], Loss: 1.0704
# Epoch [1072/3000], Step [1], Loss: 1.0706
# Epoch [1073/3000], Step [1], Loss: 1.0704
# Epoch [1074/3000], Step [1], Loss: 1.0654
# Epoch [1075/3000], Step [1], Loss: 1.0637
# Epoch [1076/3000], Step [1], Loss: 1.0622
# Epoch [1077/3000], Step [1], Loss: 1.0626
# Epoch [1078/3000], Step [1], Loss: 1.0554
# Epoch [1079/3000], Step [1], Loss: 1.0525
# Epoch [1080/3000], Step [1], Loss: 1.0474
# Epoch [1081/3000], Step [1], Loss: 1.0415
# Epoch [1082/3000], Step [1], Loss: 1.0416
# Epoch [1083/3000], Step [1], Loss: 1.0406
# Epoch [1084/3000], Step [1], Loss: 1.0391
# Epoch [1085/3000], Step [1], Loss: 1.0357
# Epoch [1086/3000], Step [1], Loss: 1.0372
# Epoch [1087/3000], Step [1], Loss: 1.0373
# Epoch [1088/3000], Step [1], Loss: 1.0317
# Epoch [1089/3000], Step [1], Loss: 1.0357
# Epoch [1090/3000], Step [1], Loss: 1.0308
# Epoch [1091/3000], Step [1], Loss: 1.0246
# Epoch [1092/3000], Step [1], Loss: 1.0220
# Epoch [1093/3000], Step [1], Loss: 1.0188
# Epoch [1094/3000], Step [1], Loss: 1.0204
# Epoch [1095/3000], Step [1], Loss: 1.0177
# Epoch [1096/3000], Step [1], Loss: 1.0134
# Epoch [1097/3000], Step [1], Loss: 1.0134
# Epoch [1098/3000], Step [1], Loss: 1.0152
# Epoch [1099/3000], Step [1], Loss: 1.0162
# Epoch [1100/3000], Step [1], Loss: 1.0189
# Epoch [1101/3000], Step [1], Loss: 1.0125
# Epoch [1102/3000], Step [1], Loss: 1.0151
# Epoch [1103/3000], Step [1], Loss: 1.0170
# Epoch [1104/3000], Step [1], Loss: 1.0238
# Epoch [1105/3000], Step [1], Loss: 1.0127
# Epoch [1106/3000], Step [1], Loss: 1.0201
# Epoch [1107/3000], Step [1], Loss: 1.0129
# Epoch [1108/3000], Step [1], Loss: 1.0160
# Epoch [1109/3000], Step [1], Loss: 1.0197
# Epoch [1110/3000], Step [1], Loss: 1.0190
# Epoch [1111/3000], Step [1], Loss: 1.0146
# Epoch [1112/3000], Step [1], Loss: 1.0156
# Epoch [1113/3000], Step [1], Loss: 1.0146
# Epoch [1114/3000], Step [1], Loss: 1.0139
# Epoch [1115/3000], Step [1], Loss: 1.0114
# Epoch [1116/3000], Step [1], Loss: 1.0142
# Epoch [1117/3000], Step [1], Loss: 1.0174
# Epoch [1118/3000], Step [1], Loss: 1.0161
# Epoch [1119/3000], Step [1], Loss: 1.0205
# Epoch [1120/3000], Step [1], Loss: 1.0138
# Epoch [1121/3000], Step [1], Loss: 1.0109
# Epoch [1122/3000], Step [1], Loss: 1.0182
# Epoch [1123/3000], Step [1], Loss: 1.0129
# Epoch [1124/3000], Step [1], Loss: 1.0114
# Epoch [1125/3000], Step [1], Loss: 1.0099
# Epoch [1126/3000], Step [1], Loss: 1.0093
# Epoch [1127/3000], Step [1], Loss: 1.0135
# Epoch [1128/3000], Step [1], Loss: 1.0171
# Epoch [1129/3000], Step [1], Loss: 1.0308
# Epoch [1130/3000], Step [1], Loss: 1.0167
# Epoch [1131/3000], Step [1], Loss: 1.0222
# Epoch [1132/3000], Step [1], Loss: 1.0173
# Epoch [1133/3000], Step [1], Loss: 1.0118
# Epoch [1134/3000], Step [1], Loss: 1.0103
# Epoch [1135/3000], Step [1], Loss: 1.0067
# Epoch [1136/3000], Step [1], Loss: 1.0101
# Epoch [1137/3000], Step [1], Loss: 1.0126
# Epoch [1138/3000], Step [1], Loss: 1.0158
# Epoch [1139/3000], Step [1], Loss: 1.0139
# Epoch [1140/3000], Step [1], Loss: 1.0131
# Epoch [1141/3000], Step [1], Loss: 1.0154
# Epoch [1142/3000], Step [1], Loss: 1.0142
# Epoch [1143/3000], Step [1], Loss: 1.0138
# Epoch [1144/3000], Step [1], Loss: 1.0151
# Epoch [1145/3000], Step [1], Loss: 1.0099
# Epoch [1146/3000], Step [1], Loss: 1.0099
# Epoch [1147/3000], Step [1], Loss: 1.0114
# Epoch [1148/3000], Step [1], Loss: 1.0108
# Epoch [1149/3000], Step [1], Loss: 1.0098
# Epoch [1150/3000], Step [1], Loss: 1.0095
# Epoch [1151/3000], Step [1], Loss: 1.0106
# Epoch [1152/3000], Step [1], Loss: 1.0139
# Epoch [1153/3000], Step [1], Loss: 1.0154
# Epoch [1154/3000], Step [1], Loss: 1.0139
# Epoch [1155/3000], Step [1], Loss: 1.0122
# Epoch [1156/3000], Step [1], Loss: 1.0098
# Epoch [1157/3000], Step [1], Loss: 1.0124
# Epoch [1158/3000], Step [1], Loss: 1.0145
# Epoch [1159/3000], Step [1], Loss: 1.0090
# Epoch [1160/3000], Step [1], Loss: 1.0105
# Epoch [1161/3000], Step [1], Loss: 1.0126
# Epoch [1162/3000], Step [1], Loss: 1.0145
# Epoch [1163/3000], Step [1], Loss: 1.0148
# Epoch [1164/3000], Step [1], Loss: 1.0128
# Epoch [1165/3000], Step [1], Loss: 1.0099
# Epoch [1166/3000], Step [1], Loss: 1.0077
# Epoch [1167/3000], Step [1], Loss: 1.0062
# Epoch [1168/3000], Step [1], Loss: 1.0085
# ...
# Epoch [2621/3000], Step [1], Loss: 0.9916
# Epoch [2622/3000], Step [1], Loss: 0.9890
# Epoch [2623/3000], Step [1], Loss: 0.9928
# Epoch [2624/3000], Step [1], Loss: 0.9924
# Epoch [2625/3000], Step [1], Loss: 0.9905
# Epoch [2626/3000], Step [1], Loss: 0.9903
# Epoch [2627/3000], Step [1], Loss: 0.9897
# Epoch [2628/3000], Step [1], Loss: 0.9890
# Epoch [2629/3000], Step [1], Loss: 0.9869
# Epoch [2630/3000], Step [1], Loss: 0.9889
# Epoch [2631/3000], Step [1], Loss: 0.9893
# Epoch [2632/3000], Step [1], Loss: 0.9882
# Epoch [2633/3000], Step [1], Loss: 0.9898
# Epoch [2634/3000], Step [1], Loss: 0.9902
# Epoch [2635/3000], Step [1], Loss: 0.9928
# Epoch [2636/3000], Step [1], Loss: 0.9953
# Epoch [2637/3000], Step [1], Loss: 0.9924
# Epoch [2638/3000], Step [1], Loss: 0.9861
# Epoch [2639/3000], Step [1], Loss: 0.9862
# Epoch [2640/3000], Step [1], Loss: 0.9879
# Epoch [2641/3000], Step [1], Loss: 0.9888
# Epoch [2642/3000], Step [1], Loss: 0.9874
# Epoch [2643/3000], Step [1], Loss: 0.9885
# Epoch [2644/3000], Step [1], Loss: 0.9933
# Epoch [2645/3000], Step [1], Loss: 0.9997
# Epoch [2646/3000], Step [1], Loss: 1.0074
# Epoch [2647/3000], Step [1], Loss: 0.9971
# Epoch [2648/3000], Step [1], Loss: 0.9949
# Epoch [2649/3000], Step [1], Loss: 0.9908
# Epoch [2650/3000], Step [1], Loss: 0.9914
# Epoch [2651/3000], Step [1], Loss: 0.9882
# Epoch [2652/3000], Step [1], Loss: 0.9914
# Epoch [2653/3000], Step [1], Loss: 0.9940
# Epoch [2654/3000], Step [1], Loss: 0.9905
# Epoch [2655/3000], Step [1], Loss: 0.9914
# Epoch [2656/3000], Step [1], Loss: 0.9904
# Epoch [2657/3000], Step [1], Loss: 0.9945
# Epoch [2658/3000], Step [1], Loss: 0.9884
# Epoch [2659/3000], Step [1], Loss: 0.9879
# Epoch [2660/3000], Step [1], Loss: 0.9883
# Epoch [2661/3000], Step [1], Loss: 0.9852
# Epoch [2662/3000], Step [1], Loss: 0.9869
# Epoch [2663/3000], Step [1], Loss: 0.9893
# Epoch [2664/3000], Step [1], Loss: 0.9857
# Epoch [2665/3000], Step [1], Loss: 0.9922
# Epoch [2666/3000], Step [1], Loss: 0.9871
# Epoch [2667/3000], Step [1], Loss: 0.9918
# Epoch [2668/3000], Step [1], Loss: 0.9877
# Epoch [2669/3000], Step [1], Loss: 0.9878
# Epoch [2670/3000], Step [1], Loss: 0.9867
# Epoch [2671/3000], Step [1], Loss: 0.9854
# Epoch [2672/3000], Step [1], Loss: 0.9888
# Epoch [2673/3000], Step [1], Loss: 0.9846
# Epoch [2674/3000], Step [1], Loss: 0.9857
# Epoch [2675/3000], Step [1], Loss: 0.9872
# Epoch [2676/3000], Step [1], Loss: 0.9923
# Epoch [2677/3000], Step [1], Loss: 0.9865
# Epoch [2678/3000], Step [1], Loss: 0.9893
# Epoch [2679/3000], Step [1], Loss: 0.9942
# Epoch [2680/3000], Step [1], Loss: 0.9881
# Epoch [2681/3000], Step [1], Loss: 0.9876
# Epoch [2682/3000], Step [1], Loss: 0.9897
# Epoch [2683/3000], Step [1], Loss: 0.9876
# Epoch [2684/3000], Step [1], Loss: 0.9909
# Epoch [2685/3000], Step [1], Loss: 0.9934
# Epoch [2686/3000], Step [1], Loss: 0.9933
# Epoch [2687/3000], Step [1], Loss: 0.9914
# Epoch [2688/3000], Step [1], Loss: 0.9960
# Epoch [2689/3000], Step [1], Loss: 0.9947
# Epoch [2690/3000], Step [1], Loss: 0.9931
# Epoch [2691/3000], Step [1], Loss: 0.9942
# Epoch [2692/3000], Step [1], Loss: 0.9887
# Epoch [2693/3000], Step [1], Loss: 0.9889
# Epoch [2694/3000], Step [1], Loss: 0.9884
# Epoch [2695/3000], Step [1], Loss: 0.9912
# Epoch [2696/3000], Step [1], Loss: 0.9872
# Epoch [2697/3000], Step [1], Loss: 0.9877
# Epoch [2698/3000], Step [1], Loss: 0.9894
# Epoch [2699/3000], Step [1], Loss: 0.9863
# Epoch [2700/3000], Step [1], Loss: 0.9856
# Epoch [2701/3000], Step [1], Loss: 0.9847
# Epoch [2702/3000], Step [1], Loss: 0.9865
# Epoch [2703/3000], Step [1], Loss: 0.9903
# Epoch [2704/3000], Step [1], Loss: 0.9906
# Epoch [2705/3000], Step [1], Loss: 0.9863
# Epoch [2706/3000], Step [1], Loss: 0.9913
# Epoch [2707/3000], Step [1], Loss: 0.9928
# Epoch [2708/3000], Step [1], Loss: 0.9880
# Epoch [2709/3000], Step [1], Loss: 0.9917
# Epoch [2710/3000], Step [1], Loss: 0.9884
# Epoch [2711/3000], Step [1], Loss: 0.9879
# Epoch [2712/3000], Step [1], Loss: 0.9893
# Epoch [2713/3000], Step [1], Loss: 0.9842
# Epoch [2714/3000], Step [1], Loss: 0.9922
# Epoch [2715/3000], Step [1], Loss: 0.9896
# Epoch [2716/3000], Step [1], Loss: 0.9956
# Epoch [2717/3000], Step [1], Loss: 0.9933
# Epoch [2718/3000], Step [1], Loss: 0.9906
# Epoch [2719/3000], Step [1], Loss: 0.9894
# Epoch [2720/3000], Step [1], Loss: 0.9861
# Epoch [2721/3000], Step [1], Loss: 0.9867
# Epoch [2722/3000], Step [1], Loss: 0.9868
# Epoch [2723/3000], Step [1], Loss: 0.9873
# Epoch [2724/3000], Step [1], Loss: 0.9881
# Epoch [2725/3000], Step [1], Loss: 0.9872
# Epoch [2726/3000], Step [1], Loss: 0.9891
# Epoch [2727/3000], Step [1], Loss: 0.9905
# Epoch [2728/3000], Step [1], Loss: 0.9933
# Epoch [2729/3000], Step [1], Loss: 0.9882
# Epoch [2730/3000], Step [1], Loss: 0.9903
# Epoch [2731/3000], Step [1], Loss: 0.9951
# Epoch [2732/3000], Step [1], Loss: 0.9886
# Epoch [2733/3000], Step [1], Loss: 0.9913
# Epoch [2734/3000], Step [1], Loss: 0.9942
# Epoch [2735/3000], Step [1], Loss: 0.9919
# Epoch [2736/3000], Step [1], Loss: 0.9911
# Epoch [2737/3000], Step [1], Loss: 0.9925
# Epoch [2738/3000], Step [1], Loss: 0.9866
# Epoch [2739/3000], Step [1], Loss: 0.9929
# Epoch [2740/3000], Step [1], Loss: 0.9966
# Epoch [2741/3000], Step [1], Loss: 0.9895
# Epoch [2742/3000], Step [1], Loss: 0.9933
# Epoch [2743/3000], Step [1], Loss: 0.9921
# Epoch [2744/3000], Step [1], Loss: 0.9973
# Epoch [2745/3000], Step [1], Loss: 0.9962
# Epoch [2746/3000], Step [1], Loss: 0.9894
# Epoch [2747/3000], Step [1], Loss: 0.9842
# Epoch [2748/3000], Step [1], Loss: 0.9872
# Epoch [2749/3000], Step [1], Loss: 0.9848
# Epoch [2750/3000], Step [1], Loss: 0.9850
# Epoch [2751/3000], Step [1], Loss: 0.9937
# Epoch [2752/3000], Step [1], Loss: 0.9855
# Epoch [2753/3000], Step [1], Loss: 0.9902
# Epoch [2754/3000], Step [1], Loss: 0.9873
# Epoch [2755/3000], Step [1], Loss: 0.9842
# Epoch [2756/3000], Step [1], Loss: 0.9935
# Epoch [2757/3000], Step [1], Loss: 0.9854
# Epoch [2758/3000], Step [1], Loss: 0.9883
# Epoch [2759/3000], Step [1], Loss: 0.9904
# Epoch [2760/3000], Step [1], Loss: 0.9853
# Epoch [2761/3000], Step [1], Loss: 0.9863
# Epoch [2762/3000], Step [1], Loss: 0.9855
# Epoch [2763/3000], Step [1], Loss: 0.9908
# Epoch [2764/3000], Step [1], Loss: 0.9844
# Epoch [2765/3000], Step [1], Loss: 0.9917
# Epoch [2766/3000], Step [1], Loss: 0.9852
# Epoch [2767/3000], Step [1], Loss: 0.9887
# Epoch [2768/3000], Step [1], Loss: 0.9849
# Epoch [2769/3000], Step [1], Loss: 0.9934
# Epoch [2770/3000], Step [1], Loss: 0.9875
# Epoch [2771/3000], Step [1], Loss: 0.9862
# Epoch [2772/3000], Step [1], Loss: 0.9940
# Epoch [2773/3000], Step [1], Loss: 0.9897
# Epoch [2774/3000], Step [1], Loss: 0.9917
# Epoch [2775/3000], Step [1], Loss: 0.9901
# Epoch [2776/3000], Step [1], Loss: 0.9899
# Epoch [2777/3000], Step [1], Loss: 0.9887
# Epoch [2778/3000], Step [1], Loss: 0.9884
# Epoch [2779/3000], Step [1], Loss: 0.9884
# Epoch [2780/3000], Step [1], Loss: 0.9865
# Epoch [2781/3000], Step [1], Loss: 0.9863
# Epoch [2782/3000], Step [1], Loss: 0.9858
# Epoch [2783/3000], Step [1], Loss: 0.9879
# Epoch [2784/3000], Step [1], Loss: 0.9891
# Epoch [2785/3000], Step [1], Loss: 0.9898
# Epoch [2786/3000], Step [1], Loss: 0.9892
# Epoch [2787/3000], Step [1], Loss: 0.9882
# Epoch [2788/3000], Step [1], Loss: 0.9936
# Epoch [2789/3000], Step [1], Loss: 0.9895
# Epoch [2790/3000], Step [1], Loss: 0.9855
# Epoch [2791/3000], Step [1], Loss: 0.9872
# Epoch [2792/3000], Step [1], Loss: 0.9923
# Epoch [2793/3000], Step [1], Loss: 0.9921
# Epoch [2794/3000], Step [1], Loss: 0.9932
# Epoch [2795/3000], Step [1], Loss: 0.9900
# Epoch [2796/3000], Step [1], Loss: 0.9880
# Epoch [2797/3000], Step [1], Loss: 0.9900
# Epoch [2798/3000], Step [1], Loss: 0.9865
# Epoch [2799/3000], Step [1], Loss: 0.9905
# Epoch [2800/3000], Step [1], Loss: 0.9913
# Epoch [2801/3000], Step [1], Loss: 0.9893
# Epoch [2802/3000], Step [1], Loss: 0.9906
# Epoch [2803/3000], Step [1], Loss: 0.9912
# Epoch [2804/3000], Step [1], Loss: 0.9899
# Epoch [2805/3000], Step [1], Loss: 0.9902
# Epoch [2806/3000], Step [1], Loss: 0.9944
# Epoch [2807/3000], Step [1], Loss: 0.9896
# Epoch [2808/3000], Step [1], Loss: 0.9912
# Epoch [2809/3000], Step [1], Loss: 0.9878
# Epoch [2810/3000], Step [1], Loss: 0.9876
# Epoch [2811/3000], Step [1], Loss: 0.9894
# Epoch [2812/3000], Step [1], Loss: 0.9904
# Epoch [2813/3000], Step [1], Loss: 0.9877
# Epoch [2814/3000], Step [1], Loss: 0.9893
# Epoch [2815/3000], Step [1], Loss: 0.9914
# Epoch [2816/3000], Step [1], Loss: 0.9923
# Epoch [2817/3000], Step [1], Loss: 0.9902
# Epoch [2818/3000], Step [1], Loss: 0.9874
# Epoch [2819/3000], Step [1], Loss: 0.9908
# Epoch [2820/3000], Step [1], Loss: 0.9871
# Epoch [2821/3000], Step [1], Loss: 0.9856
# Epoch [2822/3000], Step [1], Loss: 0.9858
# Epoch [2823/3000], Step [1], Loss: 0.9858
# Epoch [2824/3000], Step [1], Loss: 0.9870
# Epoch [2825/3000], Step [1], Loss: 0.9870
# Epoch [2826/3000], Step [1], Loss: 0.9899
# Epoch [2827/3000], Step [1], Loss: 0.9900
# Epoch [2828/3000], Step [1], Loss: 0.9885
# Epoch [2829/3000], Step [1], Loss: 0.9875
# Epoch [2830/3000], Step [1], Loss: 0.9899
# Epoch [2831/3000], Step [1], Loss: 0.9894
# Epoch [2832/3000], Step [1], Loss: 0.9934
# Epoch [2833/3000], Step [1], Loss: 0.9874
# Epoch [2834/3000], Step [1], Loss: 0.9896
# Epoch [2835/3000], Step [1], Loss: 0.9880
# Epoch [2836/3000], Step [1], Loss: 0.9914
# Epoch [2837/3000], Step [1], Loss: 0.9932
# Epoch [2838/3000], Step [1], Loss: 0.9981
# Epoch [2839/3000], Step [1], Loss: 0.9881
# Epoch [2840/3000], Step [1], Loss: 0.9879
# Epoch [2841/3000], Step [1], Loss: 0.9945
# Epoch [2842/3000], Step [1], Loss: 0.9868
# Epoch [2843/3000], Step [1], Loss: 0.9913
# Epoch [2844/3000], Step [1], Loss: 0.9897
# Epoch [2845/3000], Step [1], Loss: 0.9892
# Epoch [2846/3000], Step [1], Loss: 0.9932
# Epoch [2847/3000], Step [1], Loss: 0.9938
# Epoch [2848/3000], Step [1], Loss: 0.9896
# Epoch [2849/3000], Step [1], Loss: 0.9917
# Epoch [2850/3000], Step [1], Loss: 0.9893
# Epoch [2851/3000], Step [1], Loss: 0.9899
# Epoch [2852/3000], Step [1], Loss: 0.9905
# Epoch [2853/3000], Step [1], Loss: 0.9914
# Epoch [2854/3000], Step [1], Loss: 0.9858
# Epoch [2855/3000], Step [1], Loss: 0.9850
# Epoch [2856/3000], Step [1], Loss: 0.9923
# Epoch [2857/3000], Step [1], Loss: 0.9933
# Epoch [2858/3000], Step [1], Loss: 0.9885
# Epoch [2859/3000], Step [1], Loss: 0.9865
# Epoch [2860/3000], Step [1], Loss: 0.9873
# Epoch [2861/3000], Step [1], Loss: 0.9858
# Epoch [2862/3000], Step [1], Loss: 0.9856
# Epoch [2863/3000], Step [1], Loss: 0.9862
# Epoch [2864/3000], Step [1], Loss: 0.9850
# Epoch [2865/3000], Step [1], Loss: 0.9951
# Epoch [2866/3000], Step [1], Loss: 0.9870
# Epoch [2867/3000], Step [1], Loss: 0.9933
# Epoch [2868/3000], Step [1], Loss: 0.9879
# Epoch [2869/3000], Step [1], Loss: 0.9878
# Epoch [2870/3000], Step [1], Loss: 0.9879
# Epoch [2871/3000], Step [1], Loss: 0.9872
# Epoch [2872/3000], Step [1], Loss: 0.9857
# Epoch [2873/3000], Step [1], Loss: 0.9864
# Epoch [2874/3000], Step [1], Loss: 0.9976
# Epoch [2875/3000], Step [1], Loss: 0.9936
# Epoch [2876/3000], Step [1], Loss: 0.9939
# Epoch [2877/3000], Step [1], Loss: 0.9908
# Epoch [2878/3000], Step [1], Loss: 0.9909
# Epoch [2879/3000], Step [1], Loss: 0.9910
# Epoch [2880/3000], Step [1], Loss: 0.9929
# Epoch [2881/3000], Step [1], Loss: 0.9885
# Epoch [2882/3000], Step [1], Loss: 0.9917
# Epoch [2883/3000], Step [1], Loss: 0.9956
# Epoch [2884/3000], Step [1], Loss: 0.9949
# Epoch [2885/3000], Step [1], Loss: 0.9880
# Epoch [2886/3000], Step [1], Loss: 0.9884
# Epoch [2887/3000], Step [1], Loss: 0.9928
# Epoch [2888/3000], Step [1], Loss: 0.9877
# Epoch [2889/3000], Step [1], Loss: 0.9851
# Epoch [2890/3000], Step [1], Loss: 0.9866
# Epoch [2891/3000], Step [1], Loss: 0.9854
# Epoch [2892/3000], Step [1], Loss: 0.9841
# Epoch [2893/3000], Step [1], Loss: 0.9879
# Epoch [2894/3000], Step [1], Loss: 0.9905
# Epoch [2895/3000], Step [1], Loss: 0.9934
# Epoch [2896/3000], Step [1], Loss: 0.9877
# Epoch [2897/3000], Step [1], Loss: 0.9868
# Epoch [2898/3000], Step [1], Loss: 0.9875
# Epoch [2899/3000], Step [1], Loss: 0.9905
# Epoch [2900/3000], Step [1], Loss: 0.9902
# Epoch [2901/3000], Step [1], Loss: 0.9875
# Epoch [2902/3000], Step [1], Loss: 0.9877
# Epoch [2903/3000], Step [1], Loss: 0.9895
# Epoch [2904/3000], Step [1], Loss: 0.9959
# Epoch [2905/3000], Step [1], Loss: 1.0008
# Epoch [2906/3000], Step [1], Loss: 0.9977
# Epoch [2907/3000], Step [1], Loss: 0.9964
# Epoch [2908/3000], Step [1], Loss: 0.9918
# Epoch [2909/3000], Step [1], Loss: 0.9903
# Epoch [2910/3000], Step [1], Loss: 0.9857
# Epoch [2911/3000], Step [1], Loss: 0.9890
# Epoch [2912/3000], Step [1], Loss: 0.9877
# Epoch [2913/3000], Step [1], Loss: 0.9886
# Epoch [2914/3000], Step [1], Loss: 0.9906
# Epoch [2915/3000], Step [1], Loss: 0.9920
# Epoch [2916/3000], Step [1], Loss: 0.9901
# Epoch [2917/3000], Step [1], Loss: 0.9869
# Epoch [2918/3000], Step [1], Loss: 0.9860
# Epoch [2919/3000], Step [1], Loss: 0.9880
# Epoch [2920/3000], Step [1], Loss: 0.9915
# Epoch [2921/3000], Step [1], Loss: 0.9882
# Epoch [2922/3000], Step [1], Loss: 0.9879
# Epoch [2923/3000], Step [1], Loss: 0.9851
# Epoch [2924/3000], Step [1], Loss: 0.9863
# Epoch [2925/3000], Step [1], Loss: 0.9877
# Epoch [2926/3000], Step [1], Loss: 0.9893
# Epoch [2927/3000], Step [1], Loss: 0.9876
# Epoch [2928/3000], Step [1], Loss: 0.9910
# Epoch [2929/3000], Step [1], Loss: 0.9892
# Epoch [2930/3000], Step [1], Loss: 0.9950
# Epoch [2931/3000], Step [1], Loss: 0.9895
# Epoch [2932/3000], Step [1], Loss: 0.9910
# Epoch [2933/3000], Step [1], Loss: 0.9898
# Epoch [2934/3000], Step [1], Loss: 0.9887
# Epoch [2935/3000], Step [1], Loss: 0.9885
# Epoch [2936/3000], Step [1], Loss: 0.9871
# Epoch [2937/3000], Step [1], Loss: 0.9853
# Epoch [2938/3000], Step [1], Loss: 0.9878
# Epoch [2939/3000], Step [1], Loss: 0.9923
# Epoch [2940/3000], Step [1], Loss: 0.9918
# Epoch [2941/3000], Step [1], Loss: 0.9884
# Epoch [2942/3000], Step [1], Loss: 0.9857
# Epoch [2943/3000], Step [1], Loss: 0.9887
# Epoch [2944/3000], Step [1], Loss: 0.9917
# Epoch [2945/3000], Step [1], Loss: 0.9885
# Epoch [2946/3000], Step [1], Loss: 0.9913
# Epoch [2947/3000], Step [1], Loss: 0.9900
# Epoch [2948/3000], Step [1], Loss: 0.9936
# Epoch [2949/3000], Step [1], Loss: 0.9925
# Epoch [2950/3000], Step [1], Loss: 0.9937
# Epoch [2951/3000], Step [1], Loss: 0.9929
# Epoch [2952/3000], Step [1], Loss: 0.9884
# Epoch [2953/3000], Step [1], Loss: 0.9876
# Epoch [2954/3000], Step [1], Loss: 0.9900
# Epoch [2955/3000], Step [1], Loss: 0.9863
# Epoch [2956/3000], Step [1], Loss: 0.9873
# Epoch [2957/3000], Step [1], Loss: 0.9923
# Epoch [2958/3000], Step [1], Loss: 0.9859
# Epoch [2959/3000], Step [1], Loss: 0.9852
# Epoch [2960/3000], Step [1], Loss: 0.9869
# Epoch [2961/3000], Step [1], Loss: 0.9895
# Epoch [2962/3000], Step [1], Loss: 0.9896
# Epoch [2963/3000], Step [1], Loss: 0.9922
# Epoch [2964/3000], Step [1], Loss: 0.9960
# Epoch [2965/3000], Step [1], Loss: 0.9863
# Epoch [2966/3000], Step [1], Loss: 0.9871
# Epoch [2967/3000], Step [1], Loss: 0.9866
# Epoch [2968/3000], Step [1], Loss: 0.9915
# Epoch [2969/3000], Step [1], Loss: 0.9910
# Epoch [2970/3000], Step [1], Loss: 0.9841
# Epoch [2971/3000], Step [1], Loss: 0.9880
# Epoch [2972/3000], Step [1], Loss: 0.9862
# Epoch [2973/3000], Step [1], Loss: 0.9877
# Epoch [2974/3000], Step [1], Loss: 0.9928
# Epoch [2975/3000], Step [1], Loss: 0.9874
# Epoch [2976/3000], Step [1], Loss: 0.9877
# Epoch [2977/3000], Step [1], Loss: 0.9876
# Epoch [2978/3000], Step [1], Loss: 0.9877
# Epoch [2979/3000], Step [1], Loss: 0.9865
# Epoch [2980/3000], Step [1], Loss: 0.9903
# Epoch [2981/3000], Step [1], Loss: 0.9929
# Epoch [2982/3000], Step [1], Loss: 0.9888
# Epoch [2983/3000], Step [1], Loss: 0.9894
# Epoch [2984/3000], Step [1], Loss: 0.9887
# Epoch [2985/3000], Step [1], Loss: 0.9896
# Epoch [2986/3000], Step [1], Loss: 0.9861
# Epoch [2987/3000], Step [1], Loss: 0.9898
# Epoch [2988/3000], Step [1], Loss: 0.9842
# Epoch [2989/3000], Step [1], Loss: 0.9867
# Epoch [2990/3000], Step [1], Loss: 0.9914
# Epoch [2991/3000], Step [1], Loss: 0.9927
# Epoch [2992/3000], Step [1], Loss: 0.9894
# Epoch [2993/3000], Step [1], Loss: 0.9883
# Epoch [2994/3000], Step [1], Loss: 0.9907
# Epoch [2995/3000], Step [1], Loss: 0.9981
# Epoch [2996/3000], Step [1], Loss: 0.9917
# Epoch [2997/3000], Step [1], Loss: 0.9903
# Epoch [2998/3000], Step [1], Loss: 0.9873
# Epoch [2999/3000], Step [1], Loss: 0.9932
# Epoch [3000/3000], Step [1], Loss: 0.9909

# %%
predicted_abcd[1,1,:,:].shape
# Out:
# torch.Size([64, 64])

# %%
a_pre = predicted_abcd[1,0,:,:].detach().cpu().numpy()
b_pre = predicted_abcd[1,1,:,:].detach().cpu().numpy()
c_pre = predicted_abcd[1,2,:,:].detach().cpu().numpy()
d_pre = predicted_abcd[1,3,:,:].detach().cpu().numpy()

# %%
a_test_grad_x, a_test_grad_y = np.gradient(a_pre, dx)
b_test_grad_x, b_test_grad_y = np.gradient(b_pre, dx)
c_test_grad_x, c_test_grad_y = np.gradient(c_pre, dx)
d_test_grad_x, d_test_grad_y = np.gradient(d_pre, dx)

# %%
# U_x_pred_test = a_pre * b_test_grad_x - b_pre * a_test_grad_x + c_pre * d_test_grad_x - d_pre * c_test_grad_x
# U_y_pred_test = a_pre * b_test_grad_y - b_pre * a_test_grad_y + c_pre * d_test_grad_y - d_pre * c_test_grad_y
# U_magnitude_pred_test = np.sqrt(U_x_pred_test**2 + U_y_pred_test**2)

# %%
U_x_pred_test = a_pre + b_pre
U_y_pred_test = c_pre + d_pre
U_magnitude_pred_test = np.sqrt(U_x_pred_test**2 + U_y_pred_test**2)

# %%
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.imshow(U_x_pred_test, cmap='viridis')
# plt.colorbar()
plt.subplot(1, 2, 2)
plt.imshow(U_y_pred_test, cmap='viridis')

# %%
vort_pre = vorticity(U_x_pred_test, U_y_pred_test, dx, dx)

vorticity_normalized_pre = vorticity_normalize(vort_pre)

plt.imshow(vorticity_normalized_pre, cmap='RdBu_r',vmin=-0.3,vmax=0.3,interpolation='bilinear')
plt.colorbar()
