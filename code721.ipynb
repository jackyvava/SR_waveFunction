# %% [markdown]
# # TG涡

# %% [markdown]
# 函数 \(a(x, y)\)、\(b(x, y)\)、\(c(x, y)\) 和 \(d(x, y)\) 定义如下：
# \begin{align*}
#     H(x) &=
#     \begin{cases}
#       \frac{x}{2} & \text{如果 } 0 \leq x \leq \pi \\
#       \pi - \frac{x}{2} & \text{如果 } \pi < x \leq 2\pi
#     \end{cases} \\
#     a(x, y) &= \cos[H(x)] \cos\left(\frac{\cos(y) (2 - \cos(x))}{\hbar}\right), \\
#     b(x, y) &= \cos[H(x)] \sin\left(\frac{\cos(y) (2 - \cos(x))}{\hbar}\right), \\
#     c(x, y) &= \sin[H(x)] \cos\left(\frac{\cos(y) (2 + \cos(x))}{\hbar}\right), \\
#     d(x, y) &= -\sin[H(x)] \sin\left(\frac{\cos(y) (2 + \cos(x))}{\hbar}\right).
# \end{align*}
# 其中，$\hbar $是一个常数（为了简化，设为1）。

# %% [markdown]
# 速度场计算
# $$
# \mathbf{u} = \hbar(a \mathbf \nabla b-b\mathbf \nabla a + c\mathbf \nabla d - d\mathbf \nabla c)
# $$
#
# 速度场分量 $u_x$ 和 $u_y$ 使用 $a$、$b$、$c$、$d$ 的梯度计算得到：
# $$
# \begin{align*}
#     \nabla a &= \left(\frac{\partial a}{\partial x}, \frac{\partial a}{\partial y}\right), \\
#     \nabla b &= \left(\frac{\partial b}{\partial x}, \frac{\partial b}{\partial y}\right), \\
#     \nabla c &= \left(\frac{\partial c}{\partial x}, \frac{\partial c}{\partial y}\right), \\
#     \nabla d &= \left(\frac{\partial d}{\partial x}, \frac{\partial d}{\partial y}\right).
# \end{align*}
# $$

# %% [markdown]
# 速度场的计算公式为：
# \begin{align*}
#     u_x &= \hbar \left(a \frac{\partial b}{\partial x} - b \frac{\partial a}{\partial x} + c \frac{\partial d}{\partial x} - d \frac{\partial c}{\partial x}\right), \\
#     u_y &= \hbar \left(a \frac{\partial b}{\partial y} - b \frac{\partial a}{\partial y} + c \frac{\partial d}{\partial y} - d \frac{\partial c}{\partial y}\right).
# \end{align*}

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# 定义常数
hbar = 1

# 定义 H(x)
def H(x):
    return np.where((0 <= x) & (x <= np.pi), x / 2, np.pi - x / 2)

# 定义函数 a, b, c, d
def a(x, y):
    return np.cos(H(x)) * np.cos(np.cos(y) * (2 - np.cos(x)) / hbar)

def b(x, y):
    return np.cos(H(x)) * np.sin(np.cos(y) * (2 - np.cos(x)) / hbar)

def c(x, y):
    return np.sin(H(x)) * np.cos(np.cos(y) * (2 + np.cos(x)) / hbar)

def d(x, y):
    return -np.sin(H(x)) * np.sin(np.cos(y) * (2 + np.cos(x)) / hbar)

# 计算梯度
def gradient(f, x, y, eps=1e-5):
    f_x = (f(x + eps, y) - f(x - eps, y)) / (2 * eps)
    f_y = (f(x, y + eps) - f(x, y - eps)) / (2 * eps)
    return f_x, f_y

# %%
# 计算速度场
def compute_velocity_field_np(x, y, dx, dy):
    # 使用内置的np 求解梯度
    a_val = a(x, y)
    b_val = b(x, y)
    c_val = c(x, y)
    d_val = d(x, y)

    a_grad_x, a_grad_y = np.gradient(a_val, dx, dy)
    b_grad_x, b_grad_y = np.gradient(b_val, dx, dy)
    c_grad_x, c_grad_y = np.gradient(c_val, dx, dy)
    d_grad_x, d_grad_y = np.gradient(d_val, dx, dy)

    u_x = hbar * (a_val * b_grad_x - b_val * a_grad_x + c_val * d_grad_x - d_val * c_grad_x)
    u_y = hbar * (a_val * b_grad_y - b_val * a_grad_y + c_val * d_grad_y - d_val * c_grad_y)

    return u_x, u_y

# %% [markdown]
# 此处我们设定low像素:   $32\times 32$
#
# 设定High像素为    $128\times 128$

# %%
size_low = 64
size_High = 256
x_low = np.linspace(0, 2 * np.pi, size_low)
y_low = np.linspace(0, 2 * np.pi, size_low)

x_high = np.linspace(0, 2 * np.pi, size_High)
y_high = np.linspace(0, 2 * np.pi, size_High)


X_low, Y_low = np.meshgrid(x_low, y_low)
X_high, Y_high = np.meshgrid(x_high, y_high)

# %%
# 计算函数值
A_low = a(X_low, Y_low)
B_low = b(X_low, Y_low)
C_low = c(X_low, Y_low)
D_low = d(X_low, Y_low)

A_high = a(X_high, Y_high)
B_high = b(X_high, Y_high)
C_high = c(X_high, Y_high)
D_high = d(X_high, Y_high)

# %%
# 计算步长
dx_low = x_low[1] - x_low[0]
dy_low = y_low[1] - y_low[0]

dx_high = x_high[1] - x_high[0]
dy_high = y_high[1] - y_high[0]

# %% [markdown]
# ## 可视化速度场

# %%
U_x_low, U_y_low = compute_velocity_field_np(X_low, Y_low, dx_low, dy_low)
U_x_high, U_y_high = compute_velocity_field_np(X_high, Y_high, dx_high, dy_high)

# 计算速度场的大小
U_magnitude_low = np.sqrt(U_x_low**2 + U_y_low**2)
U_magnitude_high = np.sqrt(U_x_high**2 + U_y_high**2)

U_magnitude_low.shape, U_magnitude_high.shape
# Out:
# ((64, 64), (256, 256))

# %%
plt.figure(figsize=(16, 6))
plt.subplot(121)
plt.contourf(X_low, Y_low, U_magnitude_low, levels=50, cmap='viridis')
# plt.streamplot(X_low, Y_low, U_x_low, U_y_low, color='white', linewidth=1)
plt.title('TG vortex xy-plane velocity field (low accuracy)')
# plt.streamplot(X, Y, U_x_FD, U_y_FD, color='white', linewidth=1)
plt.xlim(0, 2 * np.pi)
plt.ylim(0, 2 * np.pi)

plt.tick_params(axis='both', direction='in', length=6)
plt.colorbar()



plt.subplot(122)
plt.contourf(X_high, Y_high, U_magnitude_high, levels=50, cmap='viridis')
# plt.streamplot(X_high, Y_high, U_x_high, U_y_high, color='white', linewidth=1)
plt.title('TG vortex xy-plane velocity field (High accuracy)')
# plt.streamplot(X, Y, U_x_FD, U_y_FD, color='white', linewidth=1)
plt.xlim(0, 2 * np.pi)
plt.ylim(0, 2 * np.pi)

plt.tick_params(axis='both', direction='in', length=6)
plt.colorbar()

plt.show()

# %% [markdown]
# ## 可视化涡度场

# %%
def vorticity(U_x, U_y, dx, dy):
    dU_y_dx, _ = np.gradient(U_y, dx, axis=0), np.gradient(U_y, dy, axis=1)
    _, dU_x_dy = np.gradient(U_x, dx, axis=0), np.gradient(U_x, dy, axis=1)
    return dU_y_dx - dU_x_dy

# %%
# 计算旋度
vort_low = vorticity(U_x_low, U_y_low, dx_low, dy_low)
vort_high = vorticity(U_x_high, U_y_high, dx_high, dy_high)


# 归一化旋度
max_vort_low = np.max(np.abs(vort_low))
vort_normalized_low = vort_low / max_vort_low if max_vort_low != 0 else vort_low

max_vort_high = np.max(np.abs(vort_high))
vort_normalized_high = vort_high / max_vort_high if max_vort_high != 0 else vort_high

# %%
plt.figure(figsize=(14, 6))
plt.subplot(121)
plt.contourf(X_low, Y_low, vort_normalized_low, levels=50, cmap='RdBu_r', vmin=-1, vmax=1)
plt.colorbar()
plt.title('TG vortex xy-plane normalized vorticity field (low accuracy)')
plt.tick_params(axis='both', direction='in', length=6)

plt.subplot(122)
plt.contourf(X_high, Y_high, vort_normalized_high, levels=50, cmap='RdBu_r', vmin=-1, vmax=1)
plt.colorbar()
plt.title('TG vortex xy-plane normalized vorticity field (High accuracy)')


plt.tick_params(axis='both', direction='in', length=6)


plt.show()

# %% [markdown]
# ## 特征提取阶段
#
#
# 从速度场得到abcd

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import DataLoader, TensorDataset, random_split

# %%
import os
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation

# %% [markdown]
# ### 数据处理

# %%
# 将数据转换为PyTorch张量
U_x = torch.tensor(U_x_low, dtype=torch.float32).unsqueeze(0).unsqueeze(0)  # 增加batch和channel维度
U_y = torch.tensor(U_y_low, dtype=torch.float32).unsqueeze(0).unsqueeze(0)
U_magnitude = torch.tensor(U_magnitude_low, dtype=torch.float32).unsqueeze(0).unsqueeze(0)

# 合并速度场作为输入
velocity_field = torch.cat((U_x, U_y, U_magnitude), dim=1)

# 目标abcd (假设为0初始化)
target_abcd = torch.zeros((1, 4, size_low, size_low), dtype=torch.float32)

# 创建数据集和数据加载器
dataset = TensorDataset(velocity_field, target_abcd)
dataloader = DataLoader(dataset, batch_size=500, shuffle=True)

# %%
U_magnitude.shape,target_abcd.shape
# Out:
# (torch.Size([1, 1, 64, 64]), torch.Size([1, 4, 64, 64]))

# %% [markdown]
# ### 构建模型

# %%
class BasicModelA(nn.Module):
    def __init__(self):
        super(BasicModelA, self).__init__()
        self.conv1 = nn.Conv2d(3, 64, kernel_size=3, padding=1)
        self.bn1 = nn.BatchNorm2d(64)
        self.conv2 = nn.Conv2d(64, 128, kernel_size=3, padding=1)
        self.bn2 = nn.BatchNorm2d(128)
        self.conv3 = nn.Conv2d(128, 256, kernel_size=3, padding=1)
        self.bn3 = nn.BatchNorm2d(256)
        self.pool = nn.MaxPool2d(2, 2)
        self.conv4 = nn.Conv2d(256, 512, kernel_size=3, padding=1)
        self.bn4 = nn.BatchNorm2d(512)
        self.upsample = nn.Upsample(scale_factor=8, mode='bilinear', align_corners=True)
        self.conv5 = nn.Conv2d(512, 4, kernel_size=3, padding=1)

    def forward(self, x):
        x = F.relu(self.bn1(self.conv1(x)))
        x = self.pool(x)
        x = F.relu(self.bn2(self.conv2(x)))
        x = self.pool(x)
        x = F.relu(self.bn3(self.conv3(x)))
        x = self.pool(x)
        x = F.relu(self.bn4(self.conv4(x)))
        x = self.upsample(x)  # 使用上采样恢复到原始尺寸
        x = self.conv5(x)
        return x

# %%
class ConstraintLayer(nn.Module):
    def __init__(self):
        super(ConstraintLayer, self).__init__()

    def forward(self, x):
        # 假设x的形状为 [batch_size, 4, height, width]，其中4代表abcd
        norm = torch.sqrt(x[:, 0, :, :]**2 + x[:, 1, :, :]**2 + x[:, 2, :, :]**2 + x[:, 3, :, :]**2 + 1e-8)
        norm = norm.unsqueeze(1)  # 为了与abcd的四个通道对齐
        x = x / norm  # 归一化
        return x

# %%
 
class ModelAWithConstraints(nn.Module):
    def __init__(self):
        super(ModelAWithConstraints, self).__init__()
        self.model = BasicModelA()
        self.constraint_layer = ConstraintLayer()

    def forward(self, x):
        x = self.model(x)
        x = self.constraint_layer(x)
        return x

# %% [markdown]
# ### 定义Loss function

# %%
def calculate_gradients_with_numpy(tensor):
    # 确保 Tensor 不需要梯度跟踪，且在 CPU 上
    tensor_np = tensor.detach().cpu().numpy()

   
    # 计算梯度
    grad_x = np.gradient(tensor_np, axis=1)  # 假设水平方向是 axis=1
    grad_y = np.gradient(tensor_np, axis=2)  # 假设垂直方向是 axis=2
    
    # 转换回 Tensor
    grad_x_tensor = torch.from_numpy(grad_x).to(tensor.device)
    grad_y_tensor = torch.from_numpy(grad_y).to(tensor.device)
    
    return grad_x_tensor, grad_y_tensor

# %%
def laplacian_2d(array, dx, dy):
    grad_x = np.gradient(array, dx, axis=1, edge_order=2)  # 计算 x 方向的一阶导数
    grad_y = np.gradient(array, dy, axis=0, edge_order=2)  # 计算 y 方向的一阶导数
    
    laplacian_x = np.gradient(grad_x, dx, axis=1, edge_order=2)  # 计算 x 方向的二阶导数
    laplacian_y = np.gradient(grad_y, dy, axis=0, edge_order=2)  # 计算 y 方向的二阶导数
    
    return laplacian_x + laplacian_y


def laplacian_2d_torch(tensor, dx, dy):
    # 确保tensor是浮点类型，因为梯度计算通常需要浮点运算
    tensor = tensor.float()
    tensor_np = tensor.detach().cpu().numpy()

    # 计算x和y方向的一阶导数
    grad_x = np.gradient(tensor_np, axis=1)  # x方向
    grad_y = np.gradient(tensor_np, axis=2)  # y方向

    # 计算x和y方向的二阶导数
    laplacian_x = np.gradient(grad_x, axis=1)
    laplacian_y = np.gradient(grad_y, axis=2)

    laplacian_x_tensor = torch.from_numpy(laplacian_x).to(tensor.device)
    laplacian_y_tensor = torch.from_numpy(laplacian_y).to(tensor.device)

    # 相加得到完整的拉普拉斯算子
    laplacian = laplacian_x_tensor + laplacian_y_tensor

    return laplacian

# %%
# 定义损失函数
# 这个 loss function 考虑了数学和物理约束
def loss_function(predicted_abcd, true_velocity, epsilon):
    # 提取 a, b, c, d
    # 提取 a, b, c, d，并增加批次维度以兼容梯度计算
    a = predicted_abcd[:, 0, :, :]
    b = predicted_abcd[:, 1, :, :]
    c = predicted_abcd[:, 2, :, :]
    d = predicted_abcd[:, 3, :, :]
    # print(a.shape)
    
    # 计算梯度
    a_grad_x, a_grad_y = calculate_gradients_with_numpy(a)
    b_grad_x, b_grad_y = calculate_gradients_with_numpy(b)
    c_grad_x, c_grad_y = calculate_gradients_with_numpy(c)
    d_grad_x, d_grad_y = calculate_gradients_with_numpy(d)

    hbar = 1  # 你可以根据具体情况调整这个参数


        # 根据 a, b, c, d 计算预测的速度场
    U_x_pred = a + b
    U_y_pred = c + d
    U_magnitude_pred = torch.sqrt(U_x_pred**2 + U_y_pred**2)
    
    # 计算速度场的损失
    U_x_true = true_velocity[:, 0, :, :]
    U_y_true = true_velocity[:, 1, :, :]
    U_magnitude_true = true_velocity[:, 2, :, :]


    # U_x_pred = hbar * (a * b_grad_x - b * a_grad_x + c * d_grad_x - d * c_grad_x)
    # U_y_pred = hbar * (a * b_grad_y - b * a_grad_y + c * d_grad_y - d * c_grad_y)
    # U_magnitude_pred = torch.sqrt(U_x_pred**2 + U_y_pred**2)
    
    # # # 计算速度场的损失
    # U_x_true = true_velocity[:, 0, :, :]
    # U_y_true = true_velocity[:, 1, :, :]
    # U_magnitude_true = true_velocity[:, 2, :, :]


    loss_velocity =  F.mse_loss(U_magnitude_pred, U_magnitude_true)+F.mse_loss(U_x_pred, U_x_true) + F.mse_loss(U_y_pred, U_y_true) 
    
    # 计算归一化约束
    # psi1 = a + 1j * b
    # psi2 = c + 1j * d
    norm = a**2 + b**2 + c**2 + d**2

    
    norm_constraint = F.mse_loss(norm, torch.ones_like(norm))
    
    #     # 计算拉普拉斯算子
    lap_b = laplacian_2d_torch(b, dx_low,dy_low)
    lap_a = laplacian_2d_torch(a, dx_low,dy_low)
    lap_d = laplacian_2d_torch(d, dx_low,dy_low)
    lap_c = laplacian_2d_torch(c, dx_low,dy_low)

    # # 计算螺旋度约束

    curl_constraint = (a * lap_b - b * lap_a + c * lap_d - d * lap_c).sum()
    
    # # 计算正则化项
    regularization_term = epsilon * 0.25*(torch.sum(a**2) + torch.sum(b**2) + torch.sum(c**2) + torch.sum(d**2))
    
    # # 总损失
    total_loss = loss_velocity #+ norm_constraint + curl_constraint #+ regularization_term 
    return total_loss

# %% [markdown]
# ### 设置超参数

# %%
# 超参数
learning_rate = 0.001
num_epochs = 5000
epsilon = 0.01

channels = 3

# 创建模型和优化器
model = ModelAWithConstraints()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

# %%
def plot_comparison(predicted, actual, step):
    
    a = predicted_abcd[:, 0, :, :]
    b = predicted_abcd[:, 1, :, :]
    c = predicted_abcd[:, 2, :, :]
    d = predicted_abcd[:, 3, :, :]
    
    a_grad_x, a_grad_y = calculate_gradients_with_numpy(a)
    b_grad_x, b_grad_y = calculate_gradients_with_numpy(b)
    c_grad_x, c_grad_y = calculate_gradients_with_numpy(c)
    d_grad_x, d_grad_y = calculate_gradients_with_numpy(d)

    hbar = 1

    U_x_pred = hbar * (a * b_grad_x - b * a_grad_x + c * d_grad_x - d * c_grad_x)
    U_y_pred = hbar * (a * b_grad_y - b * a_grad_y + c * d_grad_y - d * c_grad_y)
    U_magnitude_pred = torch.sqrt(U_x_pred**2 + U_y_pred**2)

    
    
    plt.subplots(2, 3, figsize=(10, 8))

    plt.subplot(2, 3, 1)
    plt.imshow(U_magnitude_pred[0].detach().cpu().numpy(), cmap='viridis')

    plt.title('Predicted Magnitude')

    plt.subplot(2, 3, 2)
    plt.imshow(U_x_pred[0].detach().cpu().numpy(), cmap='viridis')
    plt.title('Predicted U_x')

    plt.subplot(2, 3, 3)
    plt.imshow(U_y_pred[0].detach().cpu().numpy(), cmap='viridis')
    plt.title('Predicted U_y')

    plt.subplot(2, 3, 4)
    plt.imshow(actual[0,2].detach().cpu().numpy(), cmap='viridis')
    plt.title('Actual Magnitude')

    plt.subplot(2, 3, 5)
    plt.imshow(actual[0,1].detach().cpu().numpy(), cmap='viridis'   )
    plt.title('Actual U_x')

    plt.subplot(2, 3, 6)
    plt.imshow(actual[0,0].detach().cpu().numpy(), cmap='viridis')
    plt.title('Actual U_y')

    plt.suptitle(f'Step {step}')
    plt.show()

# %%
# 训练模型
for epoch in range(num_epochs):
    for i, (velocity, _) in enumerate(dataloader):
        optimizer.zero_grad()
        predicted_abcd = model(velocity)
        loss = loss_function(predicted_abcd, velocity, epsilon)
        loss.backward()
        optimizer.step()
        if i % 10 == 0:
            print(f'Epoch [{epoch+1}/{num_epochs}], Step [{i+1}], Loss: {loss.item():.4f}')
# Out:
# Epoch [1/5000], Step [1], Loss: 1.6488
# Epoch [2/5000], Step [1], Loss: 0.7899
# Epoch [3/5000], Step [1], Loss: 0.5423
# Epoch [4/5000], Step [1], Loss: 0.3510
# Epoch [5/5000], Step [1], Loss: 0.2034
# Epoch [6/5000], Step [1], Loss: 0.1159
# Epoch [7/5000], Step [1], Loss: 0.0855
# Epoch [8/5000], Step [1], Loss: 0.0851
# Epoch [9/5000], Step [1], Loss: 0.0928
# Epoch [10/5000], Step [1], Loss: 0.0984
# Epoch [11/5000], Step [1], Loss: 0.0989
# Epoch [12/5000], Step [1], Loss: 0.0944
# Epoch [13/5000], Step [1], Loss: 0.0864
# Epoch [14/5000], Step [1], Loss: 0.0767
# Epoch [15/5000], Step [1], Loss: 0.0667
# Epoch [16/5000], Step [1], Loss: 0.0574
# Epoch [17/5000], Step [1], Loss: 0.0495
# Epoch [18/5000], Step [1], Loss: 0.0432
# Epoch [19/5000], Step [1], Loss: 0.0385
# Epoch [20/5000], Step [1], Loss: 0.0354
# Epoch [21/5000], Step [1], Loss: 0.0334
# Epoch [22/5000], Step [1], Loss: 0.0321
# Epoch [23/5000], Step [1], Loss: 0.0311
# Epoch [24/5000], Step [1], Loss: 0.0302
# Epoch [25/5000], Step [1], Loss: 0.0292
# Epoch [26/5000], Step [1], Loss: 0.0279
# Epoch [27/5000], Step [1], Loss: 0.0263
# Epoch [28/5000], Step [1], Loss: 0.0244
# Epoch [29/5000], Step [1], Loss: 0.0224
# Epoch [30/5000], Step [1], Loss: 0.0203
# Epoch [31/5000], Step [1], Loss: 0.0183
# Epoch [32/5000], Step [1], Loss: 0.0165
# Epoch [33/5000], Step [1], Loss: 0.0149
# Epoch [34/5000], Step [1], Loss: 0.0137
# Epoch [35/5000], Step [1], Loss: 0.0127
# Epoch [36/5000], Step [1], Loss: 0.0119
# Epoch [37/5000], Step [1], Loss: 0.0111
# Epoch [38/5000], Step [1], Loss: 0.0104
# Epoch [39/5000], Step [1], Loss: 0.0096
# Epoch [40/5000], Step [1], Loss: 0.0089
# Epoch [41/5000], Step [1], Loss: 0.0083
# Epoch [42/5000], Step [1], Loss: 0.0078
# Epoch [43/5000], Step [1], Loss: 0.0073
# Epoch [44/5000], Step [1], Loss: 0.0069
# Epoch [45/5000], Step [1], Loss: 0.0064
# Epoch [46/5000], Step [1], Loss: 0.0060
# Epoch [47/5000], Step [1], Loss: 0.0057
# Epoch [48/5000], Step [1], Loss: 0.0054
# Epoch [49/5000], Step [1], Loss: 0.0052
# Epoch [50/5000], Step [1], Loss: 0.0051
# Epoch [51/5000], Step [1], Loss: 0.0049
# Epoch [52/5000], Step [1], Loss: 0.0048
# Epoch [53/5000], Step [1], Loss: 0.0046
# Epoch [54/5000], Step [1], Loss: 0.0044
# Epoch [55/5000], Step [1], Loss: 0.0043
# Epoch [56/5000], Step [1], Loss: 0.0041
# Epoch [57/5000], Step [1], Loss: 0.0040
# Epoch [58/5000], Step [1], Loss: 0.0039
# Epoch [59/5000], Step [1], Loss: 0.0038
# Epoch [60/5000], Step [1], Loss: 0.0037
# Epoch [61/5000], Step [1], Loss: 0.0037
# Epoch [62/5000], Step [1], Loss: 0.0036
# Epoch [63/5000], Step [1], Loss: 0.0035
# Epoch [64/5000], Step [1], Loss: 0.0034
# Epoch [65/5000], Step [1], Loss: 0.0033
# Epoch [66/5000], Step [1], Loss: 0.0032
# Epoch [67/5000], Step [1], Loss: 0.0031
# Epoch [68/5000], Step [1], Loss: 0.0030
# Epoch [69/5000], Step [1], Loss: 0.0029
# Epoch [70/5000], Step [1], Loss: 0.0029
# Epoch [71/5000], Step [1], Loss: 0.0028
# Epoch [72/5000], Step [1], Loss: 0.0028
# Epoch [73/5000], Step [1], Loss: 0.0027
# Epoch [74/5000], Step [1], Loss: 0.0027
# Epoch [75/5000], Step [1], Loss: 0.0026
# Epoch [76/5000], Step [1], Loss: 0.0026
# Epoch [77/5000], Step [1], Loss: 0.0025
# Epoch [78/5000], Step [1], Loss: 0.0025
# Epoch [79/5000], Step [1], Loss: 0.0024
# Epoch [80/5000], Step [1], Loss: 0.0024
# Epoch [81/5000], Step [1], Loss: 0.0023
# Epoch [82/5000], Step [1], Loss: 0.0023
# Epoch [83/5000], Step [1], Loss: 0.0023
# Epoch [84/5000], Step [1], Loss: 0.0022
# Epoch [85/5000], Step [1], Loss: 0.0022
# Epoch [86/5000], Step [1], Loss: 0.0022
# Epoch [87/5000], Step [1], Loss: 0.0021
# Epoch [88/5000], Step [1], Loss: 0.0021
# Epoch [89/5000], Step [1], Loss: 0.0021
# Epoch [90/5000], Step [1], Loss: 0.0020
# Epoch [91/5000], Step [1], Loss: 0.0020
# Epoch [92/5000], Step [1], Loss: 0.0020
# Epoch [93/5000], Step [1], Loss: 0.0020
# Epoch [94/5000], Step [1], Loss: 0.0019
# Epoch [95/5000], Step [1], Loss: 0.0019
# Epoch [96/5000], Step [1], Loss: 0.0019
# Epoch [97/5000], Step [1], Loss: 0.0019
# Epoch [98/5000], Step [1], Loss: 0.0018
# Epoch [99/5000], Step [1], Loss: 0.0018
# Epoch [100/5000], Step [1], Loss: 0.0018
# Epoch [101/5000], Step [1], Loss: 0.0018
# Epoch [102/5000], Step [1], Loss: 0.0018
# Epoch [103/5000], Step [1], Loss: 0.0017
# Epoch [104/5000], Step [1], Loss: 0.0017
# Epoch [105/5000], Step [1], Loss: 0.0017
# Epoch [106/5000], Step [1], Loss: 0.0017
# Epoch [107/5000], Step [1], Loss: 0.0017
# Epoch [108/5000], Step [1], Loss: 0.0017
# Epoch [109/5000], Step [1], Loss: 0.0016
# Epoch [110/5000], Step [1], Loss: 0.0016
# Epoch [111/5000], Step [1], Loss: 0.0016
# Epoch [112/5000], Step [1], Loss: 0.0016
# Epoch [113/5000], Step [1], Loss: 0.0016
# Epoch [114/5000], Step [1], Loss: 0.0016
# Epoch [115/5000], Step [1], Loss: 0.0016
# Epoch [116/5000], Step [1], Loss: 0.0016
# Epoch [117/5000], Step [1], Loss: 0.0015
# Epoch [118/5000], Step [1], Loss: 0.0015
# Epoch [119/5000], Step [1], Loss: 0.0015
# Epoch [120/5000], Step [1], Loss: 0.0015
# Epoch [121/5000], Step [1], Loss: 0.0015
# Epoch [122/5000], Step [1], Loss: 0.0015
# Epoch [123/5000], Step [1], Loss: 0.0015
# Epoch [124/5000], Step [1], Loss: 0.0015
# Epoch [125/5000], Step [1], Loss: 0.0015
# Epoch [126/5000], Step [1], Loss: 0.0014
# Epoch [127/5000], Step [1], Loss: 0.0014
# Epoch [128/5000], Step [1], Loss: 0.0014
# Epoch [129/5000], Step [1], Loss: 0.0014
# Epoch [130/5000], Step [1], Loss: 0.0014
# Epoch [131/5000], Step [1], Loss: 0.0014
# Epoch [132/5000], Step [1], Loss: 0.0014
# Epoch [133/5000], Step [1], Loss: 0.0014
# Epoch [134/5000], Step [1], Loss: 0.0014
# Epoch [135/5000], Step [1], Loss: 0.0014
# Epoch [136/5000], Step [1], Loss: 0.0014
# Epoch [137/5000], Step [1], Loss: 0.0013
# Epoch [138/5000], Step [1], Loss: 0.0013
# Epoch [139/5000], Step [1], Loss: 0.0013
# Epoch [140/5000], Step [1], Loss: 0.0013
# Epoch [141/5000], Step [1], Loss: 0.0013
# Epoch [142/5000], Step [1], Loss: 0.0013
# Epoch [143/5000], Step [1], Loss: 0.0013
# Epoch [144/5000], Step [1], Loss: 0.0013
# Epoch [145/5000], Step [1], Loss: 0.0013
# Epoch [146/5000], Step [1], Loss: 0.0013
# Epoch [147/5000], Step [1], Loss: 0.0013
# Epoch [148/5000], Step [1], Loss: 0.0013
# Epoch [149/5000], Step [1], Loss: 0.0013
# Epoch [150/5000], Step [1], Loss: 0.0013
# Epoch [151/5000], Step [1], Loss: 0.0012
# Epoch [152/5000], Step [1], Loss: 0.0012
# Epoch [153/5000], Step [1], Loss: 0.0012
# Epoch [154/5000], Step [1], Loss: 0.0012
# Epoch [155/5000], Step [1], Loss: 0.0012
# Epoch [156/5000], Step [1], Loss: 0.0012
# Epoch [157/5000], Step [1], Loss: 0.0012
# Epoch [158/5000], Step [1], Loss: 0.0012
# Epoch [159/5000], Step [1], Loss: 0.0012
# Epoch [160/5000], Step [1], Loss: 0.0012
# Epoch [161/5000], Step [1], Loss: 0.0012
# Epoch [162/5000], Step [1], Loss: 0.0012
# Epoch [163/5000], Step [1], Loss: 0.0012
# Epoch [164/5000], Step [1], Loss: 0.0012
# Epoch [165/5000], Step [1], Loss: 0.0012
# Epoch [166/5000], Step [1], Loss: 0.0012
# Epoch [167/5000], Step [1], Loss: 0.0012
# Epoch [168/5000], Step [1], Loss: 0.0012
# Epoch [169/5000], Step [1], Loss: 0.0011
# Epoch [170/5000], Step [1], Loss: 0.0011
# Epoch [171/5000], Step [1], Loss: 0.0011
# Epoch [172/5000], Step [1], Loss: 0.0011
# Epoch [173/5000], Step [1], Loss: 0.0011
# Epoch [174/5000], Step [1], Loss: 0.0011
# Epoch [175/5000], Step [1], Loss: 0.0011
# Epoch [176/5000], Step [1], Loss: 0.0011
# Epoch [177/5000], Step [1], Loss: 0.0011
# Epoch [178/5000], Step [1], Loss: 0.0011
# Epoch [179/5000], Step [1], Loss: 0.0011
# Epoch [180/5000], Step [1], Loss: 0.0011
# Epoch [181/5000], Step [1], Loss: 0.0011
# Epoch [182/5000], Step [1], Loss: 0.0011
# Epoch [183/5000], Step [1], Loss: 0.0011
# Epoch [184/5000], Step [1], Loss: 0.0011
# Epoch [185/5000], Step [1], Loss: 0.0011
# Epoch [186/5000], Step [1], Loss: 0.0011
# Epoch [187/5000], Step [1], Loss: 0.0011
# Epoch [188/5000], Step [1], Loss: 0.0011
# Epoch [189/5000], Step [1], Loss: 0.0011
# Epoch [190/5000], Step [1], Loss: 0.0011
# Epoch [191/5000], Step [1], Loss: 0.0011
# Epoch [192/5000], Step [1], Loss: 0.0011
# Epoch [193/5000], Step [1], Loss: 0.0011
# Epoch [194/5000], Step [1], Loss: 0.0011
# Epoch [195/5000], Step [1], Loss: 0.0010
# Epoch [196/5000], Step [1], Loss: 0.0010
# Epoch [197/5000], Step [1], Loss: 0.0010
# Epoch [198/5000], Step [1], Loss: 0.0010
# Epoch [199/5000], Step [1], Loss: 0.0010
# Epoch [200/5000], Step [1], Loss: 0.0010
# Epoch [201/5000], Step [1], Loss: 0.0010
# Epoch [202/5000], Step [1], Loss: 0.0010
# Epoch [203/5000], Step [1], Loss: 0.0010
# Epoch [204/5000], Step [1], Loss: 0.0010
# Epoch [205/5000], Step [1], Loss: 0.0010
# Epoch [206/5000], Step [1], Loss: 0.0010
# Epoch [207/5000], Step [1], Loss: 0.0010
# Epoch [208/5000], Step [1], Loss: 0.0010
# Epoch [209/5000], Step [1], Loss: 0.0010
# Epoch [210/5000], Step [1], Loss: 0.0010
# Epoch [211/5000], Step [1], Loss: 0.0010
# Epoch [212/5000], Step [1], Loss: 0.0010
# Epoch [213/5000], Step [1], Loss: 0.0010
# Epoch [214/5000], Step [1], Loss: 0.0010
# Epoch [215/5000], Step [1], Loss: 0.0010
# Epoch [216/5000], Step [1], Loss: 0.0010
# Epoch [217/5000], Step [1], Loss: 0.0010
# Epoch [218/5000], Step [1], Loss: 0.0010
# Epoch [219/5000], Step [1], Loss: 0.0010
# Epoch [220/5000], Step [1], Loss: 0.0010
# Epoch [221/5000], Step [1], Loss: 0.0010
# Epoch [222/5000], Step [1], Loss: 0.0010
# Epoch [223/5000], Step [1], Loss: 0.0010
# Epoch [224/5000], Step [1], Loss: 0.0010
# Epoch [225/5000], Step [1], Loss: 0.0010
# Epoch [226/5000], Step [1], Loss: 0.0010
# Epoch [227/5000], Step [1], Loss: 0.0010
# Epoch [228/5000], Step [1], Loss: 0.0010
# Epoch [229/5000], Step [1], Loss: 0.0010
# Epoch [230/5000], Step [1], Loss: 0.0010
# Epoch [231/5000], Step [1], Loss: 0.0010
# Epoch [232/5000], Step [1], Loss: 0.0010
# Epoch [233/5000], Step [1], Loss: 0.0010
# Epoch [234/5000], Step [1], Loss: 0.0010
# Epoch [235/5000], Step [1], Loss: 0.0009
# Epoch [236/5000], Step [1], Loss: 0.0009
# Epoch [237/5000], Step [1], Loss: 0.0009
# Epoch [238/5000], Step [1], Loss: 0.0009
# Epoch [239/5000], Step [1], Loss: 0.0009
# Epoch [240/5000], Step [1], Loss: 0.0009
# Epoch [241/5000], Step [1], Loss: 0.0009
# Epoch [242/5000], Step [1], Loss: 0.0009
# Epoch [243/5000], Step [1], Loss: 0.0009
# Epoch [244/5000], Step [1], Loss: 0.0009
# Epoch [245/5000], Step [1], Loss: 0.0009
# Epoch [246/5000], Step [1], Loss: 0.0009
# Epoch [247/5000], Step [1], Loss: 0.0009
# Epoch [248/5000], Step [1], Loss: 0.0009
# Epoch [249/5000], Step [1], Loss: 0.0009
# Epoch [250/5000], Step [1], Loss: 0.0009
# Epoch [251/5000], Step [1], Loss: 0.0009
# Epoch [252/5000], Step [1], Loss: 0.0009
# Epoch [253/5000], Step [1], Loss: 0.0009
# Epoch [254/5000], Step [1], Loss: 0.0009
# Epoch [255/5000], Step [1], Loss: 0.0009
# Epoch [256/5000], Step [1], Loss: 0.0009
# Epoch [257/5000], Step [1], Loss: 0.0009
# Epoch [258/5000], Step [1], Loss: 0.0009
# Epoch [259/5000], Step [1], Loss: 0.0009
# Epoch [260/5000], Step [1], Loss: 0.0009
# Epoch [261/5000], Step [1], Loss: 0.0009
# Epoch [262/5000], Step [1], Loss: 0.0009
# Epoch [263/5000], Step [1], Loss: 0.0009
# Epoch [264/5000], Step [1], Loss: 0.0009
# Epoch [265/5000], Step [1], Loss: 0.0009
# Epoch [266/5000], Step [1], Loss: 0.0009
# Epoch [267/5000], Step [1], Loss: 0.0009
# Epoch [268/5000], Step [1], Loss: 0.0009
# Epoch [269/5000], Step [1], Loss: 0.0009
# Epoch [270/5000], Step [1], Loss: 0.0009
# Epoch [271/5000], Step [1], Loss: 0.0009
# Epoch [272/5000], Step [1], Loss: 0.0009
# Epoch [273/5000], Step [1], Loss: 0.0009
# Epoch [274/5000], Step [1], Loss: 0.0009
# Epoch [275/5000], Step [1], Loss: 0.0009
# Epoch [276/5000], Step [1], Loss: 0.0009
# Epoch [277/5000], Step [1], Loss: 0.0009
# Epoch [278/5000], Step [1], Loss: 0.0009
# Epoch [279/5000], Step [1], Loss: 0.0009
# Epoch [280/5000], Step [1], Loss: 0.0009
# Epoch [281/5000], Step [1], Loss: 0.0009
# Epoch [282/5000], Step [1], Loss: 0.0009
# Epoch [283/5000], Step [1], Loss: 0.0009
# Epoch [284/5000], Step [1], Loss: 0.0009
# Epoch [285/5000], Step [1], Loss: 0.0009
# Epoch [286/5000], Step [1], Loss: 0.0009
# Epoch [287/5000], Step [1], Loss: 0.0009
# Epoch [288/5000], Step [1], Loss: 0.0009
# Epoch [289/5000], Step [1], Loss: 0.0009
# Epoch [290/5000], Step [1], Loss: 0.0009
# Epoch [291/5000], Step [1], Loss: 0.0009
# Epoch [292/5000], Step [1], Loss: 0.0009
# Epoch [293/5000], Step [1], Loss: 0.0009
# Epoch [294/5000], Step [1], Loss: 0.0009
# Epoch [295/5000], Step [1], Loss: 0.0009
# Epoch [296/5000], Step [1], Loss: 0.0009
# Epoch [297/5000], Step [1], Loss: 0.0009
# Epoch [298/5000], Step [1], Loss: 0.0009
# Epoch [299/5000], Step [1], Loss: 0.0009
# Epoch [300/5000], Step [1], Loss: 0.0009
# Epoch [301/5000], Step [1], Loss: 0.0009
# Epoch [302/5000], Step [1], Loss: 0.0009
# Epoch [303/5000], Step [1], Loss: 0.0008
# Epoch [304/5000], Step [1], Loss: 0.0008
# Epoch [305/5000], Step [1], Loss: 0.0008
# Epoch [306/5000], Step [1], Loss: 0.0008
# Epoch [307/5000], Step [1], Loss: 0.0008
# Epoch [308/5000], Step [1], Loss: 0.0008
# Epoch [309/5000], Step [1], Loss: 0.0008
# Epoch [310/5000], Step [1], Loss: 0.0008
# Epoch [311/5000], Step [1], Loss: 0.0008
# Epoch [312/5000], Step [1], Loss: 0.0008
# Epoch [313/5000], Step [1], Loss: 0.0008
# Epoch [314/5000], Step [1], Loss: 0.0008
# Epoch [315/5000], Step [1], Loss: 0.0008
# Epoch [316/5000], Step [1], Loss: 0.0008
# Epoch [317/5000], Step [1], Loss: 0.0008
# Epoch [318/5000], Step [1], Loss: 0.0008
# Epoch [319/5000], Step [1], Loss: 0.0008
# Epoch [320/5000], Step [1], Loss: 0.0008
# Epoch [321/5000], Step [1], Loss: 0.0008
# Epoch [322/5000], Step [1], Loss: 0.0008
# Epoch [323/5000], Step [1], Loss: 0.0008
# Epoch [324/5000], Step [1], Loss: 0.0008
# Epoch [325/5000], Step [1], Loss: 0.0008
# Epoch [326/5000], Step [1], Loss: 0.0008
# Epoch [327/5000], Step [1], Loss: 0.0008
# Epoch [328/5000], Step [1], Loss: 0.0008
# Epoch [329/5000], Step [1], Loss: 0.0008
# Epoch [330/5000], Step [1], Loss: 0.0008
# Epoch [331/5000], Step [1], Loss: 0.0008
# Epoch [332/5000], Step [1], Loss: 0.0008
# Epoch [333/5000], Step [1], Loss: 0.0008
# Epoch [334/5000], Step [1], Loss: 0.0008
# Epoch [335/5000], Step [1], Loss: 0.0008
# Epoch [336/5000], Step [1], Loss: 0.0008
# Epoch [337/5000], Step [1], Loss: 0.0008
# Epoch [338/5000], Step [1], Loss: 0.0008
# Epoch [339/5000], Step [1], Loss: 0.0008
# Epoch [340/5000], Step [1], Loss: 0.0008
# Epoch [341/5000], Step [1], Loss: 0.0008
# Epoch [342/5000], Step [1], Loss: 0.0008
# Epoch [343/5000], Step [1], Loss: 0.0008
# Epoch [344/5000], Step [1], Loss: 0.0008
# Epoch [345/5000], Step [1], Loss: 0.0008
# Epoch [346/5000], Step [1], Loss: 0.0008
# Epoch [347/5000], Step [1], Loss: 0.0008
# Epoch [348/5000], Step [1], Loss: 0.0008
# Epoch [349/5000], Step [1], Loss: 0.0008
# Epoch [350/5000], Step [1], Loss: 0.0008
# Epoch [351/5000], Step [1], Loss: 0.0008
# Epoch [352/5000], Step [1], Loss: 0.0008
# Epoch [353/5000], Step [1], Loss: 0.0008
# Epoch [354/5000], Step [1], Loss: 0.0008
# Epoch [355/5000], Step [1], Loss: 0.0008
# Epoch [356/5000], Step [1], Loss: 0.0008
# Epoch [357/5000], Step [1], Loss: 0.0008
# Epoch [358/5000], Step [1], Loss: 0.0008
# Epoch [359/5000], Step [1], Loss: 0.0008
# Epoch [360/5000], Step [1], Loss: 0.0008
# Epoch [361/5000], Step [1], Loss: 0.0008
# Epoch [362/5000], Step [1], Loss: 0.0008
# Epoch [363/5000], Step [1], Loss: 0.0008
# Epoch [364/5000], Step [1], Loss: 0.0008
# Epoch [365/5000], Step [1], Loss: 0.0008
# Epoch [366/5000], Step [1], Loss: 0.0008
# Epoch [367/5000], Step [1], Loss: 0.0008
# Epoch [368/5000], Step [1], Loss: 0.0008
# Epoch [369/5000], Step [1], Loss: 0.0008
# Epoch [370/5000], Step [1], Loss: 0.0008
# Epoch [371/5000], Step [1], Loss: 0.0008
# Epoch [372/5000], Step [1], Loss: 0.0008
# Epoch [373/5000], Step [1], Loss: 0.0008
# Epoch [374/5000], Step [1], Loss: 0.0008
# Epoch [375/5000], Step [1], Loss: 0.0008
# Epoch [376/5000], Step [1], Loss: 0.0008
# Epoch [377/5000], Step [1], Loss: 0.0008
# Epoch [378/5000], Step [1], Loss: 0.0008
# Epoch [379/5000], Step [1], Loss: 0.0008
# Epoch [380/5000], Step [1], Loss: 0.0008
# Epoch [381/5000], Step [1], Loss: 0.0008
# Epoch [382/5000], Step [1], Loss: 0.0008
# Epoch [383/5000], Step [1], Loss: 0.0008
# Epoch [384/5000], Step [1], Loss: 0.0008
# Epoch [385/5000], Step [1], Loss: 0.0008
# Epoch [386/5000], Step [1], Loss: 0.0008
# Epoch [387/5000], Step [1], Loss: 0.0008
# Epoch [388/5000], Step [1], Loss: 0.0008
# Epoch [389/5000], Step [1], Loss: 0.0008
# Epoch [390/5000], Step [1], Loss: 0.0008
# Epoch [391/5000], Step [1], Loss: 0.0008
# Epoch [392/5000], Step [1], Loss: 0.0008
# Epoch [393/5000], Step [1], Loss: 0.0008
# Epoch [394/5000], Step [1], Loss: 0.0008
# Epoch [395/5000], Step [1], Loss: 0.0008
# Epoch [396/5000], Step [1], Loss: 0.0008
# Epoch [397/5000], Step [1], Loss: 0.0008
# Epoch [398/5000], Step [1], Loss: 0.0008
# Epoch [399/5000], Step [1], Loss: 0.0008
# Epoch [400/5000], Step [1], Loss: 0.0008
# Epoch [401/5000], Step [1], Loss: 0.0008
# Epoch [402/5000], Step [1], Loss: 0.0008
# Epoch [403/5000], Step [1], Loss: 0.0008
# Epoch [404/5000], Step [1], Loss: 0.0008
# Epoch [405/5000], Step [1], Loss: 0.0008
# Epoch [406/5000], Step [1], Loss: 0.0008
# Epoch [407/5000], Step [1], Loss: 0.0008
# Epoch [408/5000], Step [1], Loss: 0.0008
# Epoch [409/5000], Step [1], Loss: 0.0008
# Epoch [410/5000], Step [1], Loss: 0.0008
# Epoch [411/5000], Step [1], Loss: 0.0008
# Epoch [412/5000], Step [1], Loss: 0.0008
# Epoch [413/5000], Step [1], Loss: 0.0008
# Epoch [414/5000], Step [1], Loss: 0.0008
# Epoch [415/5000], Step [1], Loss: 0.0008
# Epoch [416/5000], Step [1], Loss: 0.0008
# Epoch [417/5000], Step [1], Loss: 0.0007
# Epoch [418/5000], Step [1], Loss: 0.0007
# Epoch [419/5000], Step [1], Loss: 0.0007
# Epoch [420/5000], Step [1], Loss: 0.0007
# Epoch [421/5000], Step [1], Loss: 0.0007
# Epoch [422/5000], Step [1], Loss: 0.0007
# Epoch [423/5000], Step [1], Loss: 0.0007
# Epoch [424/5000], Step [1], Loss: 0.0007
# Epoch [425/5000], Step [1], Loss: 0.0007
# Epoch [426/5000], Step [1], Loss: 0.0007
# Epoch [427/5000], Step [1], Loss: 0.0007
# Epoch [428/5000], Step [1], Loss: 0.0007
# Epoch [429/5000], Step [1], Loss: 0.0007
# Epoch [430/5000], Step [1], Loss: 0.0007
# Epoch [431/5000], Step [1], Loss: 0.0007
# Epoch [432/5000], Step [1], Loss: 0.0007
# Epoch [433/5000], Step [1], Loss: 0.0007
# Epoch [434/5000], Step [1], Loss: 0.0007
# Epoch [435/5000], Step [1], Loss: 0.0007
# Epoch [436/5000], Step [1], Loss: 0.0007
# Epoch [437/5000], Step [1], Loss: 0.0007
# Epoch [438/5000], Step [1], Loss: 0.0007
# Epoch [439/5000], Step [1], Loss: 0.0007
# Epoch [440/5000], Step [1], Loss: 0.0007
# Epoch [441/5000], Step [1], Loss: 0.0007
# Epoch [442/5000], Step [1], Loss: 0.0007
# Epoch [443/5000], Step [1], Loss: 0.0007
# Epoch [444/5000], Step [1], Loss: 0.0007
# Epoch [445/5000], Step [1], Loss: 0.0007
# Epoch [446/5000], Step [1], Loss: 0.0007
# Epoch [447/5000], Step [1], Loss: 0.0007
# Epoch [448/5000], Step [1], Loss: 0.0007
# Epoch [449/5000], Step [1], Loss: 0.0007
# Epoch [450/5000], Step [1], Loss: 0.0007
# Epoch [451/5000], Step [1], Loss: 0.0007
# Epoch [452/5000], Step [1], Loss: 0.0007
# Epoch [453/5000], Step [1], Loss: 0.0007
# Epoch [454/5000], Step [1], Loss: 0.0007
# Epoch [455/5000], Step [1], Loss: 0.0007
# Epoch [456/5000], Step [1], Loss: 0.0007
# Epoch [457/5000], Step [1], Loss: 0.0007
# Epoch [458/5000], Step [1], Loss: 0.0007
# Epoch [459/5000], Step [1], Loss: 0.0007
# Epoch [460/5000], Step [1], Loss: 0.0007
# Epoch [461/5000], Step [1], Loss: 0.0007
# Epoch [462/5000], Step [1], Loss: 0.0007
# Epoch [463/5000], Step [1], Loss: 0.0007
# Epoch [464/5000], Step [1], Loss: 0.0007
# Epoch [465/5000], Step [1], Loss: 0.0007
# Epoch [466/5000], Step [1], Loss: 0.0007
# Epoch [467/5000], Step [1], Loss: 0.0007
# Epoch [468/5000], Step [1], Loss: 0.0007
# Epoch [469/5000], Step [1], Loss: 0.0007
# Epoch [470/5000], Step [1], Loss: 0.0007
# Epoch [471/5000], Step [1], Loss: 0.0007
# Epoch [472/5000], Step [1], Loss: 0.0007
# Epoch [473/5000], Step [1], Loss: 0.0007
# Epoch [474/5000], Step [1], Loss: 0.0007
# Epoch [475/5000], Step [1], Loss: 0.0007
# Epoch [476/5000], Step [1], Loss: 0.0007
# Epoch [477/5000], Step [1], Loss: 0.0007
# Epoch [478/5000], Step [1], Loss: 0.0007
# Epoch [479/5000], Step [1], Loss: 0.0007
# Epoch [480/5000], Step [1], Loss: 0.0007
# Epoch [481/5000], Step [1], Loss: 0.0007
# Epoch [482/5000], Step [1], Loss: 0.0007
# Epoch [483/5000], Step [1], Loss: 0.0007
# Epoch [484/5000], Step [1], Loss: 0.0007
# Epoch [485/5000], Step [1], Loss: 0.0007
# Epoch [486/5000], Step [1], Loss: 0.0007
# Epoch [487/5000], Step [1], Loss: 0.0007
# Epoch [488/5000], Step [1], Loss: 0.0007
# Epoch [489/5000], Step [1], Loss: 0.0007
# Epoch [490/5000], Step [1], Loss: 0.0007
# Epoch [491/5000], Step [1], Loss: 0.0007
# Epoch [492/5000], Step [1], Loss: 0.0007
# Epoch [493/5000], Step [1], Loss: 0.0007
# Epoch [494/5000], Step [1], Loss: 0.0007
# Epoch [495/5000], Step [1], Loss: 0.0007
# Epoch [496/5000], Step [1], Loss: 0.0007
# Epoch [497/5000], Step [1], Loss: 0.0007
# Epoch [498/5000], Step [1], Loss: 0.0007
# Epoch [499/5000], Step [1], Loss: 0.0007
# Epoch [500/5000], Step [1], Loss: 0.0007
# Epoch [501/5000], Step [1], Loss: 0.0007
# Epoch [502/5000], Step [1], Loss: 0.0007
# Epoch [503/5000], Step [1], Loss: 0.0007
# Epoch [504/5000], Step [1], Loss: 0.0007
# Epoch [505/5000], Step [1], Loss: 0.0007
# Epoch [506/5000], Step [1], Loss: 0.0007
# Epoch [507/5000], Step [1], Loss: 0.0007
# Epoch [508/5000], Step [1], Loss: 0.0007
# Epoch [509/5000], Step [1], Loss: 0.0007
# Epoch [510/5000], Step [1], Loss: 0.0007
# Epoch [511/5000], Step [1], Loss: 0.0007
# Epoch [512/5000], Step [1], Loss: 0.0007
# Epoch [513/5000], Step [1], Loss: 0.0007
# Epoch [514/5000], Step [1], Loss: 0.0007
# Epoch [515/5000], Step [1], Loss: 0.0007
# Epoch [516/5000], Step [1], Loss: 0.0007
# Epoch [517/5000], Step [1], Loss: 0.0007
# Epoch [518/5000], Step [1], Loss: 0.0007
# Epoch [519/5000], Step [1], Loss: 0.0007
# Epoch [520/5000], Step [1], Loss: 0.0007
# Epoch [521/5000], Step [1], Loss: 0.0007
# Epoch [522/5000], Step [1], Loss: 0.0007
# Epoch [523/5000], Step [1], Loss: 0.0007
# Epoch [524/5000], Step [1], Loss: 0.0007
# Epoch [525/5000], Step [1], Loss: 0.0007
# Epoch [526/5000], Step [1], Loss: 0.0007
# Epoch [527/5000], Step [1], Loss: 0.0007
# Epoch [528/5000], Step [1], Loss: 0.0007
# Epoch [529/5000], Step [1], Loss: 0.0007
# Epoch [530/5000], Step [1], Loss: 0.0007
# Epoch [531/5000], Step [1], Loss: 0.0007
# Epoch [532/5000], Step [1], Loss: 0.0007
# Epoch [533/5000], Step [1], Loss: 0.0007
# Epoch [534/5000], Step [1], Loss: 0.0007
# Epoch [535/5000], Step [1], Loss: 0.0007
# Epoch [536/5000], Step [1], Loss: 0.0007
# Epoch [537/5000], Step [1], Loss: 0.0007
# Epoch [538/5000], Step [1], Loss: 0.0007
# Epoch [539/5000], Step [1], Loss: 0.0007
# Epoch [540/5000], Step [1], Loss: 0.0007
# Epoch [541/5000], Step [1], Loss: 0.0007
# Epoch [542/5000], Step [1], Loss: 0.0007
# Epoch [543/5000], Step [1], Loss: 0.0007
# Epoch [544/5000], Step [1], Loss: 0.0007
# Epoch [545/5000], Step [1], Loss: 0.0007
# Epoch [546/5000], Step [1], Loss: 0.0007
# Epoch [547/5000], Step [1], Loss: 0.0007
# Epoch [548/5000], Step [1], Loss: 0.0007
# Epoch [549/5000], Step [1], Loss: 0.0007
# Epoch [550/5000], Step [1], Loss: 0.0007
# Epoch [551/5000], Step [1], Loss: 0.0007
# Epoch [552/5000], Step [1], Loss: 0.0007
# Epoch [553/5000], Step [1], Loss: 0.0007
# Epoch [554/5000], Step [1], Loss: 0.0007
# Epoch [555/5000], Step [1], Loss: 0.0007
# Epoch [556/5000], Step [1], Loss: 0.0006
# Epoch [557/5000], Step [1], Loss: 0.0006
# Epoch [558/5000], Step [1], Loss: 0.0006
# Epoch [559/5000], Step [1], Loss: 0.0006
# Epoch [560/5000], Step [1], Loss: 0.0006
# Epoch [561/5000], Step [1], Loss: 0.0006
# Epoch [562/5000], Step [1], Loss: 0.0006
# Epoch [563/5000], Step [1], Loss: 0.0006
# Epoch [564/5000], Step [1], Loss: 0.0006
# Epoch [565/5000], Step [1], Loss: 0.0006
# Epoch [566/5000], Step [1], Loss: 0.0006
# Epoch [567/5000], Step [1], Loss: 0.0006
# Epoch [568/5000], Step [1], Loss: 0.0006
# Epoch [569/5000], Step [1], Loss: 0.0006
# Epoch [570/5000], Step [1], Loss: 0.0006
# Epoch [571/5000], Step [1], Loss: 0.0006
# Epoch [572/5000], Step [1], Loss: 0.0006
# Epoch [573/5000], Step [1], Loss: 0.0006
# Epoch [574/5000], Step [1], Loss: 0.0006
# Epoch [575/5000], Step [1], Loss: 0.0006
# Epoch [576/5000], Step [1], Loss: 0.0006
# Epoch [577/5000], Step [1], Loss: 0.0006
# Epoch [578/5000], Step [1], Loss: 0.0006
# Epoch [579/5000], Step [1], Loss: 0.0006
# Epoch [580/5000], Step [1], Loss: 0.0006
# Epoch [581/5000], Step [1], Loss: 0.0006
# Epoch [582/5000], Step [1], Loss: 0.0006
# Epoch [583/5000], Step [1], Loss: 0.0006
# Epoch [584/5000], Step [1], Loss: 0.0006
# Epoch [585/5000], Step [1], Loss: 0.0006
# Epoch [586/5000], Step [1], Loss: 0.0006
# Epoch [587/5000], Step [1], Loss: 0.0006
# Epoch [588/5000], Step [1], Loss: 0.0006
# Epoch [589/5000], Step [1], Loss: 0.0006
# Epoch [590/5000], Step [1], Loss: 0.0006
# Epoch [591/5000], Step [1], Loss: 0.0006
# Epoch [592/5000], Step [1], Loss: 0.0006
# Epoch [593/5000], Step [1], Loss: 0.0006
# Epoch [594/5000], Step [1], Loss: 0.0006
# Epoch [595/5000], Step [1], Loss: 0.0006
# Epoch [596/5000], Step [1], Loss: 0.0006
# Epoch [597/5000], Step [1], Loss: 0.0006
# Epoch [598/5000], Step [1], Loss: 0.0006
# Epoch [599/5000], Step [1], Loss: 0.0006
# Epoch [600/5000], Step [1], Loss: 0.0006
# Epoch [601/5000], Step [1], Loss: 0.0006
# Epoch [602/5000], Step [1], Loss: 0.0006
# Epoch [603/5000], Step [1], Loss: 0.0006
# Epoch [604/5000], Step [1], Loss: 0.0006
# Epoch [605/5000], Step [1], Loss: 0.0006
# Epoch [606/5000], Step [1], Loss: 0.0006
# Epoch [607/5000], Step [1], Loss: 0.0006
# Epoch [608/5000], Step [1], Loss: 0.0006
# Epoch [609/5000], Step [1], Loss: 0.0006
# Epoch [610/5000], Step [1], Loss: 0.0006
# Epoch [611/5000], Step [1], Loss: 0.0006
# Epoch [612/5000], Step [1], Loss: 0.0006
# Epoch [613/5000], Step [1], Loss: 0.0006
# Epoch [614/5000], Step [1], Loss: 0.0006
# Epoch [615/5000], Step [1], Loss: 0.0006
# Epoch [616/5000], Step [1], Loss: 0.0006
# Epoch [617/5000], Step [1], Loss: 0.0006
# Epoch [618/5000], Step [1], Loss: 0.0006
# Epoch [619/5000], Step [1], Loss: 0.0006
# Epoch [620/5000], Step [1], Loss: 0.0006
# Epoch [621/5000], Step [1], Loss: 0.0006
# Epoch [622/5000], Step [1], Loss: 0.0006
# Epoch [623/5000], Step [1], Loss: 0.0006
# Epoch [624/5000], Step [1], Loss: 0.0006
# Epoch [625/5000], Step [1], Loss: 0.0006
# Epoch [626/5000], Step [1], Loss: 0.0006
# Epoch [627/5000], Step [1], Loss: 0.0006
# Epoch [628/5000], Step [1], Loss: 0.0006
# Epoch [629/5000], Step [1], Loss: 0.0006
# Epoch [630/5000], Step [1], Loss: 0.0006
# Epoch [631/5000], Step [1], Loss: 0.0006
# Epoch [632/5000], Step [1], Loss: 0.0006
# Epoch [633/5000], Step [1], Loss: 0.0006
# Epoch [634/5000], Step [1], Loss: 0.0006
# Epoch [635/5000], Step [1], Loss: 0.0006
# Epoch [636/5000], Step [1], Loss: 0.0006
# Epoch [637/5000], Step [1], Loss: 0.0006
# Epoch [638/5000], Step [1], Loss: 0.0006
# Epoch [639/5000], Step [1], Loss: 0.0006
# Epoch [640/5000], Step [1], Loss: 0.0006
# Epoch [641/5000], Step [1], Loss: 0.0006
# Epoch [642/5000], Step [1], Loss: 0.0006
# Epoch [643/5000], Step [1], Loss: 0.0006
# Epoch [644/5000], Step [1], Loss: 0.0006
# Epoch [645/5000], Step [1], Loss: 0.0006
# Epoch [646/5000], Step [1], Loss: 0.0006
# Epoch [647/5000], Step [1], Loss: 0.0006
# Epoch [648/5000], Step [1], Loss: 0.0006
# Epoch [649/5000], Step [1], Loss: 0.0006
# Epoch [650/5000], Step [1], Loss: 0.0006
# Epoch [651/5000], Step [1], Loss: 0.0006
# Epoch [652/5000], Step [1], Loss: 0.0006
# Epoch [653/5000], Step [1], Loss: 0.0006
# Epoch [654/5000], Step [1], Loss: 0.0006
# Epoch [655/5000], Step [1], Loss: 0.0006
# Epoch [656/5000], Step [1], Loss: 0.0006
# Epoch [657/5000], Step [1], Loss: 0.0006
# Epoch [658/5000], Step [1], Loss: 0.0006
# Epoch [659/5000], Step [1], Loss: 0.0006
# Epoch [660/5000], Step [1], Loss: 0.0006
# Epoch [661/5000], Step [1], Loss: 0.0006
# Epoch [662/5000], Step [1], Loss: 0.0006
# Epoch [663/5000], Step [1], Loss: 0.0006
# Epoch [664/5000], Step [1], Loss: 0.0006
# Epoch [665/5000], Step [1], Loss: 0.0006
# Epoch [666/5000], Step [1], Loss: 0.0006
# Epoch [667/5000], Step [1], Loss: 0.0006
# Epoch [668/5000], Step [1], Loss: 0.0006
# Epoch [669/5000], Step [1], Loss: 0.0006
# Epoch [670/5000], Step [1], Loss: 0.0006
# Epoch [671/5000], Step [1], Loss: 0.0006
# Epoch [672/5000], Step [1], Loss: 0.0006
# Epoch [673/5000], Step [1], Loss: 0.0006
# Epoch [674/5000], Step [1], Loss: 0.0006
# Epoch [675/5000], Step [1], Loss: 0.0006
# Epoch [676/5000], Step [1], Loss: 0.0006
# Epoch [677/5000], Step [1], Loss: 0.0006
# Epoch [678/5000], Step [1], Loss: 0.0006
# Epoch [679/5000], Step [1], Loss: 0.0006
# Epoch [680/5000], Step [1], Loss: 0.0006
# Epoch [681/5000], Step [1], Loss: 0.0006
# Epoch [682/5000], Step [1], Loss: 0.0006
# Epoch [683/5000], Step [1], Loss: 0.0006
# Epoch [684/5000], Step [1], Loss: 0.0006
# Epoch [685/5000], Step [1], Loss: 0.0006
# Epoch [686/5000], Step [1], Loss: 0.0006
# Epoch [687/5000], Step [1], Loss: 0.0006
# Epoch [688/5000], Step [1], Loss: 0.0006
# Epoch [689/5000], Step [1], Loss: 0.0006
# Epoch [690/5000], Step [1], Loss: 0.0006
# Epoch [691/5000], Step [1], Loss: 0.0006
# Epoch [692/5000], Step [1], Loss: 0.0006
# Epoch [693/5000], Step [1], Loss: 0.0006
# Epoch [694/5000], Step [1], Loss: 0.0006
# Epoch [695/5000], Step [1], Loss: 0.0006
# Epoch [696/5000], Step [1], Loss: 0.0006
# Epoch [697/5000], Step [1], Loss: 0.0006
# Epoch [698/5000], Step [1], Loss: 0.0006
# Epoch [699/5000], Step [1], Loss: 0.0006
# Epoch [700/5000], Step [1], Loss: 0.0006
# Epoch [701/5000], Step [1], Loss: 0.0006
# Epoch [702/5000], Step [1], Loss: 0.0006
# Epoch [703/5000], Step [1], Loss: 0.0006
# Epoch [704/5000], Step [1], Loss: 0.0005
# Epoch [705/5000], Step [1], Loss: 0.0005
# Epoch [706/5000], Step [1], Loss: 0.0005
# Epoch [707/5000], Step [1], Loss: 0.0005
# Epoch [708/5000], Step [1], Loss: 0.0005
# Epoch [709/5000], Step [1], Loss: 0.0005
# Epoch [710/5000], Step [1], Loss: 0.0005
# Epoch [711/5000], Step [1], Loss: 0.0005
# Epoch [712/5000], Step [1], Loss: 0.0005
# Epoch [713/5000], Step [1], Loss: 0.0005
# Epoch [714/5000], Step [1], Loss: 0.0005
# Epoch [715/5000], Step [1], Loss: 0.0005
# Epoch [716/5000], Step [1], Loss: 0.0005
# Epoch [717/5000], Step [1], Loss: 0.0005
# Epoch [718/5000], Step [1], Loss: 0.0005
# Epoch [719/5000], Step [1], Loss: 0.0005
# Epoch [720/5000], Step [1], Loss: 0.0005
# Epoch [721/5000], Step [1], Loss: 0.0005
# Epoch [722/5000], Step [1], Loss: 0.0005
# Epoch [723/5000], Step [1], Loss: 0.0005
# Epoch [724/5000], Step [1], Loss: 0.0005
# Epoch [725/5000], Step [1], Loss: 0.0005
# Epoch [726/5000], Step [1], Loss: 0.0005
# Epoch [727/5000], Step [1], Loss: 0.0005
# Epoch [728/5000], Step [1], Loss: 0.0005
# Epoch [729/5000], Step [1], Loss: 0.0005
# Epoch [730/5000], Step [1], Loss: 0.0005
# Epoch [731/5000], Step [1], Loss: 0.0005
# Epoch [732/5000], Step [1], Loss: 0.0005
# Epoch [733/5000], Step [1], Loss: 0.0005
# Epoch [734/5000], Step [1], Loss: 0.0005
# Epoch [735/5000], Step [1], Loss: 0.0005
# Epoch [736/5000], Step [1], Loss: 0.0005
# Epoch [737/5000], Step [1], Loss: 0.0005
# Epoch [738/5000], Step [1], Loss: 0.0005
# Epoch [739/5000], Step [1], Loss: 0.0005
# Epoch [740/5000], Step [1], Loss: 0.0005
# Epoch [741/5000], Step [1], Loss: 0.0005
# Epoch [742/5000], Step [1], Loss: 0.0005
# Epoch [743/5000], Step [1], Loss: 0.0005
# Epoch [744/5000], Step [1], Loss: 0.0005
# Epoch [745/5000], Step [1], Loss: 0.0005
# Epoch [746/5000], Step [1], Loss: 0.0005
# Epoch [747/5000], Step [1], Loss: 0.0005
# Epoch [748/5000], Step [1], Loss: 0.0005
# Epoch [749/5000], Step [1], Loss: 0.0005
# Epoch [750/5000], Step [1], Loss: 0.0005
# Epoch [751/5000], Step [1], Loss: 0.0005
# Epoch [752/5000], Step [1], Loss: 0.0005
# Epoch [753/5000], Step [1], Loss: 0.0005
# Epoch [754/5000], Step [1], Loss: 0.0005
# Epoch [755/5000], Step [1], Loss: 0.0005
# Epoch [756/5000], Step [1], Loss: 0.0005
# Epoch [757/5000], Step [1], Loss: 0.0005
# Epoch [758/5000], Step [1], Loss: 0.0005
# Epoch [759/5000], Step [1], Loss: 0.0005
# Epoch [760/5000], Step [1], Loss: 0.0005
# Epoch [761/5000], Step [1], Loss: 0.0005
# Epoch [762/5000], Step [1], Loss: 0.0005
# Epoch [763/5000], Step [1], Loss: 0.0005
# Epoch [764/5000], Step [1], Loss: 0.0005
# Epoch [765/5000], Step [1], Loss: 0.0005
# Epoch [766/5000], Step [1], Loss: 0.0005
# Epoch [767/5000], Step [1], Loss: 0.0005
# Epoch [768/5000], Step [1], Loss: 0.0005
# Epoch [769/5000], Step [1], Loss: 0.0005
# Epoch [770/5000], Step [1], Loss: 0.0005
# Epoch [771/5000], Step [1], Loss: 0.0005
# Epoch [772/5000], Step [1], Loss: 0.0005
# Epoch [773/5000], Step [1], Loss: 0.0005
# Epoch [774/5000], Step [1], Loss: 0.0005
# Epoch [775/5000], Step [1], Loss: 0.0005
# Epoch [776/5000], Step [1], Loss: 0.0005
# Epoch [777/5000], Step [1], Loss: 0.0005
# Epoch [778/5000], Step [1], Loss: 0.0005
# Epoch [779/5000], Step [1], Loss: 0.0005
# Epoch [780/5000], Step [1], Loss: 0.0005
# Epoch [781/5000], Step [1], Loss: 0.0005
# Epoch [782/5000], Step [1], Loss: 0.0005
# Epoch [783/5000], Step [1], Loss: 0.0005
# Epoch [784/5000], Step [1], Loss: 0.0005
# Epoch [785/5000], Step [1], Loss: 0.0005
# Epoch [786/5000], Step [1], Loss: 0.0005
# Epoch [787/5000], Step [1], Loss: 0.0005
# Epoch [788/5000], Step [1], Loss: 0.0005
# Epoch [789/5000], Step [1], Loss: 0.0005
# Epoch [790/5000], Step [1], Loss: 0.0005
# Epoch [791/5000], Step [1], Loss: 0.0005
# Epoch [792/5000], Step [1], Loss: 0.0005
# Epoch [793/5000], Step [1], Loss: 0.0005
# Epoch [794/5000], Step [1], Loss: 0.0005
# Epoch [795/5000], Step [1], Loss: 0.0005
# Epoch [796/5000], Step [1], Loss: 0.0005
# Epoch [797/5000], Step [1], Loss: 0.0005
# Epoch [798/5000], Step [1], Loss: 0.0005
# Epoch [799/5000], Step [1], Loss: 0.0005
# Epoch [800/5000], Step [1], Loss: 0.0005
# Epoch [801/5000], Step [1], Loss: 0.0005
# Epoch [802/5000], Step [1], Loss: 0.0005
# Epoch [803/5000], Step [1], Loss: 0.0005
# Epoch [804/5000], Step [1], Loss: 0.0005
# Epoch [805/5000], Step [1], Loss: 0.0005
# Epoch [806/5000], Step [1], Loss: 0.0005
# Epoch [807/5000], Step [1], Loss: 0.0005
# Epoch [808/5000], Step [1], Loss: 0.0005
# Epoch [809/5000], Step [1], Loss: 0.0005
# Epoch [810/5000], Step [1], Loss: 0.0005
# Epoch [811/5000], Step [1], Loss: 0.0005
# Epoch [812/5000], Step [1], Loss: 0.0005
# Epoch [813/5000], Step [1], Loss: 0.0005
# Epoch [814/5000], Step [1], Loss: 0.0005
# Epoch [815/5000], Step [1], Loss: 0.0005
# Epoch [816/5000], Step [1], Loss: 0.0005
# Epoch [817/5000], Step [1], Loss: 0.0005
# Epoch [818/5000], Step [1], Loss: 0.0005
# Epoch [819/5000], Step [1], Loss: 0.0005
# Epoch [820/5000], Step [1], Loss: 0.0005
# Epoch [821/5000], Step [1], Loss: 0.0005
# Epoch [822/5000], Step [1], Loss: 0.0005
# Epoch [823/5000], Step [1], Loss: 0.0005
# Epoch [824/5000], Step [1], Loss: 0.0005
# Epoch [825/5000], Step [1], Loss: 0.0005
# Epoch [826/5000], Step [1], Loss: 0.0005
# Epoch [827/5000], Step [1], Loss: 0.0005
# Epoch [828/5000], Step [1], Loss: 0.0005
# Epoch [829/5000], Step [1], Loss: 0.0005
# Epoch [830/5000], Step [1], Loss: 0.0005
# Epoch [831/5000], Step [1], Loss: 0.0005
# Epoch [832/5000], Step [1], Loss: 0.0005
# Epoch [833/5000], Step [1], Loss: 0.0005
# Epoch [834/5000], Step [1], Loss: 0.0005
# Epoch [835/5000], Step [1], Loss: 0.0005
# Epoch [836/5000], Step [1], Loss: 0.0005
# Epoch [837/5000], Step [1], Loss: 0.0005
# Epoch [838/5000], Step [1], Loss: 0.0005
# Epoch [839/5000], Step [1], Loss: 0.0005
# Epoch [840/5000], Step [1], Loss: 0.0005
# Epoch [841/5000], Step [1], Loss: 0.0005
# Epoch [842/5000], Step [1], Loss: 0.0005
# Epoch [843/5000], Step [1], Loss: 0.0005
# Epoch [844/5000], Step [1], Loss: 0.0005
# Epoch [845/5000], Step [1], Loss: 0.0005
# Epoch [846/5000], Step [1], Loss: 0.0005
# Epoch [847/5000], Step [1], Loss: 0.0005
# Epoch [848/5000], Step [1], Loss: 0.0005
# Epoch [849/5000], Step [1], Loss: 0.0005
# Epoch [850/5000], Step [1], Loss: 0.0005
# Epoch [851/5000], Step [1], Loss: 0.0005
# Epoch [852/5000], Step [1], Loss: 0.0005
# Epoch [853/5000], Step [1], Loss: 0.0005
# Epoch [854/5000], Step [1], Loss: 0.0005
# Epoch [855/5000], Step [1], Loss: 0.0005
# Epoch [856/5000], Step [1], Loss: 0.0005
# Epoch [857/5000], Step [1], Loss: 0.0005
# Epoch [858/5000], Step [1], Loss: 0.0005
# Epoch [859/5000], Step [1], Loss: 0.0005
# Epoch [860/5000], Step [1], Loss: 0.0005
# Epoch [861/5000], Step [1], Loss: 0.0005
# Epoch [862/5000], Step [1], Loss: 0.0005
# Epoch [863/5000], Step [1], Loss: 0.0005
# Epoch [864/5000], Step [1], Loss: 0.0005
# Epoch [865/5000], Step [1], Loss: 0.0005
# Epoch [866/5000], Step [1], Loss: 0.0005
# Epoch [867/5000], Step [1], Loss: 0.0005
# Epoch [868/5000], Step [1], Loss: 0.0005
# Epoch [869/5000], Step [1], Loss: 0.0005
# Epoch [870/5000], Step [1], Loss: 0.0005
# Epoch [871/5000], Step [1], Loss: 0.0005
# Epoch [872/5000], Step [1], Loss: 0.0005
# Epoch [873/5000], Step [1], Loss: 0.0005
# Epoch [874/5000], Step [1], Loss: 0.0005
# Epoch [875/5000], Step [1], Loss: 0.0005
# Epoch [876/5000], Step [1], Loss: 0.0005
# Epoch [877/5000], Step [1], Loss: 0.0005
# Epoch [878/5000], Step [1], Loss: 0.0005
# Epoch [879/5000], Step [1], Loss: 0.0005
# Epoch [880/5000], Step [1], Loss: 0.0005
# Epoch [881/5000], Step [1], Loss: 0.0004
# Epoch [882/5000], Step [1], Loss: 0.0004
# Epoch [883/5000], Step [1], Loss: 0.0004
# Epoch [884/5000], Step [1], Loss: 0.0005
# Epoch [885/5000], Step [1], Loss: 0.0005
# Epoch [886/5000], Step [1], Loss: 0.0005
# Epoch [887/5000], Step [1], Loss: 0.0005
# Epoch [888/5000], Step [1], Loss: 0.0005
# Epoch [889/5000], Step [1], Loss: 0.0006
# Epoch [890/5000], Step [1], Loss: 0.0008
# Epoch [891/5000], Step [1], Loss: 0.0010
# Epoch [892/5000], Step [1], Loss: 0.0013
# Epoch [893/5000], Step [1], Loss: 0.0011
# Epoch [894/5000], Step [1], Loss: 0.0006
# Epoch [895/5000], Step [1], Loss: 0.0005
# Epoch [896/5000], Step [1], Loss: 0.0008
# Epoch [897/5000], Step [1], Loss: 0.0006
# Epoch [898/5000], Step [1], Loss: 0.0005
# Epoch [899/5000], Step [1], Loss: 0.0006
# Epoch [900/5000], Step [1], Loss: 0.0006
# Epoch [901/5000], Step [1], Loss: 0.0005
# Epoch [902/5000], Step [1], Loss: 0.0006
# Epoch [903/5000], Step [1], Loss: 0.0005
# Epoch [904/5000], Step [1], Loss: 0.0005
# Epoch [905/5000], Step [1], Loss: 0.0005
# Epoch [906/5000], Step [1], Loss: 0.0005
# Epoch [907/5000], Step [1], Loss: 0.0005
# Epoch [908/5000], Step [1], Loss: 0.0005
# Epoch [909/5000], Step [1], Loss: 0.0005
# Epoch [910/5000], Step [1], Loss: 0.0005
# Epoch [911/5000], Step [1], Loss: 0.0005
# Epoch [912/5000], Step [1], Loss: 0.0005
# Epoch [913/5000], Step [1], Loss: 0.0005
# Epoch [914/5000], Step [1], Loss: 0.0005
# Epoch [915/5000], Step [1], Loss: 0.0005
# Epoch [916/5000], Step [1], Loss: 0.0005
# Epoch [917/5000], Step [1], Loss: 0.0005
# Epoch [918/5000], Step [1], Loss: 0.0004
# Epoch [919/5000], Step [1], Loss: 0.0005
# Epoch [920/5000], Step [1], Loss: 0.0004
# Epoch [921/5000], Step [1], Loss: 0.0005
# Epoch [922/5000], Step [1], Loss: 0.0004
# Epoch [923/5000], Step [1], Loss: 0.0004
# Epoch [924/5000], Step [1], Loss: 0.0004
# Epoch [925/5000], Step [1], Loss: 0.0004
# Epoch [926/5000], Step [1], Loss: 0.0004
# Epoch [927/5000], Step [1], Loss: 0.0004
# Epoch [928/5000], Step [1], Loss: 0.0004
# Epoch [929/5000], Step [1], Loss: 0.0004
# Epoch [930/5000], Step [1], Loss: 0.0004
# Epoch [931/5000], Step [1], Loss: 0.0004
# Epoch [932/5000], Step [1], Loss: 0.0004
# Epoch [933/5000], Step [1], Loss: 0.0004
# Epoch [934/5000], Step [1], Loss: 0.0004
# Epoch [935/5000], Step [1], Loss: 0.0004
# Epoch [936/5000], Step [1], Loss: 0.0004
# Epoch [937/5000], Step [1], Loss: 0.0004
# Epoch [938/5000], Step [1], Loss: 0.0004
# Epoch [939/5000], Step [1], Loss: 0.0004
# Epoch [940/5000], Step [1], Loss: 0.0004
# Epoch [941/5000], Step [1], Loss: 0.0004
# Epoch [942/5000], Step [1], Loss: 0.0004
# Epoch [943/5000], Step [1], Loss: 0.0004
# Epoch [944/5000], Step [1], Loss: 0.0004
# Epoch [945/5000], Step [1], Loss: 0.0004
# Epoch [946/5000], Step [1], Loss: 0.0004
# Epoch [947/5000], Step [1], Loss: 0.0004
# Epoch [948/5000], Step [1], Loss: 0.0004
# Epoch [949/5000], Step [1], Loss: 0.0004
# Epoch [950/5000], Step [1], Loss: 0.0004
# Epoch [951/5000], Step [1], Loss: 0.0004
# Epoch [952/5000], Step [1], Loss: 0.0004
# Epoch [953/5000], Step [1], Loss: 0.0004
# Epoch [954/5000], Step [1], Loss: 0.0004
# Epoch [955/5000], Step [1], Loss: 0.0004
# Epoch [956/5000], Step [1], Loss: 0.0004
# Epoch [957/5000], Step [1], Loss: 0.0004
# Epoch [958/5000], Step [1], Loss: 0.0004
# Epoch [959/5000], Step [1], Loss: 0.0004
# Epoch [960/5000], Step [1], Loss: 0.0004
# Epoch [961/5000], Step [1], Loss: 0.0004
# Epoch [962/5000], Step [1], Loss: 0.0004
# Epoch [963/5000], Step [1], Loss: 0.0004
# Epoch [964/5000], Step [1], Loss: 0.0004
# Epoch [965/5000], Step [1], Loss: 0.0004
# Epoch [966/5000], Step [1], Loss: 0.0004
# Epoch [967/5000], Step [1], Loss: 0.0004
# Epoch [968/5000], Step [1], Loss: 0.0004
# Epoch [969/5000], Step [1], Loss: 0.0004
# Epoch [970/5000], Step [1], Loss: 0.0004
# Epoch [971/5000], Step [1], Loss: 0.0004
# Epoch [972/5000], Step [1], Loss: 0.0004
# Epoch [973/5000], Step [1], Loss: 0.0004
# Epoch [974/5000], Step [1], Loss: 0.0004
# Epoch [975/5000], Step [1], Loss: 0.0004
# Epoch [976/5000], Step [1], Loss: 0.0004
# Epoch [977/5000], Step [1], Loss: 0.0004
# Epoch [978/5000], Step [1], Loss: 0.0004
# Epoch [979/5000], Step [1], Loss: 0.0004
# Epoch [980/5000], Step [1], Loss: 0.0004
# Epoch [981/5000], Step [1], Loss: 0.0004
# Epoch [982/5000], Step [1], Loss: 0.0004
# Epoch [983/5000], Step [1], Loss: 0.0004
# Epoch [984/5000], Step [1], Loss: 0.0004
# Epoch [985/5000], Step [1], Loss: 0.0004
# Epoch [986/5000], Step [1], Loss: 0.0004
# Epoch [987/5000], Step [1], Loss: 0.0004
# Epoch [988/5000], Step [1], Loss: 0.0004
# Epoch [989/5000], Step [1], Loss: 0.0004
# Epoch [990/5000], Step [1], Loss: 0.0004
# Epoch [991/5000], Step [1], Loss: 0.0004
# Epoch [992/5000], Step [1], Loss: 0.0004
# Epoch [993/5000], Step [1], Loss: 0.0004
# Epoch [994/5000], Step [1], Loss: 0.0004
# Epoch [995/5000], Step [1], Loss: 0.0004
# Epoch [996/5000], Step [1], Loss: 0.0004
# Epoch [997/5000], Step [1], Loss: 0.0004
# Epoch [998/5000], Step [1], Loss: 0.0004
# Epoch [999/5000], Step [1], Loss: 0.0004
# Epoch [1000/5000], Step [1], Loss: 0.0004
# Epoch [1001/5000], Step [1], Loss: 0.0004
# Epoch [1002/5000], Step [1], Loss: 0.0004
# Epoch [1003/5000], Step [1], Loss: 0.0004
# Epoch [1004/5000], Step [1], Loss: 0.0004
# Epoch [1005/5000], Step [1], Loss: 0.0004
# Epoch [1006/5000], Step [1], Loss: 0.0004
# Epoch [1007/5000], Step [1], Loss: 0.0004
# Epoch [1008/5000], Step [1], Loss: 0.0004
# Epoch [1009/5000], Step [1], Loss: 0.0004
# Epoch [1010/5000], Step [1], Loss: 0.0004
# Epoch [1011/5000], Step [1], Loss: 0.0004
# Epoch [1012/5000], Step [1], Loss: 0.0004
# Epoch [1013/5000], Step [1], Loss: 0.0004
# Epoch [1014/5000], Step [1], Loss: 0.0004
# Epoch [1015/5000], Step [1], Loss: 0.0004
# Epoch [1016/5000], Step [1], Loss: 0.0004
# Epoch [1017/5000], Step [1], Loss: 0.0004
# Epoch [1018/5000], Step [1], Loss: 0.0004
# Epoch [1019/5000], Step [1], Loss: 0.0004
# Epoch [1020/5000], Step [1], Loss: 0.0004
# Epoch [1021/5000], Step [1], Loss: 0.0004
# Epoch [1022/5000], Step [1], Loss: 0.0004
# Epoch [1023/5000], Step [1], Loss: 0.0004
# Epoch [1024/5000], Step [1], Loss: 0.0004
# Epoch [1025/5000], Step [1], Loss: 0.0004
# Epoch [1026/5000], Step [1], Loss: 0.0004
# Epoch [1027/5000], Step [1], Loss: 0.0004
# Epoch [1028/5000], Step [1], Loss: 0.0004
# Epoch [1029/5000], Step [1], Loss: 0.0004
# Epoch [1030/5000], Step [1], Loss: 0.0004
# Epoch [1031/5000], Step [1], Loss: 0.0004
# Epoch [1032/5000], Step [1], Loss: 0.0004
# Epoch [1033/5000], Step [1], Loss: 0.0004
# Epoch [1034/5000], Step [1], Loss: 0.0004
# Epoch [1035/5000], Step [1], Loss: 0.0004
# Epoch [1036/5000], Step [1], Loss: 0.0004
# Epoch [1037/5000], Step [1], Loss: 0.0004
# Epoch [1038/5000], Step [1], Loss: 0.0004
# Epoch [1039/5000], Step [1], Loss: 0.0004
# Epoch [1040/5000], Step [1], Loss: 0.0004
# Epoch [1041/5000], Step [1], Loss: 0.0004
# Epoch [1042/5000], Step [1], Loss: 0.0004
# Epoch [1043/5000], Step [1], Loss: 0.0004
# Epoch [1044/5000], Step [1], Loss: 0.0004
# Epoch [1045/5000], Step [1], Loss: 0.0004
# Epoch [1046/5000], Step [1], Loss: 0.0004
# Epoch [1047/5000], Step [1], Loss: 0.0004
# Epoch [1048/5000], Step [1], Loss: 0.0004
# Epoch [1049/5000], Step [1], Loss: 0.0004
# Epoch [1050/5000], Step [1], Loss: 0.0004
# Epoch [1051/5000], Step [1], Loss: 0.0004
# Epoch [1052/5000], Step [1], Loss: 0.0004
# Epoch [1053/5000], Step [1], Loss: 0.0004
# Epoch [1054/5000], Step [1], Loss: 0.0004
# Epoch [1055/5000], Step [1], Loss: 0.0004
# Epoch [1056/5000], Step [1], Loss: 0.0004
# Epoch [1057/5000], Step [1], Loss: 0.0004
# Epoch [1058/5000], Step [1], Loss: 0.0004
# Epoch [1059/5000], Step [1], Loss: 0.0004
# Epoch [1060/5000], Step [1], Loss: 0.0004
# Epoch [1061/5000], Step [1], Loss: 0.0004
# Epoch [1062/5000], Step [1], Loss: 0.0004
# Epoch [1063/5000], Step [1], Loss: 0.0004
# Epoch [1064/5000], Step [1], Loss: 0.0004
# Epoch [1065/5000], Step [1], Loss: 0.0004
# Epoch [1066/5000], Step [1], Loss: 0.0004
# Epoch [1067/5000], Step [1], Loss: 0.0004
# Epoch [1068/5000], Step [1], Loss: 0.0004
# Epoch [1069/5000], Step [1], Loss: 0.0004
# Epoch [1070/5000], Step [1], Loss: 0.0004
# Epoch [1071/5000], Step [1], Loss: 0.0004
# Epoch [1072/5000], Step [1], Loss: 0.0004
# Epoch [1073/5000], Step [1], Loss: 0.0004
# Epoch [1074/5000], Step [1], Loss: 0.0004
# Epoch [1075/5000], Step [1], Loss: 0.0004
# Epoch [1076/5000], Step [1], Loss: 0.0004
# Epoch [1077/5000], Step [1], Loss: 0.0004
# Epoch [1078/5000], Step [1], Loss: 0.0004
# Epoch [1079/5000], Step [1], Loss: 0.0004
# Epoch [1080/5000], Step [1], Loss: 0.0004
# Epoch [1081/5000], Step [1], Loss: 0.0004
# Epoch [1082/5000], Step [1], Loss: 0.0004
# Epoch [1083/5000], Step [1], Loss: 0.0004
# Epoch [1084/5000], Step [1], Loss: 0.0004
# Epoch [1085/5000], Step [1], Loss: 0.0004
# Epoch [1086/5000], Step [1], Loss: 0.0004
# Epoch [1087/5000], Step [1], Loss: 0.0004
# Epoch [1088/5000], Step [1], Loss: 0.0004
# Epoch [1089/5000], Step [1], Loss: 0.0004
# Epoch [1090/5000], Step [1], Loss: 0.0004
# Epoch [1091/5000], Step [1], Loss: 0.0004
# Epoch [1092/5000], Step [1], Loss: 0.0004
# Epoch [1093/5000], Step [1], Loss: 0.0004
# Epoch [1094/5000], Step [1], Loss: 0.0004
# Epoch [1095/5000], Step [1], Loss: 0.0004
# Epoch [1096/5000], Step [1], Loss: 0.0004
# Epoch [1097/5000], Step [1], Loss: 0.0004
# Epoch [1098/5000], Step [1], Loss: 0.0004
# Epoch [1099/5000], Step [1], Loss: 0.0004
# Epoch [1100/5000], Step [1], Loss: 0.0004
# Epoch [1101/5000], Step [1], Loss: 0.0004
# Epoch [1102/5000], Step [1], Loss: 0.0004
# Epoch [1103/5000], Step [1], Loss: 0.0004
# Epoch [1104/5000], Step [1], Loss: 0.0004
# Epoch [1105/5000], Step [1], Loss: 0.0004
# Epoch [1106/5000], Step [1], Loss: 0.0004
# Epoch [1107/5000], Step [1], Loss: 0.0004
# Epoch [1108/5000], Step [1], Loss: 0.0004
# Epoch [1109/5000], Step [1], Loss: 0.0004
# Epoch [1110/5000], Step [1], Loss: 0.0004
# Epoch [1111/5000], Step [1], Loss: 0.0004
# Epoch [1112/5000], Step [1], Loss: 0.0004
# Epoch [1113/5000], Step [1], Loss: 0.0004
# Epoch [1114/5000], Step [1], Loss: 0.0004
# Epoch [1115/5000], Step [1], Loss: 0.0004
# Epoch [1116/5000], Step [1], Loss: 0.0004
# Epoch [1117/5000], Step [1], Loss: 0.0004
# Epoch [1118/5000], Step [1], Loss: 0.0004
# Epoch [1119/5000], Step [1], Loss: 0.0004
# Epoch [1120/5000], Step [1], Loss: 0.0004
# Epoch [1121/5000], Step [1], Loss: 0.0004
# Epoch [1122/5000], Step [1], Loss: 0.0004
# Epoch [1123/5000], Step [1], Loss: 0.0004
# Epoch [1124/5000], Step [1], Loss: 0.0004
# Epoch [1125/5000], Step [1], Loss: 0.0004
# Epoch [1126/5000], Step [1], Loss: 0.0004
# Epoch [1127/5000], Step [1], Loss: 0.0004
# Epoch [1128/5000], Step [1], Loss: 0.0004
# Epoch [1129/5000], Step [1], Loss: 0.0004
# Epoch [1130/5000], Step [1], Loss: 0.0003
# Epoch [1131/5000], Step [1], Loss: 0.0003
# Epoch [1132/5000], Step [1], Loss: 0.0003
# Epoch [1133/5000], Step [1], Loss: 0.0003
# Epoch [1134/5000], Step [1], Loss: 0.0003
# Epoch [1135/5000], Step [1], Loss: 0.0003
# Epoch [1136/5000], Step [1], Loss: 0.0003
# Epoch [1137/5000], Step [1], Loss: 0.0003
# Epoch [1138/5000], Step [1], Loss: 0.0003
# Epoch [1139/5000], Step [1], Loss: 0.0003
# Epoch [1140/5000], Step [1], Loss: 0.0004
# Epoch [1141/5000], Step [1], Loss: 0.0004
# Epoch [1142/5000], Step [1], Loss: 0.0004
# Epoch [1143/5000], Step [1], Loss: 0.0004
# Epoch [1144/5000], Step [1], Loss: 0.0004
# Epoch [1145/5000], Step [1], Loss: 0.0004
# Epoch [1146/5000], Step [1], Loss: 0.0004
# Epoch [1147/5000], Step [1], Loss: 0.0004
# Epoch [1148/5000], Step [1], Loss: 0.0004
# Epoch [1149/5000], Step [1], Loss: 0.0003
# Epoch [1150/5000], Step [1], Loss: 0.0003
# Epoch [1151/5000], Step [1], Loss: 0.0004
# Epoch [1152/5000], Step [1], Loss: 0.0004
# Epoch [1153/5000], Step [1], Loss: 0.0004
# Epoch [1154/5000], Step [1], Loss: 0.0003
# Epoch [1155/5000], Step [1], Loss: 0.0003
# Epoch [1156/5000], Step [1], Loss: 0.0004
# Epoch [1157/5000], Step [1], Loss: 0.0004
# Epoch [1158/5000], Step [1], Loss: 0.0003
# Epoch [1159/5000], Step [1], Loss: 0.0003
# Epoch [1160/5000], Step [1], Loss: 0.0003
# Epoch [1161/5000], Step [1], Loss: 0.0003
# Epoch [1162/5000], Step [1], Loss: 0.0003
# Epoch [1163/5000], Step [1], Loss: 0.0003
# Epoch [1164/5000], Step [1], Loss: 0.0003
# Epoch [1165/5000], Step [1], Loss: 0.0003
# Epoch [1166/5000], Step [1], Loss: 0.0003
# Epoch [1167/5000], Step [1], Loss: 0.0003
# Epoch [1168/5000], Step [1], Loss: 0.0003
# Epoch [1169/5000], Step [1], Loss: 0.0003
# ...
# Epoch [4621/5000], Step [1], Loss: 0.0001
# Epoch [4622/5000], Step [1], Loss: 0.0001
# Epoch [4623/5000], Step [1], Loss: 0.0001
# Epoch [4624/5000], Step [1], Loss: 0.0001
# Epoch [4625/5000], Step [1], Loss: 0.0001
# Epoch [4626/5000], Step [1], Loss: 0.0001
# Epoch [4627/5000], Step [1], Loss: 0.0001
# Epoch [4628/5000], Step [1], Loss: 0.0001
# Epoch [4629/5000], Step [1], Loss: 0.0001
# Epoch [4630/5000], Step [1], Loss: 0.0001
# Epoch [4631/5000], Step [1], Loss: 0.0001
# Epoch [4632/5000], Step [1], Loss: 0.0001
# Epoch [4633/5000], Step [1], Loss: 0.0001
# Epoch [4634/5000], Step [1], Loss: 0.0001
# Epoch [4635/5000], Step [1], Loss: 0.0001
# Epoch [4636/5000], Step [1], Loss: 0.0001
# Epoch [4637/5000], Step [1], Loss: 0.0001
# Epoch [4638/5000], Step [1], Loss: 0.0001
# Epoch [4639/5000], Step [1], Loss: 0.0001
# Epoch [4640/5000], Step [1], Loss: 0.0001
# Epoch [4641/5000], Step [1], Loss: 0.0001
# Epoch [4642/5000], Step [1], Loss: 0.0001
# Epoch [4643/5000], Step [1], Loss: 0.0001
# Epoch [4644/5000], Step [1], Loss: 0.0001
# Epoch [4645/5000], Step [1], Loss: 0.0001
# Epoch [4646/5000], Step [1], Loss: 0.0001
# Epoch [4647/5000], Step [1], Loss: 0.0001
# Epoch [4648/5000], Step [1], Loss: 0.0001
# Epoch [4649/5000], Step [1], Loss: 0.0001
# Epoch [4650/5000], Step [1], Loss: 0.0001
# Epoch [4651/5000], Step [1], Loss: 0.0001
# Epoch [4652/5000], Step [1], Loss: 0.0001
# Epoch [4653/5000], Step [1], Loss: 0.0001
# Epoch [4654/5000], Step [1], Loss: 0.0001
# Epoch [4655/5000], Step [1], Loss: 0.0001
# Epoch [4656/5000], Step [1], Loss: 0.0001
# Epoch [4657/5000], Step [1], Loss: 0.0001
# Epoch [4658/5000], Step [1], Loss: 0.0001
# Epoch [4659/5000], Step [1], Loss: 0.0001
# Epoch [4660/5000], Step [1], Loss: 0.0001
# Epoch [4661/5000], Step [1], Loss: 0.0001
# Epoch [4662/5000], Step [1], Loss: 0.0001
# Epoch [4663/5000], Step [1], Loss: 0.0001
# Epoch [4664/5000], Step [1], Loss: 0.0001
# Epoch [4665/5000], Step [1], Loss: 0.0001
# Epoch [4666/5000], Step [1], Loss: 0.0001
# Epoch [4667/5000], Step [1], Loss: 0.0001
# Epoch [4668/5000], Step [1], Loss: 0.0001
# Epoch [4669/5000], Step [1], Loss: 0.0001
# Epoch [4670/5000], Step [1], Loss: 0.0001
# Epoch [4671/5000], Step [1], Loss: 0.0001
# Epoch [4672/5000], Step [1], Loss: 0.0001
# Epoch [4673/5000], Step [1], Loss: 0.0001
# Epoch [4674/5000], Step [1], Loss: 0.0001
# Epoch [4675/5000], Step [1], Loss: 0.0001
# Epoch [4676/5000], Step [1], Loss: 0.0001
# Epoch [4677/5000], Step [1], Loss: 0.0001
# Epoch [4678/5000], Step [1], Loss: 0.0001
# Epoch [4679/5000], Step [1], Loss: 0.0001
# Epoch [4680/5000], Step [1], Loss: 0.0001
# Epoch [4681/5000], Step [1], Loss: 0.0001
# Epoch [4682/5000], Step [1], Loss: 0.0001
# Epoch [4683/5000], Step [1], Loss: 0.0001
# Epoch [4684/5000], Step [1], Loss: 0.0001
# Epoch [4685/5000], Step [1], Loss: 0.0001
# Epoch [4686/5000], Step [1], Loss: 0.0001
# Epoch [4687/5000], Step [1], Loss: 0.0001
# Epoch [4688/5000], Step [1], Loss: 0.0001
# Epoch [4689/5000], Step [1], Loss: 0.0001
# Epoch [4690/5000], Step [1], Loss: 0.0001
# Epoch [4691/5000], Step [1], Loss: 0.0001
# Epoch [4692/5000], Step [1], Loss: 0.0001
# Epoch [4693/5000], Step [1], Loss: 0.0001
# Epoch [4694/5000], Step [1], Loss: 0.0001
# Epoch [4695/5000], Step [1], Loss: 0.0001
# Epoch [4696/5000], Step [1], Loss: 0.0001
# Epoch [4697/5000], Step [1], Loss: 0.0001
# Epoch [4698/5000], Step [1], Loss: 0.0001
# Epoch [4699/5000], Step [1], Loss: 0.0001
# Epoch [4700/5000], Step [1], Loss: 0.0001
# Epoch [4701/5000], Step [1], Loss: 0.0001
# Epoch [4702/5000], Step [1], Loss: 0.0001
# Epoch [4703/5000], Step [1], Loss: 0.0001
# Epoch [4704/5000], Step [1], Loss: 0.0001
# Epoch [4705/5000], Step [1], Loss: 0.0001
# Epoch [4706/5000], Step [1], Loss: 0.0001
# Epoch [4707/5000], Step [1], Loss: 0.0001
# Epoch [4708/5000], Step [1], Loss: 0.0001
# Epoch [4709/5000], Step [1], Loss: 0.0001
# Epoch [4710/5000], Step [1], Loss: 0.0001
# Epoch [4711/5000], Step [1], Loss: 0.0001
# Epoch [4712/5000], Step [1], Loss: 0.0002
# Epoch [4713/5000], Step [1], Loss: 0.0003
# Epoch [4714/5000], Step [1], Loss: 0.0004
# Epoch [4715/5000], Step [1], Loss: 0.0005
# Epoch [4716/5000], Step [1], Loss: 0.0006
# Epoch [4717/5000], Step [1], Loss: 0.0007
# Epoch [4718/5000], Step [1], Loss: 0.0007
# Epoch [4719/5000], Step [1], Loss: 0.0007
# Epoch [4720/5000], Step [1], Loss: 0.0007
# Epoch [4721/5000], Step [1], Loss: 0.0006
# Epoch [4722/5000], Step [1], Loss: 0.0005
# Epoch [4723/5000], Step [1], Loss: 0.0003
# Epoch [4724/5000], Step [1], Loss: 0.0002
# Epoch [4725/5000], Step [1], Loss: 0.0002
# Epoch [4726/5000], Step [1], Loss: 0.0003
# Epoch [4727/5000], Step [1], Loss: 0.0002
# Epoch [4728/5000], Step [1], Loss: 0.0002
# Epoch [4729/5000], Step [1], Loss: 0.0002
# Epoch [4730/5000], Step [1], Loss: 0.0002
# Epoch [4731/5000], Step [1], Loss: 0.0001
# Epoch [4732/5000], Step [1], Loss: 0.0001
# Epoch [4733/5000], Step [1], Loss: 0.0001
# Epoch [4734/5000], Step [1], Loss: 0.0001
# Epoch [4735/5000], Step [1], Loss: 0.0001
# Epoch [4736/5000], Step [1], Loss: 0.0001
# Epoch [4737/5000], Step [1], Loss: 0.0001
# Epoch [4738/5000], Step [1], Loss: 0.0001
# Epoch [4739/5000], Step [1], Loss: 0.0001
# Epoch [4740/5000], Step [1], Loss: 0.0001
# Epoch [4741/5000], Step [1], Loss: 0.0001
# Epoch [4742/5000], Step [1], Loss: 0.0001
# Epoch [4743/5000], Step [1], Loss: 0.0001
# Epoch [4744/5000], Step [1], Loss: 0.0001
# Epoch [4745/5000], Step [1], Loss: 0.0001
# Epoch [4746/5000], Step [1], Loss: 0.0001
# Epoch [4747/5000], Step [1], Loss: 0.0001
# Epoch [4748/5000], Step [1], Loss: 0.0001
# Epoch [4749/5000], Step [1], Loss: 0.0001
# Epoch [4750/5000], Step [1], Loss: 0.0001
# Epoch [4751/5000], Step [1], Loss: 0.0001
# Epoch [4752/5000], Step [1], Loss: 0.0001
# Epoch [4753/5000], Step [1], Loss: 0.0001
# Epoch [4754/5000], Step [1], Loss: 0.0001
# Epoch [4755/5000], Step [1], Loss: 0.0001
# Epoch [4756/5000], Step [1], Loss: 0.0001
# Epoch [4757/5000], Step [1], Loss: 0.0001
# Epoch [4758/5000], Step [1], Loss: 0.0001
# Epoch [4759/5000], Step [1], Loss: 0.0001
# Epoch [4760/5000], Step [1], Loss: 0.0001
# Epoch [4761/5000], Step [1], Loss: 0.0001
# Epoch [4762/5000], Step [1], Loss: 0.0001
# Epoch [4763/5000], Step [1], Loss: 0.0001
# Epoch [4764/5000], Step [1], Loss: 0.0001
# Epoch [4765/5000], Step [1], Loss: 0.0001
# Epoch [4766/5000], Step [1], Loss: 0.0001
# Epoch [4767/5000], Step [1], Loss: 0.0001
# Epoch [4768/5000], Step [1], Loss: 0.0001
# Epoch [4769/5000], Step [1], Loss: 0.0001
# Epoch [4770/5000], Step [1], Loss: 0.0001
# Epoch [4771/5000], Step [1], Loss: 0.0001
# Epoch [4772/5000], Step [1], Loss: 0.0001
# Epoch [4773/5000], Step [1], Loss: 0.0001
# Epoch [4774/5000], Step [1], Loss: 0.0001
# Epoch [4775/5000], Step [1], Loss: 0.0001
# Epoch [4776/5000], Step [1], Loss: 0.0001
# Epoch [4777/5000], Step [1], Loss: 0.0001
# Epoch [4778/5000], Step [1], Loss: 0.0001
# Epoch [4779/5000], Step [1], Loss: 0.0001
# Epoch [4780/5000], Step [1], Loss: 0.0001
# Epoch [4781/5000], Step [1], Loss: 0.0001
# Epoch [4782/5000], Step [1], Loss: 0.0001
# Epoch [4783/5000], Step [1], Loss: 0.0001
# Epoch [4784/5000], Step [1], Loss: 0.0001
# Epoch [4785/5000], Step [1], Loss: 0.0001
# Epoch [4786/5000], Step [1], Loss: 0.0001
# Epoch [4787/5000], Step [1], Loss: 0.0001
# Epoch [4788/5000], Step [1], Loss: 0.0001
# Epoch [4789/5000], Step [1], Loss: 0.0001
# Epoch [4790/5000], Step [1], Loss: 0.0001
# Epoch [4791/5000], Step [1], Loss: 0.0001
# Epoch [4792/5000], Step [1], Loss: 0.0001
# Epoch [4793/5000], Step [1], Loss: 0.0001
# Epoch [4794/5000], Step [1], Loss: 0.0001
# Epoch [4795/5000], Step [1], Loss: 0.0001
# Epoch [4796/5000], Step [1], Loss: 0.0001
# Epoch [4797/5000], Step [1], Loss: 0.0001
# Epoch [4798/5000], Step [1], Loss: 0.0001
# Epoch [4799/5000], Step [1], Loss: 0.0001
# Epoch [4800/5000], Step [1], Loss: 0.0001
# Epoch [4801/5000], Step [1], Loss: 0.0001
# Epoch [4802/5000], Step [1], Loss: 0.0001
# Epoch [4803/5000], Step [1], Loss: 0.0001
# Epoch [4804/5000], Step [1], Loss: 0.0001
# Epoch [4805/5000], Step [1], Loss: 0.0001
# Epoch [4806/5000], Step [1], Loss: 0.0001
# Epoch [4807/5000], Step [1], Loss: 0.0001
# Epoch [4808/5000], Step [1], Loss: 0.0001
# Epoch [4809/5000], Step [1], Loss: 0.0001
# Epoch [4810/5000], Step [1], Loss: 0.0001
# Epoch [4811/5000], Step [1], Loss: 0.0001
# Epoch [4812/5000], Step [1], Loss: 0.0001
# Epoch [4813/5000], Step [1], Loss: 0.0001
# Epoch [4814/5000], Step [1], Loss: 0.0001
# Epoch [4815/5000], Step [1], Loss: 0.0001
# Epoch [4816/5000], Step [1], Loss: 0.0001
# Epoch [4817/5000], Step [1], Loss: 0.0001
# Epoch [4818/5000], Step [1], Loss: 0.0001
# Epoch [4819/5000], Step [1], Loss: 0.0001
# Epoch [4820/5000], Step [1], Loss: 0.0001
# Epoch [4821/5000], Step [1], Loss: 0.0001
# Epoch [4822/5000], Step [1], Loss: 0.0001
# Epoch [4823/5000], Step [1], Loss: 0.0001
# Epoch [4824/5000], Step [1], Loss: 0.0001
# Epoch [4825/5000], Step [1], Loss: 0.0001
# Epoch [4826/5000], Step [1], Loss: 0.0001
# Epoch [4827/5000], Step [1], Loss: 0.0001
# Epoch [4828/5000], Step [1], Loss: 0.0001
# Epoch [4829/5000], Step [1], Loss: 0.0001
# Epoch [4830/5000], Step [1], Loss: 0.0001
# Epoch [4831/5000], Step [1], Loss: 0.0001
# Epoch [4832/5000], Step [1], Loss: 0.0001
# Epoch [4833/5000], Step [1], Loss: 0.0001
# Epoch [4834/5000], Step [1], Loss: 0.0001
# Epoch [4835/5000], Step [1], Loss: 0.0001
# Epoch [4836/5000], Step [1], Loss: 0.0001
# Epoch [4837/5000], Step [1], Loss: 0.0001
# Epoch [4838/5000], Step [1], Loss: 0.0001
# Epoch [4839/5000], Step [1], Loss: 0.0001
# Epoch [4840/5000], Step [1], Loss: 0.0001
# Epoch [4841/5000], Step [1], Loss: 0.0001
# Epoch [4842/5000], Step [1], Loss: 0.0001
# Epoch [4843/5000], Step [1], Loss: 0.0001
# Epoch [4844/5000], Step [1], Loss: 0.0001
# Epoch [4845/5000], Step [1], Loss: 0.0001
# Epoch [4846/5000], Step [1], Loss: 0.0001
# Epoch [4847/5000], Step [1], Loss: 0.0001
# Epoch [4848/5000], Step [1], Loss: 0.0001
# Epoch [4849/5000], Step [1], Loss: 0.0001
# Epoch [4850/5000], Step [1], Loss: 0.0001
# Epoch [4851/5000], Step [1], Loss: 0.0001
# Epoch [4852/5000], Step [1], Loss: 0.0001
# Epoch [4853/5000], Step [1], Loss: 0.0001
# Epoch [4854/5000], Step [1], Loss: 0.0001
# Epoch [4855/5000], Step [1], Loss: 0.0001
# Epoch [4856/5000], Step [1], Loss: 0.0001
# Epoch [4857/5000], Step [1], Loss: 0.0001
# Epoch [4858/5000], Step [1], Loss: 0.0001
# Epoch [4859/5000], Step [1], Loss: 0.0001
# Epoch [4860/5000], Step [1], Loss: 0.0001
# Epoch [4861/5000], Step [1], Loss: 0.0001
# Epoch [4862/5000], Step [1], Loss: 0.0001
# Epoch [4863/5000], Step [1], Loss: 0.0001
# Epoch [4864/5000], Step [1], Loss: 0.0002
# Epoch [4865/5000], Step [1], Loss: 0.0002
# Epoch [4866/5000], Step [1], Loss: 0.0003
# Epoch [4867/5000], Step [1], Loss: 0.0004
# Epoch [4868/5000], Step [1], Loss: 0.0005
# Epoch [4869/5000], Step [1], Loss: 0.0005
# Epoch [4870/5000], Step [1], Loss: 0.0005
# Epoch [4871/5000], Step [1], Loss: 0.0004
# Epoch [4872/5000], Step [1], Loss: 0.0004
# Epoch [4873/5000], Step [1], Loss: 0.0003
# Epoch [4874/5000], Step [1], Loss: 0.0003
# Epoch [4875/5000], Step [1], Loss: 0.0003
# Epoch [4876/5000], Step [1], Loss: 0.0003
# Epoch [4877/5000], Step [1], Loss: 0.0002
# Epoch [4878/5000], Step [1], Loss: 0.0001
# Epoch [4879/5000], Step [1], Loss: 0.0001
# Epoch [4880/5000], Step [1], Loss: 0.0001
# Epoch [4881/5000], Step [1], Loss: 0.0002
# Epoch [4882/5000], Step [1], Loss: 0.0002
# Epoch [4883/5000], Step [1], Loss: 0.0001
# Epoch [4884/5000], Step [1], Loss: 0.0001
# Epoch [4885/5000], Step [1], Loss: 0.0001
# Epoch [4886/5000], Step [1], Loss: 0.0001
# Epoch [4887/5000], Step [1], Loss: 0.0001
# Epoch [4888/5000], Step [1], Loss: 0.0001
# Epoch [4889/5000], Step [1], Loss: 0.0001
# Epoch [4890/5000], Step [1], Loss: 0.0001
# Epoch [4891/5000], Step [1], Loss: 0.0001
# Epoch [4892/5000], Step [1], Loss: 0.0001
# Epoch [4893/5000], Step [1], Loss: 0.0001
# Epoch [4894/5000], Step [1], Loss: 0.0001
# Epoch [4895/5000], Step [1], Loss: 0.0001
# Epoch [4896/5000], Step [1], Loss: 0.0001
# Epoch [4897/5000], Step [1], Loss: 0.0001
# Epoch [4898/5000], Step [1], Loss: 0.0001
# Epoch [4899/5000], Step [1], Loss: 0.0001
# Epoch [4900/5000], Step [1], Loss: 0.0001
# Epoch [4901/5000], Step [1], Loss: 0.0001
# Epoch [4902/5000], Step [1], Loss: 0.0001
# Epoch [4903/5000], Step [1], Loss: 0.0001
# Epoch [4904/5000], Step [1], Loss: 0.0001
# Epoch [4905/5000], Step [1], Loss: 0.0001
# Epoch [4906/5000], Step [1], Loss: 0.0001
# Epoch [4907/5000], Step [1], Loss: 0.0001
# Epoch [4908/5000], Step [1], Loss: 0.0001
# Epoch [4909/5000], Step [1], Loss: 0.0001
# Epoch [4910/5000], Step [1], Loss: 0.0001
# Epoch [4911/5000], Step [1], Loss: 0.0001
# Epoch [4912/5000], Step [1], Loss: 0.0001
# Epoch [4913/5000], Step [1], Loss: 0.0001
# Epoch [4914/5000], Step [1], Loss: 0.0001
# Epoch [4915/5000], Step [1], Loss: 0.0001
# Epoch [4916/5000], Step [1], Loss: 0.0001
# Epoch [4917/5000], Step [1], Loss: 0.0001
# Epoch [4918/5000], Step [1], Loss: 0.0001
# Epoch [4919/5000], Step [1], Loss: 0.0001
# Epoch [4920/5000], Step [1], Loss: 0.0001
# Epoch [4921/5000], Step [1], Loss: 0.0001
# Epoch [4922/5000], Step [1], Loss: 0.0001
# Epoch [4923/5000], Step [1], Loss: 0.0001
# Epoch [4924/5000], Step [1], Loss: 0.0001
# Epoch [4925/5000], Step [1], Loss: 0.0001
# Epoch [4926/5000], Step [1], Loss: 0.0001
# Epoch [4927/5000], Step [1], Loss: 0.0001
# Epoch [4928/5000], Step [1], Loss: 0.0001
# Epoch [4929/5000], Step [1], Loss: 0.0001
# Epoch [4930/5000], Step [1], Loss: 0.0001
# Epoch [4931/5000], Step [1], Loss: 0.0001
# Epoch [4932/5000], Step [1], Loss: 0.0001
# Epoch [4933/5000], Step [1], Loss: 0.0001
# Epoch [4934/5000], Step [1], Loss: 0.0001
# Epoch [4935/5000], Step [1], Loss: 0.0001
# Epoch [4936/5000], Step [1], Loss: 0.0001
# Epoch [4937/5000], Step [1], Loss: 0.0001
# Epoch [4938/5000], Step [1], Loss: 0.0001
# Epoch [4939/5000], Step [1], Loss: 0.0001
# Epoch [4940/5000], Step [1], Loss: 0.0001
# Epoch [4941/5000], Step [1], Loss: 0.0001
# Epoch [4942/5000], Step [1], Loss: 0.0001
# Epoch [4943/5000], Step [1], Loss: 0.0001
# Epoch [4944/5000], Step [1], Loss: 0.0001
# Epoch [4945/5000], Step [1], Loss: 0.0001
# Epoch [4946/5000], Step [1], Loss: 0.0001
# Epoch [4947/5000], Step [1], Loss: 0.0001
# Epoch [4948/5000], Step [1], Loss: 0.0001
# Epoch [4949/5000], Step [1], Loss: 0.0001
# Epoch [4950/5000], Step [1], Loss: 0.0001
# Epoch [4951/5000], Step [1], Loss: 0.0001
# Epoch [4952/5000], Step [1], Loss: 0.0001
# Epoch [4953/5000], Step [1], Loss: 0.0001
# Epoch [4954/5000], Step [1], Loss: 0.0001
# Epoch [4955/5000], Step [1], Loss: 0.0001
# Epoch [4956/5000], Step [1], Loss: 0.0001
# Epoch [4957/5000], Step [1], Loss: 0.0001
# Epoch [4958/5000], Step [1], Loss: 0.0001
# Epoch [4959/5000], Step [1], Loss: 0.0001
# Epoch [4960/5000], Step [1], Loss: 0.0001
# Epoch [4961/5000], Step [1], Loss: 0.0001
# Epoch [4962/5000], Step [1], Loss: 0.0001
# Epoch [4963/5000], Step [1], Loss: 0.0001
# Epoch [4964/5000], Step [1], Loss: 0.0001
# Epoch [4965/5000], Step [1], Loss: 0.0001
# Epoch [4966/5000], Step [1], Loss: 0.0001
# Epoch [4967/5000], Step [1], Loss: 0.0001
# Epoch [4968/5000], Step [1], Loss: 0.0001
# Epoch [4969/5000], Step [1], Loss: 0.0001
# Epoch [4970/5000], Step [1], Loss: 0.0001
# Epoch [4971/5000], Step [1], Loss: 0.0001
# Epoch [4972/5000], Step [1], Loss: 0.0001
# Epoch [4973/5000], Step [1], Loss: 0.0001
# Epoch [4974/5000], Step [1], Loss: 0.0001
# Epoch [4975/5000], Step [1], Loss: 0.0001
# Epoch [4976/5000], Step [1], Loss: 0.0001
# Epoch [4977/5000], Step [1], Loss: 0.0001
# Epoch [4978/5000], Step [1], Loss: 0.0001
# Epoch [4979/5000], Step [1], Loss: 0.0001
# Epoch [4980/5000], Step [1], Loss: 0.0001
# Epoch [4981/5000], Step [1], Loss: 0.0002
# Epoch [4982/5000], Step [1], Loss: 0.0003
# Epoch [4983/5000], Step [1], Loss: 0.0004
# Epoch [4984/5000], Step [1], Loss: 0.0006
# Epoch [4985/5000], Step [1], Loss: 0.0009
# Epoch [4986/5000], Step [1], Loss: 0.0011
# Epoch [4987/5000], Step [1], Loss: 0.0012
# Epoch [4988/5000], Step [1], Loss: 0.0010
# Epoch [4989/5000], Step [1], Loss: 0.0006
# Epoch [4990/5000], Step [1], Loss: 0.0002
# Epoch [4991/5000], Step [1], Loss: 0.0001
# Epoch [4992/5000], Step [1], Loss: 0.0003
# Epoch [4993/5000], Step [1], Loss: 0.0005
# Epoch [4994/5000], Step [1], Loss: 0.0004
# Epoch [4995/5000], Step [1], Loss: 0.0002
# Epoch [4996/5000], Step [1], Loss: 0.0001
# Epoch [4997/5000], Step [1], Loss: 0.0002
# Epoch [4998/5000], Step [1], Loss: 0.0003
# Epoch [4999/5000], Step [1], Loss: 0.0002
# Epoch [5000/5000], Step [1], Loss: 0.0001

# %%
# 测试数据生成
U_x_test, U_y_test = compute_velocity_field_np(X_low, Y_low, dx_low, dy_low)
U_magnitude_test = np.sqrt(U_x_test**2 + U_y_test**2)

# 将测试数据转换为PyTorch张量
U_x_test = torch.tensor(U_x_test, dtype=torch.float32).unsqueeze(0).unsqueeze(0)
U_y_test = torch.tensor(U_y_test, dtype=torch.float32).unsqueeze(0).unsqueeze(0)
U_magnitude_test = torch.tensor(U_magnitude_test, dtype=torch.float32).unsqueeze(0).unsqueeze(0)

# 合并测试速度场作为输入
velocity_field_test = torch.cat((U_x_test, U_y_test, U_magnitude_test), dim=1)

# 将模型设置为评估模式
model.eval()

# 使用测试数据进行预测
with torch.no_grad():
    predicted_abcd_test = model(velocity_field_test)

# 打印预测结果
print("Predicted a, b, c, d:")
print(predicted_abcd_test)

# 计算预测的速度场
a_test = predicted_abcd_test[:, 0, :, :].squeeze().numpy()
b_test = predicted_abcd_test[:, 1, :, :].squeeze().numpy()
c_test = predicted_abcd_test[:, 2, :, :].squeeze().numpy()
d_test = predicted_abcd_test[:, 3, :, :].squeeze().numpy()

U_x_pred_test = a_test + b_test
U_y_pred_test = c_test + d_test
U_magnitude_pred_test = np.sqrt(U_x_pred_test**2 + U_y_pred_test**2)
# Out:
# Predicted a, b, c, d:
# tensor([[[[ 6.7297e-01,  6.7468e-01,  6.7422e-01,  ...,  5.6150e-01,
#             5.7664e-01,  5.8163e-01],
#           [ 6.5410e-01,  6.5090e-01,  6.5010e-01,  ...,  5.2735e-01,
#             5.4396e-01,  5.5388e-01],
#           [ 6.0328e-01,  6.0173e-01,  6.0080e-01,  ...,  4.5386e-01,
#             4.7217e-01,  4.8210e-01],
#           ...,
#           [ 7.5182e-01,  7.3176e-01,  7.0609e-01,  ...,  7.9166e-01,
#             7.9945e-01,  7.9965e-01],
#           [ 7.1884e-01,  7.0101e-01,  6.7907e-01,  ...,  7.5109e-01,
#             7.5664e-01,  7.5443e-01],
#           [ 6.9935e-01,  6.8295e-01,  6.6173e-01,  ...,  7.2643e-01,
#             7.3019e-01,  7.2988e-01]],
#
#          [[-7.1761e-01, -7.2017e-01, -7.1813e-01,  ..., -6.0405e-01,
#            -6.2073e-01, -6.3175e-01],
#           [-7.4737e-01, -7.4690e-01, -7.4393e-01,  ..., -6.1923e-01,
#            -6.3905e-01, -6.4998e-01],
#           [-7.9431e-01, -7.9279e-01, -7.8772e-01,  ..., -6.3896e-01,
#            -6.6335e-01, -6.7505e-01],
#           ...,
#           [-5.4576e-01, -5.2729e-01, -5.0532e-01,  ..., -5.9287e-01,
#            -5.9639e-01, -5.9820e-01],
#           [-6.1099e-01, -5.9376e-01, -5.7359e-01,  ..., -6.4481e-01,
#            -6.4815e-01, -6.5027e-01],
#           [-6.4077e-01, -6.2567e-01, -6.0603e-01,  ..., -6.7099e-01,
#            -6.7385e-01, -6.7270e-01]],
#
#          [[-9.8921e-02, -5.4555e-02,  2.6103e-02,  ..., -4.8933e-01,
#            -4.2585e-01, -3.8982e-01],
#           [-5.3626e-02, -3.0915e-02,  4.8751e-02,  ..., -5.0100e-01,
#            -4.3450e-01, -3.9528e-01],
#           [-2.0394e-02,  2.1243e-03,  8.4702e-02,  ..., -5.2803e-01,
#            -4.5985e-01, -4.2172e-01],
#           ...,
#           [-2.3480e-01, -2.5105e-01, -2.4058e-01,  ..., -6.2109e-02,
#            -5.0385e-02, -5.2198e-02],
#           [-2.0660e-01, -2.2309e-01, -2.0925e-01,  ..., -1.0024e-01,
#            -8.3463e-02, -8.3921e-02],
#           [-1.9621e-01, -2.1262e-01, -1.9746e-01,  ..., -1.3066e-01,
#            -1.1258e-01, -1.0877e-01]],
#
#          [[ 1.4953e-01,  1.5227e-01,  1.7040e-01,  ...,  2.8355e-01,
#             3.1754e-01,  3.3264e-01],
#           [ 1.0354e-01,  1.3233e-01,  1.4682e-01,  ...,  2.9571e-01,
#             3.2701e-01,  3.3836e-01],
#           [ 6.8667e-02,  9.6907e-02,  1.0661e-01,  ...,  3.2698e-01,
#             3.5434e-01,  3.6612e-01],
#           ...,
#           [ 2.8596e-01,  3.5137e-01,  4.3383e-01,  ..., -1.3387e-01,
#            -5.1498e-02, -1.0071e-04],
#           [ 2.5938e-01,  3.2599e-01,  4.0752e-01,  ..., -1.0013e-01,
#            -2.0746e-02,  3.0654e-02],
#           [ 2.4865e-01,  3.1131e-01,  3.9477e-01,  ..., -7.0692e-02,
#             9.0642e-03,  5.3987e-02]]]])

# %%
# 绘图
fig, axes = plt.subplots(3, 2, figsize=(12, 12))

# U_x
axes[0, 0].imshow(U_x_test.squeeze().numpy(), cmap='viridis')
axes[0, 0].set_title('True U_x')
axes[0, 1].imshow(U_x_pred_test, cmap='viridis')
axes[0, 1].set_title('Predicted U_x')

# U_y
axes[1, 0].imshow(U_y_test.squeeze().numpy(), cmap='viridis')
axes[1, 0].set_title('True U_y')
axes[1, 1].imshow(U_y_pred_test, cmap='viridis')
axes[1, 1].set_title('Predicted U_y')

# U_magnitude
axes[2, 0].imshow(U_magnitude_test.squeeze().numpy(), cmap='viridis')
axes[2, 0].set_title('True U_magnitude')
axes[2, 1].imshow(U_magnitude_pred_test, cmap='viridis')
axes[2, 1].set_title('Predicted U_magnitude')

plt.tight_layout()
plt.show()

# %%
plt.imshow(U_magnitude_test.squeeze().numpy(), cmap='viridis')
plt.savefig('U_x_pred_test.png')

# %%
U_magnitude_high.shape
# Out:
# (256, 256)

# %%
# Out:
# 256

# %%
plt.figure(figsize=(8, 8))
plt.imshow(U_magnitude_high, cmap='viridis', interpolation='nearest')
plt.axis('off')  # 隐藏坐标轴

# 保存图像
plt.savefig('velocity_magnitude_256x256.png', bbox_inches='tight', pad_inches=0, dpi=300)
plt.show()

# %%
import matplotlib.pyplot as plt
from PIL import Image
import os

# 假设 U_magnitude_high 是 (256, 256) 形状的图像数据
plt.figure(figsize=(8, 8))  # 设置图像显示大小
plt.imshow(U_magnitude_high, cmap='viridis', interpolation='nearest')
plt.axis('off')  # 隐藏坐标轴

# 保存为临时文件
temp_filename = 'temp_velocity_magnitude_256x256.png'
plt.savefig(temp_filename, bbox_inches='tight', pad_inches=0, dpi=300, format='png')

# 使用 PIL 去掉 alpha 通道
img = Image.open(temp_filename)
img = img.convert('RGB')  # 转换为 RGB 模式，去掉 alpha 通道
img.save('velocity_magnitude_256x256.png', format='png')

# 清理临时文件
os.remove(temp_filename)

# 显示图像
plt.show()

# %%
U_magnitude_test64 = U_magnitude_test.squeeze().numpy().copy()

# %%
U_magnitude_test64
# Out:
# array([[0.07041945, 0.11096729, 0.20350367, ..., 0.20350367, 0.11096729,
#         0.07041945],
#        [0.11105035, 0.13978752, 0.21939544, ..., 0.21939544, 0.13978752,
#         0.11105035],
#        [0.20372783, 0.21956132, 0.27402085, ..., 0.27402085, 0.21956132,
#         0.20372783],
#        ...,
#        [0.20372783, 0.21956132, 0.27402085, ..., 0.27402085, 0.21956132,
#         0.20372783],
#        [0.11105035, 0.13978752, 0.21939544, ..., 0.21939544, 0.13978752,
#         0.11105035],
#        [0.07041945, 0.11096729, 0.20350367, ..., 0.20350367, 0.11096729,
#         0.07041945]], dtype=float32)

# %%
plt.figure(figsize=(2, 2))
plt.imshow(U_magnitude_test64, cmap='viridis', interpolation='nearest')
plt.axis('off')  # 隐藏坐标轴

# 保存图像
plt.savefig('velocity_magnitude_64x64.png', bbox_inches='tight', pad_inches=0, dpi=300, format='png')

plt.show()

# %%
import matplotlib.pyplot as plt
from PIL import Image

# 假设 U_magnitude_test64 是 (64, 64) 形状的图像数据
plt.figure(figsize=(2, 2))  # 设置图像显示大小
plt.imshow(U_magnitude_test64, cmap='viridis', interpolation='nearest')
plt.axis('off')  # 隐藏坐标轴

# 保存为临时文件
temp_filename = 'temp_velocity_magnitude_64x64.png'
plt.savefig(temp_filename, bbox_inches='tight', pad_inches=0, dpi=300, format='png')

# 使用 PIL 去掉 alpha 通道
img = Image.open(temp_filename)
img = img.convert('RGB')  # 转换为 RGB 模式，去掉 alpha 通道
img.save('velocity_magnitude_64x64.png', format='png')

# 清理临时文件
import os
os.remove(temp_filename)

# 显示图像
plt.show()

# %%
U_magnitude_high.shape
# Out:
# (256, 256)

# %%
print(U_magnitude_test64.shape)  # 打印形状
print(U_magnitude_high.shape)  # 打印形状
# Out:
# (64, 64)
# (256, 256)
