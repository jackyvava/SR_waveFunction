# %% [markdown]
# <center>基于波函数的流体超分辨研究</center>

# %% [markdown]
# # 问题描述

# %% [markdown]
# 传统的超分辨是给定图片a，经过超分辨能够得到精度更高的图片b
#
# 我们希望能够在超分辨模型前后进行结构的调整，使得其能够自适应涡旋流体超分辨，为方便后续研究，我们暂且将这个方法的名字成为$Clebsch$流体超分辨。

# %% [markdown]
# $Clebsch$流体超分辨分为四个步骤：
# 我们首先有一些流体的图片集，我们是能够已知其图片的结构的，即网格数据，和网格对应的速度场。
# 其次，我们能够知道双分量波函数是可以经过公式转换得到对应速度场的，双分量波函数形如$\psi = a+bi+cj+dk$
#
# 1. 从任意一张已知的图片出发，我们假设该图片是$128\times 128$，经过$model_A$后我们能够找到$a,b,c,d$，与之对应的，$a,b,c,d$每一个单独的量都应该是$128\times 128$
#
# 2. 我们将得到的$a,b,c,d$再经过一个$model_B$，这个$model_B$是一个超分辨模型，然后我们将得到对应的$a,b,c,d$，我们假设其分辨率从128提高到了256
#
# 3. 我们需要再训练一个从abcd到速度场的$model_c$，然后我们就能得到256的速度场了。
#
# 我们希望经过我们改进后的超分辨模型，能够更加适应用于涡旋的流体现象，因为我们能够chern的文章中验证通过波函数的方法能够较好的捕捉涡结构。

# %% [markdown]
# 为了能够得到上面的模型，我们需要逐步训练各个部分模型，这项工作，只是进行一个简单的尝试，因此，我们会对采用精度较低的图片，以提高模型的训练速度，来验证本项工作的可行性。

# %% [markdown]
# # 初始案例构建

# %% [markdown]
# 函数 \(a(x, y)\)、\(b(x, y)\)、\(c(x, y)\) 和 \(d(x, y)\) 定义如下：
# \begin{align*}
#     H(x) &=
#     \begin{cases}
#       \frac{x}{2} & \text{如果 } 0 \leq x \leq \pi \\
#       \pi - \frac{x}{2} & \text{如果 } \pi < x \leq 2\pi
#     \end{cases} \\
#     a(x, y) &= \cos[H(x)] \cos\left(\frac{\cos(y) (2 - \cos(x))}{\hbar}\right), \\
#     b(x, y) &= \cos[H(x)] \sin\left(\frac{\cos(y) (2 - \cos(x))}{\hbar}\right), \\
#     c(x, y) &= \sin[H(x)] \cos\left(\frac{\cos(y) (2 + \cos(x))}{\hbar}\right), \\
#     d(x, y) &= -\sin[H(x)] \sin\left(\frac{\cos(y) (2 + \cos(x))}{\hbar}\right).
# \end{align*}
# 其中，$\hbar $是一个常数（为了简化，设为1）。

# %% [markdown]
# 速度场计算
# $$
# \mathbf{u} = \hbar(a \mathbf \nabla b-b\mathbf \nabla a + c\mathbf \nabla d - d\mathbf \nabla c)
# $$
#
# 速度场分量 $u_x$ 和 $u_y$ 使用 $a$、$b$、$c$、$d$ 的梯度计算得到：
# $$
# \begin{align*}
#     \nabla a &= \left(\frac{\partial a}{\partial x}, \frac{\partial a}{\partial y}\right), \\
#     \nabla b &= \left(\frac{\partial b}{\partial x}, \frac{\partial b}{\partial y}\right), \\
#     \nabla c &= \left(\frac{\partial c}{\partial x}, \frac{\partial c}{\partial y}\right), \\
#     \nabla d &= \left(\frac{\partial d}{\partial x}, \frac{\partial d}{\partial y}\right).
# \end{align*}
# $$

# %% [markdown]
# 速度场的计算公式为：
# \begin{align*}
#     u_x &= \hbar \left(a \frac{\partial b}{\partial x} - b \frac{\partial a}{\partial x} + c \frac{\partial d}{\partial x} - d \frac{\partial c}{\partial x}\right), \\
#     u_y &= \hbar \left(a \frac{\partial b}{\partial y} - b \frac{\partial a}{\partial y} + c \frac{\partial d}{\partial y} - d \frac{\partial c}{\partial y}\right).
# \end{align*}

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# 定义常数
hbar = 1

# 定义 H(x)
def H(x):
    return np.where((0 <= x) & (x <= np.pi), x / 2, np.pi - x / 2)

# 定义函数 a, b, c, d
def a(x, y):
    return np.cos(H(x)) * np.cos(np.cos(y) * (2 - np.cos(x)) / hbar)

def b(x, y):
    return np.cos(H(x)) * np.sin(np.cos(y) * (2 - np.cos(x)) / hbar)

def c(x, y):
    return np.sin(H(x)) * np.cos(np.cos(y) * (2 + np.cos(x)) / hbar)

def d(x, y):
    return -np.sin(H(x)) * np.sin(np.cos(y) * (2 + np.cos(x)) / hbar)

# 计算梯度
def gradient(f, x, y, eps=1e-5):
    f_x = (f(x + eps, y) - f(x - eps, y)) / (2 * eps)
    f_y = (f(x, y + eps) - f(x, y - eps)) / (2 * eps)
    return f_x, f_y

# 计算速度场
def compute_velocity_field_np(x, y, dx, dy):
    # 使用内置的np 求解梯度
    a_val = a(x, y)
    b_val = b(x, y)
    c_val = c(x, y)
    d_val = d(x, y)

    a_grad_x, a_grad_y = np.gradient(a_val, dx, dy)
    b_grad_x, b_grad_y = np.gradient(b_val, dx, dy)
    c_grad_x, c_grad_y = np.gradient(c_val, dx, dy)
    d_grad_x, d_grad_y = np.gradient(d_val, dx, dy)

    u_x = hbar * (a_val * b_grad_x - b_val * a_grad_x + c_val * d_grad_x - d_val * c_grad_x)
    u_y = hbar * (a_val * b_grad_y - b_val * a_grad_y + c_val * d_grad_y - d_val * c_grad_y)

    return u_x, u_y

def compute_velocity_field_FD(x, y):
    # 有限差分进行计算
    a_val = a(x, y)
    b_val = b(x, y)
    c_val = c(x, y)
    d_val = d(x, y)

    a_grad_x, a_grad_y = gradient(a, x, y)
    b_grad_x, b_grad_y = gradient(b, x, y)
    c_grad_x, c_grad_y = gradient(c, x, y)
    d_grad_x, d_grad_y = gradient(d, x, y)

    u_x = hbar * (a_val * b_grad_x - b_val * a_grad_x + c_val * d_grad_x - d_val * c_grad_x)
    u_y = hbar * (a_val * b_grad_y - b_val * a_grad_y + c_val * d_grad_y - d_val * c_grad_y)

    return u_x, u_y

# %%
size = 128
x = np.linspace(0, 2 * np.pi, size)
y = np.linspace(0, 2 * np.pi, size)
X, Y = np.meshgrid(x, y)

# %%
# 计算函数值
A = a(X, Y)
B = b(X, Y)
C = c(X, Y)
D = d(X, Y)

# %%
# 计算步长
dx = x[1] - x[0]
dy = y[1] - y[0]

# %%
U_x, U_y = compute_velocity_field_np(X, Y, dx, dy)

U_x_FD, U_y_FD = compute_velocity_field_FD(X, Y)

# 计算速度场的大小
U_magnitude = np.sqrt(U_x**2 + U_y**2)

U_magnitude_FD = np.sqrt(U_x_FD**2 + U_y_FD**2)

# %%
# 可视化
fig, axs = plt.subplots(3, 2, figsize=(12, 18))

# 可视化 a, b, c, d
axs[0, 0].contourf(X, Y, A, levels=50, cmap='viridis')
axs[0, 0].set_title('Function a')
axs[0, 1].contourf(X, Y, B, levels=50, cmap='viridis')
axs[0, 1].set_title('Function b')
axs[1, 0].contourf(X, Y, C, levels=50, cmap='viridis')
axs[1, 0].set_title('Function c')
axs[1, 1].contourf(X, Y, D, levels=50, cmap='viridis')
axs[1, 1].set_title('Function d')

# 可视化速度场
axs[2, 0].quiver(X, Y, U_x, U_y)
axs[2, 0].set_title('Velocity Field (U_x, U_y)')
axs[2, 1].contourf(X, Y, U_magnitude, levels=50, cmap='plasma')
axs[2, 1].set_title('Magnitude of Velocity Field')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 可视化速度场

# %%
plt.figure(figsize=(15, 5))

plt.subplot(1,3,1)
plt.contourf(X, Y, U_magnitude_FD, levels=50, cmap='viridis')
plt.streamplot(X, Y, U_x_FD, U_y_FD, color='white', linewidth=1)
plt.title('Finite Difference')
plt.colorbar()


plt.subplot(1,3,2)
plt.contourf(X, Y, U_magnitude, levels=50, cmap='viridis')
# plt.streamplot(X, Y, U_x, U_y, color='white', linewidth=1)
plt.title('Numpy Gradient')
plt.colorbar()


plt.subplot(1,3,3)
plt.contourf(X, Y, U_magnitude_FD-U_magnitude, levels=50, cmap='viridis', vmin=-0.1, vmax=0.1)
plt.title('Difference')
plt.colorbar()

plt.show()

# %% [markdown]
# ## 可视化涡量场

# %%
# 计算旋度
def vorticity(U_x, U_y, dx, dy):
    dU_y_dx, _ = np.gradient(U_y, dx, axis=0), np.gradient(U_y, dy, axis=1)
    _, dU_x_dy = np.gradient(U_x, dx, axis=0), np.gradient(U_x, dy, axis=1)
    return dU_y_dx - dU_x_dy

# %%
# 计算旋度
vort = vorticity(U_x, U_y, dx, dy)
vort_FD = vorticity(U_x_FD, U_y_FD, dx, dy)

# 归一化旋度
max_vort = np.max(np.abs(vort))
vort_normalized = vort / max_vort if max_vort != 0 else vort

max_vort_FD = np.max(np.abs(vort_FD))
vort_normalized_FD = vort_FD / max_vort_FD if max_vort_FD != 0 else vort_FD

# %%
plt.figure(figsize=(15, 5))

plt.subplot(1,3,1)
plt.contourf(X, Y, vort_normalized_FD, levels=50, cmap='RdBu_r')
plt.title('Finite Difference')
plt.colorbar()

plt.subplot(1,3,2)
plt.contourf(X, Y, vort_normalized, levels=50, cmap='RdBu_r')
plt.title('Numpy Gradient')
plt.colorbar()

plt.subplot(1,3,3)
plt.contourf(X, Y, vort_normalized_FD-vort_normalized, levels=50, cmap='RdBu_r')
plt.title('Difference')
plt.colorbar()

plt.show()

# %% [markdown]
# 从这个结果看，我们采用np的内置梯度求导函数的结果与Zhaoyuan Meng(2023)的文章从视觉上看是一直的，而采用有限差分的求梯度似乎存在一定的问题，这个问题，在有np内置梯度函数的情况下，目前不太影响我们的模型，因此，我们当前先记录下这个问题，继续进行后续模型的训练。
#
#
# 根据上述文中代码所属，我们最后选择是：
# 1. 速度变量的分量是：`U_x, U_y, U_magnitude`
# 2. 归一化后的涡量是：`vort_normalized`

# %% [markdown]
# # $model_A$训练

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import DataLoader, TensorDataset, random_split

# %%
import os
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation

# %%
# 将数据转换为PyTorch张量
U_x = torch.tensor(U_x, dtype=torch.float32).unsqueeze(0).unsqueeze(0)  # 增加batch和channel维度
U_y = torch.tensor(U_y, dtype=torch.float32).unsqueeze(0).unsqueeze(0)
U_magnitude = torch.tensor(U_magnitude, dtype=torch.float32).unsqueeze(0).unsqueeze(0)

# 合并速度场作为输入
velocity_field = torch.cat((U_x, U_y, U_magnitude), dim=1)

# 目标abcd (假设为0初始化)
target_abcd = torch.zeros((1, 4, size, size), dtype=torch.float32)

# 创建数据集和数据加载器
dataset = TensorDataset(velocity_field, target_abcd)
dataloader = DataLoader(dataset, batch_size=500, shuffle=True)

# %%
# class ModelA(nn.Module):
#     def __init__(self):
#         super(ModelA, self).__init__()
#         self.conv1 = nn.Conv2d(3, 64, kernel_size=3, padding=1)
#         self.bn1 = nn.BatchNorm2d(64)
#         self.conv2 = nn.Conv2d(64, 128, kernel_size=3, padding=1)
#         self.bn2 = nn.BatchNorm2d(128)
#         self.conv3 = nn.Conv2d(128, 256, kernel_size=3, padding=1)
#         self.bn3 = nn.BatchNorm2d(256)
#         self.pool = nn.MaxPool2d(2, 2)
#         self.conv4 = nn.Conv2d(256, 512, kernel_size=3, padding=1)
#         self.bn4 = nn.BatchNorm2d(512)
#         self.upsample = nn.Upsample(scale_factor=8, mode='bilinear', align_corners=True)
#         self.conv5 = nn.Conv2d(512, 4, kernel_size=3, padding=1)

#     def forward(self, x):
#         x = F.relu(self.bn1(self.conv1(x)))
#         x = self.pool(x)
#         x = F.relu(self.bn2(self.conv2(x)))
#         x = self.pool(x)
#         x = F.relu(self.bn3(self.conv3(x)))
#         x = self.pool(x)
#         x = F.relu(self.bn4(self.conv4(x)))
#         x = self.upsample(x)  # 使用上采样恢复到原始尺寸
#         x = self.conv5(x)
#         return x

class BasicModelA(nn.Module):
    def __init__(self):
        super(BasicModelA, self).__init__()
        self.conv1 = nn.Conv2d(3, 64, kernel_size=3, padding=1)
        self.bn1 = nn.BatchNorm2d(64)
        self.conv2 = nn.Conv2d(64, 128, kernel_size=3, padding=1)
        self.bn2 = nn.BatchNorm2d(128)
        self.conv3 = nn.Conv2d(128, 256, kernel_size=3, padding=1)
        self.bn3 = nn.BatchNorm2d(256)
        self.pool = nn.MaxPool2d(2, 2)
        self.conv4 = nn.Conv2d(256, 512, kernel_size=3, padding=1)
        self.bn4 = nn.BatchNorm2d(512)
        self.upsample = nn.Upsample(scale_factor=8, mode='bilinear', align_corners=True)
        self.conv5 = nn.Conv2d(512, 4, kernel_size=3, padding=1)

    def forward(self, x):
        x = F.relu(self.bn1(self.conv1(x)))
        x = self.pool(x)
        x = F.relu(self.bn2(self.conv2(x)))
        x = self.pool(x)
        x = F.relu(self.bn3(self.conv3(x)))
        x = self.pool(x)
        x = F.relu(self.bn4(self.conv4(x)))
        x = self.upsample(x)  # 使用上采样恢复到原始尺寸
        x = self.conv5(x)
        return x

class ConstraintLayer(nn.Module):
    def __init__(self):
        super(ConstraintLayer, self).__init__()

    def forward(self, x):
        # 假设x的形状为 [batch_size, 4, height, width]，其中4代表abcd
        norm = torch.sqrt(x[:, 0, :, :]**2 + x[:, 1, :, :]**2 + x[:, 2, :, :]**2 + x[:, 3, :, :]**2 + 1e-8)
        norm = norm.unsqueeze(1)  # 为了与abcd的四个通道对齐
        x = x / norm  # 归一化
        return x
    

class ModelAWithConstraints(nn.Module):
    def __init__(self):
        super(ModelAWithConstraints, self).__init__()
        self.model = BasicModelA()
        self.constraint_layer = ConstraintLayer()

    def forward(self, x):
        x = self.model(x)
        x = self.constraint_layer(x)
        return x

# %% [markdown]
# ### 传统 loss function
# 这里的loss function我们进行了修改

# %%
# 定义损失函数
# 这个 loss function 比较基础，没有考虑数学和物理相关知识。
def loss_function(predicted_abcd, true_velocity, epsilon):
    # 提取 a, b, c, d
    a = predicted_abcd[:, 0, :, :]
    b = predicted_abcd[:, 1, :, :]
    c = predicted_abcd[:, 2, :, :]
    d = predicted_abcd[:, 3, :, :]

    # 根据 a, b, c, d 计算预测的速度场
    U_x_pred = a + b
    U_y_pred = c + d
    U_magnitude_pred = torch.sqrt(U_x_pred**2 + U_y_pred**2)
    
    # 计算速度场的损失
    U_x_true = true_velocity[:, 0, :, :]
    U_y_true = true_velocity[:, 1, :, :]
    U_magnitude_true = true_velocity[:, 2, :, :]
    
    loss_velocity = F.mse_loss(U_x_pred, U_x_true) + F.mse_loss(U_y_pred, U_y_true) + F.mse_loss(U_magnitude_pred, U_magnitude_true)
    
    # 计算正则化项
    regularization_term = epsilon * (torch.sum(a**2) + torch.sum(b**2) + torch.sum(c**2) + torch.sum(d**2))
    
    # 总损失
    total_loss = loss_velocity + regularization_term
    return total_loss

# %% [markdown]
# ### 考虑数学和物理约束的loss function

# %%
def calculate_gradients_with_numpy(tensor):
    # 确保 Tensor 不需要梯度跟踪，且在 CPU 上
    tensor_np = tensor.detach().cpu().numpy()

   
    # 计算梯度
    grad_x = np.gradient(tensor_np, axis=1)  # 假设水平方向是 axis=1
    grad_y = np.gradient(tensor_np, axis=2)  # 假设垂直方向是 axis=2
    
    # 转换回 Tensor
    grad_x_tensor = torch.from_numpy(grad_x).to(tensor.device)
    grad_y_tensor = torch.from_numpy(grad_y).to(tensor.device)
    
    return grad_x_tensor, grad_y_tensor

# %%
def laplacian_2d(array, dx, dy):
    grad_x = np.gradient(array, dx, axis=1, edge_order=2)  # 计算 x 方向的一阶导数
    grad_y = np.gradient(array, dy, axis=0, edge_order=2)  # 计算 y 方向的一阶导数
    
    laplacian_x = np.gradient(grad_x, dx, axis=1, edge_order=2)  # 计算 x 方向的二阶导数
    laplacian_y = np.gradient(grad_y, dy, axis=0, edge_order=2)  # 计算 y 方向的二阶导数
    
    return laplacian_x + laplacian_y


def laplacian_2d_torch(tensor, dx, dy):
    # 确保tensor是浮点类型，因为梯度计算通常需要浮点运算
    tensor = tensor.float()
    tensor_np = tensor.detach().cpu().numpy()

    # 计算x和y方向的一阶导数
    grad_x = np.gradient(tensor_np, axis=1)  # x方向
    grad_y = np.gradient(tensor_np, axis=2)  # y方向

    # 计算x和y方向的二阶导数
    laplacian_x = np.gradient(grad_x, axis=1)
    laplacian_y = np.gradient(grad_y, axis=2)

    laplacian_x_tensor = torch.from_numpy(laplacian_x).to(tensor.device)
    laplacian_y_tensor = torch.from_numpy(laplacian_y).to(tensor.device)

    # 相加得到完整的拉普拉斯算子
    laplacian = laplacian_x_tensor + laplacian_y_tensor

    return laplacian

# %%
# # 简单测试一下正确性
# import numpy as np
# import matplotlib.pyplot as plt


# # 设置
# x = np.linspace(0, 10, 100)
# y = np.linspace(0, 10, 100)
# xx, yy = np.meshgrid(x, y)
# array = np.sin(xx) + np.cos(yy)

# # 计算拉普拉斯的正确步长
# dx = dy = (10 - 0) / (100 - 1)
# laplacian_calculated = laplacian_2d(array, dx, dy)
# correct_laplacian = -np.sin(xx) - np.cos(yy)

# # 可视化比较
# plt.figure(figsize=(15, 5))
# plt.subplot(1, 3, 1)
# plt.imshow(correct_laplacian, extent=(0, 10, 0, 10), origin='lower')
# plt.colorbar()
# plt.title('Correct Laplacian')

# plt.subplot(1, 3, 2)
# plt.imshow(laplacian_calculated, extent=(0, 10, 0, 10), origin='lower')
# plt.colorbar()
# plt.title('Calculated Laplacian')

# plt.subplot(1, 3, 3)
# plt.imshow(laplacian_calculated - correct_laplacian, extent=(0, 10, 0, 10), origin='lower')
# plt.colorbar()
# plt.title('Difference')

# plt.show()

# %%
# 定义损失函数
# 这个 loss function 考虑了数学和物理约束
def loss_function(predicted_abcd, true_velocity, epsilon):
    # 提取 a, b, c, d
    # 提取 a, b, c, d，并增加批次维度以兼容梯度计算
    a = predicted_abcd[:, 0, :, :]
    b = predicted_abcd[:, 1, :, :]
    c = predicted_abcd[:, 2, :, :]
    d = predicted_abcd[:, 3, :, :]
    # print(a.shape)
    
    # 计算梯度
    a_grad_x, a_grad_y = calculate_gradients_with_numpy(a)
    b_grad_x, b_grad_y = calculate_gradients_with_numpy(b)
    c_grad_x, c_grad_y = calculate_gradients_with_numpy(c)
    d_grad_x, d_grad_y = calculate_gradients_with_numpy(d)

    hbar = 1  # 你可以根据具体情况调整这个参数


        # 根据 a, b, c, d 计算预测的速度场
    U_x_pred = a + b
    U_y_pred = c + d
    U_magnitude_pred = torch.sqrt(U_x_pred**2 + U_y_pred**2)
    
    # 计算速度场的损失
    U_x_true = true_velocity[:, 0, :, :]
    U_y_true = true_velocity[:, 1, :, :]
    U_magnitude_true = true_velocity[:, 2, :, :]


    # U_x_pred = hbar * (a * b_grad_x - b * a_grad_x + c * d_grad_x - d * c_grad_x)
    # U_y_pred = hbar * (a * b_grad_y - b * a_grad_y + c * d_grad_y - d * c_grad_y)
    # U_magnitude_pred = torch.sqrt(U_x_pred**2 + U_y_pred**2)
    
    # # 计算速度场的损失
    # U_x_true = true_velocity[:, 0, :, :]
    # U_y_true = true_velocity[:, 1, :, :]
    # U_magnitude_true = true_velocity[:, 2, :, :]


    loss_velocity =  F.mse_loss(U_magnitude_pred, U_magnitude_true)+F.mse_loss(U_x_pred, U_x_true) + F.mse_loss(U_y_pred, U_y_true) 
    
    # 计算归一化约束
    # psi1 = a + 1j * b
    # psi2 = c + 1j * d
    norm = a**2 + b**2 + c**2 + d**2

    
    norm_constraint = F.mse_loss(norm, torch.ones_like(norm))

    #     # 计算拉普拉斯算子
    lap_b = laplacian_2d_torch(b, dx,dy)
    lap_a = laplacian_2d_torch(a, dx,dy)
    lap_d = laplacian_2d_torch(d, dx,dy)
    lap_c = laplacian_2d_torch(c, dx,dy)

    # # 计算螺旋度约束

    curl_constraint = (a * lap_b - b * lap_a + c * lap_d - d * lap_c).sum()
    
    # # 计算正则化项
    regularization_term = epsilon * 0.25*(torch.sum(a**2) + torch.sum(b**2) + torch.sum(c**2) + torch.sum(d**2))
    
    # # 总损失
    total_loss = loss_velocity #+ norm_constraint + curl_constraint #+ regularization_term 
    return total_loss

# %%
# 超参数
learning_rate = 0.001
num_epochs = 1000
epsilon = 0.01

# 创建模型和优化器
model = ModelAWithConstraints()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

# %%
# 训练模型
for epoch in range(num_epochs):
    for i, (velocity, _) in enumerate(dataloader):
        optimizer.zero_grad()
        predicted_abcd = model(velocity)
        loss = loss_function(predicted_abcd, velocity, epsilon)
        loss.backward()
        optimizer.step()
        if i % 10 == 0:
            print(f'Epoch [{epoch+1}/{num_epochs}], Step [{i+1}], Loss: {loss.item():.4f}')
# Out:
# Epoch [1/1000], Step [1], Loss: 1.3430
# Epoch [2/1000], Step [1], Loss: 0.5879
# Epoch [3/1000], Step [1], Loss: 0.3811
# Epoch [4/1000], Step [1], Loss: 0.2523
# Epoch [5/1000], Step [1], Loss: 0.1629
# Epoch [6/1000], Step [1], Loss: 0.1058
# Epoch [7/1000], Step [1], Loss: 0.0739
# Epoch [8/1000], Step [1], Loss: 0.0599
# Epoch [9/1000], Step [1], Loss: 0.0552
# Epoch [10/1000], Step [1], Loss: 0.0537
# Epoch [11/1000], Step [1], Loss: 0.0516
# Epoch [12/1000], Step [1], Loss: 0.0477
# Epoch [13/1000], Step [1], Loss: 0.0436
# Epoch [14/1000], Step [1], Loss: 0.0409
# Epoch [15/1000], Step [1], Loss: 0.0399
# Epoch [16/1000], Step [1], Loss: 0.0395
# Epoch [17/1000], Step [1], Loss: 0.0389
# Epoch [18/1000], Step [1], Loss: 0.0374
# Epoch [19/1000], Step [1], Loss: 0.0354
# Epoch [20/1000], Step [1], Loss: 0.0335
# Epoch [21/1000], Step [1], Loss: 0.0322
# Epoch [22/1000], Step [1], Loss: 0.0314
# Epoch [23/1000], Step [1], Loss: 0.0309
# Epoch [24/1000], Step [1], Loss: 0.0303
# Epoch [25/1000], Step [1], Loss: 0.0295
# Epoch [26/1000], Step [1], Loss: 0.0285
# Epoch [27/1000], Step [1], Loss: 0.0275
# Epoch [28/1000], Step [1], Loss: 0.0266
# Epoch [29/1000], Step [1], Loss: 0.0259
# Epoch [30/1000], Step [1], Loss: 0.0254
# Epoch [31/1000], Step [1], Loss: 0.0247
# Epoch [32/1000], Step [1], Loss: 0.0239
# Epoch [33/1000], Step [1], Loss: 0.0231
# Epoch [34/1000], Step [1], Loss: 0.0223
# Epoch [35/1000], Step [1], Loss: 0.0217
# Epoch [36/1000], Step [1], Loss: 0.0212
# Epoch [37/1000], Step [1], Loss: 0.0207
# Epoch [38/1000], Step [1], Loss: 0.0201
# Epoch [39/1000], Step [1], Loss: 0.0195
# Epoch [40/1000], Step [1], Loss: 0.0190
# Epoch [41/1000], Step [1], Loss: 0.0185
# Epoch [42/1000], Step [1], Loss: 0.0181
# Epoch [43/1000], Step [1], Loss: 0.0177
# Epoch [44/1000], Step [1], Loss: 0.0173
# Epoch [45/1000], Step [1], Loss: 0.0169
# Epoch [46/1000], Step [1], Loss: 0.0165
# Epoch [47/1000], Step [1], Loss: 0.0161
# Epoch [48/1000], Step [1], Loss: 0.0158
# Epoch [49/1000], Step [1], Loss: 0.0154
# Epoch [50/1000], Step [1], Loss: 0.0151
# Epoch [51/1000], Step [1], Loss: 0.0147
# Epoch [52/1000], Step [1], Loss: 0.0144
# Epoch [53/1000], Step [1], Loss: 0.0141
# Epoch [54/1000], Step [1], Loss: 0.0138
# Epoch [55/1000], Step [1], Loss: 0.0136
# Epoch [56/1000], Step [1], Loss: 0.0133
# Epoch [57/1000], Step [1], Loss: 0.0130
# Epoch [58/1000], Step [1], Loss: 0.0128
# Epoch [59/1000], Step [1], Loss: 0.0125
# Epoch [60/1000], Step [1], Loss: 0.0123
# Epoch [61/1000], Step [1], Loss: 0.0120
# Epoch [62/1000], Step [1], Loss: 0.0118
# Epoch [63/1000], Step [1], Loss: 0.0116
# Epoch [64/1000], Step [1], Loss: 0.0114
# Epoch [65/1000], Step [1], Loss: 0.0112
# Epoch [66/1000], Step [1], Loss: 0.0110
# Epoch [67/1000], Step [1], Loss: 0.0108
# Epoch [68/1000], Step [1], Loss: 0.0106
# Epoch [69/1000], Step [1], Loss: 0.0104
# Epoch [70/1000], Step [1], Loss: 0.0103
# Epoch [71/1000], Step [1], Loss: 0.0101
# Epoch [72/1000], Step [1], Loss: 0.0099
# Epoch [73/1000], Step [1], Loss: 0.0098
# Epoch [74/1000], Step [1], Loss: 0.0096
# Epoch [75/1000], Step [1], Loss: 0.0095
# Epoch [76/1000], Step [1], Loss: 0.0093
# Epoch [77/1000], Step [1], Loss: 0.0092
# Epoch [78/1000], Step [1], Loss: 0.0091
# Epoch [79/1000], Step [1], Loss: 0.0089
# Epoch [80/1000], Step [1], Loss: 0.0088
# Epoch [81/1000], Step [1], Loss: 0.0087
# Epoch [82/1000], Step [1], Loss: 0.0086
# Epoch [83/1000], Step [1], Loss: 0.0085
# Epoch [84/1000], Step [1], Loss: 0.0083
# Epoch [85/1000], Step [1], Loss: 0.0082
# Epoch [86/1000], Step [1], Loss: 0.0081
# Epoch [87/1000], Step [1], Loss: 0.0080
# Epoch [88/1000], Step [1], Loss: 0.0079
# Epoch [89/1000], Step [1], Loss: 0.0078
# Epoch [90/1000], Step [1], Loss: 0.0077
# Epoch [91/1000], Step [1], Loss: 0.0076
# Epoch [92/1000], Step [1], Loss: 0.0076
# Epoch [93/1000], Step [1], Loss: 0.0075
# Epoch [94/1000], Step [1], Loss: 0.0074
# Epoch [95/1000], Step [1], Loss: 0.0073
# Epoch [96/1000], Step [1], Loss: 0.0072
# Epoch [97/1000], Step [1], Loss: 0.0071
# Epoch [98/1000], Step [1], Loss: 0.0070
# Epoch [99/1000], Step [1], Loss: 0.0070
# Epoch [100/1000], Step [1], Loss: 0.0069
# Epoch [101/1000], Step [1], Loss: 0.0068
# Epoch [102/1000], Step [1], Loss: 0.0067
# Epoch [103/1000], Step [1], Loss: 0.0067
# Epoch [104/1000], Step [1], Loss: 0.0066
# Epoch [105/1000], Step [1], Loss: 0.0065
# Epoch [106/1000], Step [1], Loss: 0.0065
# Epoch [107/1000], Step [1], Loss: 0.0064
# Epoch [108/1000], Step [1], Loss: 0.0063
# Epoch [109/1000], Step [1], Loss: 0.0063
# Epoch [110/1000], Step [1], Loss: 0.0062
# Epoch [111/1000], Step [1], Loss: 0.0061
# Epoch [112/1000], Step [1], Loss: 0.0061
# Epoch [113/1000], Step [1], Loss: 0.0060
# Epoch [114/1000], Step [1], Loss: 0.0060
# Epoch [115/1000], Step [1], Loss: 0.0059
# Epoch [116/1000], Step [1], Loss: 0.0058
# Epoch [117/1000], Step [1], Loss: 0.0058
# Epoch [118/1000], Step [1], Loss: 0.0057
# Epoch [119/1000], Step [1], Loss: 0.0057
# Epoch [120/1000], Step [1], Loss: 0.0056
# Epoch [121/1000], Step [1], Loss: 0.0056
# Epoch [122/1000], Step [1], Loss: 0.0055
# Epoch [123/1000], Step [1], Loss: 0.0055
# Epoch [124/1000], Step [1], Loss: 0.0055
# Epoch [125/1000], Step [1], Loss: 0.0054
# Epoch [126/1000], Step [1], Loss: 0.0054
# Epoch [127/1000], Step [1], Loss: 0.0055
# Epoch [128/1000], Step [1], Loss: 0.0055
# Epoch [129/1000], Step [1], Loss: 0.0054
# Epoch [130/1000], Step [1], Loss: 0.0052
# Epoch [131/1000], Step [1], Loss: 0.0051
# Epoch [132/1000], Step [1], Loss: 0.0052
# Epoch [133/1000], Step [1], Loss: 0.0052
# Epoch [134/1000], Step [1], Loss: 0.0051
# Epoch [135/1000], Step [1], Loss: 0.0050
# Epoch [136/1000], Step [1], Loss: 0.0049
# Epoch [137/1000], Step [1], Loss: 0.0049
# Epoch [138/1000], Step [1], Loss: 0.0050
# Epoch [139/1000], Step [1], Loss: 0.0050
# Epoch [140/1000], Step [1], Loss: 0.0050
# Epoch [141/1000], Step [1], Loss: 0.0050
# Epoch [142/1000], Step [1], Loss: 0.0048
# Epoch [143/1000], Step [1], Loss: 0.0047
# Epoch [144/1000], Step [1], Loss: 0.0047
# Epoch [145/1000], Step [1], Loss: 0.0048
# Epoch [146/1000], Step [1], Loss: 0.0048
# Epoch [147/1000], Step [1], Loss: 0.0046
# Epoch [148/1000], Step [1], Loss: 0.0045
# Epoch [149/1000], Step [1], Loss: 0.0045
# Epoch [150/1000], Step [1], Loss: 0.0045
# Epoch [151/1000], Step [1], Loss: 0.0045
# Epoch [152/1000], Step [1], Loss: 0.0045
# Epoch [153/1000], Step [1], Loss: 0.0046
# Epoch [154/1000], Step [1], Loss: 0.0047
# Epoch [155/1000], Step [1], Loss: 0.0049
# Epoch [156/1000], Step [1], Loss: 0.0047
# Epoch [157/1000], Step [1], Loss: 0.0044
# Epoch [158/1000], Step [1], Loss: 0.0043
# Epoch [159/1000], Step [1], Loss: 0.0044
# Epoch [160/1000], Step [1], Loss: 0.0044
# Epoch [161/1000], Step [1], Loss: 0.0042
# Epoch [162/1000], Step [1], Loss: 0.0042
# Epoch [163/1000], Step [1], Loss: 0.0043
# Epoch [164/1000], Step [1], Loss: 0.0043
# Epoch [165/1000], Step [1], Loss: 0.0041
# Epoch [166/1000], Step [1], Loss: 0.0040
# Epoch [167/1000], Step [1], Loss: 0.0040
# Epoch [168/1000], Step [1], Loss: 0.0041
# Epoch [169/1000], Step [1], Loss: 0.0041
# Epoch [170/1000], Step [1], Loss: 0.0041
# Epoch [171/1000], Step [1], Loss: 0.0041
# Epoch [172/1000], Step [1], Loss: 0.0040
# Epoch [173/1000], Step [1], Loss: 0.0039
# Epoch [174/1000], Step [1], Loss: 0.0038
# Epoch [175/1000], Step [1], Loss: 0.0038
# Epoch [176/1000], Step [1], Loss: 0.0039
# Epoch [177/1000], Step [1], Loss: 0.0040
# Epoch [178/1000], Step [1], Loss: 0.0041
# Epoch [179/1000], Step [1], Loss: 0.0043
# Epoch [180/1000], Step [1], Loss: 0.0044
# Epoch [181/1000], Step [1], Loss: 0.0042
# Epoch [182/1000], Step [1], Loss: 0.0039
# Epoch [183/1000], Step [1], Loss: 0.0037
# Epoch [184/1000], Step [1], Loss: 0.0039
# Epoch [185/1000], Step [1], Loss: 0.0040
# Epoch [186/1000], Step [1], Loss: 0.0038
# Epoch [187/1000], Step [1], Loss: 0.0036
# Epoch [188/1000], Step [1], Loss: 0.0037
# Epoch [189/1000], Step [1], Loss: 0.0038
# Epoch [190/1000], Step [1], Loss: 0.0038
# Epoch [191/1000], Step [1], Loss: 0.0036
# Epoch [192/1000], Step [1], Loss: 0.0035
# Epoch [193/1000], Step [1], Loss: 0.0035
# Epoch [194/1000], Step [1], Loss: 0.0036
# Epoch [195/1000], Step [1], Loss: 0.0037
# Epoch [196/1000], Step [1], Loss: 0.0037
# Epoch [197/1000], Step [1], Loss: 0.0036
# Epoch [198/1000], Step [1], Loss: 0.0034
# Epoch [199/1000], Step [1], Loss: 0.0034
# Epoch [200/1000], Step [1], Loss: 0.0033
# Epoch [201/1000], Step [1], Loss: 0.0034
# Epoch [202/1000], Step [1], Loss: 0.0035
# Epoch [203/1000], Step [1], Loss: 0.0037
# Epoch [204/1000], Step [1], Loss: 0.0040
# Epoch [205/1000], Step [1], Loss: 0.0044
# Epoch [206/1000], Step [1], Loss: 0.0043
# Epoch [207/1000], Step [1], Loss: 0.0037
# Epoch [208/1000], Step [1], Loss: 0.0033
# Epoch [209/1000], Step [1], Loss: 0.0037
# Epoch [210/1000], Step [1], Loss: 0.0037
# Epoch [211/1000], Step [1], Loss: 0.0032
# Epoch [212/1000], Step [1], Loss: 0.0034
# Epoch [213/1000], Step [1], Loss: 0.0036
# Epoch [214/1000], Step [1], Loss: 0.0032
# Epoch [215/1000], Step [1], Loss: 0.0032
# Epoch [216/1000], Step [1], Loss: 0.0034
# Epoch [217/1000], Step [1], Loss: 0.0032
# Epoch [218/1000], Step [1], Loss: 0.0032
# Epoch [219/1000], Step [1], Loss: 0.0033
# Epoch [220/1000], Step [1], Loss: 0.0031
# Epoch [221/1000], Step [1], Loss: 0.0032
# Epoch [222/1000], Step [1], Loss: 0.0033
# Epoch [223/1000], Step [1], Loss: 0.0030
# Epoch [224/1000], Step [1], Loss: 0.0033
# Epoch [225/1000], Step [1], Loss: 0.0033
# Epoch [226/1000], Step [1], Loss: 0.0030
# Epoch [227/1000], Step [1], Loss: 0.0033
# Epoch [228/1000], Step [1], Loss: 0.0030
# Epoch [229/1000], Step [1], Loss: 0.0030
# Epoch [230/1000], Step [1], Loss: 0.0031
# Epoch [231/1000], Step [1], Loss: 0.0028
# Epoch [232/1000], Step [1], Loss: 0.0030
# Epoch [233/1000], Step [1], Loss: 0.0029
# Epoch [234/1000], Step [1], Loss: 0.0028
# Epoch [235/1000], Step [1], Loss: 0.0029
# Epoch [236/1000], Step [1], Loss: 0.0027
# Epoch [237/1000], Step [1], Loss: 0.0028
# Epoch [238/1000], Step [1], Loss: 0.0030
# Epoch [239/1000], Step [1], Loss: 0.0034
# Epoch [240/1000], Step [1], Loss: 0.0050
# Epoch [241/1000], Step [1], Loss: 0.0081
# Epoch [242/1000], Step [1], Loss: 0.0052
# Epoch [243/1000], Step [1], Loss: 0.0045
# Epoch [244/1000], Step [1], Loss: 0.0059
# Epoch [245/1000], Step [1], Loss: 0.0037
# Epoch [246/1000], Step [1], Loss: 0.0053
# Epoch [247/1000], Step [1], Loss: 0.0038
# Epoch [248/1000], Step [1], Loss: 0.0047
# Epoch [249/1000], Step [1], Loss: 0.0039
# Epoch [250/1000], Step [1], Loss: 0.0042
# Epoch [251/1000], Step [1], Loss: 0.0038
# Epoch [252/1000], Step [1], Loss: 0.0040
# Epoch [253/1000], Step [1], Loss: 0.0035
# Epoch [254/1000], Step [1], Loss: 0.0038
# Epoch [255/1000], Step [1], Loss: 0.0034
# Epoch [256/1000], Step [1], Loss: 0.0035
# Epoch [257/1000], Step [1], Loss: 0.0033
# Epoch [258/1000], Step [1], Loss: 0.0033
# Epoch [259/1000], Step [1], Loss: 0.0032
# Epoch [260/1000], Step [1], Loss: 0.0032
# Epoch [261/1000], Step [1], Loss: 0.0031
# Epoch [262/1000], Step [1], Loss: 0.0032
# Epoch [263/1000], Step [1], Loss: 0.0029
# Epoch [264/1000], Step [1], Loss: 0.0031
# Epoch [265/1000], Step [1], Loss: 0.0028
# Epoch [266/1000], Step [1], Loss: 0.0029
# Epoch [267/1000], Step [1], Loss: 0.0028
# Epoch [268/1000], Step [1], Loss: 0.0028
# Epoch [269/1000], Step [1], Loss: 0.0028
# Epoch [270/1000], Step [1], Loss: 0.0027
# Epoch [271/1000], Step [1], Loss: 0.0027
# Epoch [272/1000], Step [1], Loss: 0.0026
# Epoch [273/1000], Step [1], Loss: 0.0026
# Epoch [274/1000], Step [1], Loss: 0.0026
# Epoch [275/1000], Step [1], Loss: 0.0025
# Epoch [276/1000], Step [1], Loss: 0.0025
# Epoch [277/1000], Step [1], Loss: 0.0025
# Epoch [278/1000], Step [1], Loss: 0.0024
# Epoch [279/1000], Step [1], Loss: 0.0024
# Epoch [280/1000], Step [1], Loss: 0.0024
# Epoch [281/1000], Step [1], Loss: 0.0023
# Epoch [282/1000], Step [1], Loss: 0.0023
# Epoch [283/1000], Step [1], Loss: 0.0023
# Epoch [284/1000], Step [1], Loss: 0.0023
# Epoch [285/1000], Step [1], Loss: 0.0022
# Epoch [286/1000], Step [1], Loss: 0.0022
# Epoch [287/1000], Step [1], Loss: 0.0022
# Epoch [288/1000], Step [1], Loss: 0.0022
# Epoch [289/1000], Step [1], Loss: 0.0022
# Epoch [290/1000], Step [1], Loss: 0.0023
# Epoch [291/1000], Step [1], Loss: 0.0024
# Epoch [292/1000], Step [1], Loss: 0.0025
# Epoch [293/1000], Step [1], Loss: 0.0027
# Epoch [294/1000], Step [1], Loss: 0.0025
# Epoch [295/1000], Step [1], Loss: 0.0022
# Epoch [296/1000], Step [1], Loss: 0.0020
# Epoch [297/1000], Step [1], Loss: 0.0022
# Epoch [298/1000], Step [1], Loss: 0.0024
# Epoch [299/1000], Step [1], Loss: 0.0023
# Epoch [300/1000], Step [1], Loss: 0.0022
# Epoch [301/1000], Step [1], Loss: 0.0020
# Epoch [302/1000], Step [1], Loss: 0.0019
# Epoch [303/1000], Step [1], Loss: 0.0020
# Epoch [304/1000], Step [1], Loss: 0.0021
# Epoch [305/1000], Step [1], Loss: 0.0023
# Epoch [306/1000], Step [1], Loss: 0.0024
# Epoch [307/1000], Step [1], Loss: 0.0023
# Epoch [308/1000], Step [1], Loss: 0.0021
# Epoch [309/1000], Step [1], Loss: 0.0019
# Epoch [310/1000], Step [1], Loss: 0.0018
# Epoch [311/1000], Step [1], Loss: 0.0019
# Epoch [312/1000], Step [1], Loss: 0.0021
# Epoch [313/1000], Step [1], Loss: 0.0021
# Epoch [314/1000], Step [1], Loss: 0.0020
# Epoch [315/1000], Step [1], Loss: 0.0018
# Epoch [316/1000], Step [1], Loss: 0.0017
# Epoch [317/1000], Step [1], Loss: 0.0018
# Epoch [318/1000], Step [1], Loss: 0.0018
# Epoch [319/1000], Step [1], Loss: 0.0017
# Epoch [320/1000], Step [1], Loss: 0.0017
# Epoch [321/1000], Step [1], Loss: 0.0017
# Epoch [322/1000], Step [1], Loss: 0.0018
# Epoch [323/1000], Step [1], Loss: 0.0023
# Epoch [324/1000], Step [1], Loss: 0.0036
# Epoch [325/1000], Step [1], Loss: 0.0049
# Epoch [326/1000], Step [1], Loss: 0.0035
# Epoch [327/1000], Step [1], Loss: 0.0038
# Epoch [328/1000], Step [1], Loss: 0.0026
# Epoch [329/1000], Step [1], Loss: 0.0033
# Epoch [330/1000], Step [1], Loss: 0.0033
# Epoch [331/1000], Step [1], Loss: 0.0026
# Epoch [332/1000], Step [1], Loss: 0.0032
# Epoch [333/1000], Step [1], Loss: 0.0027
# Epoch [334/1000], Step [1], Loss: 0.0027
# Epoch [335/1000], Step [1], Loss: 0.0027
# Epoch [336/1000], Step [1], Loss: 0.0026
# Epoch [337/1000], Step [1], Loss: 0.0024
# Epoch [338/1000], Step [1], Loss: 0.0026
# Epoch [339/1000], Step [1], Loss: 0.0024
# Epoch [340/1000], Step [1], Loss: 0.0021
# Epoch [341/1000], Step [1], Loss: 0.0024
# Epoch [342/1000], Step [1], Loss: 0.0022
# Epoch [343/1000], Step [1], Loss: 0.0021
# Epoch [344/1000], Step [1], Loss: 0.0023
# Epoch [345/1000], Step [1], Loss: 0.0021
# Epoch [346/1000], Step [1], Loss: 0.0020
# Epoch [347/1000], Step [1], Loss: 0.0021
# Epoch [348/1000], Step [1], Loss: 0.0019
# Epoch [349/1000], Step [1], Loss: 0.0019
# Epoch [350/1000], Step [1], Loss: 0.0019
# Epoch [351/1000], Step [1], Loss: 0.0017
# Epoch [352/1000], Step [1], Loss: 0.0018
# Epoch [353/1000], Step [1], Loss: 0.0017
# Epoch [354/1000], Step [1], Loss: 0.0017
# Epoch [355/1000], Step [1], Loss: 0.0017
# Epoch [356/1000], Step [1], Loss: 0.0016
# Epoch [357/1000], Step [1], Loss: 0.0016
# Epoch [358/1000], Step [1], Loss: 0.0016
# Epoch [359/1000], Step [1], Loss: 0.0015
# Epoch [360/1000], Step [1], Loss: 0.0015
# Epoch [361/1000], Step [1], Loss: 0.0016
# Epoch [362/1000], Step [1], Loss: 0.0015
# Epoch [363/1000], Step [1], Loss: 0.0015
# Epoch [364/1000], Step [1], Loss: 0.0014
# Epoch [365/1000], Step [1], Loss: 0.0014
# Epoch [366/1000], Step [1], Loss: 0.0014
# Epoch [367/1000], Step [1], Loss: 0.0014
# Epoch [368/1000], Step [1], Loss: 0.0013
# Epoch [369/1000], Step [1], Loss: 0.0013
# Epoch [370/1000], Step [1], Loss: 0.0013
# Epoch [371/1000], Step [1], Loss: 0.0014
# Epoch [372/1000], Step [1], Loss: 0.0015
# Epoch [373/1000], Step [1], Loss: 0.0020
# Epoch [374/1000], Step [1], Loss: 0.0032
# Epoch [375/1000], Step [1], Loss: 0.0047
# Epoch [376/1000], Step [1], Loss: 0.0046
# Epoch [377/1000], Step [1], Loss: 0.0022
# Epoch [378/1000], Step [1], Loss: 0.0030
# Epoch [379/1000], Step [1], Loss: 0.0028
# Epoch [380/1000], Step [1], Loss: 0.0023
# Epoch [381/1000], Step [1], Loss: 0.0027
# Epoch [382/1000], Step [1], Loss: 0.0023
# Epoch [383/1000], Step [1], Loss: 0.0024
# Epoch [384/1000], Step [1], Loss: 0.0020
# Epoch [385/1000], Step [1], Loss: 0.0022
# Epoch [386/1000], Step [1], Loss: 0.0019
# Epoch [387/1000], Step [1], Loss: 0.0020
# Epoch [388/1000], Step [1], Loss: 0.0019
# Epoch [389/1000], Step [1], Loss: 0.0017
# Epoch [390/1000], Step [1], Loss: 0.0018
# Epoch [391/1000], Step [1], Loss: 0.0016
# Epoch [392/1000], Step [1], Loss: 0.0018
# Epoch [393/1000], Step [1], Loss: 0.0014
# Epoch [394/1000], Step [1], Loss: 0.0017
# Epoch [395/1000], Step [1], Loss: 0.0014
# Epoch [396/1000], Step [1], Loss: 0.0016
# Epoch [397/1000], Step [1], Loss: 0.0013
# Epoch [398/1000], Step [1], Loss: 0.0014
# Epoch [399/1000], Step [1], Loss: 0.0013
# Epoch [400/1000], Step [1], Loss: 0.0013
# Epoch [401/1000], Step [1], Loss: 0.0013
# Epoch [402/1000], Step [1], Loss: 0.0013
# Epoch [403/1000], Step [1], Loss: 0.0013
# Epoch [404/1000], Step [1], Loss: 0.0017
# Epoch [405/1000], Step [1], Loss: 0.0018
# Epoch [406/1000], Step [1], Loss: 0.0024
# Epoch [407/1000], Step [1], Loss: 0.0017
# Epoch [408/1000], Step [1], Loss: 0.0012
# Epoch [409/1000], Step [1], Loss: 0.0016
# Epoch [410/1000], Step [1], Loss: 0.0015
# Epoch [411/1000], Step [1], Loss: 0.0012
# Epoch [412/1000], Step [1], Loss: 0.0014
# Epoch [413/1000], Step [1], Loss: 0.0012
# Epoch [414/1000], Step [1], Loss: 0.0012
# Epoch [415/1000], Step [1], Loss: 0.0012
# Epoch [416/1000], Step [1], Loss: 0.0011
# Epoch [417/1000], Step [1], Loss: 0.0011
# Epoch [418/1000], Step [1], Loss: 0.0012
# Epoch [419/1000], Step [1], Loss: 0.0010
# Epoch [420/1000], Step [1], Loss: 0.0010
# Epoch [421/1000], Step [1], Loss: 0.0011
# Epoch [422/1000], Step [1], Loss: 0.0011
# Epoch [423/1000], Step [1], Loss: 0.0010
# Epoch [424/1000], Step [1], Loss: 0.0010
# Epoch [425/1000], Step [1], Loss: 0.0011
# Epoch [426/1000], Step [1], Loss: 0.0011
# Epoch [427/1000], Step [1], Loss: 0.0011
# Epoch [428/1000], Step [1], Loss: 0.0011
# Epoch [429/1000], Step [1], Loss: 0.0011
# Epoch [430/1000], Step [1], Loss: 0.0011
# Epoch [431/1000], Step [1], Loss: 0.0012
# Epoch [432/1000], Step [1], Loss: 0.0012
# Epoch [433/1000], Step [1], Loss: 0.0011
# Epoch [434/1000], Step [1], Loss: 0.0009
# Epoch [435/1000], Step [1], Loss: 0.0009
# Epoch [436/1000], Step [1], Loss: 0.0010
# Epoch [437/1000], Step [1], Loss: 0.0010
# Epoch [438/1000], Step [1], Loss: 0.0009
# Epoch [439/1000], Step [1], Loss: 0.0008
# Epoch [440/1000], Step [1], Loss: 0.0009
# Epoch [441/1000], Step [1], Loss: 0.0009
# Epoch [442/1000], Step [1], Loss: 0.0009
# Epoch [443/1000], Step [1], Loss: 0.0009
# Epoch [444/1000], Step [1], Loss: 0.0009
# Epoch [445/1000], Step [1], Loss: 0.0010
# Epoch [446/1000], Step [1], Loss: 0.0010
# Epoch [447/1000], Step [1], Loss: 0.0011
# Epoch [448/1000], Step [1], Loss: 0.0010
# Epoch [449/1000], Step [1], Loss: 0.0010
# Epoch [450/1000], Step [1], Loss: 0.0010
# Epoch [451/1000], Step [1], Loss: 0.0011
# Epoch [452/1000], Step [1], Loss: 0.0012
# Epoch [453/1000], Step [1], Loss: 0.0011
# Epoch [454/1000], Step [1], Loss: 0.0009
# Epoch [455/1000], Step [1], Loss: 0.0008
# Epoch [456/1000], Step [1], Loss: 0.0009
# Epoch [457/1000], Step [1], Loss: 0.0010
# Epoch [458/1000], Step [1], Loss: 0.0010
# Epoch [459/1000], Step [1], Loss: 0.0009
# Epoch [460/1000], Step [1], Loss: 0.0010
# Epoch [461/1000], Step [1], Loss: 0.0011
# Epoch [462/1000], Step [1], Loss: 0.0013
# Epoch [463/1000], Step [1], Loss: 0.0011
# Epoch [464/1000], Step [1], Loss: 0.0009
# Epoch [465/1000], Step [1], Loss: 0.0008
# Epoch [466/1000], Step [1], Loss: 0.0009
# Epoch [467/1000], Step [1], Loss: 0.0010
# Epoch [468/1000], Step [1], Loss: 0.0009
# Epoch [469/1000], Step [1], Loss: 0.0008
# Epoch [470/1000], Step [1], Loss: 0.0009
# Epoch [471/1000], Step [1], Loss: 0.0008
# Epoch [472/1000], Step [1], Loss: 0.0008
# Epoch [473/1000], Step [1], Loss: 0.0007
# Epoch [474/1000], Step [1], Loss: 0.0008
# Epoch [475/1000], Step [1], Loss: 0.0009
# Epoch [476/1000], Step [1], Loss: 0.0008
# Epoch [477/1000], Step [1], Loss: 0.0008
# Epoch [478/1000], Step [1], Loss: 0.0009
# Epoch [479/1000], Step [1], Loss: 0.0009
# Epoch [480/1000], Step [1], Loss: 0.0009
# Epoch [481/1000], Step [1], Loss: 0.0008
# Epoch [482/1000], Step [1], Loss: 0.0009
# Epoch [483/1000], Step [1], Loss: 0.0011
# Epoch [484/1000], Step [1], Loss: 0.0012
# Epoch [485/1000], Step [1], Loss: 0.0011
# Epoch [486/1000], Step [1], Loss: 0.0011
# Epoch [487/1000], Step [1], Loss: 0.0010
# Epoch [488/1000], Step [1], Loss: 0.0008
# Epoch [489/1000], Step [1], Loss: 0.0007
# Epoch [490/1000], Step [1], Loss: 0.0008
# Epoch [491/1000], Step [1], Loss: 0.0009
# Epoch [492/1000], Step [1], Loss: 0.0008
# Epoch [493/1000], Step [1], Loss: 0.0007
# Epoch [494/1000], Step [1], Loss: 0.0007
# Epoch [495/1000], Step [1], Loss: 0.0007
# Epoch [496/1000], Step [1], Loss: 0.0007
# Epoch [497/1000], Step [1], Loss: 0.0007
# Epoch [498/1000], Step [1], Loss: 0.0007
# Epoch [499/1000], Step [1], Loss: 0.0007
# Epoch [500/1000], Step [1], Loss: 0.0007
# Epoch [501/1000], Step [1], Loss: 0.0007
# Epoch [502/1000], Step [1], Loss: 0.0006
# Epoch [503/1000], Step [1], Loss: 0.0006
# Epoch [504/1000], Step [1], Loss: 0.0006
# Epoch [505/1000], Step [1], Loss: 0.0006
# Epoch [506/1000], Step [1], Loss: 0.0006
# Epoch [507/1000], Step [1], Loss: 0.0006
# Epoch [508/1000], Step [1], Loss: 0.0006
# Epoch [509/1000], Step [1], Loss: 0.0007
# Epoch [510/1000], Step [1], Loss: 0.0009
# Epoch [511/1000], Step [1], Loss: 0.0012
# Epoch [512/1000], Step [1], Loss: 0.0023
# Epoch [513/1000], Step [1], Loss: 0.0019
# Epoch [514/1000], Step [1], Loss: 0.0020
# Epoch [515/1000], Step [1], Loss: 0.0013
# Epoch [516/1000], Step [1], Loss: 0.0015
# Epoch [517/1000], Step [1], Loss: 0.0019
# Epoch [518/1000], Step [1], Loss: 0.0013
# Epoch [519/1000], Step [1], Loss: 0.0016
# Epoch [520/1000], Step [1], Loss: 0.0012
# Epoch [521/1000], Step [1], Loss: 0.0016
# Epoch [522/1000], Step [1], Loss: 0.0009
# Epoch [523/1000], Step [1], Loss: 0.0012
# Epoch [524/1000], Step [1], Loss: 0.0010
# Epoch [525/1000], Step [1], Loss: 0.0011
# Epoch [526/1000], Step [1], Loss: 0.0009
# Epoch [527/1000], Step [1], Loss: 0.0010
# Epoch [528/1000], Step [1], Loss: 0.0008
# Epoch [529/1000], Step [1], Loss: 0.0009
# Epoch [530/1000], Step [1], Loss: 0.0009
# Epoch [531/1000], Step [1], Loss: 0.0008
# Epoch [532/1000], Step [1], Loss: 0.0009
# Epoch [533/1000], Step [1], Loss: 0.0009
# Epoch [534/1000], Step [1], Loss: 0.0008
# Epoch [535/1000], Step [1], Loss: 0.0007
# Epoch [536/1000], Step [1], Loss: 0.0008
# Epoch [537/1000], Step [1], Loss: 0.0006
# Epoch [538/1000], Step [1], Loss: 0.0007
# Epoch [539/1000], Step [1], Loss: 0.0006
# Epoch [540/1000], Step [1], Loss: 0.0007
# Epoch [541/1000], Step [1], Loss: 0.0006
# Epoch [542/1000], Step [1], Loss: 0.0007
# Epoch [543/1000], Step [1], Loss: 0.0007
# Epoch [544/1000], Step [1], Loss: 0.0007
# Epoch [545/1000], Step [1], Loss: 0.0008
# Epoch [546/1000], Step [1], Loss: 0.0010
# Epoch [547/1000], Step [1], Loss: 0.0015
# Epoch [548/1000], Step [1], Loss: 0.0018
# Epoch [549/1000], Step [1], Loss: 0.0022
# Epoch [550/1000], Step [1], Loss: 0.0017
# Epoch [551/1000], Step [1], Loss: 0.0011
# Epoch [552/1000], Step [1], Loss: 0.0011
# Epoch [553/1000], Step [1], Loss: 0.0010
# Epoch [554/1000], Step [1], Loss: 0.0012
# Epoch [555/1000], Step [1], Loss: 0.0009
# Epoch [556/1000], Step [1], Loss: 0.0008
# Epoch [557/1000], Step [1], Loss: 0.0011
# Epoch [558/1000], Step [1], Loss: 0.0008
# Epoch [559/1000], Step [1], Loss: 0.0008
# Epoch [560/1000], Step [1], Loss: 0.0008
# Epoch [561/1000], Step [1], Loss: 0.0007
# Epoch [562/1000], Step [1], Loss: 0.0008
# Epoch [563/1000], Step [1], Loss: 0.0007
# Epoch [564/1000], Step [1], Loss: 0.0006
# Epoch [565/1000], Step [1], Loss: 0.0007
# Epoch [566/1000], Step [1], Loss: 0.0006
# Epoch [567/1000], Step [1], Loss: 0.0005
# Epoch [568/1000], Step [1], Loss: 0.0006
# Epoch [569/1000], Step [1], Loss: 0.0006
# Epoch [570/1000], Step [1], Loss: 0.0005
# Epoch [571/1000], Step [1], Loss: 0.0006
# Epoch [572/1000], Step [1], Loss: 0.0005
# Epoch [573/1000], Step [1], Loss: 0.0005
# Epoch [574/1000], Step [1], Loss: 0.0005
# Epoch [575/1000], Step [1], Loss: 0.0005
# Epoch [576/1000], Step [1], Loss: 0.0005
# Epoch [577/1000], Step [1], Loss: 0.0005
# Epoch [578/1000], Step [1], Loss: 0.0005
# Epoch [579/1000], Step [1], Loss: 0.0005
# Epoch [580/1000], Step [1], Loss: 0.0005
# Epoch [581/1000], Step [1], Loss: 0.0005
# Epoch [582/1000], Step [1], Loss: 0.0005
# Epoch [583/1000], Step [1], Loss: 0.0005
# Epoch [584/1000], Step [1], Loss: 0.0005
# Epoch [585/1000], Step [1], Loss: 0.0005
# Epoch [586/1000], Step [1], Loss: 0.0006
# Epoch [587/1000], Step [1], Loss: 0.0008
# Epoch [588/1000], Step [1], Loss: 0.0010
# Epoch [589/1000], Step [1], Loss: 0.0015
# Epoch [590/1000], Step [1], Loss: 0.0015
# Epoch [591/1000], Step [1], Loss: 0.0012
# Epoch [592/1000], Step [1], Loss: 0.0008
# Epoch [593/1000], Step [1], Loss: 0.0007
# Epoch [594/1000], Step [1], Loss: 0.0010
# Epoch [595/1000], Step [1], Loss: 0.0006
# Epoch [596/1000], Step [1], Loss: 0.0008
# Epoch [597/1000], Step [1], Loss: 0.0010
# Epoch [598/1000], Step [1], Loss: 0.0005
# Epoch [599/1000], Step [1], Loss: 0.0008
# Epoch [600/1000], Step [1], Loss: 0.0010
# Epoch [601/1000], Step [1], Loss: 0.0006
# Epoch [602/1000], Step [1], Loss: 0.0009
# Epoch [603/1000], Step [1], Loss: 0.0008
# Epoch [604/1000], Step [1], Loss: 0.0006
# Epoch [605/1000], Step [1], Loss: 0.0007
# Epoch [606/1000], Step [1], Loss: 0.0007
# Epoch [607/1000], Step [1], Loss: 0.0006
# Epoch [608/1000], Step [1], Loss: 0.0007
# Epoch [609/1000], Step [1], Loss: 0.0006
# Epoch [610/1000], Step [1], Loss: 0.0006
# Epoch [611/1000], Step [1], Loss: 0.0006
# Epoch [612/1000], Step [1], Loss: 0.0005
# Epoch [613/1000], Step [1], Loss: 0.0005
# Epoch [614/1000], Step [1], Loss: 0.0005
# Epoch [615/1000], Step [1], Loss: 0.0005
# Epoch [616/1000], Step [1], Loss: 0.0005
# Epoch [617/1000], Step [1], Loss: 0.0005
# Epoch [618/1000], Step [1], Loss: 0.0004
# Epoch [619/1000], Step [1], Loss: 0.0005
# Epoch [620/1000], Step [1], Loss: 0.0004
# Epoch [621/1000], Step [1], Loss: 0.0004
# Epoch [622/1000], Step [1], Loss: 0.0005
# Epoch [623/1000], Step [1], Loss: 0.0004
# Epoch [624/1000], Step [1], Loss: 0.0004
# Epoch [625/1000], Step [1], Loss: 0.0004
# Epoch [626/1000], Step [1], Loss: 0.0004
# Epoch [627/1000], Step [1], Loss: 0.0004
# Epoch [628/1000], Step [1], Loss: 0.0004
# Epoch [629/1000], Step [1], Loss: 0.0004
# Epoch [630/1000], Step [1], Loss: 0.0004
# Epoch [631/1000], Step [1], Loss: 0.0005
# Epoch [632/1000], Step [1], Loss: 0.0005
# Epoch [633/1000], Step [1], Loss: 0.0008
# Epoch [634/1000], Step [1], Loss: 0.0011
# Epoch [635/1000], Step [1], Loss: 0.0021
# Epoch [636/1000], Step [1], Loss: 0.0019
# Epoch [637/1000], Step [1], Loss: 0.0013
# Epoch [638/1000], Step [1], Loss: 0.0011
# Epoch [639/1000], Step [1], Loss: 0.0008
# Epoch [640/1000], Step [1], Loss: 0.0009
# Epoch [641/1000], Step [1], Loss: 0.0011
# Epoch [642/1000], Step [1], Loss: 0.0006
# Epoch [643/1000], Step [1], Loss: 0.0009
# Epoch [644/1000], Step [1], Loss: 0.0008
# Epoch [645/1000], Step [1], Loss: 0.0006
# Epoch [646/1000], Step [1], Loss: 0.0008
# Epoch [647/1000], Step [1], Loss: 0.0007
# Epoch [648/1000], Step [1], Loss: 0.0006
# Epoch [649/1000], Step [1], Loss: 0.0006
# Epoch [650/1000], Step [1], Loss: 0.0006
# Epoch [651/1000], Step [1], Loss: 0.0005
# Epoch [652/1000], Step [1], Loss: 0.0006
# Epoch [653/1000], Step [1], Loss: 0.0006
# Epoch [654/1000], Step [1], Loss: 0.0005
# Epoch [655/1000], Step [1], Loss: 0.0005
# Epoch [656/1000], Step [1], Loss: 0.0005
# Epoch [657/1000], Step [1], Loss: 0.0005
# Epoch [658/1000], Step [1], Loss: 0.0005
# Epoch [659/1000], Step [1], Loss: 0.0005
# Epoch [660/1000], Step [1], Loss: 0.0005
# Epoch [661/1000], Step [1], Loss: 0.0004
# Epoch [662/1000], Step [1], Loss: 0.0004
# Epoch [663/1000], Step [1], Loss: 0.0004
# Epoch [664/1000], Step [1], Loss: 0.0004
# Epoch [665/1000], Step [1], Loss: 0.0004
# Epoch [666/1000], Step [1], Loss: 0.0004
# Epoch [667/1000], Step [1], Loss: 0.0004
# Epoch [668/1000], Step [1], Loss: 0.0004
# Epoch [669/1000], Step [1], Loss: 0.0004
# Epoch [670/1000], Step [1], Loss: 0.0004
# Epoch [671/1000], Step [1], Loss: 0.0003
# Epoch [672/1000], Step [1], Loss: 0.0004
# Epoch [673/1000], Step [1], Loss: 0.0003
# Epoch [674/1000], Step [1], Loss: 0.0003
# Epoch [675/1000], Step [1], Loss: 0.0003
# Epoch [676/1000], Step [1], Loss: 0.0003
# Epoch [677/1000], Step [1], Loss: 0.0003
# Epoch [678/1000], Step [1], Loss: 0.0003
# Epoch [679/1000], Step [1], Loss: 0.0003
# Epoch [680/1000], Step [1], Loss: 0.0003
# Epoch [681/1000], Step [1], Loss: 0.0003
# Epoch [682/1000], Step [1], Loss: 0.0003
# Epoch [683/1000], Step [1], Loss: 0.0004
# Epoch [684/1000], Step [1], Loss: 0.0004
# Epoch [685/1000], Step [1], Loss: 0.0004
# Epoch [686/1000], Step [1], Loss: 0.0006
# Epoch [687/1000], Step [1], Loss: 0.0008
# Epoch [688/1000], Step [1], Loss: 0.0008
# Epoch [689/1000], Step [1], Loss: 0.0008
# Epoch [690/1000], Step [1], Loss: 0.0007
# Epoch [691/1000], Step [1], Loss: 0.0005
# Epoch [692/1000], Step [1], Loss: 0.0005
# Epoch [693/1000], Step [1], Loss: 0.0005
# Epoch [694/1000], Step [1], Loss: 0.0004
# Epoch [695/1000], Step [1], Loss: 0.0004
# Epoch [696/1000], Step [1], Loss: 0.0005
# Epoch [697/1000], Step [1], Loss: 0.0005
# Epoch [698/1000], Step [1], Loss: 0.0004
# Epoch [699/1000], Step [1], Loss: 0.0004
# Epoch [700/1000], Step [1], Loss: 0.0004
# Epoch [701/1000], Step [1], Loss: 0.0004
# Epoch [702/1000], Step [1], Loss: 0.0003
# Epoch [703/1000], Step [1], Loss: 0.0003
# Epoch [704/1000], Step [1], Loss: 0.0004
# Epoch [705/1000], Step [1], Loss: 0.0003
# Epoch [706/1000], Step [1], Loss: 0.0003
# Epoch [707/1000], Step [1], Loss: 0.0003
# Epoch [708/1000], Step [1], Loss: 0.0003
# Epoch [709/1000], Step [1], Loss: 0.0003
# Epoch [710/1000], Step [1], Loss: 0.0003
# Epoch [711/1000], Step [1], Loss: 0.0003
# Epoch [712/1000], Step [1], Loss: 0.0003
# Epoch [713/1000], Step [1], Loss: 0.0003
# Epoch [714/1000], Step [1], Loss: 0.0003
# Epoch [715/1000], Step [1], Loss: 0.0003
# Epoch [716/1000], Step [1], Loss: 0.0004
# Epoch [717/1000], Step [1], Loss: 0.0004
# Epoch [718/1000], Step [1], Loss: 0.0005
# Epoch [719/1000], Step [1], Loss: 0.0006
# Epoch [720/1000], Step [1], Loss: 0.0007
# Epoch [721/1000], Step [1], Loss: 0.0008
# Epoch [722/1000], Step [1], Loss: 0.0009
# Epoch [723/1000], Step [1], Loss: 0.0006
# Epoch [724/1000], Step [1], Loss: 0.0004
# Epoch [725/1000], Step [1], Loss: 0.0004
# Epoch [726/1000], Step [1], Loss: 0.0005
# Epoch [727/1000], Step [1], Loss: 0.0004
# Epoch [728/1000], Step [1], Loss: 0.0003
# Epoch [729/1000], Step [1], Loss: 0.0004
# Epoch [730/1000], Step [1], Loss: 0.0004
# Epoch [731/1000], Step [1], Loss: 0.0004
# Epoch [732/1000], Step [1], Loss: 0.0004
# Epoch [733/1000], Step [1], Loss: 0.0005
# Epoch [734/1000], Step [1], Loss: 0.0004
# Epoch [735/1000], Step [1], Loss: 0.0004
# Epoch [736/1000], Step [1], Loss: 0.0004
# Epoch [737/1000], Step [1], Loss: 0.0004
# Epoch [738/1000], Step [1], Loss: 0.0003
# Epoch [739/1000], Step [1], Loss: 0.0003
# Epoch [740/1000], Step [1], Loss: 0.0003
# Epoch [741/1000], Step [1], Loss: 0.0003
# Epoch [742/1000], Step [1], Loss: 0.0003
# Epoch [743/1000], Step [1], Loss: 0.0003
# Epoch [744/1000], Step [1], Loss: 0.0003
# Epoch [745/1000], Step [1], Loss: 0.0003
# Epoch [746/1000], Step [1], Loss: 0.0003
# Epoch [747/1000], Step [1], Loss: 0.0003
# Epoch [748/1000], Step [1], Loss: 0.0003
# Epoch [749/1000], Step [1], Loss: 0.0003
# Epoch [750/1000], Step [1], Loss: 0.0002
# Epoch [751/1000], Step [1], Loss: 0.0003
# Epoch [752/1000], Step [1], Loss: 0.0003
# Epoch [753/1000], Step [1], Loss: 0.0002
# Epoch [754/1000], Step [1], Loss: 0.0003
# Epoch [755/1000], Step [1], Loss: 0.0003
# Epoch [756/1000], Step [1], Loss: 0.0003
# Epoch [757/1000], Step [1], Loss: 0.0003
# Epoch [758/1000], Step [1], Loss: 0.0003
# Epoch [759/1000], Step [1], Loss: 0.0003
# Epoch [760/1000], Step [1], Loss: 0.0004
# Epoch [761/1000], Step [1], Loss: 0.0005
# Epoch [762/1000], Step [1], Loss: 0.0008
# Epoch [763/1000], Step [1], Loss: 0.0016
# Epoch [764/1000], Step [1], Loss: 0.0025
# Epoch [765/1000], Step [1], Loss: 0.0047
# Epoch [766/1000], Step [1], Loss: 0.0023
# Epoch [767/1000], Step [1], Loss: 0.0017
# Epoch [768/1000], Step [1], Loss: 0.0027
# Epoch [769/1000], Step [1], Loss: 0.0015
# Epoch [770/1000], Step [1], Loss: 0.0021
# Epoch [771/1000], Step [1], Loss: 0.0011
# Epoch [772/1000], Step [1], Loss: 0.0016
# Epoch [773/1000], Step [1], Loss: 0.0013
# Epoch [774/1000], Step [1], Loss: 0.0011
# Epoch [775/1000], Step [1], Loss: 0.0013
# Epoch [776/1000], Step [1], Loss: 0.0009
# Epoch [777/1000], Step [1], Loss: 0.0012
# Epoch [778/1000], Step [1], Loss: 0.0008
# Epoch [779/1000], Step [1], Loss: 0.0010
# Epoch [780/1000], Step [1], Loss: 0.0007
# Epoch [781/1000], Step [1], Loss: 0.0009
# Epoch [782/1000], Step [1], Loss: 0.0007
# Epoch [783/1000], Step [1], Loss: 0.0007
# Epoch [784/1000], Step [1], Loss: 0.0008
# Epoch [785/1000], Step [1], Loss: 0.0006
# Epoch [786/1000], Step [1], Loss: 0.0007
# Epoch [787/1000], Step [1], Loss: 0.0005
# Epoch [788/1000], Step [1], Loss: 0.0007
# Epoch [789/1000], Step [1], Loss: 0.0007
# Epoch [790/1000], Step [1], Loss: 0.0007
# Epoch [791/1000], Step [1], Loss: 0.0006
# Epoch [792/1000], Step [1], Loss: 0.0005
# Epoch [793/1000], Step [1], Loss: 0.0004
# Epoch [794/1000], Step [1], Loss: 0.0005
# Epoch [795/1000], Step [1], Loss: 0.0005
# Epoch [796/1000], Step [1], Loss: 0.0005
# Epoch [797/1000], Step [1], Loss: 0.0004
# Epoch [798/1000], Step [1], Loss: 0.0004
# Epoch [799/1000], Step [1], Loss: 0.0005
# Epoch [800/1000], Step [1], Loss: 0.0004
# Epoch [801/1000], Step [1], Loss: 0.0005
# Epoch [802/1000], Step [1], Loss: 0.0004
# Epoch [803/1000], Step [1], Loss: 0.0004
# Epoch [804/1000], Step [1], Loss: 0.0004
# Epoch [805/1000], Step [1], Loss: 0.0004
# Epoch [806/1000], Step [1], Loss: 0.0004
# Epoch [807/1000], Step [1], Loss: 0.0004
# Epoch [808/1000], Step [1], Loss: 0.0004
# Epoch [809/1000], Step [1], Loss: 0.0003
# Epoch [810/1000], Step [1], Loss: 0.0003
# Epoch [811/1000], Step [1], Loss: 0.0003
# Epoch [812/1000], Step [1], Loss: 0.0003
# Epoch [813/1000], Step [1], Loss: 0.0004
# Epoch [814/1000], Step [1], Loss: 0.0004
# Epoch [815/1000], Step [1], Loss: 0.0004
# Epoch [816/1000], Step [1], Loss: 0.0005
# Epoch [817/1000], Step [1], Loss: 0.0006
# Epoch [818/1000], Step [1], Loss: 0.0009
# Epoch [819/1000], Step [1], Loss: 0.0009
# Epoch [820/1000], Step [1], Loss: 0.0008
# Epoch [821/1000], Step [1], Loss: 0.0004
# Epoch [822/1000], Step [1], Loss: 0.0005
# Epoch [823/1000], Step [1], Loss: 0.0006
# Epoch [824/1000], Step [1], Loss: 0.0003
# Epoch [825/1000], Step [1], Loss: 0.0005
# Epoch [826/1000], Step [1], Loss: 0.0005
# Epoch [827/1000], Step [1], Loss: 0.0003
# Epoch [828/1000], Step [1], Loss: 0.0005
# Epoch [829/1000], Step [1], Loss: 0.0005
# Epoch [830/1000], Step [1], Loss: 0.0003
# Epoch [831/1000], Step [1], Loss: 0.0005
# Epoch [832/1000], Step [1], Loss: 0.0005
# Epoch [833/1000], Step [1], Loss: 0.0003
# Epoch [834/1000], Step [1], Loss: 0.0004
# Epoch [835/1000], Step [1], Loss: 0.0004
# Epoch [836/1000], Step [1], Loss: 0.0003
# Epoch [837/1000], Step [1], Loss: 0.0004
# Epoch [838/1000], Step [1], Loss: 0.0004
# Epoch [839/1000], Step [1], Loss: 0.0003
# Epoch [840/1000], Step [1], Loss: 0.0005
# Epoch [841/1000], Step [1], Loss: 0.0005
# Epoch [842/1000], Step [1], Loss: 0.0005
# Epoch [843/1000], Step [1], Loss: 0.0005
# Epoch [844/1000], Step [1], Loss: 0.0005
# Epoch [845/1000], Step [1], Loss: 0.0003
# Epoch [846/1000], Step [1], Loss: 0.0004
# Epoch [847/1000], Step [1], Loss: 0.0004
# Epoch [848/1000], Step [1], Loss: 0.0003
# Epoch [849/1000], Step [1], Loss: 0.0004
# Epoch [850/1000], Step [1], Loss: 0.0004
# Epoch [851/1000], Step [1], Loss: 0.0003
# Epoch [852/1000], Step [1], Loss: 0.0004
# Epoch [853/1000], Step [1], Loss: 0.0004
# Epoch [854/1000], Step [1], Loss: 0.0003
# Epoch [855/1000], Step [1], Loss: 0.0003
# Epoch [856/1000], Step [1], Loss: 0.0003
# Epoch [857/1000], Step [1], Loss: 0.0002
# Epoch [858/1000], Step [1], Loss: 0.0003
# Epoch [859/1000], Step [1], Loss: 0.0003
# Epoch [860/1000], Step [1], Loss: 0.0002
# Epoch [861/1000], Step [1], Loss: 0.0003
# Epoch [862/1000], Step [1], Loss: 0.0003
# Epoch [863/1000], Step [1], Loss: 0.0002
# Epoch [864/1000], Step [1], Loss: 0.0003
# Epoch [865/1000], Step [1], Loss: 0.0002
# Epoch [866/1000], Step [1], Loss: 0.0002
# Epoch [867/1000], Step [1], Loss: 0.0003
# Epoch [868/1000], Step [1], Loss: 0.0002
# Epoch [869/1000], Step [1], Loss: 0.0002
# Epoch [870/1000], Step [1], Loss: 0.0002
# Epoch [871/1000], Step [1], Loss: 0.0002
# Epoch [872/1000], Step [1], Loss: 0.0002
# Epoch [873/1000], Step [1], Loss: 0.0002
# Epoch [874/1000], Step [1], Loss: 0.0002
# Epoch [875/1000], Step [1], Loss: 0.0002
# Epoch [876/1000], Step [1], Loss: 0.0002
# Epoch [877/1000], Step [1], Loss: 0.0002
# Epoch [878/1000], Step [1], Loss: 0.0002
# Epoch [879/1000], Step [1], Loss: 0.0002
# Epoch [880/1000], Step [1], Loss: 0.0002
# Epoch [881/1000], Step [1], Loss: 0.0002
# Epoch [882/1000], Step [1], Loss: 0.0002
# Epoch [883/1000], Step [1], Loss: 0.0002
# Epoch [884/1000], Step [1], Loss: 0.0002
# Epoch [885/1000], Step [1], Loss: 0.0002
# Epoch [886/1000], Step [1], Loss: 0.0002
# Epoch [887/1000], Step [1], Loss: 0.0002
# Epoch [888/1000], Step [1], Loss: 0.0002
# Epoch [889/1000], Step [1], Loss: 0.0002
# Epoch [890/1000], Step [1], Loss: 0.0003
# Epoch [891/1000], Step [1], Loss: 0.0003
# Epoch [892/1000], Step [1], Loss: 0.0004
# Epoch [893/1000], Step [1], Loss: 0.0007
# Epoch [894/1000], Step [1], Loss: 0.0010
# Epoch [895/1000], Step [1], Loss: 0.0014
# Epoch [896/1000], Step [1], Loss: 0.0010
# Epoch [897/1000], Step [1], Loss: 0.0005
# Epoch [898/1000], Step [1], Loss: 0.0005
# Epoch [899/1000], Step [1], Loss: 0.0007
# Epoch [900/1000], Step [1], Loss: 0.0004
# Epoch [901/1000], Step [1], Loss: 0.0004
# Epoch [902/1000], Step [1], Loss: 0.0006
# Epoch [903/1000], Step [1], Loss: 0.0003
# Epoch [904/1000], Step [1], Loss: 0.0004
# Epoch [905/1000], Step [1], Loss: 0.0005
# Epoch [906/1000], Step [1], Loss: 0.0003
# Epoch [907/1000], Step [1], Loss: 0.0003
# Epoch [908/1000], Step [1], Loss: 0.0004
# Epoch [909/1000], Step [1], Loss: 0.0003
# Epoch [910/1000], Step [1], Loss: 0.0003
# Epoch [911/1000], Step [1], Loss: 0.0004
# Epoch [912/1000], Step [1], Loss: 0.0003
# Epoch [913/1000], Step [1], Loss: 0.0003
# Epoch [914/1000], Step [1], Loss: 0.0003
# Epoch [915/1000], Step [1], Loss: 0.0003
# Epoch [916/1000], Step [1], Loss: 0.0003
# Epoch [917/1000], Step [1], Loss: 0.0003
# Epoch [918/1000], Step [1], Loss: 0.0002
# Epoch [919/1000], Step [1], Loss: 0.0003
# Epoch [920/1000], Step [1], Loss: 0.0003
# Epoch [921/1000], Step [1], Loss: 0.0003
# Epoch [922/1000], Step [1], Loss: 0.0005
# Epoch [923/1000], Step [1], Loss: 0.0008
# Epoch [924/1000], Step [1], Loss: 0.0009
# Epoch [925/1000], Step [1], Loss: 0.0010
# Epoch [926/1000], Step [1], Loss: 0.0005
# Epoch [927/1000], Step [1], Loss: 0.0005
# Epoch [928/1000], Step [1], Loss: 0.0006
# Epoch [929/1000], Step [1], Loss: 0.0005
# Epoch [930/1000], Step [1], Loss: 0.0005
# Epoch [931/1000], Step [1], Loss: 0.0004
# Epoch [932/1000], Step [1], Loss: 0.0005
# Epoch [933/1000], Step [1], Loss: 0.0003
# Epoch [934/1000], Step [1], Loss: 0.0004
# Epoch [935/1000], Step [1], Loss: 0.0004
# Epoch [936/1000], Step [1], Loss: 0.0003
# Epoch [937/1000], Step [1], Loss: 0.0004
# Epoch [938/1000], Step [1], Loss: 0.0003
# Epoch [939/1000], Step [1], Loss: 0.0004
# Epoch [940/1000], Step [1], Loss: 0.0002
# Epoch [941/1000], Step [1], Loss: 0.0003
# Epoch [942/1000], Step [1], Loss: 0.0003
# Epoch [943/1000], Step [1], Loss: 0.0003
# Epoch [944/1000], Step [1], Loss: 0.0003
# Epoch [945/1000], Step [1], Loss: 0.0002
# Epoch [946/1000], Step [1], Loss: 0.0003
# Epoch [947/1000], Step [1], Loss: 0.0002
# Epoch [948/1000], Step [1], Loss: 0.0003
# Epoch [949/1000], Step [1], Loss: 0.0002
# Epoch [950/1000], Step [1], Loss: 0.0002
# Epoch [951/1000], Step [1], Loss: 0.0002
# Epoch [952/1000], Step [1], Loss: 0.0002
# Epoch [953/1000], Step [1], Loss: 0.0002
# Epoch [954/1000], Step [1], Loss: 0.0002
# Epoch [955/1000], Step [1], Loss: 0.0002
# Epoch [956/1000], Step [1], Loss: 0.0002
# Epoch [957/1000], Step [1], Loss: 0.0002
# Epoch [958/1000], Step [1], Loss: 0.0002
# Epoch [959/1000], Step [1], Loss: 0.0002
# Epoch [960/1000], Step [1], Loss: 0.0002
# Epoch [961/1000], Step [1], Loss: 0.0002
# Epoch [962/1000], Step [1], Loss: 0.0002
# Epoch [963/1000], Step [1], Loss: 0.0002
# Epoch [964/1000], Step [1], Loss: 0.0002
# Epoch [965/1000], Step [1], Loss: 0.0002
# Epoch [966/1000], Step [1], Loss: 0.0002
# Epoch [967/1000], Step [1], Loss: 0.0002
# Epoch [968/1000], Step [1], Loss: 0.0002
# Epoch [969/1000], Step [1], Loss: 0.0003
# Epoch [970/1000], Step [1], Loss: 0.0003
# Epoch [971/1000], Step [1], Loss: 0.0003
# Epoch [972/1000], Step [1], Loss: 0.0003
# Epoch [973/1000], Step [1], Loss: 0.0002
# Epoch [974/1000], Step [1], Loss: 0.0002
# Epoch [975/1000], Step [1], Loss: 0.0002
# Epoch [976/1000], Step [1], Loss: 0.0002
# Epoch [977/1000], Step [1], Loss: 0.0002
# Epoch [978/1000], Step [1], Loss: 0.0002
# Epoch [979/1000], Step [1], Loss: 0.0002
# Epoch [980/1000], Step [1], Loss: 0.0002
# Epoch [981/1000], Step [1], Loss: 0.0002
# Epoch [982/1000], Step [1], Loss: 0.0002
# Epoch [983/1000], Step [1], Loss: 0.0002
# Epoch [984/1000], Step [1], Loss: 0.0002
# Epoch [985/1000], Step [1], Loss: 0.0002
# Epoch [986/1000], Step [1], Loss: 0.0002
# Epoch [987/1000], Step [1], Loss: 0.0002
# Epoch [988/1000], Step [1], Loss: 0.0002
# Epoch [989/1000], Step [1], Loss: 0.0002
# Epoch [990/1000], Step [1], Loss: 0.0002
# Epoch [991/1000], Step [1], Loss: 0.0002
# Epoch [992/1000], Step [1], Loss: 0.0002
# Epoch [993/1000], Step [1], Loss: 0.0002
# Epoch [994/1000], Step [1], Loss: 0.0002
# Epoch [995/1000], Step [1], Loss: 0.0002
# Epoch [996/1000], Step [1], Loss: 0.0002
# Epoch [997/1000], Step [1], Loss: 0.0002
# Epoch [998/1000], Step [1], Loss: 0.0002
# Epoch [999/1000], Step [1], Loss: 0.0002
# Epoch [1000/1000], Step [1], Loss: 0.0002

# %%
# 测试数据生成
U_x_test, U_y_test = compute_velocity_field_np(X, Y, dx, dy)
U_magnitude_test = np.sqrt(U_x_test**2 + U_y_test**2)

# 将测试数据转换为PyTorch张量
U_x_test = torch.tensor(U_x_test, dtype=torch.float32).unsqueeze(0).unsqueeze(0)
U_y_test = torch.tensor(U_y_test, dtype=torch.float32).unsqueeze(0).unsqueeze(0)
U_magnitude_test = torch.tensor(U_magnitude_test, dtype=torch.float32).unsqueeze(0).unsqueeze(0)

# 合并测试速度场作为输入
velocity_field_test = torch.cat((U_x_test, U_y_test, U_magnitude_test), dim=1)

# 将模型设置为评估模式
model.eval()

# 使用测试数据进行预测
with torch.no_grad():
    predicted_abcd_test = model(velocity_field_test)

# 打印预测结果
print("Predicted a, b, c, d:")
print(predicted_abcd_test)

# 计算预测的速度场
a_test = predicted_abcd_test[:, 0, :, :].squeeze().numpy()
b_test = predicted_abcd_test[:, 1, :, :].squeeze().numpy()
c_test = predicted_abcd_test[:, 2, :, :].squeeze().numpy()
d_test = predicted_abcd_test[:, 3, :, :].squeeze().numpy()

U_x_pred_test = a_test + b_test
U_y_pred_test = c_test + d_test
U_magnitude_pred_test = np.sqrt(U_x_pred_test**2 + U_y_pred_test**2)
# Out:
# Predicted a, b, c, d:
# tensor([[[[-0.7081, -0.6835, -0.6778,  ..., -0.6853, -0.6831, -0.6730],
#           [-0.7176, -0.7014, -0.6958,  ..., -0.7052, -0.7035, -0.6934],
#           [-0.7408, -0.7243, -0.7186,  ..., -0.7265, -0.7249, -0.7157],
#           ...,
#           [-0.6552, -0.6412, -0.6373,  ..., -0.6349, -0.6330, -0.6250],
#           [-0.6819, -0.6677, -0.6636,  ..., -0.6605, -0.6588, -0.6506],
#           [-0.6888, -0.6789, -0.6759,  ..., -0.6737, -0.6724, -0.6634]],
#
#          [[ 0.6700,  0.6618,  0.6562,  ...,  0.6621,  0.6584,  0.6506],
#           [ 0.6656,  0.6482,  0.6429,  ...,  0.6489,  0.6461,  0.6417],
#           [ 0.6424,  0.6248,  0.6198,  ...,  0.6269,  0.6241,  0.6192],
#           ...,
#           [ 0.7472,  0.7346,  0.7307,  ...,  0.7288,  0.7272,  0.7212],
#           [ 0.7236,  0.7123,  0.7086,  ...,  0.7065,  0.7049,  0.6998],
#           [ 0.7211,  0.7065,  0.7025,  ...,  0.7006,  0.6986,  0.6975]],
#
#          [[-0.1497, -0.1831, -0.1764,  ..., -0.2577, -0.2424, -0.2554],
#           [-0.1294, -0.1768, -0.1695,  ..., -0.2464, -0.2297, -0.2396],
#           [-0.1232, -0.1732, -0.1661,  ..., -0.2428, -0.2258, -0.2360],
#           ...,
#           [-0.0608, -0.1199, -0.1121,  ..., -0.2244, -0.2062, -0.2187],
#           [-0.0570, -0.1160, -0.1079,  ..., -0.2233, -0.2048, -0.2169],
#           [-0.0403, -0.1065, -0.0978,  ..., -0.2049, -0.1855, -0.1915]],
#
#          [[ 0.1653,  0.2476,  0.2806,  ...,  0.1601,  0.2028,  0.2422],
#           [ 0.1590,  0.2381,  0.2716,  ...,  0.1447,  0.1870,  0.2237],
#           [ 0.1527,  0.2347,  0.2680,  ...,  0.1426,  0.1843,  0.2206],
#           ...,
#           [ 0.0933,  0.1866,  0.2176,  ...,  0.1241,  0.1672,  0.2033],
#           [ 0.0906,  0.1830,  0.2140,  ...,  0.1215,  0.1647,  0.1999],
#           [ 0.0623,  0.1692,  0.2003,  ...,  0.1151,  0.1593,  0.1916]]]])

# %%
# 绘图
fig, axes = plt.subplots(3, 2, figsize=(12, 12))

# U_x
axes[0, 0].imshow(U_x_test.squeeze().numpy(), cmap='jet')
axes[0, 0].set_title('True U_x')
axes[0, 1].imshow(U_x_pred_test, cmap='jet')
axes[0, 1].set_title('Predicted U_x')

# U_y
axes[1, 0].imshow(U_y_test.squeeze().numpy(), cmap='jet')
axes[1, 0].set_title('True U_y')
axes[1, 1].imshow(U_y_pred_test, cmap='jet')
axes[1, 1].set_title('Predicted U_y')

# U_magnitude
axes[2, 0].imshow(U_magnitude_test.squeeze().numpy(), cmap='jet')
axes[2, 0].set_title('True U_magnitude')
axes[2, 1].imshow(U_magnitude_pred_test, cmap='jet')
axes[2, 1].set_title('Predicted U_magnitude')

plt.tight_layout()
plt.show()

# %%
# 计算真实的a, b, c, d值
a_real = a(X, Y)
b_real = b(X, Y)
c_real = c(X, Y)
d_real = d(X, Y)

# %%
import matplotlib.pyplot as plt

# 创建图形窗口
fig, axs = plt.subplots(4, 2, figsize=(12, 24))

# 可视化真实和预测的a参数
axs[0, 0].imshow(a_real, cmap='viridis')
axs[0, 0].set_title('Real a parameter')
axs[0, 0].axis('off')

axs[0, 1].imshow(a_test, cmap='viridis')
axs[0, 1].set_title('Predicted a parameter')
axs[0, 1].axis('off')

# 可视化真实和预测的b参数
axs[1, 0].imshow(b_real, cmap='viridis')
axs[1, 0].set_title('Real b parameter')
axs[1, 0].axis('off')

axs[1, 1].imshow(b_test, cmap='viridis')
axs[1, 1].set_title('Predicted b parameter')
axs[1, 1].axis('off')

# 可视化真实和预测的c参数
axs[2, 0].imshow(c_real, cmap='viridis')
axs[2, 0].set_title('Real c parameter')
axs[2, 0].axis('off')

axs[2, 1].imshow(c_test, cmap='viridis')
axs[2, 1].set_title('Predicted c parameter')
axs[2, 1].axis('off')

# 可视化真实和预测的d参数
axs[3, 0].imshow(d_real, cmap='viridis')
axs[3, 0].set_title('Real d parameter')
axs[3, 0].axis('off')

axs[3, 1].imshow(d_test, cmap='viridis')
axs[3, 1].set_title('Predicted d parameter')
axs[3, 1].axis('off')

# 显示图形
plt.show()

# %%
q=a_test**2 + b_test**2 + c_test**2 + d_test**2

# %%
plt.imshow(q,vmin=0,vmax=2)

plt.colorbar()
